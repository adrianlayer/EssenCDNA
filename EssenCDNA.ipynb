# %% [markdown]
# # EssenCDNA Analysis Notebook (DepMap 24Q2)

# %% [markdown]
# Adrian Layer (alayer@ucsd.edu); Anthony Vasquez (pavasquez@ucsd.edu); Yasmin A. Jaber (yjaber@ucsd.edu); Omar Halawa (ohalawa@ucsd.edu)

# %% [markdown]
# ##### The following is an analysis notebook that utilizes the repository code to <u>analyze the correlation between CRISPR gene essentiality (dependency) and the presence (or absence) of ecDNA</u> for DepMap 24Q2.

# %% [markdown]
# ##### By changing "Input Data" filepaths below, you may carry out the same analysis on your data of interest.

# %% [markdown]
# # Imports:

# %%
# Importing functions from utils.py supporting file
import sys
sys.path.append('src/')
from utils import *

import matplotlib
import matplotlib.pyplot as plt
print(f"matplotlib: {matplotlib.__version__}")

import pandas as pd
print(f"pandas: {pd.__version__}")

import seaborn as sns
print(f"seaborn: {sns.__version__}")

import numpy as np
print(f"numpy: {np.__version__}")

import scipy
from scipy import stats
print(f"scipy: {scipy.__version__}")
# Out:
# matplotlib: 3.8.4
# pandas: 2.2.2
# seaborn: 0.13.2
# numpy: 1.26.4
# scipy: 1.13.1

# %% [markdown]
# # Input Data:

# %% [markdown]
# ### Change the following to match your respective data inputs:

# %%
# DepMap standard-format CRISPR essentiality data file
DEPMAP_CRISPR_ESEN = "data/DepMap 24Q2/CRISPRGeneEffect.csv"

# DepMap metadata file
DEPMAP_METDATA = "data/DepMap 24Q2/Model.csv"

# Amplicon Architect standard-format aggregated results file
AA_RESULTS = "data/AA/aggregated_results.csv"

# Dataset obtained from literature corresponding to most differentially-expressed genes for ecDNA up/downregulation
# See cell below for source
LITERATURE_ECDNA_TARGET_GENES = "data/Literature/ecDNA Target genes.csv"

# %% [markdown]
# Lin Miin S., Jo Se-Young, Luebeck Jens, Chang Howard Y., Wu Sihan, Mischel Paul S., Bafna Vineet (2023) <b>Transcriptional immune suppression and upregulation of double stranded DNA damage and repair repertoires in ecDNA-containing tumors</b> <i>eLife</i> 12:RP88895
#
# https://doi.org/10.7554/eLife.88895.2

# %% [markdown]
# # Processing Data:

# %% [markdown]
# ### DepMap CRISPR essentiality data (cell-lines along rows, genes along columns):

# %% [markdown]
# ##### For the reason behind using the CRISPRGeneEffect.csv file as opposed to CRISPRGeneDependency, see [here.](https://forum.depmap.org/t/crisprgeneeffect-vs-crisprgenedependency/2333)

# %%
esen_df = read_esen(DEPMAP_CRISPR_ESEN)
esen_df.head()
# Out:
#                 A1BG      A1CF       A2M     A2ML1   A3GALT2    A4GALT  \
# ACH-000001 -0.134132  0.029103  0.016454 -0.137540 -0.047273  0.181367
# ACH-000004 -0.001436 -0.080068 -0.125263 -0.027607 -0.053838 -0.151272
# ACH-000005 -0.144940  0.026541  0.160605  0.088015 -0.202605 -0.243420
# ACH-000007 -0.053334 -0.120420  0.047978  0.086984 -0.018987 -0.017309
# ACH-000009 -0.027684 -0.144202  0.052846  0.073833  0.038823 -0.108149
#
#                A4GNT      AAAS      AACS     AADAC  ...    ZWILCH     ZWINT  \
# ACH-000001 -0.082437 -0.059023  0.194592  0.035473  ... -0.123528  0.085140
# ACH-000004  0.240094 -0.038922  0.186438  0.160221  ... -0.186899 -0.359257
# ACH-000005  0.133726 -0.034895 -0.126105  0.036030  ... -0.309668 -0.344502
# ACH-000007 -0.000041 -0.158419 -0.169559  0.201305  ... -0.323038 -0.387265
# ACH-000009  0.010811 -0.088600  0.032194  0.114270  ... -0.253057 -0.159965
#
#                 ZXDA      ZXDB      ZXDC    ZYG11A    ZYG11B       ZYX  \
# ACH-000001  0.181954  0.239474  0.172965 -0.230327  0.055657  0.044296
# ACH-000004  0.202271  0.057740  0.089295  0.086703 -0.304930  0.086858
# ACH-000005 -0.056160 -0.092447 -0.015550 -0.170380 -0.080934 -0.059685
# ACH-000007 -0.013816  0.183228  0.038424 -0.051728 -0.383499 -0.012801
# ACH-000009 -0.025342  0.191500 -0.071632 -0.077843 -0.525599  0.093219
#
#                ZZEF1      ZZZ3
# ACH-000001  0.107361 -0.410449
# ACH-000004  0.254538 -0.087671
# ACH-000005  0.030254 -0.145055
# ACH-000007 -0.294771 -0.431575
# ACH-000009 -0.029515 -0.255204
#
# [5 rows x 18443 columns]

# %% [markdown]
# ### DepMap Metadata:

# %%
meta_df = read_metadata(DEPMAP_METDATA)
meta_df.head()
# Out:
#             PatientID CellLineName StrippedCellLineName DepmapModelType  \
# ModelID
# ACH-000001  PT-gj46wT  NIH:OVCAR-3            NIHOVCAR3           HGSOC
# ACH-000002  PT-5qa3uk        HL-60                 HL60             AML
# ACH-000003  PT-puKIyc        CACO2                CACO2            COAD
# ACH-000004  PT-q4K2cp          HEL                  HEL             AML
# ACH-000005  PT-q4K2cp   HEL 92.1.7              HEL9217             AML
#
#                  OncotreeLineage     OncotreePrimaryDisease  \
# ModelID
# ACH-000001  Ovary/Fallopian Tube   Ovarian Epithelial Tumor
# ACH-000002               Myeloid     Acute Myeloid Leukemia
# ACH-000003                 Bowel  Colorectal Adenocarcinoma
# ACH-000004               Myeloid     Acute Myeloid Leukemia
# ACH-000005               Myeloid     Acute Myeloid Leukemia
#
#                              OncotreeSubtype OncotreeCode  \
# ModelID
# ACH-000001  High-Grade Serous Ovarian Cancer        HGSOC
# ACH-000002            Acute Myeloid Leukemia          AML
# ACH-000003              Colon Adenocarcinoma         COAD
# ACH-000004            Acute Myeloid Leukemia          AML
# ACH-000005            Acute Myeloid Leukemia          AML
#
#            LegacyMolecularSubtype   LegacySubSubtype  ... EngineeredModel  \
# ModelID                                               ...
# ACH-000001                    NaN  high_grade_serous  ...             NaN
# ACH-000002                    NaN                 M3  ...             NaN
# ACH-000003                    NaN                NaN  ...             NaN
# ACH-000004                    NaN                 M6  ...             NaN
# ACH-000005                    NaN                 M6  ...             NaN
#
#            TissueOrigin  ModelDerivationMaterial PublicComments  \
# ModelID
# ACH-000001          NaN                      NaN            NaN
# ACH-000002          NaN                      NaN            NaN
# ACH-000003          NaN                      NaN            NaN
# ACH-000004          NaN                      NaN            NaN
# ACH-000005          NaN                      NaN            NaN
#
#                                               CCLEName HCMIID  \
# ModelID
# ACH-000001                             NIHOVCAR3_OVARY    NaN
# ACH-000002     HL60_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE    NaN
# ACH-000003                       CACO2_LARGE_INTESTINE    NaN
# ACH-000004      HEL_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE    NaN
# ACH-000005  HEL9217_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE    NaN
#
#            WTSIMasterCellID SangerModelID  COSMICID DateSharedIndbGaP
# ModelID
# ACH-000001           2201.0     SIDM00105  905933.0               NaN
# ACH-000002             55.0     SIDM00829  905938.0               NaN
# ACH-000003              NaN     SIDM00891       NaN               NaN
# ACH-000004            783.0     SIDM00594  907053.0               NaN
# ACH-000005              NaN     SIDM00593       NaN               NaN
#
# [5 rows x 42 columns]

# %% [markdown]
# ### Amplicon Architect Results:

# %%
aa_df = read_aa(AA_RESULTS, "Classification")
aa_df.head()
# Out:
#                     Unnamed: 0         Sample name  AA amplicon number  \
# Classification
# ecDNA                        0  5637_URINARY_TRACT                 1.0
# ecDNA                        1  5637_URINARY_TRACT                 1.0
# Complex non-cyclic           2           59M_OVARY                 1.0
# ecDNA                        3           59M_OVARY                 2.0
# ecDNA                        4           59M_OVARY                 2.0
#
#                                                   Feature ID  \
# Classification
# ecDNA                   5637_URINARY_TRACT_amplicon1_ecDNA_1
# ecDNA                   5637_URINARY_TRACT_amplicon1_ecDNA_2
# Complex non-cyclic  59M_OVARY_amplicon1_Complex non-cyclic_1
# ecDNA                            59M_OVARY_amplicon2_ecDNA_2
# ecDNA                            59M_OVARY_amplicon2_ecDNA_1
#
#                                                              Location  \
# Classification
# ecDNA                                      ['chr6:20350615-22839372']
# ecDNA               ['chr3:9099507-9519221', 'chr3:9521655-1018449...
# Complex non-cyclic  ['chr5:51400000-52863895', 'chr9:104220123-104...
# ecDNA               ['chr8:124484622-125582885', 'chr8:125588889-1...
# ecDNA               ['chr8:52712046-56014576', 'chr8:65533018-6557...
#
#                                                        Oncogenes  \
# Classification
# ecDNA                                           ['E2F3', 'SOX4']
# ecDNA               ['FANCD2', 'PPARG', 'RAF1', 'SRGAP3', 'VHL']
# Complex non-cyclic                                            []
# ecDNA                                                  ['TRIB1']
# ecDNA                                                  ['TCEA1']
#
#                     Complexity score  Captured interval length  \
# Classification
# ecDNA                       1.223167                 2488757.0
# ecDNA                       0.709581                 4901014.0
# Complex non-cyclic          0.935892                 3998398.0
# ecDNA                       0.366705                 1463324.0
# ecDNA                       1.074874                 3343884.0
#
#                     Feature median copy number  Feature maximum copy number  \
# Classification
# ecDNA                                29.757287                    67.419329
# ecDNA                                13.175019                    17.283490
# Complex non-cyclic                    5.026093                     5.787943
# ecDNA                                10.047201                    10.047201
# ecDNA                                15.129375                    24.854069
#
#                     ... Tissue of origin Sample type  \
# Classification      ...
# ecDNA               ...    urinary tract   cell line
# ecDNA               ...    urinary tract   cell line
# Complex non-cyclic  ...            ovary   cell line
# ecDNA               ...            ovary   cell line
# ecDNA               ...            ovary   cell line
#
#                                                      Feature BED file  \
# Classification
# ecDNA               /Users/jluebeck/Desktop/research/CCLE/hg38/ccl...
# ecDNA               /Users/jluebeck/Desktop/research/CCLE/hg38/ccl...
# Complex non-cyclic  /Users/jluebeck/Desktop/research/CCLE/hg38/ccl...
# ecDNA               /Users/jluebeck/Desktop/research/CCLE/hg38/ccl...
# ecDNA               /Users/jluebeck/Desktop/research/CCLE/hg38/ccl...
#
#                                                          CNV BED file  \
# Classification
# ecDNA               /Users/jluebeck/Desktop/research/CCLE/hg38/ccl...
# ecDNA               /Users/jluebeck/Desktop/research/CCLE/hg38/ccl...
# Complex non-cyclic  /Users/jluebeck/Desktop/research/CCLE/hg38/ccl...
# ecDNA               /Users/jluebeck/Desktop/research/CCLE/hg38/ccl...
# ecDNA               /Users/jluebeck/Desktop/research/CCLE/hg38/ccl...
#
#                                                           AA PNG file  \
# Classification
# ecDNA               /Users/jluebeck/Desktop/research/CCLE/hg38/CCL...
# ecDNA               /Users/jluebeck/Desktop/research/CCLE/hg38/CCL...
# Complex non-cyclic  /Users/jluebeck/Desktop/research/CCLE/hg38/CCL...
# ecDNA               /Users/jluebeck/Desktop/research/CCLE/hg38/CCL...
# ecDNA               /Users/jluebeck/Desktop/research/CCLE/hg38/CCL...
#
#                                                           AA PDF file  \
# Classification
# ecDNA               /Users/jluebeck/Desktop/research/CCLE/hg38/CCL...
# ecDNA               /Users/jluebeck/Desktop/research/CCLE/hg38/CCL...
# Complex non-cyclic  /Users/jluebeck/Desktop/research/CCLE/hg38/CCL...
# ecDNA               /Users/jluebeck/Desktop/research/CCLE/hg38/CCL...
# ecDNA               /Users/jluebeck/Desktop/research/CCLE/hg38/CCL...
#
#                                                       AA summary file  \
# Classification
# ecDNA               /Users/jluebeck/Desktop/research/CCLE/hg38/CCL...
# ecDNA               /Users/jluebeck/Desktop/research/CCLE/hg38/CCL...
# Complex non-cyclic  /Users/jluebeck/Desktop/research/CCLE/hg38/CCL...
# ecDNA               /Users/jluebeck/Desktop/research/CCLE/hg38/CCL...
# ecDNA               /Users/jluebeck/Desktop/research/CCLE/hg38/CCL...
#
#                                                     Run metadata JSON  \
# Classification
# ecDNA               /Users/jluebeck/Desktop/research/CCLE/hg38/ccl...
# ecDNA               /Users/jluebeck/Desktop/research/CCLE/hg38/ccl...
# Complex non-cyclic  /Users/jluebeck/Desktop/research/CCLE/hg38/ccl...
# ecDNA               /Users/jluebeck/Desktop/research/CCLE/hg38/ccl...
# ecDNA               /Users/jluebeck/Desktop/research/CCLE/hg38/ccl...
#
#                                                  Sample metadata JSON  \
# Classification
# ecDNA               /Users/jluebeck/Desktop/research/CCLE/hg38/ccl...
# ecDNA               /Users/jluebeck/Desktop/research/CCLE/hg38/ccl...
# Complex non-cyclic  /Users/jluebeck/Desktop/research/CCLE/hg38/ccl...
# ecDNA               /Users/jluebeck/Desktop/research/CCLE/hg38/ccl...
# ecDNA               /Users/jluebeck/Desktop/research/CCLE/hg38/ccl...
#
#                                                             All genes
# Classification
# ecDNA               ['CASC15', 'CDKAL1', 'E2F3', 'HDGFL1', 'NBAT1'...
# ecDNA               ['ARPC4', 'ARPC4-TTLL3', 'ATG7', 'ATP2B2', 'AT...
# Complex non-cyclic  ['ABCA1', 'DNAJC25', 'DNAJC25-GNG10', 'ECPAS',...
# ecDNA               ['MTSS1', 'NDUFB9', 'NSMCE2', 'SQLE', 'TATDN1'...
# ecDNA               ['ATP6V1H', 'LYN', 'LYPLA1', 'MRPL15', 'NPBWR1...
#
# [5 rows x 22 columns]

# %% [markdown]
# # Generating Gene Lists:

# %% [markdown]
# ##### Using our two datasets (<u>one from literature</u>, and the other being <u>from Amplicon Architect data</u>), we can generate two independent gene lists to utilize for our analyses.

# %% [markdown]
# ### Literature Gene List:

# %%
# The following function is niche and intended specifically for just this particular dataset, and as such, might not be very useful.
# Passing in the filename, column of gene names, and column of ecDNA regulation direction:
literature_gene_dict = read_literature_gene_list(LITERATURE_ECDNA_TARGET_GENES, "#Gene|GeneId", "direction(for_geneset_enrichment)")
literature_gene_list = list(literature_gene_dict.keys())
literature_gene_dict
# Out:
# {'RAE1': 'UP',
#  'FBXO17': 'UP',
#  'YTHDF1': 'UP',
#  'DDX27': 'UP',
#  'SEC61G': 'UP',
#  'CHMP7': 'DOWN',
#  'XPO7': 'DOWN',
#  'INTS9': 'DOWN',
#  'GJC1': 'UP',
#  'METTL1': 'UP',
#  'TACR1': 'DOWN',
#  'FAM72B': 'UP',
#  'NUP107': 'UP',
#  'KIAA1967': 'DOWN',
#  'C6orf145': 'UP',
#  'EGFR': 'UP',
#  'C20orf20': 'UP',
#  'TPX2': 'UP',
#  'KIF2C': 'UP',
#  'HOXA4': 'UP',
#  'CDK4': 'UP',
#  'PCM1': 'DOWN',
#  'AURKA': 'UP',
#  'HOXA2': 'UP',
#  'C8orf41': 'DOWN',
#  'TSFM': 'UP',
#  'FAM72D': 'UP',
#  'HOXA5': 'UP',
#  'PSMA7': 'UP',
#  'MCPH1': 'DOWN',
#  'CCDC25': 'DOWN',
#  'INTS10': 'DOWN',
#  'HOXA7': 'UP',
#  'SPAG5': 'UP',
#  'CNOT7': 'DOWN',
#  'BUB1': 'UP',
#  'HOXA3': 'UP',
#  'TRIM35': 'DOWN',
#  'PPP2R2A': 'DOWN',
#  'WRN': nan,
#  'HOXA6': 'UP',
#  'VPS37A': 'DOWN',
#  'TRIP13': 'UP',
#  'ZNF395': 'DOWN',
#  'FUT10': 'DOWN',
#  'KIF4A': 'UP',
#  'FDFT1': 'DOWN',
#  'NCAPH': 'UP',
#  'GSG2': 'UP',
#  'CDCA5': 'UP',
#  'MAK16': nan,
#  'ERI1': nan,
#  'RAD54L': 'UP',
#  'FBXO25': 'DOWN',
#  'PINX1': nan,
#  'RAD51': 'UP',
#  'MCM10': 'UP',
#  'PLK1': 'UP',
#  'CDCA8': 'UP',
#  'ORC1L': 'UP',
#  'CSTF1': 'UP',
#  'CDC20': 'UP',
#  'POLR3D': nan,
#  'FOXM1': 'UP',
#  'MRPS17': 'UP',
#  'UBXN8': nan,
#  'ERICH1': nan,
#  'KPNA2': 'UP',
#  'CHCHD2': 'UP',
#  'CDC6': 'UP',
#  'CCT6A': 'UP',
#  'CDC45': 'UP',
#  'PARP8': 'DOWN',
#  'FAM64A': 'UP',
#  'DOCK5': 'DOWN',
#  'ADAM28': 'DOWN',
#  'DTHD1': 'DOWN',
#  'NCAPG': 'UP',
#  'GPR18': 'DOWN',
#  'TTC9': 'DOWN',
#  'MDM2': 'UP',
#  'KCNRG': 'DOWN',
#  'TSPAN31': 'UP',
#  'KIF15': 'UP',
#  'HOXA11': 'UP',
#  'KIF13B': 'DOWN',
#  'UCKL1': 'UP',
#  'SYK': 'DOWN',
#  'CCT2': 'UP',
#  'CDC42SE2': 'DOWN',
#  'PFDN4': 'UP',
#  'HOXA1': 'UP',
#  'PCDH7': 'DOWN',
#  'ITGB7': 'DOWN',
#  'PSTPIP1': 'DOWN',
#  'AKNA': 'DOWN',
#  'OS9': 'UP',
#  'CYP27B1': 'UP',
#  'MLLT3': 'DOWN',
#  'ORAOV1': 'UP',
#  'TCF19': 'UP',
#  'STX19': 'DOWN',
#  'C10orf95': 'DOWN',
#  'CDCA2': nan,
#  'AVIL': 'UP',
#  'PDRG1': 'UP',
#  'TMEM194A': 'UP',
#  'PRC1': 'UP',
#  'SGOL2': 'UP',
#  'PPFIA1': 'UP',
#  'CCDC108': 'DOWN',
#  'ELP3': 'DOWN',
#  'NLRC3': 'DOWN',
#  'HOXC9': 'UP',
#  'TOP2A': 'UP',
#  'ESR1': 'DOWN',
#  'CXCR6': 'DOWN',
#  'GZMK': 'DOWN',
#  'CXCR3': 'DOWN',
#  'NUF2': 'UP',
#  'CENPL': 'UP',
#  'MARCH9': 'UP',
#  'SHOX2': 'UP',
#  'FAM179A': 'DOWN',
#  'RSPO1': 'DOWN',
#  'MAP6D1': 'UP',
#  'TAF4': 'UP',
#  'KCTD9': 'DOWN',
#  'CD5': 'DOWN',
#  'FASLG': 'DOWN',
#  'TBC1D10C': 'DOWN',
#  'CENPN': 'UP',
#  'IFT52': 'UP',
#  'GTF2E2': 'DOWN',
#  'TNIP1': 'DOWN',
#  'CCR4': 'DOWN',
#  'NUDT18': 'DOWN',
#  'YEATS4': 'UP',
#  'TTC7B': 'UP',
#  'C10orf26': 'DOWN',
#  'C9orf25': 'UP',
#  'ENTPD4': 'DOWN',
#  'GSR': 'DOWN',
#  'USP54': 'DOWN',
#  'C5orf34': 'UP',
#  'FAM160B2': 'DOWN',
#  'NLRX1': 'DOWN',
#  'CBX7': 'DOWN',
#  'MAD2L1': 'UP',
#  'MRPL36': 'UP',
#  'ZNF385B': 'DOWN',
#  'CD3E': 'DOWN',
#  'FAF1': 'UP',
#  'TRIM8': 'DOWN',
#  'DDIT3': 'UP',
#  'UBE2C': 'UP',
#  'HOXC8': 'UP',
#  'CLIC5': 'DOWN',
#  'MLH1': nan,
#  'EEF1B2': 'DOWN',
#  'CKAP2L': 'UP',
#  'C5orf33': 'UP',
#  'C20orf111': 'UP',
#  'FAM119B': 'UP',
#  'KDELR2': 'UP',
#  'ERAL1': 'UP',
#  'CTNNBL1': 'UP',
#  'C6orf97': 'DOWN',
#  'LTB': 'DOWN',
#  'NAT1': 'UP',
#  'SLC35E3': 'UP',
#  'MUC16': 'DOWN',
#  'MAD2L2': 'UP',
#  'IPCEF1': 'DOWN',
#  'SHCBP1': 'UP',
#  'PRKCQ': 'DOWN',
#  'MIPOL1': nan,
#  'C17orf37': 'UP',
#  'HOXA10': 'UP',
#  'MPV17L': 'UP',
#  'CYP4X1': 'DOWN',
#  'HOXC5': 'UP',
#  'RPL3': 'DOWN',
#  'SNTN': 'DOWN',
#  'ACAP1': 'DOWN',
#  'MED10': 'UP',
#  'ZNF883': 'UP',
#  'FTSJ2': 'UP',
#  'CKS1B': 'UP',
#  'PNPT1': 'UP',
#  'EPB49': 'DOWN',
#  'HOXC4': 'UP',
#  'MBD2': nan,
#  'CASP1': 'DOWN',
#  'AGPAT3': 'DOWN',
#  'HOXA9': nan,
#  'NDC80': 'UP',
#  'UBASH3A': 'DOWN',
#  'DEPDC1': 'UP',
#  'CD2': 'DOWN',
#  'CD3G': 'DOWN',
#  'DPM1': 'UP',
#  'BIN3': 'DOWN',
#  'RNF114': 'UP',
#  'SKA3': 'UP',
#  'IGDCC4': 'UP',
#  'MRPS27': 'DOWN',
#  'ANKLE1': 'UP',
#  'ST6GALNAC1': 'DOWN',
#  'PCMT1': 'UP',
#  'INTS5': 'DOWN',
#  'CTDSP2': 'UP',
#  'FADD': 'UP',
#  'GPR174': 'DOWN',
#  'CCNB2': 'UP',
#  'RTEL1': 'UP',
#  'CTTN': 'UP',
#  'KIF23': 'UP',
#  'JHDM1D': 'DOWN',
#  'NOP56': 'UP',
#  'NPEPL1': 'UP',
#  'TMED6': 'DOWN',
#  'WDR67': 'UP',
#  'PER2': 'DOWN',
#  'HOXC6': 'UP',
#  'BLM': 'UP',
#  'PLEKHG7': 'DOWN',
#  'ERLIN1': 'DOWN',
#  'CDC25A': 'UP',
#  'LDLRAD1': 'DOWN',
#  'YWHAB': 'UP',
#  'MCM6': nan,
#  'TMEM203': 'UP',
#  'WDHD1': 'UP',
#  'PIGR': 'DOWN',
#  'C11orf16': 'DOWN',
#  'STARD3': 'UP',
#  'EIF3L': 'DOWN',
#  'RAI2': 'DOWN',
#  'UQCC': 'UP',
#  'CCDC150': 'UP',
#  'MUC5B': 'DOWN',
#  'TRIB3': 'UP',
#  'KRT10': nan,
#  'PTK2B': 'DOWN',
#  'SAE1': 'UP',
#  'SPRED2': 'UP',
#  'MKNK2': 'DOWN',
#  'ATP9B': 'DOWN',
#  'RILPL1': 'UP',
#  'PLEKHA2': nan,
#  'ATP6V1B2': 'DOWN',
#  'KIAA1797': 'DOWN',
#  'FAM46C': 'DOWN',
#  'C10orf114': 'UP',
#  'MURC': nan,
#  'PTN': 'UP',
#  'FCRL6': 'DOWN',
#  'WDR76': nan,
#  'BSPRY': 'DOWN',
#  'ISPD': 'UP',
#  'GPR171': 'DOWN',
#  'C20orf85': 'DOWN',
#  'KIAA0415': 'UP',
#  'HOXC10': 'UP',
#  'WDR63': 'DOWN',
#  'KLHL9': nan,
#  'CHEK1': nan,
#  'C16orf54': 'DOWN',
#  'EME1': 'UP',
#  'TOM1': 'DOWN',
#  'CNDP2': 'DOWN',
#  'AMPD3': 'DOWN',
#  'MYBL2': 'UP',
#  'TIFAB': 'DOWN',
#  'INPP4A': nan,
#  'CPVL': nan,
#  'HOXC11': 'UP',
#  'TNFAIP6': 'UP',
#  'ORMDL3': 'UP',
#  'C20orf107': 'UP',
#  'CCDC6': nan,
#  'SCEL': 'DOWN',
#  'DUSP12': 'UP',
#  'SCUBE1': 'DOWN',
#  'ABCF1': 'UP',
#  'POLL': 'DOWN',
#  'CDHR4': 'DOWN',
#  'C8orf79': 'DOWN',
#  'CSE1L': 'UP',
#  'TMEM66': 'DOWN',
#  'TAGAP': 'DOWN',
#  'CALU': 'UP',
#  'DAPL1': 'DOWN',
#  'RASGEF1B': 'DOWN',
#  'ZNF516': 'DOWN',
#  'IL5RA': 'DOWN',
#  'TTK': 'UP',
#  'WDR70': 'UP',
#  'ARMC3': 'DOWN',
#  'IK': nan,
#  'SLC40A1': 'DOWN',
#  'CDK1': 'UP',
#  'DACH1': 'DOWN',
#  'BHLHA15': 'DOWN',
#  'BRD9': nan,
#  'SIT1': 'DOWN',
#  'NEK2': 'UP',
#  'MAP7D3': 'UP',
#  'IL2RB': 'DOWN',
#  'CCDC127': nan,
#  'C1orf112': 'UP',
#  'EYA2': nan,
#  'CD3D': 'DOWN',
#  'RAB36': nan,
#  'STAC': 'UP',
#  'DIDO1': nan,
#  'FAHD2B': 'UP',
#  'MON1B': 'DOWN',
#  'ZNF622': nan,
#  'PDCD6': 'UP',
#  'NDUFS6': 'UP',
#  'SPC25': 'UP',
#  'SDHA': nan,
#  'CNTFR': 'UP',
#  'THEMIS': 'DOWN',
#  'SLPI': 'DOWN',
#  'CLNK': 'DOWN',
#  'NUDT1': 'UP',
#  'RPAP3': 'UP',
#  'CCR8': 'DOWN',
#  'EXOC3': nan,
#  'CTBP2': 'DOWN',
#  'FRS2': 'UP',
#  'ASPM': 'UP',
#  'ZNF772': 'UP',
#  'PGR': 'DOWN',
#  'SEPT1': 'DOWN',
#  'GAL': 'UP',
#  'REEP4': nan,
#  'KLRK1': 'DOWN',
#  'CDC25B': 'UP',
#  'PRSS27': 'DOWN',
#  'BCR': 'DOWN',
#  'PTX3': 'UP',
#  'NOXO1': 'DOWN',
#  'S1PR4': 'DOWN',
#  'SORBS2': 'DOWN',
#  'RPS6KA1': 'DOWN',
#  'EYA4': 'UP',
#  'ENPP3': 'DOWN',
#  'ANKRD44': 'DOWN',
#  'STAU1': 'UP',
#  'HEXIM2': nan,
#  'SLC25A21': 'DOWN',
#  'LEPROTL1': 'DOWN',
#  'ARHGAP11A': 'UP',
#  'C2orf54': 'DOWN',
#  'BCL2L15': 'DOWN',
#  'IGF1': 'DOWN',
#  'GNB3': 'UP',
#  'TUBA4B': 'DOWN',
#  'CCDC17': 'DOWN',
#  'TIRAP': 'DOWN',
#  'SRPR': nan,
#  'CXCR5': 'DOWN',
#  'DCDC2B': 'DOWN',
#  'ARSD': 'DOWN',
#  'P2RY10': 'DOWN',
#  'C20orf4': 'UP',
#  'TMEM190': 'DOWN',
#  'C1orf186': 'DOWN',
#  'XPO5': 'UP',
#  'DAK': 'DOWN',
#  'FUT6': 'DOWN',
#  'CXCL17': 'DOWN',
#  'CCDC152': 'UP',
#  'GZMH': 'DOWN',
#  'TTLL10': 'DOWN',
#  'TCTEX1D4': 'DOWN',
#  'BET1': nan,
#  'PAM': 'DOWN',
#  'MYBPC2': 'DOWN',
#  'LPXN': 'DOWN',
#  'APOBEC4': 'DOWN',
#  'LYN': 'DOWN',
#  'EEF2': 'DOWN',
#  'LRFN1': 'UP',
#  'XKRX': 'DOWN',
#  'C1orf52': 'UP',
#  'EPM2AIP1': nan,
#  'SLC6A20': 'DOWN',
#  'IGF2BP3': 'UP',
#  'PTPRCAP': 'DOWN',
#  'TMEM199': 'UP',
#  'MARCKS': 'UP',
#  'KCNMA1': 'DOWN',
#  'SLC18A2': 'DOWN',
#  'EZH1': 'DOWN',
#  'C19orf44': 'UP',
#  'ALDH2': 'DOWN',
#  'PSRC1': 'UP',
#  'GCHFR': 'DOWN',
#  'MFHAS1': 'DOWN',
#  'C7orf42': nan,
#  'SNX20': 'DOWN',
#  'TCF25': 'DOWN',
#  'TMEFF1': 'UP',
#  'GZMM': 'DOWN',
#  'HMGB2': 'UP',
#  'C17orf96': 'UP',
#  'CFTR': 'DOWN',
#  'SYTL3': 'DOWN',
#  'COL4A3BP': 'DOWN',
#  'CHAF1A': 'UP',
#  'SLMO2': 'UP',
#  'C12orf74': 'DOWN',
#  'KDELR3': nan,
#  'TLR3': 'DOWN',
#  'DMBT1': 'DOWN',
#  'DHX35': 'UP',
#  'GRB7': 'UP',
#  'POLDIP2': 'UP',
#  'NKAIN1': 'UP',
#  'ZFP64': 'UP',
#  'SPN': 'DOWN',
#  'CTSB': 'DOWN',
#  'RNF144B': 'DOWN',
#  'C5orf20': 'DOWN',
#  'PSMD3': 'UP',
#  'MS4A8B': 'DOWN',
#  'LARP4B': nan,
#  'CFLAR': 'DOWN',
#  'C8orf58': nan,
#  'SERPINB1': 'DOWN',
#  'SPC24': 'UP',
#  'FAM81B': 'DOWN',
#  'ERBB2': 'UP',
#  'HKDC1': 'DOWN',
#  'C20orf27': 'UP',
#  'IDH3B': 'UP',
#  'CENPO': 'UP',
#  'ZNF311': 'UP',
#  'C2orf74': nan,
#  'ATAD2': 'UP',
#  'NPM2': 'DOWN',
#  'GTPBP4': 'UP',
#  'USP1': 'UP',
#  'C10orf140': 'UP',
#  'MTBP': 'UP',
#  'CNOT2': 'UP',
#  'SUN1': 'UP',
#  'CARD16': 'DOWN',
#  'DHX16': 'UP',
#  'DSCC1': 'UP',
#  'PTCD2': nan,
#  'FLT3': 'DOWN',
#  'C4orf21': 'UP',
#  'FUT3': 'DOWN',
#  'MORN5': 'DOWN',
#  'RACGAP1': 'UP',
#  'PDCD1': 'DOWN',
#  'FKBP9': 'UP',
#  'ZNF831': 'DOWN',
#  'SPRY4': nan,
#  'R3HCC1': 'DOWN',
#  'DUSP6': nan,
#  'EPHB2': 'UP',
#  'ARFGAP1': 'UP',
#  'KIAA0748': 'DOWN',
#  'STX18': 'DOWN',
#  'CYP7B1': 'DOWN',
#  'STAT4': 'DOWN',
#  'SDF2': 'UP',
#  'ETV4': nan,
#  'PPP5C': 'UP',
#  'ZBBX': 'DOWN',
#  'GARS': 'UP',
#  'SYTL1': 'DOWN',
#  'MUC20': nan,
#  'MAP4K1': 'DOWN',
#  'ARMC4': 'DOWN',
#  'MUC4': 'DOWN',
#  'GPR110': nan,
#  'CCR5': 'DOWN',
#  'CD6': 'DOWN',
#  'TUBB': 'UP',
#  'TXNDC3': 'DOWN',
#  'IL12B': 'DOWN',
#  'WDR62': 'UP',
#  'ALCAM': 'DOWN',
#  'FUT2': 'DOWN',
#  'PDZK1IP1': 'DOWN',
#  'FZD7': 'UP',
#  'FANCD2': 'UP',
#  'IGF2BP2': 'UP',
#  'SIKE1': 'UP',
#  'LCN2': 'DOWN',
#  'ADRA2B': 'UP',
#  'TNFRSF10A': 'DOWN',
#  'HPS6': 'DOWN',
#  'SEPP1': 'UP',
#  'FBXO18': nan,
#  'SLFN12L': 'DOWN',
#  'WWP2': 'DOWN',
#  'NUSAP1': 'UP',
#  'HOXD13': 'UP',
#  'ITGAL': 'DOWN',
#  'DLL3': 'UP',
#  'CNR2': 'DOWN',
#  'STMN1': 'UP',
#  'PSMB10': 'DOWN',
#  'FAM32A': 'UP',
#  'STT3A': nan,
#  'FAM24B': 'UP',
#  'PNPLA1': 'UP',
#  'TNFRSF10B': 'DOWN',
#  'ALOXE3': nan,
#  'FRMPD2': 'DOWN',
#  'THEM5': nan,
#  'MSL1': 'UP',
#  'CUZD1': nan,
#  'CD27': 'DOWN',
#  'IKZF2': 'DOWN',
#  'CENPF': 'UP',
#  'DGCR2': nan,
#  'SNRPD1': 'UP',
#  'E2F1': 'UP',
#  'ASMT': nan,
#  'RASAL3': 'DOWN',
#  'PRRG2': nan,
#  'IGF2BP1': nan,
#  'ST14': nan,
#  'HMGA2': 'UP',
#  'KIF14': 'UP',
#  'CD52': 'DOWN',
#  'RP9': 'UP',
#  'AKR1A1': nan,
#  'C9orf169': 'DOWN',
#  'ALOX12B': nan,
#  'SQRDL': 'DOWN',
#  'SLC4A5': nan,
#  'KRT1': nan,
#  'SBSN': 'DOWN',
#  'PLA2G4D': 'DOWN',
#  'C20orf106': 'UP',
#  'DSG1': 'DOWN',
#  'RSPH4A': 'DOWN',
#  'C1orf192': 'DOWN',
#  'C17orf72': 'DOWN',
#  'KCTD11': nan,
#  'LSR': nan,
#  'C2orf39': 'DOWN',
#  'GATAD1': nan,
#  'VWA3A': 'DOWN',
#  'GLTP': 'DOWN',
#  'DPAGT1': nan,
#  'C1orf230': 'DOWN',
#  'SLC39A2': nan,
#  'CRB3': 'DOWN',
#  'CCDC135': 'DOWN',
#  'TMEM106A': 'DOWN',
#  'C1orf210': nan,
#  'C1orf172': nan,
#  'SCNN1A': 'DOWN',
#  'NCCRP1': nan,
#  'CNKSR1': nan,
#  'KIAA1751': 'DOWN',
#  'PRSS22': nan,
#  'RTDR1': nan,
#  'CD163': nan,
#  'MSR1': 'DOWN',
#  'OLAH': nan,
#  'ACTL8': nan,
#  'CNFN': 'DOWN',
#  'MTHFD2': nan,
#  'CHMP4C': nan,
#  'RNF222': 'DOWN',
#  'CIB1': nan,
#  'ESRP2': nan,
#  'TMEM79': nan,
#  'YSK4': 'DOWN',
#  'SPINT2': 'UP',
#  'ELMO3': nan,
#  'RAB25': nan,
#  'TEX19': 'DOWN',
#  'SIGLEC1': nan,
#  'FCGR2A': 'DOWN',
#  'IFT20': 'UP',
#  'AP1M2': nan,
#  'MS4A6A': nan,
#  'FCGR3A': 'DOWN',
#  'TMEM184A': nan,
#  'ELF3': nan,
#  'PRSS8': nan,
#  'FOLR2': 'UP',
#  'CBLC': 'UP',
#  'MS4A7': nan,
#  'C20orf151': 'UP',
#  'OVOL2': nan,
#  'C7orf23': nan,
#  'CCDC64B': nan,
#  'MPP1': nan,
#  'CLDN4': nan,
#  'GRHL2': nan,
#  'CYBA': 'DOWN',
#  'MS4A4A': nan,
#  'CLDN7': nan,
#  'CSDE1': nan,
#  'C1orf194': 'DOWN',
#  'HORMAD1': 'UP',
#  'C10orf99': nan,
#  'C9orf171': 'DOWN',
#  'C6orf118': 'DOWN',
#  'TYW1': 'UP',
#  'VKORC1L1': nan,
#  'KLRB1': 'DOWN',
#  'LIPG': 'UP',
#  'CRCP': nan,
#  'CD40LG': 'DOWN',
#  'NRAS': 'UP',
#  'DR1': nan,
#  'LIME1': 'UP',
#  'HIAT1': nan,
#  'PBX4': 'UP',
#  'CCR2': 'DOWN',
#  'NRM': 'UP',
#  'TPRKB': 'UP',
#  'ZNHIT6': nan,
#  'GNAI3': 'UP',
#  'INSL3': nan,
#  'CTTNBP2NL': nan,
#  'METTL5': nan,
#  'CD48': 'DOWN',
#  'RBMXL1': nan,
#  'SNRPG': 'UP',
#  'GMIP': nan,
#  'DEK': 'UP',
#  'MITD1': nan,
#  'SLAMF7': 'DOWN',
#  'LY9': 'DOWN',
#  'C10orf125': 'UP',
#  'SNRPA1': 'UP'}

# %% [markdown]
# ### Amplicon Architect Gene List:

# %%
aa_gene_dict = ecdna_freq_genes(aa_df, "Sample name", "All genes", "Oncogenes", "Feature median copy number")
aa_oncogene_dict = ecdna_freq_genes(aa_df, "Sample name", "All genes", "Oncogenes", "Feature median copy number", True)
aa_gene_dict
# Out:
# {'CASC11': [1459.6616842484777,
#   {'AU565_BREAST',
#    'CORL23_LUNG',
#    'CORL279_LUNG',
#    'CORL311_LUNG',
#    'DMS273_LUNG',
#    'EFM192A_BREAST',
#    'FUOV1_OVARY',
#    'GCIY_STOMACH',
#    'HCC1419_BREAST',
#    'HCC44_LUNG',
#    'HGC27_STOMACH',
#    'KYSE450_OESOPHAGUS',
#    'MSTO211H_PLEURA',
#    'NCIH1792_LUNG',
#    'NCIH2122_LUNG',
#    'NCIH2170_LUNG',
#    'NCIH2171_LUNG',
#    'NCIH23_LUNG',
#    'NCIH446_LUNG',
#    'NCIH460_LUNG',
#    'NCIH510_LUNG',
#    'NCIH524_LUNG',
#    'NCIH82_LUNG',
#    'SCLC21H_LUNG',
#    'SNU16_STOMACH',
#    'SW480_LARGE_INTESTINE'}],
#  'MYC': [1459.6616842484777,
#   {'AU565_BREAST',
#    'CORL23_LUNG',
#    'CORL279_LUNG',
#    'CORL311_LUNG',
#    'DMS273_LUNG',
#    'EFM192A_BREAST',
#    'FUOV1_OVARY',
#    'GCIY_STOMACH',
#    'HCC1419_BREAST',
#    'HCC44_LUNG',
#    'HGC27_STOMACH',
#    'KYSE450_OESOPHAGUS',
#    'MSTO211H_PLEURA',
#    'NCIH1792_LUNG',
#    'NCIH2122_LUNG',
#    'NCIH2170_LUNG',
#    'NCIH2171_LUNG',
#    'NCIH23_LUNG',
#    'NCIH446_LUNG',
#    'NCIH460_LUNG',
#    'NCIH510_LUNG',
#    'NCIH524_LUNG',
#    'NCIH82_LUNG',
#    'SCLC21H_LUNG',
#    'SNU16_STOMACH',
#    'SW480_LARGE_INTESTINE'}],
#  'PVT1': [1132.3686299345698,
#   {'CORL23_LUNG',
#    'CORL311_LUNG',
#    'EFM192A_BREAST',
#    'FUOV1_OVARY',
#    'HCC1419_BREAST',
#    'HCC44_LUNG',
#    'HGC27_STOMACH',
#    'KYSE450_OESOPHAGUS',
#    'MSTO211H_PLEURA',
#    'NCIH1792_LUNG',
#    'NCIH2170_LUNG',
#    'NCIH2171_LUNG',
#    'NCIH23_LUNG',
#    'NCIH446_LUNG',
#    'NCIH460_LUNG',
#    'NCIH510_LUNG',
#    'NCIH524_LUNG',
#    'NCIH82_LUNG',
#    'SNU16_STOMACH',
#    'SW480_LARGE_INTESTINE'}],
#  'CASC8': [874.207152949892,
#   {'AU565_BREAST',
#    'CORL23_LUNG',
#    'EFM192A_BREAST',
#    'GCIY_STOMACH',
#    'HCC1419_BREAST',
#    'HCC44_LUNG',
#    'HCC827_LUNG',
#    'HGC27_STOMACH',
#    'KYSE450_OESOPHAGUS',
#    'NCIH2170_LUNG',
#    'NCIH2171_LUNG',
#    'NCIH23_LUNG',
#    'NCIH446_LUNG',
#    'NCIH510_LUNG',
#    'NCIH524_LUNG',
#    'NCIH82_LUNG',
#    'SNU16_STOMACH'}],
#  'POU5F1B': [874.207152949892,
#   {'AU565_BREAST',
#    'CORL23_LUNG',
#    'EFM192A_BREAST',
#    'GCIY_STOMACH',
#    'HCC1419_BREAST',
#    'HCC44_LUNG',
#    'HCC827_LUNG',
#    'HGC27_STOMACH',
#    'KYSE450_OESOPHAGUS',
#    'NCIH2170_LUNG',
#    'NCIH2171_LUNG',
#    'NCIH23_LUNG',
#    'NCIH446_LUNG',
#    'NCIH510_LUNG',
#    'NCIH524_LUNG',
#    'NCIH82_LUNG',
#    'SNU16_STOMACH'}],
#  'CCAT2': [858.5298486495026,
#   {'AU565_BREAST',
#    'CORL23_LUNG',
#    'EFM192A_BREAST',
#    'HCC1419_BREAST',
#    'HCC44_LUNG',
#    'HCC827_LUNG',
#    'HGC27_STOMACH',
#    'KYSE450_OESOPHAGUS',
#    'NCIH2170_LUNG',
#    'NCIH2171_LUNG',
#    'NCIH23_LUNG',
#    'NCIH446_LUNG',
#    'NCIH510_LUNG',
#    'NCIH524_LUNG',
#    'NCIH82_LUNG',
#    'SNU16_STOMACH',
#    'SW480_LARGE_INTESTINE'}],
#  'TMEM75': [813.9307671830916,
#   {'AU565_BREAST',
#    'CORL23_LUNG',
#    'CORL311_LUNG',
#    'EFM192A_BREAST',
#    'FUOV1_OVARY',
#    'HCC1419_BREAST',
#    'HCC1954_BREAST',
#    'HCC44_LUNG',
#    'HGC27_STOMACH',
#    'KYSE450_OESOPHAGUS',
#    'MSTO211H_PLEURA',
#    'NCIH1792_LUNG',
#    'NCIH2170_LUNG',
#    'NCIH23_LUNG',
#    'NCIH460_LUNG',
#    'NCIH510_LUNG',
#    'SNU16_STOMACH',
#    'SW480_LARGE_INTESTINE'}],
#  'CASC21': [647.2323930502589,
#   {'AU565_BREAST',
#    'CORL23_LUNG',
#    'EFM192A_BREAST',
#    'GCIY_STOMACH',
#    'HCC1419_BREAST',
#    'HCC44_LUNG',
#    'HCC827_LUNG',
#    'HGC27_STOMACH',
#    'KYSE450_OESOPHAGUS',
#    'NCIH2171_LUNG',
#    'NCIH23_LUNG',
#    'NCIH446_LUNG',
#    'NCIH524_LUNG',
#    'NCIH82_LUNG',
#    'SKOV3_OVARY',
#    'SNU16_STOMACH',
#    'SW480_LARGE_INTESTINE'}],
#  'ERBB2': [493.95832185281716,
#   {'BT474_BREAST',
#    'EFM192A_BREAST',
#    'HCC1419_BREAST',
#    'HCC1569_BREAST',
#    'HCC202_BREAST',
#    'KYSE410_OESOPHAGUS',
#    'MFE280_ENDOMETRIUM',
#    'MKN7_STOMACH',
#    'NCIH2170_LUNG',
#    'OE19_OESOPHAGUS',
#    'SKOV3_OVARY',
#    'UACC812_BREAST',
#    'UACC893_BREAST'}],
#  'PGAP3': [493.95832185281716,
#   {'BT474_BREAST',
#    'EFM192A_BREAST',
#    'HCC1419_BREAST',
#    'HCC1569_BREAST',
#    'HCC202_BREAST',
#    'KYSE410_OESOPHAGUS',
#    'MFE280_ENDOMETRIUM',
#    'MKN7_STOMACH',
#    'NCIH2170_LUNG',
#    'OE19_OESOPHAGUS',
#    'SKOV3_OVARY',
#    'UACC812_BREAST',
#    'UACC893_BREAST'}],
#  'GRB7': [485.20538896208427,
#   {'BT474_BREAST',
#    'EFM192A_BREAST',
#    'HCC1419_BREAST',
#    'HCC1569_BREAST',
#    'HCC202_BREAST',
#    'KYSE410_OESOPHAGUS',
#    'MFE280_ENDOMETRIUM',
#    'MKN7_STOMACH',
#    'NCIH2170_LUNG',
#    'OE19_OESOPHAGUS',
#    'UACC812_BREAST',
#    'UACC893_BREAST'}],
#  'IKZF3': [485.20538896208427,
#   {'BT474_BREAST',
#    'EFM192A_BREAST',
#    'HCC1419_BREAST',
#    'HCC1569_BREAST',
#    'HCC202_BREAST',
#    'KYSE410_OESOPHAGUS',
#    'MFE280_ENDOMETRIUM',
#    'MKN7_STOMACH',
#    'NCIH2170_LUNG',
#    'OE19_OESOPHAGUS',
#    'UACC812_BREAST',
#    'UACC893_BREAST'}],
#  'MIEN1': [485.20538896208427,
#   {'BT474_BREAST',
#    'EFM192A_BREAST',
#    'HCC1419_BREAST',
#    'HCC1569_BREAST',
#    'HCC202_BREAST',
#    'KYSE410_OESOPHAGUS',
#    'MFE280_ENDOMETRIUM',
#    'MKN7_STOMACH',
#    'NCIH2170_LUNG',
#    'OE19_OESOPHAGUS',
#    'UACC812_BREAST',
#    'UACC893_BREAST'}],
#  'PCAT1': [396.27773375957355,
#   {'AU565_BREAST',
#    'EFM192A_BREAST',
#    'HCC1419_BREAST',
#    'HCC1954_BREAST',
#    'HCC827_LUNG',
#    'HGC27_STOMACH',
#    'NCIH2170_LUNG',
#    'NCIH2171_LUNG',
#    'NCIH23_LUNG',
#    'NCIH446_LUNG',
#    'SW480_LARGE_INTESTINE'}],
#  'MYCL': [396.04242403586784,
#   {'COLO668_LUNG',
#    'CORL88_LUNG',
#    'HCC33_LUNG',
#    'NCIH1092_LUNG',
#    'NCIH1184_LUNG',
#    'NCIH1694_LUNG',
#    'NCIH1836_LUNG',
#    'NCIH1963_LUNG',
#    'NCIH510_LUNG',
#    'NCIH520_LUNG',
#    'NCIH889_LUNG',
#    'THP1_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE'}],
#  'TRIT1': [396.04242403586784,
#   {'COLO668_LUNG',
#    'CORL88_LUNG',
#    'HCC33_LUNG',
#    'NCIH1092_LUNG',
#    'NCIH1184_LUNG',
#    'NCIH1694_LUNG',
#    'NCIH1836_LUNG',
#    'NCIH1963_LUNG',
#    'NCIH510_LUNG',
#    'NCIH520_LUNG',
#    'NCIH889_LUNG',
#    'THP1_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE'}],
#  'PNMT': [395.7743331326696,
#   {'BT474_BREAST',
#    'EFM192A_BREAST',
#    'HCC1419_BREAST',
#    'HCC202_BREAST',
#    'KYSE410_OESOPHAGUS',
#    'MFE280_ENDOMETRIUM',
#    'MKN7_STOMACH',
#    'NCIH2170_LUNG',
#    'SKOV3_OVARY',
#    'UACC812_BREAST',
#    'UACC893_BREAST'}],
#  'TCAP': [395.7743331326696,
#   {'BT474_BREAST',
#    'EFM192A_BREAST',
#    'HCC1419_BREAST',
#    'HCC202_BREAST',
#    'KYSE410_OESOPHAGUS',
#    'MFE280_ENDOMETRIUM',
#    'MKN7_STOMACH',
#    'NCIH2170_LUNG',
#    'SKOV3_OVARY',
#    'UACC812_BREAST',
#    'UACC893_BREAST'}],
#  'BMP8B': [363.63030051817367,
#   {'COLO668_LUNG',
#    'CORL88_LUNG',
#    'NCIH1092_LUNG',
#    'NCIH1184_LUNG',
#    'NCIH1694_LUNG',
#    'NCIH1836_LUNG',
#    'NCIH1963_LUNG',
#    'NCIH510_LUNG',
#    'NCIH520_LUNG',
#    'NCIH889_LUNG',
#    'THP1_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE'}],
#  'HPCAL4': [363.63030051817367,
#   {'COLO668_LUNG',
#    'CORL88_LUNG',
#    'NCIH1092_LUNG',
#    'NCIH1184_LUNG',
#    'NCIH1694_LUNG',
#    'NCIH1836_LUNG',
#    'NCIH1963_LUNG',
#    'NCIH510_LUNG',
#    'NCIH520_LUNG',
#    'NCIH889_LUNG',
#    'THP1_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE'}],
#  'NT5C1A': [363.63030051817367,
#   {'COLO668_LUNG',
#    'CORL88_LUNG',
#    'NCIH1092_LUNG',
#    'NCIH1184_LUNG',
#    'NCIH1694_LUNG',
#    'NCIH1836_LUNG',
#    'NCIH1963_LUNG',
#    'NCIH510_LUNG',
#    'NCIH520_LUNG',
#    'NCIH889_LUNG',
#    'THP1_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE'}],
#  'OXCT2': [363.63030051817367,
#   {'COLO668_LUNG',
#    'CORL88_LUNG',
#    'NCIH1092_LUNG',
#    'NCIH1184_LUNG',
#    'NCIH1694_LUNG',
#    'NCIH1836_LUNG',
#    'NCIH1963_LUNG',
#    'NCIH510_LUNG',
#    'NCIH520_LUNG',
#    'NCIH889_LUNG',
#    'THP1_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE'}],
#  'PPIE': [363.63030051817367,
#   {'COLO668_LUNG',
#    'CORL88_LUNG',
#    'NCIH1092_LUNG',
#    'NCIH1184_LUNG',
#    'NCIH1694_LUNG',
#    'NCIH1836_LUNG',
#    'NCIH1963_LUNG',
#    'NCIH510_LUNG',
#    'NCIH520_LUNG',
#    'NCIH889_LUNG',
#    'THP1_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE'}],
#  'ZPBP2': [356.06760415362874,
#   {'BT474_BREAST',
#    'EFM192A_BREAST',
#    'HCC202_BREAST',
#    'MFE280_ENDOMETRIUM',
#    'MKN7_STOMACH',
#    'NCIH2170_LUNG',
#    'UACC812_BREAST',
#    'UACC893_BREAST'}],
#  'CASC19': [336.7979320645132,
#   {'AU565_BREAST',
#    'CORL23_LUNG',
#    'EFM192A_BREAST',
#    'GCIY_STOMACH',
#    'HCC1419_BREAST',
#    'HCC44_LUNG',
#    'HCC827_LUNG',
#    'HGC27_STOMACH',
#    'KYSE450_OESOPHAGUS',
#    'NCIH2171_LUNG',
#    'NCIH23_LUNG',
#    'NCIH446_LUNG',
#    'NCIH82_LUNG',
#    'SKOV3_OVARY',
#    'SW480_LARGE_INTESTINE'}],
#  'CCAT1': [336.7979320645132,
#   {'AU565_BREAST',
#    'CORL23_LUNG',
#    'EFM192A_BREAST',
#    'GCIY_STOMACH',
#    'HCC1419_BREAST',
#    'HCC44_LUNG',
#    'HCC827_LUNG',
#    'HGC27_STOMACH',
#    'KYSE450_OESOPHAGUS',
#    'NCIH2171_LUNG',
#    'NCIH23_LUNG',
#    'NCIH446_LUNG',
#    'NCIH82_LUNG',
#    'SKOV3_OVARY',
#    'SW480_LARGE_INTESTINE'}],
#  'HEYL': [320.7413911307577,
#   {'COLO668_LUNG',
#    'CORL88_LUNG',
#    'NCIH1092_LUNG',
#    'NCIH1184_LUNG',
#    'NCIH1694_LUNG',
#    'NCIH1836_LUNG',
#    'NCIH510_LUNG',
#    'NCIH520_LUNG',
#    'NCIH889_LUNG',
#    'THP1_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE'}],
#  'PCAT2': [314.5712558918975,
#   {'AU565_BREAST',
#    'CORL23_LUNG',
#    'EFM192A_BREAST',
#    'GCIY_STOMACH',
#    'HCC1419_BREAST',
#    'HCC1954_BREAST',
#    'HCC44_LUNG',
#    'HCC827_LUNG',
#    'HGC27_STOMACH',
#    'NCIH2171_LUNG',
#    'NCIH23_LUNG',
#    'NCIH446_LUNG',
#    'NCIH82_LUNG',
#    'SW480_LARGE_INTESTINE'}],
#  'PRNCR1': [314.5712558918975,
#   {'AU565_BREAST',
#    'CORL23_LUNG',
#    'EFM192A_BREAST',
#    'GCIY_STOMACH',
#    'HCC1419_BREAST',
#    'HCC1954_BREAST',
#    'HCC44_LUNG',
#    'HCC827_LUNG',
#    'HGC27_STOMACH',
#    'NCIH2171_LUNG',
#    'NCIH23_LUNG',
#    'NCIH446_LUNG',
#    'NCIH82_LUNG',
#    'SW480_LARGE_INTESTINE'}],
#  'MFSD2A': [307.0736614199096,
#   {'COLO668_LUNG',
#    'CORL88_LUNG',
#    'HCC33_LUNG',
#    'NCIH1092_LUNG',
#    'NCIH1184_LUNG',
#    'NCIH1694_LUNG',
#    'NCIH1836_LUNG',
#    'NCIH1963_LUNG',
#    'NCIH520_LUNG',
#    'THP1_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE'}],
#  'RLF': [297.7715662233615,
#   {'COLO668_LUNG',
#    'CORL88_LUNG',
#    'HCC33_LUNG',
#    'NCIH1092_LUNG',
#    'NCIH1184_LUNG',
#    'NCIH1963_LUNG',
#    'NCIH520_LUNG',
#    'NCIH889_LUNG',
#    'THP1_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE'}],
#  'CDC6': [287.1185415738305,
#   {'NCIH2170_LUNG', 'UACC812_BREAST', 'UACC893_BREAST'}],
#  'RAPGEFL1': [287.1185415738305,
#   {'NCIH2170_LUNG', 'UACC812_BREAST', 'UACC893_BREAST'}],
#  'RARA': [287.1185415738305,
#   {'NCIH2170_LUNG', 'UACC812_BREAST', 'UACC893_BREAST'}],
#  'WIPF2': [287.1185415738305,
#   {'NCIH2170_LUNG', 'UACC812_BREAST', 'UACC893_BREAST'}],
#  'CAP1': [249.37500375103835,
#   {'COLO668_LUNG',
#    'CORL88_LUNG',
#    'HCC33_LUNG',
#    'NCIH1092_LUNG',
#    'NCIH1184_LUNG',
#    'NCIH1836_LUNG',
#    'NCIH1963_LUNG',
#    'NCIH520_LUNG',
#    'THP1_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE'}],
#  'PABPC4': [249.21271233359468,
#   {'COLO668_LUNG',
#    'CORL88_LUNG',
#    'NCIH1092_LUNG',
#    'NCIH1184_LUNG',
#    'NCIH1694_LUNG',
#    'NCIH1836_LUNG',
#    'NCIH510_LUNG',
#    'NCIH520_LUNG',
#    'THP1_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE'}],
#  'PABPC4-AS1': [249.21271233359468,
#   {'COLO668_LUNG',
#    'CORL88_LUNG',
#    'NCIH1092_LUNG',
#    'NCIH1184_LUNG',
#    'NCIH1694_LUNG',
#    'NCIH1836_LUNG',
#    'NCIH510_LUNG',
#    'NCIH520_LUNG',
#    'THP1_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE'}],
#  'PPIEL': [249.21271233359468,
#   {'COLO668_LUNG',
#    'CORL88_LUNG',
#    'NCIH1092_LUNG',
#    'NCIH1184_LUNG',
#    'NCIH1694_LUNG',
#    'NCIH1836_LUNG',
#    'NCIH510_LUNG',
#    'NCIH520_LUNG',
#    'THP1_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE'}],
#  'SNORA55': [249.21271233359468,
#   {'COLO668_LUNG',
#    'CORL88_LUNG',
#    'NCIH1092_LUNG',
#    'NCIH1184_LUNG',
#    'NCIH1694_LUNG',
#    'NCIH1836_LUNG',
#    'NCIH510_LUNG',
#    'NCIH520_LUNG',
#    'THP1_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE'}],
#  'OXCT2P1': [240.23803165515906,
#   {'COLO668_LUNG',
#    'CORL88_LUNG',
#    'NCIH1184_LUNG',
#    'NCIH1694_LUNG',
#    'NCIH1836_LUNG',
#    'NCIH510_LUNG',
#    'NCIH520_LUNG',
#    'THP1_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE'}],
#  'LRATD2': [238.583261161309,
#   {'CORL23_LUNG',
#    'EFM192A_BREAST',
#    'HCC1419_BREAST',
#    'HGC27_STOMACH',
#    'NCIH446_LUNG',
#    'SNU16_STOMACH',
#    'SW480_LARGE_INTESTINE'}],
#  'COL9A2': [226.24288742619854,
#   {'COLO668_LUNG',
#    'CORL88_LUNG',
#    'HCC33_LUNG',
#    'NCIH1092_LUNG',
#    'NCIH1184_LUNG',
#    'NCIH1963_LUNG',
#    'NCIH520_LUNG',
#    'THP1_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE'}],
#  'BMP8A': [210.9192929414489,
#   {'COLO668_LUNG',
#    'NCIH1184_LUNG',
#    'NCIH1694_LUNG',
#    'NCIH1836_LUNG',
#    'NCIH520_LUNG',
#    'THP1_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE'}],
#  'TTLL10': [192.5990288283006, {'HCC33_LUNG', 'SCLC21H_LUNG'}],
#  'SMAP2': [184.85608323006875,
#   {'COLO668_LUNG',
#    'CORL88_LUNG',
#    'NCIH1184_LUNG',
#    'NCIH1963_LUNG',
#    'NCIH520_LUNG',
#    'THP1_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE'}],
#  'ZFP69': [177.59444151308432,
#   {'COLO668_LUNG',
#    'CORL88_LUNG',
#    'NCIH1184_LUNG',
#    'NCIH1963_LUNG',
#    'THP1_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE'}],
#  'ZFP69B': [177.59444151308432,
#   {'COLO668_LUNG',
#    'CORL88_LUNG',
#    'NCIH1184_LUNG',
#    'NCIH1963_LUNG',
#    'THP1_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE'}],
#  'ZNF684': [177.59444151308432,
#   {'COLO668_LUNG',
#    'CORL88_LUNG',
#    'NCIH1184_LUNG',
#    'NCIH1963_LUNG',
#    'THP1_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE'}],
#  'PPT1': [166.37013462499542,
#   {'CORL88_LUNG',
#    'HCC33_LUNG',
#    'NCIH1092_LUNG',
#    'NCIH1184_LUNG',
#    'NCIH1836_LUNG',
#    'NCIH1963_LUNG',
#    'NCIH520_LUNG',
#    'THP1_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE'}],
#  'NEUROD2': [162.3807033646738,
#   {'BT474_BREAST',
#    'EFM192A_BREAST',
#    'HCC1419_BREAST',
#    'HCC202_BREAST',
#    'KYSE410_OESOPHAGUS',
#    'MFE280_ENDOMETRIUM',
#    'MKN7_STOMACH',
#    'SKOV3_OVARY',
#    'UACC812_BREAST',
#    'UACC893_BREAST'}],
#  'PPP1R1B': [162.3807033646738,
#   {'BT474_BREAST',
#    'EFM192A_BREAST',
#    'HCC1419_BREAST',
#    'HCC202_BREAST',
#    'KYSE410_OESOPHAGUS',
#    'MFE280_ENDOMETRIUM',
#    'MKN7_STOMACH',
#    'SKOV3_OVARY',
#    'UACC812_BREAST',
#    'UACC893_BREAST'}],
#  'STARD3': [162.3807033646738,
#   {'BT474_BREAST',
#    'EFM192A_BREAST',
#    'HCC1419_BREAST',
#    'HCC202_BREAST',
#    'KYSE410_OESOPHAGUS',
#    'MFE280_ENDOMETRIUM',
#    'MKN7_STOMACH',
#    'SKOV3_OVARY',
#    'UACC812_BREAST',
#    'UACC893_BREAST'}],
#  'TMCO2': [143.2380183001556,
#   {'CORL88_LUNG',
#    'HCC33_LUNG',
#    'NCIH1092_LUNG',
#    'NCIH1184_LUNG',
#    'NCIH1963_LUNG',
#    'NCIH520_LUNG',
#    'THP1_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE'}],
#  'ZMPSTE24': [143.2380183001556,
#   {'CORL88_LUNG',
#    'HCC33_LUNG',
#    'NCIH1092_LUNG',
#    'NCIH1184_LUNG',
#    'NCIH1963_LUNG',
#    'NCIH520_LUNG',
#    'THP1_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE'}],
#  'DDX1': [138.015170510484, {'CHP212_AUTONOMIC_GANGLIA', 'NCIH526_LUNG'}],
#  'GACAT3': [138.015170510484, {'CHP212_AUTONOMIC_GANGLIA', 'NCIH526_LUNG'}],
#  'MYCN': [138.015170510484, {'CHP212_AUTONOMIC_GANGLIA', 'NCIH526_LUNG'}],
#  'MYCNOS': [138.015170510484, {'CHP212_AUTONOMIC_GANGLIA', 'NCIH526_LUNG'}],
#  'MYCNUT': [138.015170510484, {'CHP212_AUTONOMIC_GANGLIA', 'NCIH526_LUNG'}],
#  'FAM91A1': [125.36230157615604,
#   {'AU565_BREAST',
#    'CORL279_LUNG',
#    'EFM192A_BREAST',
#    'HCC1419_BREAST',
#    'HGC27_STOMACH'}],
#  'FER1L6': [125.36230157615604,
#   {'AU565_BREAST',
#    'CORL279_LUNG',
#    'EFM192A_BREAST',
#    'HCC1419_BREAST',
#    'HGC27_STOMACH'}],
#  'FER1L6-AS1': [125.36230157615604,
#   {'AU565_BREAST',
#    'CORL279_LUNG',
#    'EFM192A_BREAST',
#    'HCC1419_BREAST',
#    'HGC27_STOMACH'}],
#  'FER1L6-AS2': [125.36230157615604,
#   {'AU565_BREAST',
#    'CORL279_LUNG',
#    'EFM192A_BREAST',
#    'HCC1419_BREAST',
#    'HGC27_STOMACH'}],
#  'NFYC': [122.82687723075341,
#   {'COLO668_LUNG',
#    'NCIH1184_LUNG',
#    'THP1_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE'}],
#  'NFYC-AS1': [122.82687723075341,
#   {'COLO668_LUNG',
#    'NCIH1184_LUNG',
#    'THP1_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE'}],
#  'RIMS3': [122.82687723075341,
#   {'COLO668_LUNG',
#    'NCIH1184_LUNG',
#    'THP1_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE'}],
#  'CDK12': [122.67397438563293,
#   {'BT474_BREAST',
#    'EFM192A_BREAST',
#    'HCC202_BREAST',
#    'MFE280_ENDOMETRIUM',
#    'MKN7_STOMACH',
#    'UACC812_BREAST',
#    'UACC893_BREAST'}],
#  'FBXL20': [122.67397438563293,
#   {'BT474_BREAST',
#    'EFM192A_BREAST',
#    'HCC202_BREAST',
#    'MFE280_ENDOMETRIUM',
#    'MKN7_STOMACH',
#    'UACC812_BREAST',
#    'UACC893_BREAST'}],
#  'MED1': [122.67397438563293,
#   {'BT474_BREAST',
#    'EFM192A_BREAST',
#    'HCC202_BREAST',
#    'MFE280_ENDOMETRIUM',
#    'MKN7_STOMACH',
#    'UACC812_BREAST',
#    'UACC893_BREAST'}],
#  'KIAA0754': [115.2900969496164,
#   {'NCIH1184_LUNG',
#    'NCIH1694_LUNG',
#    'NCIH1836_LUNG',
#    'NCIH510_LUNG',
#    'NCIH520_LUNG'}],
#  'APIP': [112.38103779796118, {'HCC95_LUNG', 'SNU16_STOMACH'}],
#  'CD44': [112.38103779796118, {'HCC95_LUNG', 'SNU16_STOMACH'}],
#  'FJX1': [112.38103779796118, {'HCC95_LUNG', 'SNU16_STOMACH'}],
#  'LDLRAD3': [112.38103779796118, {'HCC95_LUNG', 'SNU16_STOMACH'}],
#  'PAMR1': [112.38103779796118, {'HCC95_LUNG', 'SNU16_STOMACH'}],
#  'PDHX': [112.38103779796118, {'HCC95_LUNG', 'SNU16_STOMACH'}],
#  'SLC1A2': [112.38103779796118, {'HCC95_LUNG', 'SNU16_STOMACH'}],
#  'SNORD164': [112.38103779796118, {'HCC95_LUNG', 'SNU16_STOMACH'}],
#  'TRIM44': [112.38103779796118, {'HCC95_LUNG', 'SNU16_STOMACH'}],
#  'GJA9': [101.48161716606795,
#   {'NCIH1184_LUNG', 'NCIH2122_LUNG', 'NCIH520_LUNG', 'NCIH889_LUNG'}],
#  'GJA9-MYCBP': [101.48161716606795,
#   {'NCIH1184_LUNG', 'NCIH2122_LUNG', 'NCIH520_LUNG', 'NCIH889_LUNG'}],
#  'FGFR2': [101.19051145477715, {'KATOIII_STOMACH', 'SNU16_STOMACH'}],
#  'PLPP4': [101.19051145477715, {'KATOIII_STOMACH', 'SNU16_STOMACH'}],
#  'RPL21': [101.19051145477715, {'KATOIII_STOMACH', 'SNU16_STOMACH'}],
#  'WDR11': [101.19051145477715, {'KATOIII_STOMACH', 'SNU16_STOMACH'}],
#  'WDR11-AS1': [101.19051145477715, {'KATOIII_STOMACH', 'SNU16_STOMACH'}],
#  'MYEOV': [99.11748357749624,
#   {'CAMA1_BREAST',
#    'DMS114_LUNG',
#    'ES2_OVARY',
#    'HCC1954_BREAST',
#    'JHH7_LIVER',
#    'KYSE410_OESOPHAGUS',
#    'MDAMB175VII_BREAST',
#    'MDAMB361_BREAST',
#    'SF295_CENTRAL_NERVOUS_SYSTEM',
#    'SNU475_LIVER'}],
#  'SMIM38': [99.11748357749624,
#   {'CAMA1_BREAST',
#    'DMS114_LUNG',
#    'ES2_OVARY',
#    'HCC1954_BREAST',
#    'JHH7_LIVER',
#    'KYSE410_OESOPHAGUS',
#    'MDAMB175VII_BREAST',
#    'MDAMB361_BREAST',
#    'SF295_CENTRAL_NERVOUS_SYSTEM',
#    'SNU475_LIVER'}],
#  'ANO1': [96.97772308795994,
#   {'CAMA1_BREAST',
#    'DMS114_LUNG',
#    'ES2_OVARY',
#    'JHH7_LIVER',
#    'KYSE410_OESOPHAGUS',
#    'MDAMB134VI_BREAST',
#    'MDAMB175VII_BREAST',
#    'MDAMB361_BREAST',
#    'SNU475_LIVER'}],
#  'CASC1': [95.90981469728438,
#   {'CORL23_LUNG',
#    'DMS53_LUNG',
#    'KE39_STOMACH',
#    'KLE_ENDOMETRIUM',
#    'MKN1_STOMACH'}],
#  'ETFRF1': [95.90981469728438,
#   {'CORL23_LUNG',
#    'DMS53_LUNG',
#    'KE39_STOMACH',
#    'KLE_ENDOMETRIUM',
#    'MKN1_STOMACH'}],
#  'KRAS': [95.90981469728438,
#   {'CORL23_LUNG',
#    'DMS53_LUNG',
#    'KE39_STOMACH',
#    'KLE_ENDOMETRIUM',
#    'MKN1_STOMACH'}],
#  'LMNTD1': [95.90981469728438,
#   {'CORL23_LUNG',
#    'DMS53_LUNG',
#    'KE39_STOMACH',
#    'KLE_ENDOMETRIUM',
#    'MKN1_STOMACH'}],
#  'EXO5': [94.5895723870414,
#   {'CORL88_LUNG',
#    'NCIH1184_LUNG',
#    'NCIH1963_LUNG',
#    'THP1_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE'}],
#  'EGFR': [93.32824189532512,
#   {'HCC827_LUNG', 'KYSE520_OESOPHAGUS', 'NCIH3255_LUNG'}],
#  'EGFR-AS1': [93.32824189532512,
#   {'HCC827_LUNG', 'KYSE520_OESOPHAGUS', 'NCIH3255_LUNG'}],
#  'SEC61G': [93.32824189532512,
#   {'HCC827_LUNG', 'KYSE520_OESOPHAGUS', 'NCIH3255_LUNG'}],
#  'VSTM2A': [93.32824189532512,
#   {'HCC827_LUNG', 'KYSE520_OESOPHAGUS', 'NCIH3255_LUNG'}],
#  'VSTM2A-OT1': [93.32824189532512,
#   {'HCC827_LUNG', 'KYSE520_OESOPHAGUS', 'NCIH3255_LUNG'}],
#  'GSDMA': [91.04020463860257,
#   {'BT474_BREAST',
#    'EFM192A_BREAST',
#    'MFE280_ENDOMETRIUM',
#    'UACC812_BREAST',
#    'UACC893_BREAST'}],
#  'GSDMB': [91.04020463860257,
#   {'BT474_BREAST',
#    'EFM192A_BREAST',
#    'MFE280_ENDOMETRIUM',
#    'UACC812_BREAST',
#    'UACC893_BREAST'}],
#  'LRRC3C': [91.04020463860257,
#   {'BT474_BREAST',
#    'EFM192A_BREAST',
#    'MFE280_ENDOMETRIUM',
#    'UACC812_BREAST',
#    'UACC893_BREAST'}],
#  'ORMDL3': [91.04020463860257,
#   {'BT474_BREAST',
#    'EFM192A_BREAST',
#    'MFE280_ENDOMETRIUM',
#    'UACC812_BREAST',
#    'UACC893_BREAST'}],
#  'PSMD3': [91.04020463860257,
#   {'BT474_BREAST',
#    'EFM192A_BREAST',
#    'MFE280_ENDOMETRIUM',
#    'UACC812_BREAST',
#    'UACC893_BREAST'}],
#  'AKIRIN1': [88.54791793427303,
#   {'NCIH1184_LUNG', 'NCIH520_LUNG', 'NCIH889_LUNG'}],
#  'MYCBP': [88.54791793427303,
#   {'NCIH1184_LUNG', 'NCIH520_LUNG', 'NCIH889_LUNG'}],
#  'NDUFS5': [88.54791793427303,
#   {'NCIH1184_LUNG', 'NCIH520_LUNG', 'NCIH889_LUNG'}],
#  'RHBDL2': [88.54791793427303,
#   {'NCIH1184_LUNG', 'NCIH520_LUNG', 'NCIH889_LUNG'}],
#  'RRAGC': [88.54791793427303,
#   {'NCIH1184_LUNG', 'NCIH520_LUNG', 'NCIH889_LUNG'}],
#  'CCND1': [87.29367616061302,
#   {'CAMA1_BREAST',
#    'DMS114_LUNG',
#    'ES2_OVARY',
#    'JHH7_LIVER',
#    'KYSE410_OESOPHAGUS',
#    'MDAMB175VII_BREAST',
#    'MDAMB361_BREAST',
#    'SF295_CENTRAL_NERVOUS_SYSTEM',
#    'SNU475_LIVER'}],
#  'FGF19': [87.29367616061302,
#   {'CAMA1_BREAST',
#    'DMS114_LUNG',
#    'ES2_OVARY',
#    'JHH7_LIVER',
#    'KYSE410_OESOPHAGUS',
#    'MDAMB175VII_BREAST',
#    'MDAMB361_BREAST',
#    'SF295_CENTRAL_NERVOUS_SYSTEM',
#    'SNU475_LIVER'}],
#  'FGF3': [87.29367616061302,
#   {'CAMA1_BREAST',
#    'DMS114_LUNG',
#    'ES2_OVARY',
#    'JHH7_LIVER',
#    'KYSE410_OESOPHAGUS',
#    'MDAMB175VII_BREAST',
#    'MDAMB361_BREAST',
#    'SF295_CENTRAL_NERVOUS_SYSTEM',
#    'SNU475_LIVER'}],
#  'FGF4': [87.29367616061302,
#   {'CAMA1_BREAST',
#    'DMS114_LUNG',
#    'ES2_OVARY',
#    'JHH7_LIVER',
#    'KYSE410_OESOPHAGUS',
#    'MDAMB175VII_BREAST',
#    'MDAMB361_BREAST',
#    'SF295_CENTRAL_NERVOUS_SYSTEM',
#    'SNU475_LIVER'}],
#  'LTO1': [87.29367616061302,
#   {'CAMA1_BREAST',
#    'DMS114_LUNG',
#    'ES2_OVARY',
#    'JHH7_LIVER',
#    'KYSE410_OESOPHAGUS',
#    'MDAMB175VII_BREAST',
#    'MDAMB361_BREAST',
#    'SF295_CENTRAL_NERVOUS_SYSTEM',
#    'SNU475_LIVER'}],
#  'TPCN2': [87.29367616061302,
#   {'CAMA1_BREAST',
#    'DMS114_LUNG',
#    'ES2_OVARY',
#    'JHH7_LIVER',
#    'KYSE410_OESOPHAGUS',
#    'MDAMB175VII_BREAST',
#    'MDAMB361_BREAST',
#    'SF295_CENTRAL_NERVOUS_SYSTEM',
#    'SNU475_LIVER'}],
#  'RASSF8': [85.90159884178725,
#   {'CORL23_LUNG', 'DMS53_LUNG', 'KLE_ENDOMETRIUM', 'MKN1_STOMACH'}],
#  'RASSF8-AS1': [85.90159884178725,
#   {'CORL23_LUNG', 'DMS53_LUNG', 'KLE_ENDOMETRIUM', 'MKN1_STOMACH'}],
#  'CTTN': [80.34265323499397,
#   {'CAMA1_BREAST',
#    'DMS114_LUNG',
#    'ES2_OVARY',
#    'JHH7_LIVER',
#    'KYSE410_OESOPHAGUS',
#    'MDAMB175VII_BREAST',
#    'MDAMB361_BREAST',
#    'SNU475_LIVER'}],
#  'FADD': [80.34265323499397,
#   {'CAMA1_BREAST',
#    'DMS114_LUNG',
#    'ES2_OVARY',
#    'JHH7_LIVER',
#    'KYSE410_OESOPHAGUS',
#    'MDAMB175VII_BREAST',
#    'MDAMB361_BREAST',
#    'SNU475_LIVER'}],
#  'PPFIA1': [80.34265323499397,
#   {'CAMA1_BREAST',
#    'DMS114_LUNG',
#    'ES2_OVARY',
#    'JHH7_LIVER',
#    'KYSE410_OESOPHAGUS',
#    'MDAMB175VII_BREAST',
#    'MDAMB361_BREAST',
#    'SNU475_LIVER'}],
#  'LPIN1': [77.77440706243738, {'CHP212_AUTONOMIC_GANGLIA'}],
#  'NTSR2': [77.77440706243738, {'CHP212_AUTONOMIC_GANGLIA'}],
#  'TRIB2': [77.77440706243738, {'CHP212_AUTONOMIC_GANGLIA'}],
#  'MRGPRD': [77.45288127959732,
#   {'CAMA1_BREAST',
#    'DMS114_LUNG',
#    'JHH7_LIVER',
#    'KYSE410_OESOPHAGUS',
#    'MDAMB175VII_BREAST',
#    'MDAMB361_BREAST',
#    'SF295_CENTRAL_NERVOUS_SYSTEM',
#    'SNU475_LIVER'}],
#  'MRGPRF': [77.45288127959732,
#   {'CAMA1_BREAST',
#    'DMS114_LUNG',
#    'JHH7_LIVER',
#    'KYSE410_OESOPHAGUS',
#    'MDAMB175VII_BREAST',
#    'MDAMB361_BREAST',
#    'SF295_CENTRAL_NERVOUS_SYSTEM',
#    'SNU475_LIVER'}],
#  'MRGPRF-AS1': [77.45288127959732,
#   {'CAMA1_BREAST',
#    'DMS114_LUNG',
#    'JHH7_LIVER',
#    'KYSE410_OESOPHAGUS',
#    'MDAMB175VII_BREAST',
#    'MDAMB361_BREAST',
#    'SF295_CENTRAL_NERVOUS_SYSTEM',
#    'SNU475_LIVER'}],
#  'ADGRA2': [76.72317049510792,
#   {'BT483_BREAST',
#    'CAL120_BREAST',
#    'CAMA1_BREAST',
#    'DANG_PANCREAS',
#    'DMS114_LUNG',
#    'MDAMB134VI_BREAST',
#    'ZR751_BREAST'}],
#  'ADRB3': [76.72317049510792,
#   {'BT483_BREAST',
#    'CAL120_BREAST',
#    'CAMA1_BREAST',
#    'DANG_PANCREAS',
#    'DMS114_LUNG',
#    'MDAMB134VI_BREAST',
#    'ZR751_BREAST'}],
#  'ASH2L': [76.72317049510792,
#   {'BT483_BREAST',
#    'CAL120_BREAST',
#    'CAMA1_BREAST',
#    'DANG_PANCREAS',
#    'DMS114_LUNG',
#    'MDAMB134VI_BREAST',
#    'ZR751_BREAST'}],
#  'BRF2': [76.72317049510792,
#   {'BT483_BREAST',
#    'CAL120_BREAST',
#    'CAMA1_BREAST',
#    'DANG_PANCREAS',
#    'DMS114_LUNG',
#    'MDAMB134VI_BREAST',
#    'ZR751_BREAST'}],
#  'EIF4EBP1': [76.72317049510792,
#   {'BT483_BREAST',
#    'CAL120_BREAST',
#    'CAMA1_BREAST',
#    'DANG_PANCREAS',
#    'DMS114_LUNG',
#    'MDAMB134VI_BREAST',
#    'ZR751_BREAST'}],
#  'GOT1L1': [76.72317049510792,
#   {'BT483_BREAST',
#    'CAL120_BREAST',
#    'CAMA1_BREAST',
#    'DANG_PANCREAS',
#    'DMS114_LUNG',
#    'MDAMB134VI_BREAST',
#    'ZR751_BREAST'}],
#  'PLPBP': [76.72317049510792,
#   {'BT483_BREAST',
#    'CAL120_BREAST',
#    'CAMA1_BREAST',
#    'DANG_PANCREAS',
#    'DMS114_LUNG',
#    'MDAMB134VI_BREAST',
#    'ZR751_BREAST'}],
#  'RAB11FIP1': [76.72317049510792,
#   {'BT483_BREAST',
#    'CAL120_BREAST',
#    'CAMA1_BREAST',
#    'DANG_PANCREAS',
#    'DMS114_LUNG',
#    'MDAMB134VI_BREAST',
#    'ZR751_BREAST'}],
#  'STAR': [76.72317049510792,
#   {'BT483_BREAST',
#    'CAL120_BREAST',
#    'CAMA1_BREAST',
#    'DANG_PANCREAS',
#    'DMS114_LUNG',
#    'MDAMB134VI_BREAST',
#    'ZR751_BREAST'}],
#  'NDUFB9': [75.84731173018474,
#   {'59M_OVARY',
#    'AU565_BREAST',
#    'EFM192A_BREAST',
#    'HCC1419_BREAST',
#    'HGC27_STOMACH'}],
#  'TATDN1': [75.84731173018474,
#   {'59M_OVARY',
#    'AU565_BREAST',
#    'EFM192A_BREAST',
#    'HCC1419_BREAST',
#    'HGC27_STOMACH'}],
#  'TBC1D31': [74.65552057974547,
#   {'AU565_BREAST',
#    'EFM192A_BREAST',
#    'HCC1419_BREAST',
#    'HGC27_STOMACH',
#    'MKN7_STOMACH'}],
#  'ZDHHC11B': [72.47179515821814,
#   {'CORL279_LUNG',
#    'FU97_STOMACH',
#    'GI1_CENTRAL_NERVOUS_SYSTEM',
#    'HCC1954_BREAST',
#    'NCIH1437_LUNG',
#    'NCIH2066_LUNG',
#    'OSRC2_KIDNEY'}],
#  'MYO18A': [71.35535651672824, {'KYSE410_OESOPHAGUS', 'OE19_OESOPHAGUS'}],
#  'PHF12': [71.35535651672824, {'KYSE410_OESOPHAGUS', 'OE19_OESOPHAGUS'}],
#  'PIPOX': [71.35535651672824, {'KYSE410_OESOPHAGUS', 'OE19_OESOPHAGUS'}],
#  'TIAF1': [71.35535651672824, {'KYSE410_OESOPHAGUS', 'OE19_OESOPHAGUS'}],
#  'CSF3': [70.85557673587563,
#   {'BT474_BREAST', 'MFE280_ENDOMETRIUM', 'UACC812_BREAST', 'UACC893_BREAST'}],
#  'MED24': [70.85557673587563,
#   {'BT474_BREAST', 'MFE280_ENDOMETRIUM', 'UACC812_BREAST', 'UACC893_BREAST'}],
#  'SNORD124': [70.85557673587563,
#   {'BT474_BREAST', 'MFE280_ENDOMETRIUM', 'UACC812_BREAST', 'UACC893_BREAST'}],
#  'THRA': [70.85557673587563,
#   {'BT474_BREAST', 'MFE280_ENDOMETRIUM', 'UACC812_BREAST', 'UACC893_BREAST'}],
#  'CITED4': [70.24066411222267,
#   {'HCC2157_BREAST',
#    'NCIH1184_LUNG',
#    'NCIH1836_LUNG',
#    'THP1_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE'}],
#  'C19orf12': [67.41753444354262,
#   {'FUOV1_OVARY', 'HCC1569_BREAST', 'MKN7_STOMACH'}],
#  'CCNE1': [67.41753444354262,
#   {'FUOV1_OVARY', 'HCC1569_BREAST', 'MKN7_STOMACH'}],
#  'URI1': [67.41753444354262,
#   {'FUOV1_OVARY', 'HCC1569_BREAST', 'MKN7_STOMACH'}],
#  'C12orf77': [66.1794580424441,
#   {'DMS53_LUNG', 'KE39_STOMACH', 'KLE_ENDOMETRIUM', 'MKN1_STOMACH'}],
#  'LRMP': [66.1794580424441,
#   {'DMS53_LUNG', 'KE39_STOMACH', 'KLE_ENDOMETRIUM', 'MKN1_STOMACH'}],
#  'ANXA13': [65.80011113540458,
#   {'AU565_BREAST', 'EFM192A_BREAST', 'HCC1419_BREAST', 'HGC27_STOMACH'}],
#  'ATAD2': [65.80011113540458,
#   {'AU565_BREAST', 'EFM192A_BREAST', 'HCC1419_BREAST', 'HGC27_STOMACH'}],
#  'C8orf76': [65.80011113540458,
#   {'AU565_BREAST', 'EFM192A_BREAST', 'HCC1419_BREAST', 'HGC27_STOMACH'}],
#  'DERL1': [65.80011113540458,
#   {'AU565_BREAST', 'EFM192A_BREAST', 'HCC1419_BREAST', 'HGC27_STOMACH'}],
#  'FAM83A': [65.80011113540458,
#   {'AU565_BREAST', 'EFM192A_BREAST', 'HCC1419_BREAST', 'HGC27_STOMACH'}],
#  'FAM83A-AS1': [65.80011113540458,
#   {'AU565_BREAST', 'EFM192A_BREAST', 'HCC1419_BREAST', 'HGC27_STOMACH'}],
#  'FBXO32': [65.80011113540458,
#   {'AU565_BREAST', 'EFM192A_BREAST', 'HCC1419_BREAST', 'HGC27_STOMACH'}],
#  'KLHL38': [65.80011113540458,
#   {'AU565_BREAST', 'EFM192A_BREAST', 'HCC1419_BREAST', 'HGC27_STOMACH'}],
#  'RNF139': [65.80011113540458,
#   {'AU565_BREAST', 'EFM192A_BREAST', 'HCC1419_BREAST', 'HGC27_STOMACH'}],
#  'RNF139-AS1': [65.80011113540458,
#   {'AU565_BREAST', 'EFM192A_BREAST', 'HCC1419_BREAST', 'HGC27_STOMACH'}],
#  'SMILR': [65.80011113540458,
#   {'AU565_BREAST', 'EFM192A_BREAST', 'HCC1419_BREAST', 'HGC27_STOMACH'}],
#  'TMEM65': [65.80011113540458,
#   {'AU565_BREAST', 'EFM192A_BREAST', 'HCC1419_BREAST', 'HGC27_STOMACH'}],
#  'TRMT12': [65.80011113540458,
#   {'AU565_BREAST', 'EFM192A_BREAST', 'HCC1419_BREAST', 'HGC27_STOMACH'}],
#  'WDYHV1': [65.80011113540458,
#   {'AU565_BREAST', 'EFM192A_BREAST', 'HCC1419_BREAST', 'HGC27_STOMACH'}],
#  'ZHX1': [65.80011113540458,
#   {'AU565_BREAST', 'EFM192A_BREAST', 'HCC1419_BREAST', 'HGC27_STOMACH'}],
#  'ZHX1-C8orf76': [65.80011113540458,
#   {'AU565_BREAST', 'EFM192A_BREAST', 'HCC1419_BREAST', 'HGC27_STOMACH'}],
#  'ZHX2': [65.80011113540458,
#   {'AU565_BREAST', 'EFM192A_BREAST', 'HCC1419_BREAST', 'HGC27_STOMACH'}],
#  'CACNB1': [63.68667584314716,
#   {'BT474_BREAST',
#    'EFM192A_BREAST',
#    'MFE280_ENDOMETRIUM',
#    'MKN7_STOMACH',
#    'UACC812_BREAST'}],
#  'RPL19': [63.68667584314716,
#   {'BT474_BREAST',
#    'EFM192A_BREAST',
#    'MFE280_ENDOMETRIUM',
#    'MKN7_STOMACH',
#    'UACC812_BREAST'}],
#  'STAC2': [63.68667584314716,
#   {'BT474_BREAST',
#    'EFM192A_BREAST',
#    'MFE280_ENDOMETRIUM',
#    'MKN7_STOMACH',
#    'UACC812_BREAST'}],
#  'ZNF217': [63.50296728288886,
#   {'BT474_BREAST', 'EFM192A_BREAST', 'HCC1419_BREAST', 'MCF7_BREAST'}],
#  'MTSS1': [63.28092466160583,
#   {'59M_OVARY', 'EFM192A_BREAST', 'HCC1419_BREAST', 'HGC27_STOMACH'}],
#  'NSMCE2': [63.28092466160583,
#   {'59M_OVARY', 'EFM192A_BREAST', 'HCC1419_BREAST', 'HGC27_STOMACH'}],
#  'SQLE': [63.28092466160583,
#   {'59M_OVARY', 'EFM192A_BREAST', 'HCC1419_BREAST', 'HGC27_STOMACH'}],
#  'TRIB1': [63.28092466160583,
#   {'59M_OVARY', 'EFM192A_BREAST', 'HCC1419_BREAST', 'HGC27_STOMACH'}],
#  'WASHC5': [63.28092466160583,
#   {'59M_OVARY', 'EFM192A_BREAST', 'HCC1419_BREAST', 'HGC27_STOMACH'}],
#  'ZNF572': [63.28092466160583,
#   {'59M_OVARY', 'EFM192A_BREAST', 'HCC1419_BREAST', 'HGC27_STOMACH'}],
#  'KCNQ4': [62.954124429550305,
#   {'NCIH1184_LUNG',
#    'NCIH1836_LUNG',
#    'THP1_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE'}],
#  'CPQ': [62.30715748167915, {'NCIH82_LUNG'}],
#  'CRACR2A': [61.84571369720164,
#   {'CORL23_LUNG', 'DMS53_LUNG', 'NCIH2171_LUNG'}],
#  'PARP11': [61.84571369720164, {'CORL23_LUNG', 'DMS53_LUNG', 'NCIH2171_LUNG'}],
#  'THCAT155': [61.84571369720164,
#   {'CORL23_LUNG', 'DMS53_LUNG', 'NCIH2171_LUNG'}],
#  'TIGAR': [61.84571369720164, {'CORL23_LUNG', 'DMS53_LUNG', 'NCIH2171_LUNG'}],
#  'IGHMBP2': [61.30023021536602,
#   {'CAMA1_BREAST',
#    'DMS114_LUNG',
#    'JHH7_LIVER',
#    'MDAMB175VII_BREAST',
#    'SF295_CENTRAL_NERVOUS_SYSTEM',
#    'SNU475_LIVER'}],
#  'MRPL21': [61.30023021536602,
#   {'CAMA1_BREAST',
#    'DMS114_LUNG',
#    'JHH7_LIVER',
#    'MDAMB175VII_BREAST',
#    'SF295_CENTRAL_NERVOUS_SYSTEM',
#    'SNU475_LIVER'}],
#  'ERLIN2': [60.86639797205392,
#   {'BT483_BREAST',
#    'CAL120_BREAST',
#    'CAMA1_BREAST',
#    'DANG_PANCREAS',
#    'MDAMB134VI_BREAST',
#    'ZR751_BREAST'}],
#  'ZNF703': [60.86639797205392,
#   {'BT483_BREAST',
#    'CAL120_BREAST',
#    'CAMA1_BREAST',
#    'DANG_PANCREAS',
#    'MDAMB134VI_BREAST',
#    'ZR751_BREAST'}],
#  'BAG4': [60.81051514711103,
#   {'CAL120_BREAST',
#    'CAMA1_BREAST',
#    'DANG_PANCREAS',
#    'DMS114_LUNG',
#    'MDAMB134VI_BREAST',
#    'ZR751_BREAST'}],
#  'C8orf86': [60.81051514711103,
#   {'CAL120_BREAST',
#    'CAMA1_BREAST',
#    'DANG_PANCREAS',
#    'DMS114_LUNG',
#    'MDAMB134VI_BREAST',
#    'ZR751_BREAST'}],
#  'DDHD2': [60.81051514711103,
#   {'CAL120_BREAST',
#    'CAMA1_BREAST',
#    'DANG_PANCREAS',
#    'DMS114_LUNG',
#    'MDAMB134VI_BREAST',
#    'ZR751_BREAST'}],
#  'FGFR1': [60.81051514711103,
#   {'CAL120_BREAST',
#    'CAMA1_BREAST',
#    'DANG_PANCREAS',
#    'DMS114_LUNG',
#    'MDAMB134VI_BREAST',
#    'ZR751_BREAST'}],
#  'LETM2': [60.81051514711103,
#   {'CAL120_BREAST',
#    'CAMA1_BREAST',
#    'DANG_PANCREAS',
#    'DMS114_LUNG',
#    'MDAMB134VI_BREAST',
#    'ZR751_BREAST'}],
#  'LSM1': [60.81051514711103,
#   {'CAL120_BREAST',
#    'CAMA1_BREAST',
#    'DANG_PANCREAS',
#    'DMS114_LUNG',
#    'MDAMB134VI_BREAST',
#    'ZR751_BREAST'}],
#  'NSD3': [60.81051514711103,
#   {'CAL120_BREAST',
#    'CAMA1_BREAST',
#    'DANG_PANCREAS',
#    'DMS114_LUNG',
#    'MDAMB134VI_BREAST',
#    'ZR751_BREAST'}],
#  'PLPP5': [60.81051514711103,
#   {'CAL120_BREAST',
#    'CAMA1_BREAST',
#    'DANG_PANCREAS',
#    'DMS114_LUNG',
#    'MDAMB134VI_BREAST',
#    'ZR751_BREAST'}],
#  'NBAS': [60.24076344804664, {'NCIH526_LUNG'}],
#  'CASC3': [60.149234554534125,
#   {'MFE280_ENDOMETRIUM', 'UACC812_BREAST', 'UACC893_BREAST'}],
#  'MSL1': [60.149234554534125,
#   {'MFE280_ENDOMETRIUM', 'UACC812_BREAST', 'UACC893_BREAST'}],
#  'NR1D1': [60.149234554534125,
#   {'MFE280_ENDOMETRIUM', 'UACC812_BREAST', 'UACC893_BREAST'}],
#  'TPPP': [59.5981379335867,
#   {'FU97_STOMACH',
#    'GI1_CENTRAL_NERVOUS_SYSTEM',
#    'HCC1954_BREAST',
#    'NCIH1437_LUNG',
#    'NCIH2066_LUNG',
#    'OSRC2_KIDNEY'}],
#  'AAMDC': [59.23843333338151,
#   {'MDAMB134VI_BREAST', 'MDAMB175VII_BREAST', 'NCIH1435_LUNG'}],
#  'ACER3': [59.23843333338151,
#   {'MDAMB134VI_BREAST', 'MDAMB175VII_BREAST', 'NCIH1435_LUNG'}],
#  'ALG8': [59.23843333338151,
#   {'MDAMB134VI_BREAST', 'MDAMB175VII_BREAST', 'NCIH1435_LUNG'}],
#  'AQP11': [59.23843333338151,
#   {'MDAMB134VI_BREAST', 'MDAMB175VII_BREAST', 'NCIH1435_LUNG'}],
#  'CLNS1A': [59.23843333338151,
#   {'MDAMB134VI_BREAST', 'MDAMB175VII_BREAST', 'NCIH1435_LUNG'}],
#  'GUCY2EP': [59.23843333338151,
#   {'MDAMB134VI_BREAST', 'MDAMB175VII_BREAST', 'NCIH1435_LUNG'}],
#  'INTS4': [59.23843333338151,
#   {'MDAMB134VI_BREAST', 'MDAMB175VII_BREAST', 'NCIH1435_LUNG'}],
#  'KCTD14': [59.23843333338151,
#   {'MDAMB134VI_BREAST', 'MDAMB175VII_BREAST', 'NCIH1435_LUNG'}],
#  'KCTD21-AS1': [59.23843333338151,
#   {'MDAMB134VI_BREAST', 'MDAMB175VII_BREAST', 'NCIH1435_LUNG'}],
#  'NDUFC2': [59.23843333338151,
#   {'MDAMB134VI_BREAST', 'MDAMB175VII_BREAST', 'NCIH1435_LUNG'}],
#  'NDUFC2-KCTD14': [59.23843333338151,
#   {'MDAMB134VI_BREAST', 'MDAMB175VII_BREAST', 'NCIH1435_LUNG'}],
#  'PAK1': [59.23843333338151,
#   {'MDAMB134VI_BREAST', 'MDAMB175VII_BREAST', 'NCIH1435_LUNG'}],
#  'RSF1': [59.23843333338151,
#   {'MDAMB134VI_BREAST', 'MDAMB175VII_BREAST', 'NCIH1435_LUNG'}],
#  'THRSP': [59.23843333338151,
#   {'MDAMB134VI_BREAST', 'MDAMB175VII_BREAST', 'NCIH1435_LUNG'}],
#  'TSKU': [59.23843333338151,
#   {'MDAMB134VI_BREAST', 'MDAMB175VII_BREAST', 'NCIH1435_LUNG'}],
#  'ZNF704': [57.771649316699964,
#   {'AU565_BREAST',
#    'EFM192A_BREAST',
#    'HCC1419_BREAST',
#    'HCC38_BREAST',
#    'HCC827_LUNG'}],
#  'AKT3': [57.69865766887127, {'NCIH1694_LUNG'}],
#  'C1orf198': [57.69865766887127, {'NCIH1694_LUNG'}],
#  'CD84': [57.69865766887127, {'NCIH1694_LUNG'}],
#  'COPA': [57.69865766887127, {'NCIH1694_LUNG'}],
#  'DISC1': [57.69865766887127, {'NCIH1694_LUNG'}],
#  'NCSTN': [57.69865766887127, {'NCIH1694_LUNG'}],
#  'SLAMF6': [57.69865766887127, {'NCIH1694_LUNG'}],
#  'SNRPD2P2': [57.69865766887127, {'NCIH1694_LUNG'}],
#  'SUMO1P3': [57.69865766887127, {'NCIH1694_LUNG'}],
#  'PLEKHF1': [57.18140508675333, {'FUOV1_OVARY', 'HCC1569_BREAST'}],
#  'POP4': [57.18140508675333, {'FUOV1_OVARY', 'HCC1569_BREAST'}],
#  'VSTM2B': [57.18140508675333, {'FUOV1_OVARY', 'HCC1569_BREAST'}],
#  'ATP5MC1': [57.03053477531178,
#   {'BT474_BREAST', 'EFM192A_BREAST', 'HCC1419_BREAST', 'HCC202_BREAST'}],
#  'CALCOCO2': [57.03053477531178,
#   {'BT474_BREAST', 'EFM192A_BREAST', 'HCC1419_BREAST', 'HCC202_BREAST'}],
#  'HOXB13': [57.03053477531178,
#   {'BT474_BREAST', 'EFM192A_BREAST', 'HCC1419_BREAST', 'HCC202_BREAST'}],
#  'PRAC1': [57.03053477531178,
#   {'BT474_BREAST', 'EFM192A_BREAST', 'HCC1419_BREAST', 'HCC202_BREAST'}],
#  'PRAC2': [57.03053477531178,
#   {'BT474_BREAST', 'EFM192A_BREAST', 'HCC1419_BREAST', 'HCC202_BREAST'}],
#  'TTLL6': [57.03053477531178,
#   {'BT474_BREAST', 'EFM192A_BREAST', 'HCC1419_BREAST', 'HCC202_BREAST'}],
#  'UBE2Z': [57.03053477531178,
#   {'BT474_BREAST', 'EFM192A_BREAST', 'HCC1419_BREAST', 'HCC202_BREAST'}],
#  'BCAT1': [56.17124218694697,
#   {'DMS53_LUNG', 'KLE_ENDOMETRIUM', 'MKN1_STOMACH'}],
#  'RNF5P1': [55.39404764303252,
#   {'CAL120_BREAST',
#    'CAMA1_BREAST',
#    'DANG_PANCREAS',
#    'DMS114_LUNG',
#    'MDAMB134VI_BREAST'}],
#  'CCDC26': [55.03385079983209,
#   {'EFM192A_BREAST', 'HCC1419_BREAST', 'NCIH23_LUNG', 'NCIH460_LUNG'}],
#  'POM121L12': [54.94768878469801,
#   {'KYSE30_OESOPHAGUS', 'KYSE520_OESOPHAGUS', 'NCIH3255_LUNG'}],
#  'SAMD12': [54.8339565120553,
#   {'AU565_BREAST', 'EFM192A_BREAST', 'HCC1419_BREAST', 'HCC1954_BREAST'}],
#  'SAMD12-AS1': [54.8339565120553,
#   {'AU565_BREAST', 'EFM192A_BREAST', 'HCC1419_BREAST', 'HCC1954_BREAST'}],
#  'CSMD3': [54.54093899211058,
#   {'AU565_BREAST', 'EFM192A_BREAST', 'HGC27_STOMACH'}],
#  'TRPS1': [54.54093899211058,
#   {'AU565_BREAST', 'EFM192A_BREAST', 'HGC27_STOMACH'}],
#  'CPT1A': [54.349207289746985,
#   {'CAMA1_BREAST',
#    'DMS114_LUNG',
#    'JHH7_LIVER',
#    'MDAMB175VII_BREAST',
#    'SNU475_LIVER'}],
#  'GAL': [54.349207289746985,
#   {'CAMA1_BREAST',
#    'DMS114_LUNG',
#    'JHH7_LIVER',
#    'MDAMB175VII_BREAST',
#    'SNU475_LIVER'}],
#  'TESMIN': [54.349207289746985,
#   {'CAMA1_BREAST',
#    'DMS114_LUNG',
#    'JHH7_LIVER',
#    'MDAMB175VII_BREAST',
#    'SNU475_LIVER'}],
#  'BCAS4': [54.2961315591251,
#   {'BT474_BREAST', 'HCC1419_BREAST', 'MCF7_BREAST'}],
#  'PARD6B': [54.2961315591251,
#   {'BT474_BREAST', 'HCC1419_BREAST', 'MCF7_BREAST'}],
#  'MTDH': [53.42840570769673,
#   {'EFM192A_BREAST', 'HCC1419_BREAST', 'NCIH446_LUNG'}],
#  'FGF23': [52.62909996677239, {'CORL23_LUNG', 'DMS53_LUNG'}],
#  'PRMT8': [52.62909996677239, {'CORL23_LUNG', 'DMS53_LUNG'}],
#  'BCAS1': [52.243795139594866,
#   {'BT474_BREAST', 'EFM192A_BREAST', 'MCF7_BREAST'}],
#  'CYP24A1': [52.243795139594866,
#   {'BT474_BREAST', 'EFM192A_BREAST', 'MCF7_BREAST'}],
#  'DOK5': [52.243795139594866,
#   {'BT474_BREAST', 'EFM192A_BREAST', 'MCF7_BREAST'}],
#  'PFDN4': [52.243795139594866,
#   {'BT474_BREAST', 'EFM192A_BREAST', 'MCF7_BREAST'}],
#  'SUMO1P1': [52.243795139594866,
#   {'BT474_BREAST', 'EFM192A_BREAST', 'MCF7_BREAST'}],
#  'EIF1': [51.660732571714256, {'OE19_OESOPHAGUS'}],
#  'FKBP10': [51.660732571714256, {'OE19_OESOPHAGUS'}],
#  'GAST': [51.660732571714256, {'OE19_OESOPHAGUS'}],
#  'HAP1': [51.660732571714256, {'OE19_OESOPHAGUS'}],
#  'JUP': [51.660732571714256, {'OE19_OESOPHAGUS'}],
#  'KRT16': [51.660732571714256, {'OE19_OESOPHAGUS'}],
#  'KRT17': [51.660732571714256, {'OE19_OESOPHAGUS'}],
#  'KRT42P': [51.660732571714256, {'OE19_OESOPHAGUS'}],
#  'P3H4': [51.660732571714256, {'OE19_OESOPHAGUS'}],
#  'CASKIN2': [51.40323493716079, {'FUOV1_OVARY', 'UACC893_BREAST'}],
#  'LLGL2': [51.40323493716079, {'FUOV1_OVARY', 'UACC893_BREAST'}],
#  'MYO15B': [51.40323493716079, {'FUOV1_OVARY', 'UACC893_BREAST'}],
#  'RECQL5': [51.40323493716079, {'FUOV1_OVARY', 'UACC893_BREAST'}],
#  'SAP30BP': [51.40323493716079, {'FUOV1_OVARY', 'UACC893_BREAST'}],
#  'SMIM5': [51.40323493716079, {'FUOV1_OVARY', 'UACC893_BREAST'}],
#  'SMIM6': [51.40323493716079, {'FUOV1_OVARY', 'UACC893_BREAST'}],
#  'TSEN54': [51.40323493716079, {'FUOV1_OVARY', 'UACC893_BREAST'}],
#  'BMP7': [51.0644961274598, {'BT474_BREAST', 'MCF7_BREAST', 'UACC893_BREAST'}],
#  'BMP7-AS1': [51.0644961274598,
#   {'BT474_BREAST', 'MCF7_BREAST', 'UACC893_BREAST'}],
#  'PPP6R3': [48.48202418590656,
#   {'DMS114_LUNG', 'JHH7_LIVER', 'MDAMB175VII_BREAST', 'SNU475_LIVER'}],
#  'GBAT2': [47.09894918422762,
#   {'DMS273_LUNG',
#    'KARPAS299_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE',
#    'MFE280_ENDOMETRIUM'}],
#  'PI4KB': [47.09894918422762,
#   {'DMS273_LUNG',
#    'KARPAS299_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE',
#    'MFE280_ENDOMETRIUM'}],
#  'PSMB4': [47.09894918422762,
#   {'DMS273_LUNG',
#    'KARPAS299_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE',
#    'MFE280_ENDOMETRIUM'}],
#  'PSMD4': [47.09894918422762,
#   {'DMS273_LUNG',
#    'KARPAS299_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE',
#    'MFE280_ENDOMETRIUM'}],
#  'RFX5': [47.09894918422762,
#   {'DMS273_LUNG',
#    'KARPAS299_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE',
#    'MFE280_ENDOMETRIUM'}],
#  'SELENBP1': [47.09894918422762,
#   {'DMS273_LUNG',
#    'KARPAS299_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE',
#    'MFE280_ENDOMETRIUM'}],
#  'ZNF687': [47.09894918422762,
#   {'DMS273_LUNG',
#    'KARPAS299_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE',
#    'MFE280_ENDOMETRIUM'}],
#  'ZNF687-AS1': [47.09894918422762,
#   {'DMS273_LUNG',
#    'KARPAS299_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE',
#    'MFE280_ENDOMETRIUM'}],
#  'ARL5C': [46.93329864406614,
#   {'BT474_BREAST', 'EFM192A_BREAST', 'MFE280_ENDOMETRIUM', 'UACC812_BREAST'}],
#  'FBXO47': [46.93329864406614,
#   {'BT474_BREAST', 'EFM192A_BREAST', 'MFE280_ENDOMETRIUM', 'UACC812_BREAST'}],
#  'LRRC37A11P': [46.93329864406614,
#   {'BT474_BREAST', 'EFM192A_BREAST', 'MFE280_ENDOMETRIUM', 'UACC812_BREAST'}],
#  'PLXDC1': [46.93329864406614,
#   {'BT474_BREAST', 'EFM192A_BREAST', 'MFE280_ENDOMETRIUM', 'UACC812_BREAST'}],
#  'RDM1P5': [46.93329864406614,
#   {'BT474_BREAST', 'EFM192A_BREAST', 'MFE280_ENDOMETRIUM', 'UACC812_BREAST'}],
#  'ZBTB10': [46.51247717340597,
#   {'AU565_BREAST', 'EFM192A_BREAST', 'HCC38_BREAST', 'HCC827_LUNG'}],
#  'C1orf109': [45.82341297676038,
#   {'NCIH1184_LUNG', 'NCIH1836_LUNG', 'NCIH2122_LUNG'}],
#  'CDCA8': [45.82341297676038,
#   {'NCIH1184_LUNG', 'NCIH1836_LUNG', 'NCIH2122_LUNG'}],
#  'HOXB6': [45.771362632017784,
#   {'BT474_BREAST', 'EFM192A_BREAST', 'HCC202_BREAST'}],
#  'HOXB7': [45.771362632017784,
#   {'BT474_BREAST', 'EFM192A_BREAST', 'HCC202_BREAST'}],
#  'HOXB8': [45.771362632017784,
#   {'BT474_BREAST', 'EFM192A_BREAST', 'HCC202_BREAST'}],
#  'HOXB9': [45.771362632017784,
#   {'BT474_BREAST', 'EFM192A_BREAST', 'HCC202_BREAST'}],
#  'GAB2': [43.15024481271552, {'MDAMB175VII_BREAST', 'NCIH1435_LUNG'}],
#  'KCTD21': [43.15024481271552, {'MDAMB175VII_BREAST', 'NCIH1435_LUNG'}],
#  'NARS2': [43.15024481271552, {'MDAMB175VII_BREAST', 'NCIH1435_LUNG'}],
#  'TENM4': [43.15024481271552, {'MDAMB175VII_BREAST', 'NCIH1435_LUNG'}],
#  'USP35': [43.15024481271552, {'MDAMB175VII_BREAST', 'NCIH1435_LUNG'}],
#  'ATG5': [43.08999175559137, {'CORL311_LUNG'}],
#  'BEND3': [43.08999175559137, {'CORL311_LUNG'}],
#  'CD24': [43.08999175559137, {'CORL311_LUNG'}],
#  'CRYBG1': [43.08999175559137, {'CORL311_LUNG'}],
#  'MTRES1': [43.08999175559137, {'CORL311_LUNG'}],
#  'MYMX': [43.08999175559137, {'CORL311_LUNG'}],
#  'PDSS2': [43.08999175559137, {'CORL311_LUNG'}],
#  'PRDM1': [43.08999175559137, {'CORL311_LUNG'}],
#  'PREP': [43.08999175559137, {'CORL311_LUNG'}],
#  'QRSL1': [43.08999175559137, {'CORL311_LUNG'}],
#  'RTN4IP1': [43.08999175559137, {'CORL311_LUNG'}],
#  'SLC29A1': [43.08999175559137, {'CORL311_LUNG'}],
#  'SOBP': [43.08999175559137, {'CORL311_LUNG'}],
#  'CALB1': [43.01014909517207,
#   {'AU565_BREAST', 'EFM192A_BREAST', 'HCC1419_BREAST'}],
#  'CCN3': [43.01014909517207,
#   {'AU565_BREAST', 'EFM192A_BREAST', 'HCC1419_BREAST'}],
#  'COL14A1': [43.01014909517207,
#   {'AU565_BREAST', 'EFM192A_BREAST', 'HCC1419_BREAST'}],
#  'COLEC10': [43.01014909517207,
#   {'AU565_BREAST', 'EFM192A_BREAST', 'HCC1419_BREAST'}],
#  'DECR1': [43.01014909517207,
#   {'AU565_BREAST', 'EFM192A_BREAST', 'HCC1419_BREAST'}],
#  'DEPTOR': [43.01014909517207,
#   {'AU565_BREAST', 'EFM192A_BREAST', 'HCC1419_BREAST'}],
#  'DSCC1': [43.01014909517207,
#   {'AU565_BREAST', 'EFM192A_BREAST', 'HCC1419_BREAST'}],
#  'ENPP2': [43.01014909517207,
#   {'AU565_BREAST', 'EFM192A_BREAST', 'HCC1419_BREAST'}],
#  'HAS2': [43.01014909517207,
#   {'AU565_BREAST', 'EFM192A_BREAST', 'HCC1419_BREAST'}],
#  'HAS2-AS1': [43.01014909517207,
#   {'AU565_BREAST', 'EFM192A_BREAST', 'HCC1419_BREAST'}],
#  'MAL2': [43.01014909517207,
#   {'AU565_BREAST', 'EFM192A_BREAST', 'HCC1419_BREAST'}],
#  'MAL2-AS1': [43.01014909517207,
#   {'AU565_BREAST', 'EFM192A_BREAST', 'HCC1419_BREAST'}],
#  'MRPL13': [43.01014909517207,
#   {'AU565_BREAST', 'EFM192A_BREAST', 'HCC1419_BREAST'}],
#  'MTBP': [43.01014909517207,
#   {'AU565_BREAST', 'EFM192A_BREAST', 'HCC1419_BREAST'}],
#  'NBN': [43.01014909517207,
#   {'AU565_BREAST', 'EFM192A_BREAST', 'HCC1419_BREAST'}],
#  'SNTB1': [43.01014909517207,
#   {'AU565_BREAST', 'EFM192A_BREAST', 'HCC1419_BREAST'}],
#  'TAF2': [43.01014909517207,
#   {'AU565_BREAST', 'EFM192A_BREAST', 'HCC1419_BREAST'}],
#  'TNFRSF11B': [43.01014909517207,
#   {'AU565_BREAST', 'EFM192A_BREAST', 'HCC1419_BREAST'}],
#  'EXT1': [42.26756944347639,
#   {'EFM192A_BREAST', 'HCC1419_BREAST', 'HCC1954_BREAST'}],
#  'SNORD168': [42.26756944347639,
#   {'EFM192A_BREAST', 'HCC1419_BREAST', 'HCC1954_BREAST'}],
#  'B4GALNT2': [42.15014222736244,
#   {'BT474_BREAST', 'EFM192A_BREAST', 'HCC1419_BREAST'}],
#  'GIP': [42.15014222736244,
#   {'BT474_BREAST', 'EFM192A_BREAST', 'HCC1419_BREAST'}],
#  'IGF2BP1': [42.15014222736244,
#   {'BT474_BREAST', 'EFM192A_BREAST', 'HCC1419_BREAST'}],
#  'SNF8': [42.15014222736244,
#   {'BT474_BREAST', 'EFM192A_BREAST', 'HCC1419_BREAST'}],
#  'UNC5D': [41.766671375299154,
#   {'DANG_PANCREAS', 'DMS114_LUNG', 'MDAMB134VI_BREAST'}],
#  'NPEPL1': [41.46452909199591,
#   {'BT474_BREAST', 'HCC1419_BREAST', 'HCC1954_BREAST', 'UACC893_BREAST'}],
#  'STX16': [41.46452909199591,
#   {'BT474_BREAST', 'HCC1419_BREAST', 'HCC1954_BREAST', 'UACC893_BREAST'}],
#  'STX16-NPEPL1': [41.46452909199591,
#   {'BT474_BREAST', 'HCC1419_BREAST', 'HCC1954_BREAST', 'UACC893_BREAST'}],
#  'LY6H': [41.41411716212886, {'NCIH446_LUNG'}],
#  'C17orf98': [40.508975895366675,
#   {'BT474_BREAST', 'EFM192A_BREAST', 'UACC812_BREAST'}],
#  'CISD3': [40.508975895366675,
#   {'BT474_BREAST', 'EFM192A_BREAST', 'UACC812_BREAST'}],
#  'CWC25': [40.508975895366675,
#   {'BT474_BREAST', 'EFM192A_BREAST', 'UACC812_BREAST'}],
#  'LASP1': [40.508975895366675,
#   {'BT474_BREAST', 'EFM192A_BREAST', 'UACC812_BREAST'}],
#  'PCGF2': [40.508975895366675,
#   {'BT474_BREAST', 'EFM192A_BREAST', 'UACC812_BREAST'}],
#  'PIP4K2B': [40.508975895366675,
#   {'BT474_BREAST', 'EFM192A_BREAST', 'UACC812_BREAST'}],
#  'PSMB3': [40.508975895366675,
#   {'BT474_BREAST', 'EFM192A_BREAST', 'UACC812_BREAST'}],
#  'RPL23': [40.508975895366675,
#   {'BT474_BREAST', 'EFM192A_BREAST', 'UACC812_BREAST'}],
#  'SNORA21': [40.508975895366675,
#   {'BT474_BREAST', 'EFM192A_BREAST', 'UACC812_BREAST'}],
#  'SNORA21B': [40.508975895366675,
#   {'BT474_BREAST', 'EFM192A_BREAST', 'UACC812_BREAST'}],
#  'LPCAT1': [40.22170609612108,
#   {'GI1_CENTRAL_NERVOUS_SYSTEM',
#    'HCC1954_BREAST',
#    'NCIH1437_LUNG',
#    'NCIH650_LUNG'}],
#  'SLC6A3': [40.22170609612108,
#   {'GI1_CENTRAL_NERVOUS_SYSTEM',
#    'HCC1954_BREAST',
#    'NCIH1437_LUNG',
#    'NCIH650_LUNG'}],
#  'CTPS1': [40.17625342763783,
#   {'HCC2157_BREAST', 'NCIH1184_LUNG', 'NCIH1836_LUNG'}],
#  'SLFNL1-AS1': [40.17625342763783,
#   {'HCC2157_BREAST', 'NCIH1184_LUNG', 'NCIH1836_LUNG'}],
#  'COBL': [39.592179829055226, {'KYSE520_OESOPHAGUS', 'NCIH3255_LUNG'}],
#  'ELDR': [39.592179829055226, {'KYSE520_OESOPHAGUS', 'NCIH3255_LUNG'}],
#  'LANCL2': [39.592179829055226, {'KYSE520_OESOPHAGUS', 'NCIH3255_LUNG'}],
#  'FABP5': [39.24897531006681,
#   {'EFM192A_BREAST', 'HCC1419_BREAST', 'HCC827_LUNG'}],
#  'PAG1': [39.24897531006681,
#   {'EFM192A_BREAST', 'HCC1419_BREAST', 'HCC827_LUNG'}],
#  'PMP2': [39.24897531006681,
#   {'EFM192A_BREAST', 'HCC1419_BREAST', 'HCC827_LUNG'}],
#  'TACC1': [38.75897779006655,
#   {'CAL120_BREAST', 'CAMA1_BREAST', 'DANG_PANCREAS', 'DMS114_LUNG'}],
#  'RTEL1': [38.68504714157082, {'HCC1419_BREAST', 'MCF7_BREAST'}],
#  'RTEL1-TNFRSF6B': [38.68504714157082, {'HCC1419_BREAST', 'MCF7_BREAST'}],
#  'CASC15': [38.67681422114484, {'5637_URINARY_TRACT', 'HT1376_URINARY_TRACT'}],
#  'CDKAL1': [38.67681422114484, {'5637_URINARY_TRACT', 'HT1376_URINARY_TRACT'}],
#  'E2F3': [38.67681422114484, {'5637_URINARY_TRACT', 'HT1376_URINARY_TRACT'}],
#  'HDGFL1': [38.67681422114484, {'5637_URINARY_TRACT', 'HT1376_URINARY_TRACT'}],
#  'NBAT1': [38.67681422114484, {'5637_URINARY_TRACT', 'HT1376_URINARY_TRACT'}],
#  'PRL': [38.67681422114484, {'5637_URINARY_TRACT', 'HT1376_URINARY_TRACT'}],
#  'SOX4': [38.67681422114484, {'5637_URINARY_TRACT', 'HT1376_URINARY_TRACT'}],
#  'APPBP2': [38.13221717961833, {'BT474_BREAST', 'MCF7_BREAST'}],
#  'BCAS3': [38.13221717961833, {'BT474_BREAST', 'MCF7_BREAST'}],
#  'C17orf64': [38.13221717961833, {'BT474_BREAST', 'MCF7_BREAST'}],
#  'CA4': [38.13221717961833, {'BT474_BREAST', 'MCF7_BREAST'}],
#  'HEATR6': [38.13221717961833, {'BT474_BREAST', 'MCF7_BREAST'}],
#  'PPM1D': [38.13221717961833, {'BT474_BREAST', 'MCF7_BREAST'}],
#  'PPM1E': [38.13221717961833, {'BT474_BREAST', 'MCF7_BREAST'}],
#  'RAD51C': [38.13221717961833, {'BT474_BREAST', 'MCF7_BREAST'}],
#  'RNFT1': [38.13221717961833, {'BT474_BREAST', 'MCF7_BREAST'}],
#  'RNFT1-DT': [38.13221717961833, {'BT474_BREAST', 'MCF7_BREAST'}],
#  'RPS6KB1': [38.13221717961833, {'BT474_BREAST', 'MCF7_BREAST'}],
#  'SCARNA20': [38.13221717961833, {'BT474_BREAST', 'MCF7_BREAST'}],
#  'TBC1D3P1-DHX40P1': [38.13221717961833, {'BT474_BREAST', 'MCF7_BREAST'}],
#  'TEX14': [38.13221717961833, {'BT474_BREAST', 'MCF7_BREAST'}],
#  'TRIM37': [38.13221717961833, {'BT474_BREAST', 'MCF7_BREAST'}],
# ...
#  'ALDH3B2': [24.059387332557584, {'DMS114_LUNG', 'SNU475_LIVER'}],
#  'C11orf24': [24.059387332557584, {'DMS114_LUNG', 'SNU475_LIVER'}],
#  'CHKA': [24.059387332557584, {'DMS114_LUNG', 'SNU475_LIVER'}],
#  'FAM86C2P': [24.059387332557584, {'DMS114_LUNG', 'SNU475_LIVER'}],
#  'KMT5B': [24.059387332557584, {'DMS114_LUNG', 'SNU475_LIVER'}],
#  'LRP5': [24.059387332557584, {'DMS114_LUNG', 'SNU475_LIVER'}],
#  'NDUFS8': [24.059387332557584, {'DMS114_LUNG', 'SNU475_LIVER'}],
#  'TCIRG1': [24.059387332557584, {'DMS114_LUNG', 'SNU475_LIVER'}],
#  'UNC93B1': [24.059387332557584, {'DMS114_LUNG', 'SNU475_LIVER'}],
#  'THRA1/BTR': [23.921001686917982, {'BT474_BREAST', 'NCIH510_LUNG'}],
#  'OSGIN2': [23.825559211872907, {'AU565_BREAST', 'HCC1419_BREAST'}],
#  'RIPK2': [23.825559211872907, {'AU565_BREAST', 'HCC1419_BREAST'}],
#  'AURKA': [23.63862112918298, {'BT474_BREAST', 'UACC893_BREAST'}],
#  'C20orf85': [23.63862112918298, {'BT474_BREAST', 'UACC893_BREAST'}],
#  'CASS4': [23.63862112918298, {'BT474_BREAST', 'UACC893_BREAST'}],
#  'CBLN4': [23.63862112918298, {'BT474_BREAST', 'UACC893_BREAST'}],
#  'CSTF1': [23.63862112918298, {'BT474_BREAST', 'UACC893_BREAST'}],
#  'CTCFL': [23.63862112918298, {'BT474_BREAST', 'UACC893_BREAST'}],
#  'FAM209A': [23.63862112918298, {'BT474_BREAST', 'UACC893_BREAST'}],
#  'FAM209B': [23.63862112918298, {'BT474_BREAST', 'UACC893_BREAST'}],
#  'FAM210B': [23.63862112918298, {'BT474_BREAST', 'UACC893_BREAST'}],
#  'GCNT7': [23.63862112918298, {'BT474_BREAST', 'UACC893_BREAST'}],
#  'MC3R': [23.63862112918298, {'BT474_BREAST', 'UACC893_BREAST'}],
#  'MTRNR2L3': [23.63862112918298, {'BT474_BREAST', 'UACC893_BREAST'}],
#  'NKILA': [23.63862112918298, {'BT474_BREAST', 'UACC893_BREAST'}],
#  'PCK1': [23.63862112918298, {'BT474_BREAST', 'UACC893_BREAST'}],
#  'PMEPA1': [23.63862112918298, {'BT474_BREAST', 'UACC893_BREAST'}],
#  'RAE1': [23.63862112918298, {'BT474_BREAST', 'UACC893_BREAST'}],
#  'RBM38': [23.63862112918298, {'BT474_BREAST', 'UACC893_BREAST'}],
#  'RTF2': [23.63862112918298, {'BT474_BREAST', 'UACC893_BREAST'}],
#  'SPO11': [23.63862112918298, {'BT474_BREAST', 'UACC893_BREAST'}],
#  'TFAP2C': [23.63862112918298, {'BT474_BREAST', 'UACC893_BREAST'}],
#  'ZBP1': [23.63862112918298, {'BT474_BREAST', 'UACC893_BREAST'}],
#  'ADAM2': [23.070084354646973, {'CAL120_BREAST', 'DMS114_LUNG'}],
#  'ADAM5': [23.070084354646973, {'CAL120_BREAST', 'DMS114_LUNG'}],
#  'IDO1': [23.070084354646973, {'CAL120_BREAST', 'DMS114_LUNG'}],
#  'IDO2': [23.070084354646973, {'CAL120_BREAST', 'DMS114_LUNG'}],
#  'SIRLNT': [23.070084354646973, {'CAL120_BREAST', 'DMS114_LUNG'}],
#  'TCIM': [23.070084354646973, {'CAL120_BREAST', 'DMS114_LUNG'}],
#  'ELAC2': [23.03739739798185, {'SNU182_LIVER', 'UACC812_BREAST'}],
#  'AKAP3': [22.898743311932105, {'DMS53_LUNG'}],
#  'C12orf4': [22.898743311932105, {'DMS53_LUNG'}],
#  'DYRK4': [22.898743311932105, {'DMS53_LUNG'}],
#  'FGF6': [22.898743311932105, {'DMS53_LUNG'}],
#  'GALNT8': [22.898743311932105, {'DMS53_LUNG'}],
#  'GAU1': [22.898743311932105, {'DMS53_LUNG'}],
#  'KCNA1': [22.898743311932105, {'DMS53_LUNG'}],
#  'KCNA5': [22.898743311932105, {'DMS53_LUNG'}],
#  'KCNA6': [22.898743311932105, {'DMS53_LUNG'}],
#  'NDUFA9': [22.898743311932105, {'DMS53_LUNG'}],
#  'NTF3': [22.898743311932105, {'DMS53_LUNG'}],
#  'RAD51AP1': [22.898743311932105, {'DMS53_LUNG'}],
#  'SOX5-AS1': [22.898743311932105, {'DMS53_LUNG'}],
#  'C1orf122': [22.69129665192056, {'NCIH1184_LUNG', 'NCIH2122_LUNG'}],
#  'MANEAL': [22.69129665192056, {'NCIH1184_LUNG', 'NCIH2122_LUNG'}],
#  'YRDC': [22.69129665192056, {'NCIH1184_LUNG', 'NCIH2122_LUNG'}],
#  'SLC9A8': [22.660962418293092, {'BT474_BREAST', 'MKN1_STOMACH'}],
#  'MSRB3': [22.564503477701138, {'NCIH1792_LUNG', 'QGP1_PANCREAS'}],
#  'AASDH': [22.50836981062936, {'SW1783_CENTRAL_NERVOUS_SYSTEM'}],
#  'ARL9': [22.50836981062936, {'SW1783_CENTRAL_NERVOUS_SYSTEM'}],
#  'CEP135': [22.50836981062936, {'SW1783_CENTRAL_NERVOUS_SYSTEM'}],
#  'CLOCK': [22.50836981062936, {'SW1783_CENTRAL_NERVOUS_SYSTEM'}],
#  'CRACD': [22.50836981062936, {'SW1783_CENTRAL_NERVOUS_SYSTEM'}],
#  'EXOC1': [22.50836981062936, {'SW1783_CENTRAL_NERVOUS_SYSTEM'}],
#  'EXOC1L': [22.50836981062936, {'SW1783_CENTRAL_NERVOUS_SYSTEM'}],
#  'HOPX': [22.50836981062936, {'SW1783_CENTRAL_NERVOUS_SYSTEM'}],
#  'IGFBP7': [22.50836981062936, {'SW1783_CENTRAL_NERVOUS_SYSTEM'}],
#  'IGFBP7-AS1': [22.50836981062936, {'SW1783_CENTRAL_NERVOUS_SYSTEM'}],
#  'KDR': [22.50836981062936, {'SW1783_CENTRAL_NERVOUS_SYSTEM'}],
#  'KIT': [22.50836981062936, {'SW1783_CENTRAL_NERVOUS_SYSTEM'}],
#  'NMU': [22.50836981062936, {'SW1783_CENTRAL_NERVOUS_SYSTEM'}],
#  'NOA1': [22.50836981062936, {'SW1783_CENTRAL_NERVOUS_SYSTEM'}],
#  'PAICS': [22.50836981062936, {'SW1783_CENTRAL_NERVOUS_SYSTEM'}],
#  'PDCL2': [22.50836981062936, {'SW1783_CENTRAL_NERVOUS_SYSTEM'}],
#  'POLR2B': [22.50836981062936, {'SW1783_CENTRAL_NERVOUS_SYSTEM'}],
#  'PPAT': [22.50836981062936, {'SW1783_CENTRAL_NERVOUS_SYSTEM'}],
#  'REST': [22.50836981062936, {'SW1783_CENTRAL_NERVOUS_SYSTEM'}],
#  'SPINK2': [22.50836981062936, {'SW1783_CENTRAL_NERVOUS_SYSTEM'}],
#  'SRD5A3': [22.50836981062936, {'SW1783_CENTRAL_NERVOUS_SYSTEM'}],
#  'SRD5A3-AS1': [22.50836981062936, {'SW1783_CENTRAL_NERVOUS_SYSTEM'}],
#  'SRP72': [22.50836981062936, {'SW1783_CENTRAL_NERVOUS_SYSTEM'}],
#  'THEGL': [22.50836981062936, {'SW1783_CENTRAL_NERVOUS_SYSTEM'}],
#  'TMEM165': [22.50836981062936, {'SW1783_CENTRAL_NERVOUS_SYSTEM'}],
#  'ABTB2': [22.27792203281754, {'HCC95_LUNG'}],
#  'C11orf74': [22.27792203281754, {'HCC95_LUNG'}],
#  'CAT': [22.27792203281754, {'HCC95_LUNG'}],
#  'COMMD9': [22.27792203281754, {'HCC95_LUNG'}],
#  'EHF': [22.27792203281754, {'HCC95_LUNG'}],
#  'ELF5': [22.27792203281754, {'HCC95_LUNG'}],
#  'PRR5L': [22.27792203281754, {'HCC95_LUNG'}],
#  'RAG1': [22.27792203281754, {'HCC95_LUNG'}],
#  'RAG2': [22.27792203281754, {'HCC95_LUNG'}],
#  'TRAF6': [22.27792203281754, {'HCC95_LUNG'}],
#  'ABI3': [21.965514324635507, {'BT474_BREAST', 'HCC1419_BREAST'}],
#  'COL1A1': [21.965514324635507, {'BT474_BREAST', 'HCC1419_BREAST'}],
#  'DLX3': [21.965514324635507, {'BT474_BREAST', 'HCC1419_BREAST'}],
#  'DLX4': [21.965514324635507, {'BT474_BREAST', 'HCC1419_BREAST'}],
#  'EME1': [21.965514324635507, {'BT474_BREAST', 'HCC1419_BREAST'}],
#  'FAM117A': [21.965514324635507, {'BT474_BREAST', 'HCC1419_BREAST'}],
#  'FLJ40194': [21.965514324635507, {'BT474_BREAST', 'HCC1419_BREAST'}],
#  'FLJ45513': [21.965514324635507, {'BT474_BREAST', 'HCC1419_BREAST'}],
#  'GNGT2': [21.965514324635507, {'BT474_BREAST', 'HCC1419_BREAST'}],
#  'H1-9P': [21.965514324635507, {'BT474_BREAST', 'HCC1419_BREAST'}],
#  'ITGA3': [21.965514324635507, {'BT474_BREAST', 'HCC1419_BREAST'}],
#  'KAT7': [21.965514324635507, {'BT474_BREAST', 'HCC1419_BREAST'}],
#  'LRRC59': [21.965514324635507, {'BT474_BREAST', 'HCC1419_BREAST'}],
#  'MRPL27': [21.965514324635507, {'BT474_BREAST', 'HCC1419_BREAST'}],
#  'NGFR': [21.965514324635507, {'BT474_BREAST', 'HCC1419_BREAST'}],
#  'NXPH3': [21.965514324635507, {'BT474_BREAST', 'HCC1419_BREAST'}],
#  'PDK2': [21.965514324635507, {'BT474_BREAST', 'HCC1419_BREAST'}],
#  'PHB': [21.965514324635507, {'BT474_BREAST', 'HCC1419_BREAST'}],
#  'PHOSPHO1': [21.965514324635507, {'BT474_BREAST', 'HCC1419_BREAST'}],
#  'PICART1': [21.965514324635507, {'BT474_BREAST', 'HCC1419_BREAST'}],
#  'PPP1R9B': [21.965514324635507, {'BT474_BREAST', 'HCC1419_BREAST'}],
#  'SAMD14': [21.965514324635507, {'BT474_BREAST', 'HCC1419_BREAST'}],
#  'SGCA': [21.965514324635507, {'BT474_BREAST', 'HCC1419_BREAST'}],
#  'SLC35B1': [21.965514324635507, {'BT474_BREAST', 'HCC1419_BREAST'}],
#  'SPOP': [21.965514324635507, {'BT474_BREAST', 'HCC1419_BREAST'}],
#  'TAC4': [21.965514324635507, {'BT474_BREAST', 'HCC1419_BREAST'}],
#  'TMEM92': [21.965514324635507, {'BT474_BREAST', 'HCC1419_BREAST'}],
#  'TMEM92-AS1': [21.965514324635507, {'BT474_BREAST', 'HCC1419_BREAST'}],
#  'XYLT2': [21.965514324635507, {'BT474_BREAST', 'HCC1419_BREAST'}],
#  'ZNF652': [21.965514324635507, {'BT474_BREAST', 'HCC1419_BREAST'}],
#  'BCL2L2': [21.848964514867276, {'NCIH2029_LUNG', 'NCIH82_LUNG'}],
#  'BCL2L2-PABPN1': [21.848964514867276, {'NCIH2029_LUNG', 'NCIH82_LUNG'}],
#  'CMTM5': [21.848964514867276, {'NCIH2029_LUNG', 'NCIH82_LUNG'}],
#  'EFS': [21.848964514867276, {'NCIH2029_LUNG', 'NCIH82_LUNG'}],
#  'HOMEZ': [21.848964514867276, {'NCIH2029_LUNG', 'NCIH82_LUNG'}],
#  'IL25': [21.848964514867276, {'NCIH2029_LUNG', 'NCIH82_LUNG'}],
#  'MYH6': [21.848964514867276, {'NCIH2029_LUNG', 'NCIH82_LUNG'}],
#  'PABPN1': [21.848964514867276, {'NCIH2029_LUNG', 'NCIH82_LUNG'}],
#  'PPP1R3E': [21.848964514867276, {'NCIH2029_LUNG', 'NCIH82_LUNG'}],
#  'RNF212B': [21.848964514867276, {'NCIH2029_LUNG', 'NCIH82_LUNG'}],
#  'SLC22A17': [21.848964514867276, {'NCIH2029_LUNG', 'NCIH82_LUNG'}],
#  'GDPD5': [21.460125949408273,
#   {'CAMA1_BREAST', 'KYSE410_OESOPHAGUS', 'MDAMB175VII_BREAST'}],
#  'MAP6': [21.460125949408273,
#   {'CAMA1_BREAST', 'KYSE410_OESOPHAGUS', 'MDAMB175VII_BREAST'}],
#  'MOGAT2': [21.460125949408273,
#   {'CAMA1_BREAST', 'KYSE410_OESOPHAGUS', 'MDAMB175VII_BREAST'}],
#  'SERPINH1': [21.460125949408273,
#   {'CAMA1_BREAST', 'KYSE410_OESOPHAGUS', 'MDAMB175VII_BREAST'}],
#  'ELOC': [21.37160035205256, {'AU565_BREAST', 'HCC827_LUNG'}],
#  'GDAP1': [21.37160035205256, {'AU565_BREAST', 'HCC827_LUNG'}],
#  'JPH1': [21.37160035205256, {'AU565_BREAST', 'HCC827_LUNG'}],
#  'LY96': [21.37160035205256, {'AU565_BREAST', 'HCC827_LUNG'}],
#  'MRPS28': [21.37160035205256, {'AU565_BREAST', 'HCC827_LUNG'}],
#  'RDH10': [21.37160035205256, {'AU565_BREAST', 'HCC827_LUNG'}],
#  'RDH10-AS1': [21.37160035205256, {'AU565_BREAST', 'HCC827_LUNG'}],
#  'RPL7': [21.37160035205256, {'AU565_BREAST', 'HCC827_LUNG'}],
#  'STAU2': [21.37160035205256, {'AU565_BREAST', 'HCC827_LUNG'}],
#  'STAU2-AS1': [21.37160035205256, {'AU565_BREAST', 'HCC827_LUNG'}],
#  'TMEM70': [21.37160035205256, {'AU565_BREAST', 'HCC827_LUNG'}],
#  'TPD52': [21.37160035205256, {'AU565_BREAST', 'HCC827_LUNG'}],
#  'UBE2W': [21.37160035205256, {'AU565_BREAST', 'HCC827_LUNG'}],
#  'B3GNT6': [21.12451349545028, {'MDAMB134VI_BREAST', 'MDAMB175VII_BREAST'}],
#  'CAPN5': [21.12451349545028, {'MDAMB134VI_BREAST', 'MDAMB175VII_BREAST'}],
#  'EMSY': [21.12451349545028, {'MDAMB134VI_BREAST', 'MDAMB175VII_BREAST'}],
#  'GDPD4': [21.12451349545028, {'MDAMB134VI_BREAST', 'MDAMB175VII_BREAST'}],
#  'GVQW3': [21.12451349545028, {'MDAMB134VI_BREAST', 'MDAMB175VII_BREAST'}],
#  'LRRC32': [21.12451349545028, {'MDAMB134VI_BREAST', 'MDAMB175VII_BREAST'}],
#  'MYO7A': [21.12451349545028, {'MDAMB134VI_BREAST', 'MDAMB175VII_BREAST'}],
#  'OMP': [21.12451349545028, {'MDAMB134VI_BREAST', 'MDAMB175VII_BREAST'}],
#  'THAP12': [21.12451349545028, {'MDAMB134VI_BREAST', 'MDAMB175VII_BREAST'}],
#  'WNT11': [21.12451349545028, {'MDAMB134VI_BREAST', 'MDAMB175VII_BREAST'}],
#  'SLC7A7': [21.05249905160754, {'NCIH2029_LUNG', 'NCIH2171_LUNG'}],
#  'C11orf80': [21.023246072324326,
#   {'KYSE410_OESOPHAGUS', 'SNU475_LIVER', 'TE11_OESOPHAGUS'}],
#  'SPTBN2': [21.023246072324326,
#   {'KYSE410_OESOPHAGUS', 'SNU475_LIVER', 'TE11_OESOPHAGUS'}],
#  'ALDH1A1': [20.970659030771152, {'DANG_PANCREAS'}],
#  'ANXA1': [20.970659030771152, {'DANG_PANCREAS'}],
#  'CHTOP': [20.5755549078294, {'COV644_OVARY'}],
#  'CREB3L4': [20.5755549078294, {'COV644_OVARY'}],
#  'CRTC2': [20.5755549078294, {'COV644_OVARY'}],
#  'DENND4B': [20.5755549078294, {'COV644_OVARY'}],
#  'GATAD2B': [20.5755549078294, {'COV644_OVARY'}],
#  'ILF2': [20.5755549078294, {'COV644_OVARY'}],
#  'INTS3': [20.5755549078294, {'COV644_OVARY'}],
#  'JTB': [20.5755549078294, {'COV644_OVARY'}],
#  'NPR1': [20.5755549078294, {'COV644_OVARY'}],
#  'PGLYRP3': [20.5755549078294, {'COV644_OVARY'}],
#  'PGLYRP4': [20.5755549078294, {'COV644_OVARY'}],
#  'RAB13': [20.5755549078294, {'COV644_OVARY'}],
#  'RPS27': [20.5755549078294, {'COV644_OVARY'}],
#  'S100A1': [20.5755549078294, {'COV644_OVARY'}],
#  'S100A12': [20.5755549078294, {'COV644_OVARY'}],
#  'S100A13': [20.5755549078294, {'COV644_OVARY'}],
#  'S100A14': [20.5755549078294, {'COV644_OVARY'}],
#  'S100A16': [20.5755549078294, {'COV644_OVARY'}],
#  'S100A2': [20.5755549078294, {'COV644_OVARY'}],
#  'S100A3': [20.5755549078294, {'COV644_OVARY'}],
#  'S100A4': [20.5755549078294, {'COV644_OVARY'}],
#  'S100A5': [20.5755549078294, {'COV644_OVARY'}],
#  'S100A6': [20.5755549078294, {'COV644_OVARY'}],
#  'S100A7': [20.5755549078294, {'COV644_OVARY'}],
#  'S100A7A': [20.5755549078294, {'COV644_OVARY'}],
#  'S100A8': [20.5755549078294, {'COV644_OVARY'}],
#  'S100A9': [20.5755549078294, {'COV644_OVARY'}],
#  'SLC27A3': [20.5755549078294, {'COV644_OVARY'}],
#  'SLC39A1': [20.5755549078294, {'COV644_OVARY'}],
#  'SNAPIN': [20.5755549078294, {'COV644_OVARY'}],
#  'EPOP': [20.324347992639744, {'BT474_BREAST', 'UACC812_BREAST'}],
#  'MLLT6': [20.324347992639744, {'BT474_BREAST', 'UACC812_BREAST'}],
#  'SRCIN1': [20.324347992639744, {'BT474_BREAST', 'UACC812_BREAST'}],
#  'VIPR2': [20.305925515317426,
#   {'DMS273_LUNG', 'HGC27_STOMACH', 'MKN7_STOMACH'}],
#  'KDM4A': [20.214075936103185,
#   {'NCIH510_LUNG', 'THP1_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE'}],
#  'KDM4A-AS1': [20.214075936103185,
#   {'NCIH510_LUNG', 'THP1_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE'}],
#  'ST3GAL3': [20.214075936103185,
#   {'NCIH510_LUNG', 'THP1_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE'}],
#  'CA10': [20.18462790272693, {'EFM192A_BREAST'}],
#  'MBTD1': [20.18462790272693, {'EFM192A_BREAST'}],
#  'SPAG9': [20.18462790272693, {'EFM192A_BREAST'}],
#  'UTP18': [20.18462790272693, {'EFM192A_BREAST'}],
#  'TSPAN11': [19.790219483129633, {'MKN1_STOMACH', 'SW900_LUNG'}],
#  'ADK': [19.760913358481247, {'EFM19_BREAST', 'PC3_PROSTATE'}],
#  'AGAP5': [19.760913358481247, {'EFM19_BREAST', 'PC3_PROSTATE'}],
#  'AP3M1': [19.760913358481247, {'EFM19_BREAST', 'PC3_PROSTATE'}],
#  'BMS1P4': [19.760913358481247, {'EFM19_BREAST', 'PC3_PROSTATE'}],
#  'BMS1P4-AGAP5': [19.760913358481247, {'EFM19_BREAST', 'PC3_PROSTATE'}],
#  'C10orf55': [19.760913358481247, {'EFM19_BREAST', 'PC3_PROSTATE'}],
#  'CAMK2G': [19.760913358481247, {'EFM19_BREAST', 'PC3_PROSTATE'}],
#  'CHCHD1': [19.760913358481247, {'EFM19_BREAST', 'PC3_PROSTATE'}],
#  'COMTD1': [19.760913358481247, {'EFM19_BREAST', 'PC3_PROSTATE'}],
#  'DUSP13': [19.760913358481247, {'EFM19_BREAST', 'PC3_PROSTATE'}],
#  'FUT11': [19.760913358481247, {'EFM19_BREAST', 'PC3_PROSTATE'}],
#  'GLUD1P3': [19.760913358481247, {'EFM19_BREAST', 'PC3_PROSTATE'}],
#  'LRMDA': [19.760913358481247, {'EFM19_BREAST', 'PC3_PROSTATE'}],
#  'MYOZ1': [19.760913358481247, {'EFM19_BREAST', 'PC3_PROSTATE'}],
#  'NDST2': [19.760913358481247, {'EFM19_BREAST', 'PC3_PROSTATE'}],
#  'PLAU': [19.760913358481247, {'EFM19_BREAST', 'PC3_PROSTATE'}],
#  'SAMD8': [19.760913358481247, {'EFM19_BREAST', 'PC3_PROSTATE'}],
#  'SEC24C': [19.760913358481247, {'EFM19_BREAST', 'PC3_PROSTATE'}],
#  'SYNPO2L': [19.760913358481247, {'EFM19_BREAST', 'PC3_PROSTATE'}],
#  'VCL': [19.760913358481247, {'EFM19_BREAST', 'PC3_PROSTATE'}],
#  'VDAC2': [19.760913358481247, {'EFM19_BREAST', 'PC3_PROSTATE'}],
#  'ZNF503': [19.760913358481247, {'EFM19_BREAST', 'PC3_PROSTATE'}],
#  'ZNF503-AS1': [19.760913358481247, {'EFM19_BREAST', 'PC3_PROSTATE'}],
#  'ZNF503-AS2': [19.760913358481247, {'EFM19_BREAST', 'PC3_PROSTATE'}],
#  'ZSWIM8': [19.760913358481247, {'EFM19_BREAST', 'PC3_PROSTATE'}],
#  'ZSWIM8-AS1': [19.760913358481247, {'EFM19_BREAST', 'PC3_PROSTATE'}],
#  'DHRS13': [19.694623945013976, {'KYSE410_OESOPHAGUS'}],
#  'ERAL1': [19.694623945013976, {'KYSE410_OESOPHAGUS'}],
#  'FAM222B': [19.694623945013976, {'KYSE410_OESOPHAGUS'}],
#  'FLOT2': [19.694623945013976, {'KYSE410_OESOPHAGUS'}],
#  'FOXN1': [19.694623945013976, {'KYSE410_OESOPHAGUS'}],
#  'IFT20': [19.694623945013976, {'KYSE410_OESOPHAGUS'}],
#  'KIAA0100': [19.694623945013976, {'KYSE410_OESOPHAGUS'}],
#  'KRT18P55': [19.694623945013976, {'KYSE410_OESOPHAGUS'}],
#  'LYRM9': [19.694623945013976, {'KYSE410_OESOPHAGUS'}],
#  'NEK8': [19.694623945013976, {'KYSE410_OESOPHAGUS'}],
#  'NLK': [19.694623945013976, {'KYSE410_OESOPHAGUS'}],
#  'NOS2': [19.694623945013976, {'KYSE410_OESOPHAGUS'}],
#  'POLDIP2': [19.694623945013976, {'KYSE410_OESOPHAGUS'}],
#  'PRIM2': [19.694623945013976, {'KYSE410_OESOPHAGUS'}],
#  'PROCA1': [19.694623945013976, {'KYSE410_OESOPHAGUS'}],
#  'RAB34': [19.694623945013976, {'KYSE410_OESOPHAGUS'}],
#  'RPL23A': [19.694623945013976, {'KYSE410_OESOPHAGUS'}],
#  ...}

# %% [markdown]
# ##### Top 400 Most Frequent Genes in ecDNA:

# %%
aa_gene_list = list(aa_gene_dict.keys())[0:400]
aa_gene_list
# Out:
# ['CASC11',
#  'MYC',
#  'PVT1',
#  'CASC8',
#  'POU5F1B',
#  'CCAT2',
#  'TMEM75',
#  'CASC21',
#  'ERBB2',
#  'PGAP3',
#  'GRB7',
#  'IKZF3',
#  'MIEN1',
#  'PCAT1',
#  'MYCL',
#  'TRIT1',
#  'PNMT',
#  'TCAP',
#  'BMP8B',
#  'HPCAL4',
#  'NT5C1A',
#  'OXCT2',
#  'PPIE',
#  'ZPBP2',
#  'CASC19',
#  'CCAT1',
#  'HEYL',
#  'PCAT2',
#  'PRNCR1',
#  'MFSD2A',
#  'RLF',
#  'CDC6',
#  'RAPGEFL1',
#  'RARA',
#  'WIPF2',
#  'CAP1',
#  'PABPC4',
#  'PABPC4-AS1',
#  'PPIEL',
#  'SNORA55',
#  'OXCT2P1',
#  'LRATD2',
#  'COL9A2',
#  'BMP8A',
#  'TTLL10',
#  'SMAP2',
#  'ZFP69',
#  'ZFP69B',
#  'ZNF684',
#  'PPT1',
#  'NEUROD2',
#  'PPP1R1B',
#  'STARD3',
#  'TMCO2',
#  'ZMPSTE24',
#  'DDX1',
#  'GACAT3',
#  'MYCN',
#  'MYCNOS',
#  'MYCNUT',
#  'FAM91A1',
#  'FER1L6',
#  'FER1L6-AS1',
#  'FER1L6-AS2',
#  'NFYC',
#  'NFYC-AS1',
#  'RIMS3',
#  'CDK12',
#  'FBXL20',
#  'MED1',
#  'KIAA0754',
#  'APIP',
#  'CD44',
#  'FJX1',
#  'LDLRAD3',
#  'PAMR1',
#  'PDHX',
#  'SLC1A2',
#  'SNORD164',
#  'TRIM44',
#  'GJA9',
#  'GJA9-MYCBP',
#  'FGFR2',
#  'PLPP4',
#  'RPL21',
#  'WDR11',
#  'WDR11-AS1',
#  'MYEOV',
#  'SMIM38',
#  'ANO1',
#  'CASC1',
#  'ETFRF1',
#  'KRAS',
#  'LMNTD1',
#  'EXO5',
#  'EGFR',
#  'EGFR-AS1',
#  'SEC61G',
#  'VSTM2A',
#  'VSTM2A-OT1',
#  'GSDMA',
#  'GSDMB',
#  'LRRC3C',
#  'ORMDL3',
#  'PSMD3',
#  'AKIRIN1',
#  'MYCBP',
#  'NDUFS5',
#  'RHBDL2',
#  'RRAGC',
#  'CCND1',
#  'FGF19',
#  'FGF3',
#  'FGF4',
#  'LTO1',
#  'TPCN2',
#  'RASSF8',
#  'RASSF8-AS1',
#  'CTTN',
#  'FADD',
#  'PPFIA1',
#  'LPIN1',
#  'NTSR2',
#  'TRIB2',
#  'MRGPRD',
#  'MRGPRF',
#  'MRGPRF-AS1',
#  'ADGRA2',
#  'ADRB3',
#  'ASH2L',
#  'BRF2',
#  'EIF4EBP1',
#  'GOT1L1',
#  'PLPBP',
#  'RAB11FIP1',
#  'STAR',
#  'NDUFB9',
#  'TATDN1',
#  'TBC1D31',
#  'ZDHHC11B',
#  'MYO18A',
#  'PHF12',
#  'PIPOX',
#  'TIAF1',
#  'CSF3',
#  'MED24',
#  'SNORD124',
#  'THRA',
#  'CITED4',
#  'C19orf12',
#  'CCNE1',
#  'URI1',
#  'C12orf77',
#  'LRMP',
#  'ANXA13',
#  'ATAD2',
#  'C8orf76',
#  'DERL1',
#  'FAM83A',
#  'FAM83A-AS1',
#  'FBXO32',
#  'KLHL38',
#  'RNF139',
#  'RNF139-AS1',
#  'SMILR',
#  'TMEM65',
#  'TRMT12',
#  'WDYHV1',
#  'ZHX1',
#  'ZHX1-C8orf76',
#  'ZHX2',
#  'CACNB1',
#  'RPL19',
#  'STAC2',
#  'ZNF217',
#  'MTSS1',
#  'NSMCE2',
#  'SQLE',
#  'TRIB1',
#  'WASHC5',
#  'ZNF572',
#  'KCNQ4',
#  'CPQ',
#  'CRACR2A',
#  'PARP11',
#  'THCAT155',
#  'TIGAR',
#  'IGHMBP2',
#  'MRPL21',
#  'ERLIN2',
#  'ZNF703',
#  'BAG4',
#  'C8orf86',
#  'DDHD2',
#  'FGFR1',
#  'LETM2',
#  'LSM1',
#  'NSD3',
#  'PLPP5',
#  'NBAS',
#  'CASC3',
#  'MSL1',
#  'NR1D1',
#  'TPPP',
#  'AAMDC',
#  'ACER3',
#  'ALG8',
#  'AQP11',
#  'CLNS1A',
#  'GUCY2EP',
#  'INTS4',
#  'KCTD14',
#  'KCTD21-AS1',
#  'NDUFC2',
#  'NDUFC2-KCTD14',
#  'PAK1',
#  'RSF1',
#  'THRSP',
#  'TSKU',
#  'ZNF704',
#  'AKT3',
#  'C1orf198',
#  'CD84',
#  'COPA',
#  'DISC1',
#  'NCSTN',
#  'SLAMF6',
#  'SNRPD2P2',
#  'SUMO1P3',
#  'PLEKHF1',
#  'POP4',
#  'VSTM2B',
#  'ATP5MC1',
#  'CALCOCO2',
#  'HOXB13',
#  'PRAC1',
#  'PRAC2',
#  'TTLL6',
#  'UBE2Z',
#  'BCAT1',
#  'RNF5P1',
#  'CCDC26',
#  'POM121L12',
#  'SAMD12',
#  'SAMD12-AS1',
#  'CSMD3',
#  'TRPS1',
#  'CPT1A',
#  'GAL',
#  'TESMIN',
#  'BCAS4',
#  'PARD6B',
#  'MTDH',
#  'FGF23',
#  'PRMT8',
#  'BCAS1',
#  'CYP24A1',
#  'DOK5',
#  'PFDN4',
#  'SUMO1P1',
#  'EIF1',
#  'FKBP10',
#  'GAST',
#  'HAP1',
#  'JUP',
#  'KRT16',
#  'KRT17',
#  'KRT42P',
#  'P3H4',
#  'CASKIN2',
#  'LLGL2',
#  'MYO15B',
#  'RECQL5',
#  'SAP30BP',
#  'SMIM5',
#  'SMIM6',
#  'TSEN54',
#  'BMP7',
#  'BMP7-AS1',
#  'PPP6R3',
#  'GBAT2',
#  'PI4KB',
#  'PSMB4',
#  'PSMD4',
#  'RFX5',
#  'SELENBP1',
#  'ZNF687',
#  'ZNF687-AS1',
#  'ARL5C',
#  'FBXO47',
#  'LRRC37A11P',
#  'PLXDC1',
#  'RDM1P5',
#  'ZBTB10',
#  'C1orf109',
#  'CDCA8',
#  'HOXB6',
#  'HOXB7',
#  'HOXB8',
#  'HOXB9',
#  'GAB2',
#  'KCTD21',
#  'NARS2',
#  'TENM4',
#  'USP35',
#  'ATG5',
#  'BEND3',
#  'CD24',
#  'CRYBG1',
#  'MTRES1',
#  'MYMX',
#  'PDSS2',
#  'PRDM1',
#  'PREP',
#  'QRSL1',
#  'RTN4IP1',
#  'SLC29A1',
#  'SOBP',
#  'CALB1',
#  'CCN3',
#  'COL14A1',
#  'COLEC10',
#  'DECR1',
#  'DEPTOR',
#  'DSCC1',
#  'ENPP2',
#  'HAS2',
#  'HAS2-AS1',
#  'MAL2',
#  'MAL2-AS1',
#  'MRPL13',
#  'MTBP',
#  'NBN',
#  'SNTB1',
#  'TAF2',
#  'TNFRSF11B',
#  'EXT1',
#  'SNORD168',
#  'B4GALNT2',
#  'GIP',
#  'IGF2BP1',
#  'SNF8',
#  'UNC5D',
#  'NPEPL1',
#  'STX16',
#  'STX16-NPEPL1',
#  'LY6H',
#  'C17orf98',
#  'CISD3',
#  'CWC25',
#  'LASP1',
#  'PCGF2',
#  'PIP4K2B',
#  'PSMB3',
#  'RPL23',
#  'SNORA21',
#  'SNORA21B',
#  'LPCAT1',
#  'SLC6A3',
#  'CTPS1',
#  'SLFNL1-AS1',
#  'COBL',
#  'ELDR',
#  'LANCL2',
#  'FABP5',
#  'PAG1',
#  'PMP2',
#  'TACC1',
#  'RTEL1',
#  'RTEL1-TNFRSF6B',
#  'CASC15',
#  'CDKAL1',
#  'E2F3',
#  'HDGFL1',
#  'NBAT1',
#  'PRL',
#  'SOX4',
#  'APPBP2',
#  'BCAS3',
#  'C17orf64',
#  'CA4',
#  'HEATR6',
#  'PPM1D',
#  'PPM1E',
#  'RAD51C',
#  'RNFT1',
#  'RNFT1-DT',
#  'RPS6KB1',
#  'SCARNA20',
#  'TBC1D3P1-DHX40P1',
#  'TEX14',
#  'TRIM37',
#  'TUBD1',
#  'USP32',
#  'WFDC21P',
#  'ASZ1',
#  'CAPZA2',
#  'CAV1',
#  'CAV2',
#  'CFTR']

# %%
aa_gene_dict["CASC11"]
# Out:
# [1459.6616842484777,
#  {'AU565_BREAST',
#   'CORL23_LUNG',
#   'CORL279_LUNG',
#   'CORL311_LUNG',
#   'DMS273_LUNG',
#   'EFM192A_BREAST',
#   'FUOV1_OVARY',
#   'GCIY_STOMACH',
#   'HCC1419_BREAST',
#   'HCC44_LUNG',
#   'HGC27_STOMACH',
#   'KYSE450_OESOPHAGUS',
#   'MSTO211H_PLEURA',
#   'NCIH1792_LUNG',
#   'NCIH2122_LUNG',
#   'NCIH2170_LUNG',
#   'NCIH2171_LUNG',
#   'NCIH23_LUNG',
#   'NCIH446_LUNG',
#   'NCIH460_LUNG',
#   'NCIH510_LUNG',
#   'NCIH524_LUNG',
#   'NCIH82_LUNG',
#   'SCLC21H_LUNG',
#   'SNU16_STOMACH',
#   'SW480_LARGE_INTESTINE'}]

# %%
aa_gene_dict["CFTR"]
# Out:
# [38.10721405691402, {'HS746T_STOMACH', 'MKN45_STOMACH'}]

# %% [markdown]
# ### With Literature Gene List:

# %% [markdown]
# ##### Top 20 Most Frequent Oncogenes in ecDNA:

# %%
aa_oncogene_list = list(aa_oncogene_dict.keys())[0:20]
aa_oncogene_list
# Out:
# ['MYC',
#  'PVT1',
#  'ERBB2',
#  'CDC6',
#  'RARA',
#  'MYCN',
#  'CDK12',
#  'FGFR2',
#  'KRAS',
#  'EGFR',
#  'CCND1',
#  'FGF3',
#  'FGF4',
#  'CTTN',
#  'TRIB2',
#  'BRF2',
#  'CSF3',
#  'THRA',
#  'CCNE1',
#  'ZNF217']

# %%
aa_oncogene_dict["MYC"]
# Out:
# [1459.6616842484777,
#  {'AU565_BREAST',
#   'CORL23_LUNG',
#   'CORL279_LUNG',
#   'CORL311_LUNG',
#   'DMS273_LUNG',
#   'EFM192A_BREAST',
#   'FUOV1_OVARY',
#   'GCIY_STOMACH',
#   'HCC1419_BREAST',
#   'HCC44_LUNG',
#   'HGC27_STOMACH',
#   'KYSE450_OESOPHAGUS',
#   'MSTO211H_PLEURA',
#   'NCIH1792_LUNG',
#   'NCIH2122_LUNG',
#   'NCIH2170_LUNG',
#   'NCIH2171_LUNG',
#   'NCIH23_LUNG',
#   'NCIH446_LUNG',
#   'NCIH460_LUNG',
#   'NCIH510_LUNG',
#   'NCIH524_LUNG',
#   'NCIH82_LUNG',
#   'SCLC21H_LUNG',
#   'SNU16_STOMACH',
#   'SW480_LARGE_INTESTINE'}]

# %%
aa_oncogene_dict["ERBB2"]
# Out:
# [493.95832185281716,
#  {'BT474_BREAST',
#   'EFM192A_BREAST',
#   'HCC1419_BREAST',
#   'HCC1569_BREAST',
#   'HCC202_BREAST',
#   'KYSE410_OESOPHAGUS',
#   'MFE280_ENDOMETRIUM',
#   'MKN7_STOMACH',
#   'NCIH2170_LUNG',
#   'OE19_OESOPHAGUS',
#   'SKOV3_OVARY',
#   'UACC812_BREAST',
#   'UACC893_BREAST'}]

# %%
aa_oncogene_dict["EGFR"]
# Out:
# [93.32824189532512, {'HCC827_LUNG', 'KYSE520_OESOPHAGUS', 'NCIH3255_LUNG'}]

# %%
aa_oncogene_dict["KRAS"]
# Out:
# [95.90981469728438,
#  {'CORL23_LUNG',
#   'DMS53_LUNG',
#   'KE39_STOMACH',
#   'KLE_ENDOMETRIUM',
#   'MKN1_STOMACH'}]

# %% [markdown]
# # Splitting AA Cell-Lines (ecDNA +/-)

# %% [markdown]
# ##### We split the AA data rows into cell-lines corresponding to ecDNA presence (+) or absence (-).

# %%
ec_aa_plus_ids = set()
all_aa_ids = set()
id_dict = ccle_to_achilles(meta_df, "CCLEName")

for index, row in aa_df.iterrows():
    achilles_id = id_dict[row["Sample name"]]
    all_aa_ids.add(achilles_id)
    if index == "ecDNA":
        ec_aa_plus_ids.add(achilles_id)

print("Number of ecDNA+ cell-lines in AA data:", len(ec_aa_plus_ids))
print("Total number of cell-lines in AA data:", len(all_aa_ids))
# Out:
# Number of ecDNA+ cell-lines in AA data: 166
# Total number of cell-lines in AA data: 329

# %% [markdown]
# # Trimming Essentiality Data:

# %% [markdown]
# ##### The essentiality data <b>must</b> be trimmed to only include the AA run's cell-lines as those are the only cell-lines we are certain about the identity of their ecDNA presence or absence.

# %%
trimmed_esen_df = esen_df[esen_df.index.isin(all_aa_ids)]

# %%
trimmed_esen_df.head()
# Out:
#                 A1BG      A1CF       A2M     A2ML1   A3GALT2    A4GALT  \
# ACH-000001 -0.134132  0.029103  0.016454 -0.137540 -0.047273  0.181367
# ACH-000005 -0.144940  0.026541  0.160605  0.088015 -0.202605 -0.243420
# ACH-000007 -0.053334 -0.120420  0.047978  0.086984 -0.018987 -0.017309
# ACH-000009 -0.027684 -0.144202  0.052846  0.073833  0.038823 -0.108149
# ACH-000012 -0.139877 -0.002344  0.011211  0.048813  0.049770 -0.179609
#
#                A4GNT      AAAS      AACS     AADAC  ...    ZWILCH     ZWINT  \
# ACH-000001 -0.082437 -0.059023  0.194592  0.035473  ... -0.123528  0.085140
# ACH-000005  0.133726 -0.034895 -0.126105  0.036030  ... -0.309668 -0.344502
# ACH-000007 -0.000041 -0.158419 -0.169559  0.201305  ... -0.323038 -0.387265
# ACH-000009  0.010811 -0.088600  0.032194  0.114270  ... -0.253057 -0.159965
# ACH-000012  0.113692 -0.039238 -0.069528  0.235269  ... -0.524291 -0.623566
#
#                 ZXDA      ZXDB      ZXDC    ZYG11A    ZYG11B       ZYX  \
# ACH-000001  0.181954  0.239474  0.172965 -0.230327  0.055657  0.044296
# ACH-000005 -0.056160 -0.092447 -0.015550 -0.170380 -0.080934 -0.059685
# ACH-000007 -0.013816  0.183228  0.038424 -0.051728 -0.383499 -0.012801
# ACH-000009 -0.025342  0.191500 -0.071632 -0.077843 -0.525599  0.093219
# ACH-000012  0.089670 -0.002416 -0.081465  0.061536 -0.060163 -0.091458
#
#                ZZEF1      ZZZ3
# ACH-000001  0.107361 -0.410449
# ACH-000005  0.030254 -0.145055
# ACH-000007 -0.294771 -0.431575
# ACH-000009 -0.029515 -0.255204
# ACH-000012 -0.157398 -0.233239
#
# [5 rows x 18443 columns]

# %% [markdown]
# # Calculating Essentiality Across Cell-Lines:

# %% [markdown]
# ##### The following gene categories are based on the median values across cell-lines as follows:
# - <u>Non-essential</u> (greater than 0): genes where the knockout <b>does NOT affect</b> the cancer cell-line's <b>survival</b>
# - <u>Selectively-essential</u> (between -1 and 0): genes where the knockout <b>affects the survival of most</b> cancer cell-lines
# - <u>Common-essential</u> (less than -1): genes where the knockout <b>affects the survival of almost all</b> cancer cell-lines

# %% [markdown]
# ### With Literature Gene List:

# %% [markdown]
# ##### The following is sorted by median value (most essential):

# %%
literature_avg_esen = avg_esen(literature_gene_list, trimmed_esen_df)
literature_avg_esen.sort_values(by="Median").head()
# Out:
#        Gene      Mean    Median  Standard Deviation          Category
# 559  SNRPA1 -2.905440 -2.911526            0.416760  Common-essential
# 50     PLK1 -2.724873 -2.711673            0.479285  Common-essential
# 463  SNRPD1 -2.661759 -2.673431            0.456231  Common-essential
# 159    RPL3 -2.534814 -2.506250            0.331999  Common-essential
# 339    EEF2 -2.318079 -2.429119            0.537582  Common-essential

# %% [markdown]
# ### With Amplicon Architect Most Frequent Genes List:

# %% [markdown]
# ##### The following is sorted by median value (most essential):

# %%
aa_avg_esen = avg_esen(aa_gene_list, trimmed_esen_df)
aa_avg_esen.sort_values(by="Median").head()
# Out:
#       Gene      Mean    Median  Standard Deviation          Category
# 60   RPL21 -2.709954 -2.807940            0.494277  Common-essential
# 293  PSMB3 -2.722501 -2.723508            0.408371  Common-essential
# 294  RPL23 -2.663050 -2.701470            0.422596  Common-essential
# 229  PSMB4 -2.325610 -2.304537            0.363837  Common-essential
# 133  RPL19 -2.281648 -2.255677            0.351545  Common-essential

# %% [markdown]
# # Generating Plots and Statistics:

# %% [markdown]
# ## Individual Gene Plots:

# %% [markdown]
# ### AA Gene List:

# %%
aa_genes_plot_df = plot_genes(aa_gene_list, trimmed_esen_df, ec_aa_plus_ids, "aa")
# Out:
# Number of ecDNA+ cell lines: 121
# Number of ecDNA- cell lines: 124

# %%
aa_genes_plot_df[aa_genes_plot_df['p-value'] < 0.5]
# Out:
#          Gene  u-stat   p-value
# 116    CITED4  5564.0  0.000477
# 160      MSL1  9379.0  0.000716
# 117  C19orf12  9368.0  0.000769
# 302     TACC1  9368.0  0.000769
# 119      URI1  5637.0  0.000774
# ..        ...     ...       ...
# 289     CWC25  7105.0  0.474653
# 89       CTTN  7117.0  0.488127
# 279  B4GALNT2  7119.0  0.490392
# 180     DISC1  7120.0  0.491527
# 53      PAMR1  7879.0  0.497222
#
# [193 rows x 3 columns]

# %% [markdown]
# ### Literature Gene List:

# %%
literature_genes_plot_df = plot_genes(literature_gene_list, trimmed_esen_df, ec_aa_plus_ids, "literature")
# Out:
# Number of ecDNA+ cell lines: 121
# Number of ecDNA- cell lines: 124

# %%
literature_genes_plot_df[literature_genes_plot_df['p-value'] < 0.05]
# Out:
#           Gene  u-stat   p-value
# 347    TMEM199  9622.0  0.000133
# 536       LIPG  9434.0  0.000496
# 457       MSL1  9379.0  0.000716
# 222   ATP6V1B2  9325.0  0.001016
# 254      DAPL1  9274.0  0.001402
# 387      CENPO  9269.0  0.001447
# 432       FZD7  5752.0  0.001608
# 33         WRN  9184.0  0.002430
# 71        MDM2  9170.0  0.002641
# 349     KCNMA1  5836.0  0.002673
# 183      PCMT1  5873.0  0.003321
# 135      TRIM8  5912.0  0.004157
# 449     FAM32A  5925.0  0.004475
# 47       PINX1  9055.0  0.005121
# 192      NOP56  9005.0  0.006745
# 61        CDC6  6004.0  0.006931
# 404    RACGAP1  6042.0  0.008498
# 9       METTL1  8951.0  0.009007
# 93       CDCA2  6085.0  0.010647
# 481     RSPH4A  6106.0  0.011862
# 39       KIF4A  6124.0  0.013000
# 328       FUT6  6125.0  0.013066
# 136      DDIT3  8865.0  0.014021
# 160       SNTN  6144.0  0.014377
# 122     YEATS4  8846.0  0.015416
# 255   RASGEF1B  6170.0  0.016358
# 191      KIF23  6204.0  0.019308
# 425        CD6  6206.0  0.019496
# 66      ADAM28  6227.0  0.021559
# 134       FAF1  8773.0  0.021973
# 25      INTS10  6233.0  0.022182
# 237      MYBL2  6267.0  0.026019
# 381      SPC24  6269.0  0.026262
# 223        PTN  6278.0  0.027378
# 511    SIGLEC1  6283.0  0.028015
# 446       CNR2  6292.0  0.029195
# 502     CHMP4C  8711.0  0.029328
# 23       MCPH1  8661.0  0.036718
# 175       DPM1  8660.0  0.036880
# 108      SHOX2  6350.0  0.037869
# 459       CD27  8647.0  0.039051
# 524       MPP1  8641.0  0.040089
# 3        DDX27  8626.0  0.042787
# 444      ITGAL  8620.0  0.043909
# 271    CCDC127  8618.0  0.044288
# 269     MAP7D3  6387.0  0.044478
# 487     DPAGT1  8616.0  0.044670
# 438  TNFRSF10A  6395.0  0.046029
# 330    CCDC152  8609.0  0.046029
# 372      ZFP64  8606.0  0.046622
# 224      FCRL6  8595.0  0.048851

# %% [markdown]
# ## Individual Gene Plot (cell-lines with MYC ecDNA vs all else):

# %% [markdown]
# ### Obtaining cell-lines that express MYC in their ecDNA amplicons:

# %%
ec_aa_MYC_pos_ids = []
for ccle in (aa_gene_dict["MYC"][1]):
    ec_aa_MYC_pos_ids.append(id_dict[ccle])

ec_aa_MYC_pos_ids = list(set(ec_aa_MYC_pos_ids))

# %%
len(ec_aa_MYC_pos_ids)
# Out:
# 26

# %% [markdown]
# ### Generating plot:

# %%
aa_genes_plot_df = plot_genes(["MYC"], trimmed_esen_df, ec_aa_MYC_pos_ids, "MYC_RUN")
aa_genes_plot_df
# Out:
# Number of ecDNA+ cell lines: 21
# Number of ecDNA- cell lines: 224
#   Gene  u-stat   p-value
# 0  MYC  1619.0  0.018333

# %% [markdown]
# ## Individual Cell-Line Plots:

# %% [markdown]
# ### Grouping Genes by Essentiality Categories:

# %% [markdown]
# ### Literature Gene List:

# %% [markdown]
# #### Extracting the common-essential, selectively-essential, and non-essential genes:

# %%
common_esen_genes_list = list(literature_avg_esen[literature_avg_esen['Category'] == 'Common-essential']['Gene'])
selec_esen_genes_list = list(literature_avg_esen[literature_avg_esen['Category'] == 'Selectively-essential']['Gene'])
non_esen_genes_list = list(literature_avg_esen[literature_avg_esen['Category'] == 'Non-essential']['Gene'])

# %%
common_esen_genes_dict = {key: literature_gene_dict[key] for key in common_esen_genes_list if key in literature_gene_dict}
selec_esen_genes_dict = {key: literature_gene_dict[key] for key in selec_esen_genes_list if key in literature_gene_dict}
non_esen_genes_dict = {key: literature_gene_dict[key] for key in non_esen_genes_list if key in literature_gene_dict}

# %%
len(common_esen_genes_dict)
# Out:
# 55

# %%
len(selec_esen_genes_dict)
# Out:
# 333

# %%
len(non_esen_genes_dict)
# Out:
# 172

# %% [markdown]
# #### Common-Essential Genes Plot:

# %%
CE_cell_line_df = cell_line_plot(common_esen_genes_dict, trimmed_esen_df, all_aa_ids, ec_aa_plus_ids, "CE_cell_line")
# Out:
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
# ...
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)

# %%
CE_cell_line_df[CE_cell_line_df['p-value'] < 0.05]
# Out:
#                       Cell-Line    H-stat   p-value
# 242  ACH-000783 (ecDNA present)  6.930234  0.031269

# %% [markdown]
# #### Selectively-Essential Genes Plot:

# %%
SE_cell_line_df = cell_line_plot(selec_esen_genes_dict, trimmed_esen_df, all_aa_ids, ec_aa_plus_ids, "SE_cell_line")
# Out:
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
# ...
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)

# %%
SE_cell_line_df[SE_cell_line_df['p-value'] < 0.05]
# Out:
#                       Cell-Line     H-stat       p-value
# 80    ACH-000595 (ecDNA absent)  51.613126  6.199434e-12
# 203  ACH-000738 (ecDNA present)  41.599279  9.264702e-10
# 69   ACH-000900 (ecDNA present)  40.819003  1.368567e-09
# 21    ACH-000948 (ecDNA absent)  40.539909  1.573514e-09
# 75   ACH-000756 (ecDNA present)  40.263163  1.807029e-09
# ..                          ...        ...           ...
# 30    ACH-001129 (ecDNA absent)   8.843757  1.201165e-02
# 78    ACH-000985 (ecDNA absent)   7.908638  1.917172e-02
# 163   ACH-000139 (ecDNA absent)   7.114331  2.851955e-02
# 17   ACH-000311 (ecDNA present)   6.831990  3.284371e-02
# 148  ACH-000515 (ecDNA present)   6.357901  4.162933e-02
#
# [244 rows x 3 columns]

# %% [markdown]
# #### Non-Essential Genes Plot:

# %%
NE_cell_line_df = cell_line_plot(non_esen_genes_dict, trimmed_esen_df, all_aa_ids, ec_aa_plus_ids, "NE_cell_line")
# Out:
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
# ...
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:370: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)

# %%
NE_cell_line_df[NE_cell_line_df['p-value'] < 0.05]
# Out:
#                       Cell-Line     H-stat   p-value
# 121  ACH-000713 (ecDNA present)  10.504596  0.005235
# 65    ACH-000943 (ecDNA absent)  10.281577  0.005853
# 180   ACH-000486 (ecDNA absent)   9.218197  0.009961
# 68    ACH-000939 (ecDNA absent)   9.154954  0.010281
# 177  ACH-000986 (ecDNA present)   8.559433  0.013847
# 176  ACH-000894 (ecDNA present)   7.513751  0.023357
# 27    ACH-000343 (ecDNA absent)   6.889644  0.031910
# 109   ACH-000219 (ecDNA absent)   6.814067  0.033139
# 78    ACH-000985 (ecDNA absent)   6.526741  0.038259

# %% [markdown]
# ## Grouped Cell-Line Plots:

# %% [markdown]
# ### Calculating mean essentiality values across <b>all</b> cell-lines for each category:

# %%
meta_df_reset = meta_df.reset_index()
oncotree_lineage_dict = group_cell_lines(meta_df_reset, "ModelID", "OncotreeLineage")

# %%
oncotree_lineage_dict
# Out:
# {'Adrenal Gland': ['ACH-001401', 'ACH-001598'],
#  'Ampulla of Vater': ['ACH-000182', 'ACH-000377', 'ACH-001862', 'ACH-002023'],
#  'Biliary Tract': ['ACH-000141',
#   'ACH-000209',
#   'ACH-000268',
#   'ACH-000461',
#   'ACH-000808',
#   'ACH-000976',
#   'ACH-001494',
#   'ACH-001536',
#   'ACH-001537',
#   'ACH-001538',
#   'ACH-001607',
#   'ACH-001619',
#   'ACH-001673',
#   'ACH-001834',
#   'ACH-001835',
#   'ACH-001836',
#   'ACH-001838',
#   'ACH-001839',
#   'ACH-001841',
#   'ACH-001842',
#   'ACH-001843',
#   'ACH-001844',
#   'ACH-001845',
#   'ACH-001846',
#   'ACH-001847',
#   'ACH-001848',
#   'ACH-001849',
#   'ACH-001850',
#   'ACH-001852',
#   'ACH-001854',
#   'ACH-001855',
#   'ACH-001856',
#   'ACH-001857',
#   'ACH-001858',
#   'ACH-001861',
#   'ACH-001863',
#   'ACH-001864',
#   'ACH-001959',
#   'ACH-001960',
#   'ACH-001961',
#   'ACH-001997',
#   'ACH-002237',
#   'ACH-002312',
#   'ACH-002647'],
#  'Bladder/Urinary Tract': ['ACH-000011',
#   'ACH-000018',
#   'ACH-000026',
#   'ACH-000127',
#   'ACH-000142',
#   'ACH-000242',
#   'ACH-000384',
#   'ACH-000396',
#   'ACH-000473',
#   'ACH-000486',
#   'ACH-000522',
#   'ACH-000545',
#   'ACH-000547',
#   'ACH-000566',
#   'ACH-000593',
#   'ACH-000720',
#   'ACH-000724',
#   'ACH-000741',
#   'ACH-000753',
#   'ACH-000802',
#   'ACH-000834',
#   'ACH-000839',
#   'ACH-000862',
#   'ACH-000896',
#   'ACH-000905',
#   'ACH-000973',
#   'ACH-001183',
#   'ACH-001407',
#   'ACH-001408',
#   'ACH-001409',
#   'ACH-001410',
#   'ACH-001411',
#   'ACH-001412',
#   'ACH-001413',
#   'ACH-001414',
#   'ACH-001415',
#   'ACH-001416',
#   'ACH-002235',
#   'ACH-002266'],
#  'Bone': ['ACH-000039',
#   'ACH-000041',
#   'ACH-000052',
#   'ACH-000082',
#   'ACH-000087',
#   'ACH-000210',
#   'ACH-000279',
#   'ACH-000359',
#   'ACH-000364',
#   'ACH-000391',
#   'ACH-000410',
#   'ACH-000418',
#   'ACH-000424',
#   'ACH-000499',
#   'ACH-000516',
#   'ACH-000613',
#   'ACH-000748',
#   'ACH-001001',
#   'ACH-001007',
#   'ACH-001008',
#   'ACH-001009',
#   'ACH-001010',
#   'ACH-001022',
#   'ACH-001029',
#   'ACH-001030',
#   'ACH-001032',
#   'ACH-001034',
#   'ACH-001035',
#   'ACH-001038',
#   'ACH-001066',
#   'ACH-001094',
#   'ACH-001150',
#   'ACH-001192',
#   'ACH-001193',
#   'ACH-001205',
#   'ACH-001206',
#   'ACH-001282',
#   'ACH-001283',
#   'ACH-001430',
#   'ACH-001431',
#   'ACH-001519',
#   'ACH-001526',
#   'ACH-001712',
#   'ACH-001715',
#   'ACH-001814',
#   'ACH-001818',
#   'ACH-002067',
#   'ACH-002069',
#   'ACH-002092',
#   'ACH-002093',
#   'ACH-002094',
#   'ACH-002099',
#   'ACH-002103',
#   'ACH-002104',
#   'ACH-002105',
#   'ACH-002106',
#   'ACH-002107',
#   'ACH-002108',
#   'ACH-002109',
#   'ACH-002110',
#   'ACH-002111',
#   'ACH-002112',
#   'ACH-002113',
#   'ACH-002114',
#   'ACH-002115',
#   'ACH-002116',
#   'ACH-002117',
#   'ACH-002118',
#   'ACH-002119',
#   'ACH-002142',
#   'ACH-002160',
#   'ACH-002178',
#   'ACH-002204',
#   'ACH-002471',
#   'ACH-002780',
#   'ACH-002781',
#   'ACH-002834',
#   'ACH-003191'],
#  'Bowel': ['ACH-000003',
#   'ACH-000007',
#   'ACH-000009',
#   'ACH-000089',
#   'ACH-000202',
#   'ACH-000236',
#   'ACH-000249',
#   'ACH-000252',
#   'ACH-000253',
#   'ACH-000286',
#   'ACH-000296',
#   'ACH-000342',
#   'ACH-000350',
#   'ACH-000360',
#   'ACH-000381',
#   'ACH-000400',
#   'ACH-000403',
#   'ACH-000412',
#   'ACH-000421',
#   'ACH-000467',
#   'ACH-000470',
#   'ACH-000489',
#   'ACH-000491',
#   'ACH-000501',
#   'ACH-000532',
#   'ACH-000538',
#   'ACH-000552',
#   'ACH-000565',
#   'ACH-000651',
#   'ACH-000680',
#   'ACH-000683',
#   'ACH-000708',
#   'ACH-000710',
#   'ACH-000722',
#   'ACH-000798',
#   'ACH-000820',
#   'ACH-000842',
#   'ACH-000895',
#   'ACH-000926',
#   'ACH-000935',
#   'ACH-000943',
#   'ACH-000950',
#   'ACH-000955',
#   'ACH-000957',
#   'ACH-000958',
#   'ACH-000959',
#   'ACH-000963',
#   'ACH-000967',
#   'ACH-000969',
#   'ACH-000970',
#   'ACH-000971',
#   'ACH-000982',
#   'ACH-000985',
#   'ACH-000986',
#   'ACH-000989',
#   'ACH-000991',
#   'ACH-000997',
#   'ACH-000998',
#   'ACH-000999',
#   'ACH-001015',
#   'ACH-001039',
#   'ACH-001061',
#   'ACH-001081',
#   'ACH-001084',
#   'ACH-001091',
#   'ACH-001199',
#   'ACH-001345',
#   'ACH-001399',
#   'ACH-001454',
#   'ACH-001456',
#   'ACH-001458',
#   'ACH-001459',
#   'ACH-001460',
#   'ACH-001461',
#   'ACH-001786',
#   'ACH-001825',
#   'ACH-002024',
#   'ACH-002025',
#   'ACH-002219',
#   'ACH-002233',
#   'ACH-002287',
#   'ACH-002345',
#   'ACH-002535',
#   'ACH-002539',
#   'ACH-002543',
#   'ACH-002654',
#   'ACH-002659',
#   'ACH-002660',
#   'ACH-002662',
#   'ACH-002664',
#   'ACH-002669',
#   'ACH-002839'],
#  'Breast': ['ACH-000017',
#   'ACH-000019',
#   'ACH-000028',
#   'ACH-000044',
#   'ACH-000097',
#   'ACH-000111',
#   'ACH-000117',
#   'ACH-000147',
#   'ACH-000148',
#   'ACH-000196',
#   'ACH-000212',
#   'ACH-000223',
#   'ACH-000248',
#   'ACH-000258',
#   'ACH-000276',
#   'ACH-000277',
#   'ACH-000288',
#   'ACH-000330',
#   'ACH-000349',
#   'ACH-000352',
#   'ACH-000374',
#   'ACH-000536',
#   'ACH-000554',
#   'ACH-000568',
#   'ACH-000573',
#   'ACH-000621',
#   'ACH-000624',
#   'ACH-000642',
#   'ACH-000643',
#   'ACH-000668',
#   'ACH-000691',
#   'ACH-000699',
#   'ACH-000711',
#   'ACH-000721',
#   'ACH-000725',
#   'ACH-000755',
#   'ACH-000759',
#   'ACH-000768',
#   'ACH-000783',
#   'ACH-000818',
#   'ACH-000828',
#   'ACH-000849',
#   'ACH-000856',
#   'ACH-000857',
#   'ACH-000859',
#   'ACH-000876',
#   'ACH-000902',
#   'ACH-000910',
#   'ACH-000927',
#   'ACH-000930',
#   'ACH-000934',
#   'ACH-001065',
#   'ACH-001249',
#   'ACH-001357',
#   'ACH-001358',
#   'ACH-001388',
#   'ACH-001389',
#   'ACH-001390',
#   'ACH-001391',
#   'ACH-001392',
#   'ACH-001393',
#   'ACH-001394',
#   'ACH-001395',
#   'ACH-001396',
#   'ACH-001397',
#   'ACH-001419',
#   'ACH-001514',
#   'ACH-001662',
#   'ACH-001683',
#   'ACH-001705',
#   'ACH-001819',
#   'ACH-001820',
#   'ACH-001827',
#   'ACH-002163',
#   'ACH-002179',
#   'ACH-002208',
#   'ACH-002319',
#   'ACH-002320',
#   'ACH-002321',
#   'ACH-002322',
#   'ACH-002323',
#   'ACH-002324',
#   'ACH-002325',
#   'ACH-002326',
#   'ACH-002327',
#   'ACH-002328',
#   'ACH-002329',
#   'ACH-002330',
#   'ACH-002331',
#   'ACH-002399',
#   'ACH-002401',
#   'ACH-002883',
#   'ACH-002884',
#   'ACH-002885',
#   'ACH-002921',
#   'ACH-002950',
#   'ACH-002951'],
#  'CNS/Brain': ['ACH-000025',
#   'ACH-000027',
#   'ACH-000036',
#   'ACH-000040',
#   'ACH-000055',
#   'ACH-000067',
#   'ACH-000075',
#   'ACH-000095',
#   'ACH-000098',
#   'ACH-000102',
#   'ACH-000126',
#   'ACH-000128',
#   'ACH-000137',
#   'ACH-000152',
#   'ACH-000160',
#   'ACH-000200',
#   'ACH-000208',
#   'ACH-000211',
#   'ACH-000215',
#   'ACH-000231',
#   'ACH-000232',
#   'ACH-000244',
#   'ACH-000269',
#   'ACH-000273',
#   'ACH-000283',
#   'ACH-000289',
#   'ACH-000323',
#   'ACH-000328',
#   'ACH-000329',
#   'ACH-000368',
#   'ACH-000370',
#   'ACH-000376',
#   'ACH-000389',
#   'ACH-000437',
#   'ACH-000445',
#   'ACH-000455',
#   'ACH-000464',
#   'ACH-000469',
#   'ACH-000479',
#   'ACH-000504',
#   'ACH-000543',
#   'ACH-000558',
#   'ACH-000570',
#   'ACH-000571',
#   'ACH-000591',
#   'ACH-000592',
#   'ACH-000595',
#   'ACH-000609',
#   'ACH-000622',
#   'ACH-000623',
#   'ACH-000629',
#   'ACH-000631',
#   'ACH-000634',
#   'ACH-000655',
#   'ACH-000673',
#   'ACH-000676',
#   'ACH-000738',
#   'ACH-000756',
#   'ACH-000760',
#   'ACH-000776',
#   'ACH-000807',
#   'ACH-000819',
#   'ACH-000863',
#   'ACH-000883',
#   'ACH-000887',
#   'ACH-001000',
#   'ACH-001016',
#   'ACH-001020',
#   'ACH-001028',
#   'ACH-001031',
#   'ACH-001033',
#   'ACH-001052',
#   'ACH-001053',
#   'ACH-001054',
#   'ACH-001055',
#   'ACH-001067',
#   'ACH-001118',
#   'ACH-001125',
#   'ACH-001126',
#   'ACH-001142',
#   'ACH-001172',
#   'ACH-001198',
#   'ACH-001201',
#   'ACH-001214',
#   'ACH-001232',
#   'ACH-001289',
#   'ACH-001329',
#   'ACH-001605',
#   'ACH-001606',
#   'ACH-001608',
#   'ACH-001609',
#   'ACH-001610',
#   'ACH-001611',
#   'ACH-001622',
#   'ACH-001623',
#   'ACH-001624',
#   'ACH-001670',
#   'ACH-001711',
#   'ACH-002070',
#   'ACH-002223',
#   'ACH-002224',
#   'ACH-002225',
#   'ACH-002226',
#   'ACH-002227',
#   'ACH-002228',
#   'ACH-002229',
#   'ACH-002230',
#   'ACH-002231',
#   'ACH-002257',
#   'ACH-002259',
#   'ACH-002268',
#   'ACH-002269',
#   'ACH-002304',
#   'ACH-002348',
#   'ACH-002349',
#   'ACH-002680',
#   'ACH-002806',
#   'ACH-003135',
#   'ACH-003137',
#   'ACH-003138',
#   'ACH-003148',
#   'ACH-003150'],
#  'Cervix': ['ACH-000490',
#   'ACH-000556',
#   'ACH-001017',
#   'ACH-001071',
#   'ACH-001086',
#   'ACH-001333',
#   'ACH-001334',
#   'ACH-001335',
#   'ACH-001336',
#   'ACH-001341',
#   'ACH-001359',
#   'ACH-001360',
#   'ACH-001402',
#   'ACH-001451',
#   'ACH-001513',
#   'ACH-001515',
#   'ACH-001516',
#   'ACH-001525',
#   'ACH-001650',
#   'ACH-001651',
#   'ACH-001652',
#   'ACH-002019',
#   'ACH-002020',
#   'ACH-002180',
#   'ACH-002201'],
#  'Embryonal': ['ACH-003145'],
#  'Esophagus/Stomach': ['ACH-000047',
#   'ACH-000110',
#   'ACH-000144',
#   'ACH-000216',
#   'ACH-000225',
#   'ACH-000239',
#   'ACH-000247',
#   'ACH-000255',
#   'ACH-000303',
#   'ACH-000305',
#   'ACH-000318',
#   'ACH-000325',
#   'ACH-000344',
#   'ACH-000351',
#   'ACH-000353',
#   'ACH-000356',
#   'ACH-000383',
#   'ACH-000408',
#   'ACH-000427',
#   'ACH-000452',
#   'ACH-000466',
#   'ACH-000485',
#   'ACH-000488',
#   'ACH-000507',
#   'ACH-000544',
#   'ACH-000560',
#   'ACH-000561',
#   'ACH-000581',
#   'ACH-000605',
#   'ACH-000616',
#   'ACH-000633',
#   'ACH-000637',
#   'ACH-000647',
#   'ACH-000674',
#   'ACH-000678',
#   'ACH-000679',
#   'ACH-000693',
#   'ACH-000694',
#   'ACH-000717',
#   'ACH-000726',
#   'ACH-000736',
#   'ACH-000746',
#   'ACH-000758',
#   'ACH-000761',
#   'ACH-000764',
#   'ACH-000777',
#   'ACH-000784',
#   'ACH-000793',
#   'ACH-000809',
#   'ACH-000823',
#   'ACH-000824',
#   'ACH-000847',
#   'ACH-000855',
#   'ACH-000865',
#   'ACH-000873',
#   'ACH-000880',
#   'ACH-000898',
#   'ACH-000908',
#   'ACH-000911',
#   'ACH-000917',
#   'ACH-000919',
#   'ACH-000932',
#   'ACH-000948',
#   'ACH-000949',
#   'ACH-001368',
#   'ACH-001496',
#   'ACH-001497',
#   'ACH-001500',
#   'ACH-001544',
#   'ACH-001653',
#   'ACH-001654',
#   'ACH-001664',
#   'ACH-002141',
#   'ACH-002161',
#   'ACH-002202',
#   'ACH-002243',
#   'ACH-002263',
#   'ACH-002264',
#   'ACH-002292',
#   'ACH-002306',
#   'ACH-002311',
#   'ACH-002446',
#   'ACH-002705',
#   'ACH-002706',
#   'ACH-002730',
#   'ACH-002733',
#   'ACH-002736',
#   'ACH-002757',
#   'ACH-002835',
#   'ACH-002837',
#   'ACH-002871',
#   'ACH-002954',
#   'ACH-002967',
#   'ACH-002968',
#   'ACH-002972',
#   'ACH-002979',
#   'ACH-002981'],
#  'Eye': ['ACH-001295',
#   'ACH-001421',
#   'ACH-001441',
#   'ACH-001554',
#   'ACH-002010',
#   'ACH-002011',
#   'ACH-002014',
#   'ACH-002015',
#   'ACH-002016',
#   'ACH-002017',
#   'ACH-002018',
#   'ACH-002336',
#   'ACH-002462',
#   'ACH-002463',
#   'ACH-002464',
#   'ACH-002465',
#   'ACH-002466',
#   'ACH-002467',
#   'ACH-002687',
#   'ACH-002925',
#   'ACH-002926'],
#  'Fibroblast': ['ACH-000043',
#   'ACH-000063',
#   'ACH-000071',
#   'ACH-000079',
#   'ACH-000083',
#   'ACH-000088',
#   'ACH-000119',
#   'ACH-000125',
#   'ACH-000131',
#   'ACH-000133',
#   'ACH-000134',
#   'ACH-000135',
#   'ACH-000154',
#   'ACH-000165',
#   'ACH-000175',
#   'ACH-000180',
#   'ACH-000184',
#   'ACH-000185',
#   'ACH-000194',
#   'ACH-000199',
#   'ACH-000214',
#   'ACH-000224',
#   'ACH-000229',
#   'ACH-000230',
#   'ACH-000240',
#   'ACH-000275',
#   'ACH-000284',
#   'ACH-000306',
#   'ACH-000340',
#   'ACH-000413',
#   'ACH-000526',
#   'ACH-000529',
#   'ACH-000531',
#   'ACH-000539',
#   'ACH-000540',
#   'ACH-000742',
#   'ACH-000797',
#   'ACH-000850',
#   'ACH-001018',
#   'ACH-001093',
#   'ACH-001207',
#   'ACH-001767'],
#  'Hair': ['ACH-003159', 'ACH-003160'],
#  'Head and Neck': ['ACH-000163',
#   'ACH-000181',
#   'ACH-000188',
#   'ACH-000207',
#   'ACH-000228',
#   'ACH-000238',
#   'ACH-000254',
#   'ACH-000415',
#   'ACH-000472',
#   'ACH-000500',
#   'ACH-000503',
#   'ACH-000518',
#   'ACH-000546',
#   'ACH-000548',
#   'ACH-000549',
#   'ACH-000606',
#   'ACH-000618',
#   'ACH-000619',
#   'ACH-000630',
#   'ACH-000682',
#   'ACH-000692',
#   'ACH-000715',
#   'ACH-000723',
#   'ACH-000732',
#   'ACH-000735',
#   'ACH-000740',
#   'ACH-000762',
#   'ACH-000771',
#   'ACH-000778',
#   'ACH-000794',
#   'ACH-000832',
#   'ACH-000836',
#   'ACH-000846',
#   'ACH-000992',
#   'ACH-001023',
#   'ACH-001090',
#   'ACH-001227',
#   'ACH-001228',
#   'ACH-001229',
#   'ACH-001331',
#   'ACH-001332',
#   'ACH-001346',
#   'ACH-001347',
#   'ACH-001385',
#   'ACH-001508',
#   'ACH-001509',
#   'ACH-001510',
#   'ACH-001511',
#   'ACH-001542',
#   'ACH-001543',
#   'ACH-001625',
#   'ACH-001626',
#   'ACH-001641',
#   'ACH-001675',
#   'ACH-001690',
#   'ACH-001691',
#   'ACH-001692',
#   'ACH-001693',
#   'ACH-001694',
#   'ACH-001695',
#   'ACH-001696',
#   'ACH-001698',
#   'ACH-001699',
#   'ACH-001701',
#   'ACH-002029',
#   'ACH-002030',
#   'ACH-002042',
#   'ACH-002043',
#   'ACH-002044',
#   'ACH-002045',
#   'ACH-002212',
#   'ACH-002213',
#   'ACH-002234',
#   'ACH-002239',
#   'ACH-002244',
#   'ACH-002249',
#   'ACH-002250',
#   'ACH-002251',
#   'ACH-002265',
#   'ACH-002294',
#   'ACH-002295',
#   'ACH-002296',
#   'ACH-002297',
#   'ACH-002298',
#   'ACH-002305',
#   'ACH-002711',
#   'ACH-003099'],
#  'Kidney': ['ACH-000016',
#   'ACH-000046',
#   'ACH-000049',
#   'ACH-000096',
#   'ACH-000159',
#   'ACH-000171',
#   'ACH-000189',
#   'ACH-000201',
#   'ACH-000234',
#   'ACH-000246',
#   'ACH-000250',
#   'ACH-000262',
#   'ACH-000272',
#   'ACH-000300',
#   'ACH-000313',
#   'ACH-000317',
#   'ACH-000375',
#   'ACH-000385',
#   'ACH-000411',
#   'ACH-000428',
#   'ACH-000429',
#   'ACH-000433',
#   'ACH-000457',
#   'ACH-000459',
#   'ACH-000484',
#   'ACH-000495',
#   'ACH-000513',
#   'ACH-000533',
#   'ACH-000555',
#   'ACH-000600',
#   'ACH-000649',
#   'ACH-000684',
#   'ACH-000709',
#   'ACH-000792',
#   'ACH-000907',
#   'ACH-001087',
#   'ACH-001109',
#   'ACH-001163',
#   'ACH-001175',
#   'ACH-001194',
#   'ACH-001200',
#   'ACH-001208',
#   'ACH-001210',
#   'ACH-001224',
#   'ACH-001225',
#   'ACH-001310',
#   'ACH-001398',
#   'ACH-001532',
#   'ACH-001687',
#   'ACH-001688',
#   'ACH-002090',
#   'ACH-002139',
#   'ACH-002150',
#   'ACH-002151',
#   'ACH-002155',
#   'ACH-002167',
#   'ACH-002168',
#   'ACH-002187',
#   'ACH-002188',
#   'ACH-002189',
#   'ACH-002190',
#   'ACH-002191',
#   'ACH-002192',
#   'ACH-002195',
#   'ACH-002199',
#   'ACH-002533',
#   'ACH-003143'],
#  'Liver': ['ACH-000217',
#   'ACH-000221',
#   'ACH-000316',
#   'ACH-000361',
#   'ACH-000393',
#   'ACH-000420',
#   'ACH-000422',
#   'ACH-000471',
#   'ACH-000475',
#   'ACH-000476',
#   'ACH-000478',
#   'ACH-000480',
#   'ACH-000483',
#   'ACH-000493',
#   'ACH-000537',
#   'ACH-000577',
#   'ACH-000620',
#   'ACH-000625',
#   'ACH-000671',
#   'ACH-000686',
#   'ACH-000734',
#   'ACH-000739',
#   'ACH-000848',
#   'ACH-001021',
#   'ACH-001089',
#   'ACH-001318',
#   'ACH-001853',
#   'ACH-002523',
#   'ACH-003155'],
#  'Lung': ['ACH-000012',
#   'ACH-000015',
#   'ACH-000021',
#   'ACH-000029',
#   'ACH-000030',
#   'ACH-000033',
#   'ACH-000035',
#   'ACH-000062',
#   'ACH-000064',
#   'ACH-000066',
#   'ACH-000109',
#   'ACH-000121',
#   'ACH-000129',
#   'ACH-000143',
#   'ACH-000150',
#   'ACH-000161',
#   'ACH-000176',
#   'ACH-000179',
#   'ACH-000186',
#   'ACH-000187',
#   'ACH-000251',
#   'ACH-000257',
#   'ACH-000261',
#   'ACH-000264',
#   'ACH-000282',
#   'ACH-000290',
#   'ACH-000292',
#   'ACH-000297',
#   'ACH-000298',
#   'ACH-000309',
#   'ACH-000311',
#   'ACH-000314',
#   'ACH-000327',
#   'ACH-000337',
#   'ACH-000339',
#   'ACH-000343',
#   'ACH-000355',
#   'ACH-000358',
#   'ACH-000378',
#   'ACH-000379',
#   'ACH-000382',
#   'ACH-000390',
#   'ACH-000392',
#   'ACH-000394',
#   'ACH-000395',
#   'ACH-000399',
#   'ACH-000414',
#   'ACH-000416',
#   'ACH-000431',
#   'ACH-000434',
#   'ACH-000438',
#   'ACH-000442',
#   'ACH-000444',
#   'ACH-000447',
#   'ACH-000448',
#   'ACH-000451',
#   'ACH-000454',
#   'ACH-000463',
#   'ACH-000481',
#   'ACH-000482',
#   'ACH-000496',
#   'ACH-000506',
#   'ACH-000508',
#   'ACH-000510',
#   'ACH-000511',
#   'ACH-000514',
#   'ACH-000515',
#   'ACH-000521',
#   'ACH-000523',
#   'ACH-000525',
#   'ACH-000528',
#   'ACH-000530',
#   'ACH-000553',
#   'ACH-000559',
#   'ACH-000562',
#   'ACH-000563',
#   'ACH-000575',
#   'ACH-000578',
#   'ACH-000585',
#   'ACH-000586',
#   'ACH-000587',
#   'ACH-000589',
#   'ACH-000590',
#   'ACH-000594',
#   'ACH-000596',
#   'ACH-000603',
#   'ACH-000610',
#   'ACH-000627',
#   'ACH-000628',
#   'ACH-000638',
#   'ACH-000639',
#   'ACH-000659',
#   'ACH-000662',
#   'ACH-000665',
#   'ACH-000666',
#   'ACH-000667',
#   'ACH-000669',
#   'ACH-000670',
#   'ACH-000672',
#   'ACH-000675',
#   'ACH-000677',
#   'ACH-000681',
#   'ACH-000690',
#   'ACH-000695',
#   'ACH-000698',
#   'ACH-000700',
#   'ACH-000703',
#   'ACH-000705',
#   'ACH-000706',
#   'ACH-000712',
#   'ACH-000718',
#   'ACH-000727',
#   'ACH-000729',
#   'ACH-000731',
#   'ACH-000733',
#   'ACH-000737',
#   'ACH-000743',
#   'ACH-000744',
#   'ACH-000747',
#   'ACH-000749',
#   'ACH-000752',
#   'ACH-000757',
#   'ACH-000766',
#   'ACH-000767',
#   'ACH-000769',
#   'ACH-000774',
#   'ACH-000775',
#   'ACH-000779',
#   'ACH-000780',
#   'ACH-000781',
#   'ACH-000785',
#   'ACH-000787',
#   'ACH-000789',
#   'ACH-000790',
#   'ACH-000791',
#   'ACH-000800',
#   'ACH-000803',
#   'ACH-000813',
#   'ACH-000816',
#   'ACH-000825',
#   'ACH-000826',
#   'ACH-000830',
#   'ACH-000837',
#   'ACH-000840',
#   'ACH-000841',
#   'ACH-000843',
#   'ACH-000844',
#   'ACH-000845',
#   'ACH-000851',
#   'ACH-000852',
#   'ACH-000853',
#   'ACH-000858',
#   'ACH-000860',
#   'ACH-000861',
#   'ACH-000866',
#   'ACH-000867',
#   'ACH-000868',
#   'ACH-000869',
#   'ACH-000870',
#   'ACH-000871',
#   'ACH-000872',
#   'ACH-000875',
#   'ACH-000878',
#   'ACH-000886',
#   'ACH-000888',
#   'ACH-000890',
#   'ACH-000891',
#   'ACH-000892',
#   'ACH-000893',
#   'ACH-000894',
#   'ACH-000900',
#   'ACH-000901',
#   'ACH-000904',
#   'ACH-000912',
#   'ACH-000916',
#   'ACH-000921',
#   'ACH-000924',
#   'ACH-000925',
#   'ACH-000929',
#   'ACH-000945',
#   'ACH-000951',
#   'ACH-000975',
#   'ACH-000980',
#   'ACH-001047',
#   'ACH-001049',
#   'ACH-001075',
#   'ACH-001079',
#   'ACH-001088',
#   'ACH-001113',
#   'ACH-001136',
#   'ACH-001137',
#   'ACH-001138',
#   'ACH-001233',
#   'ACH-001234',
#   'ACH-001362',
#   'ACH-001363',
#   'ACH-001364',
#   'ACH-001365',
#   'ACH-001386',
#   'ACH-001417',
#   'ACH-001489',
#   'ACH-001490',
#   'ACH-001549',
#   'ACH-001591',
#   'ACH-001599',
#   'ACH-001958',
#   'ACH-002035',
#   'ACH-002051',
#   'ACH-002052',
#   'ACH-002077',
#   'ACH-002089',
#   'ACH-002095',
#   'ACH-002101',
#   'ACH-002102',
#   'ACH-002122',
#   'ACH-002138',
#   'ACH-002144',
#   'ACH-002145',
#   'ACH-002154',
#   'ACH-002156',
#   'ACH-002157',
#   'ACH-002158',
#   'ACH-002169',
#   'ACH-002170',
#   'ACH-002171',
#   'ACH-002172',
#   'ACH-002173',
#   'ACH-002174',
#   'ACH-002175',
#   'ACH-002177',
#   'ACH-002184',
#   'ACH-002193',
#   'ACH-002196',
#   'ACH-002197',
#   'ACH-002286',
#   'ACH-002333',
#   'ACH-002337',
#   'ACH-002490',
#   'ACH-002497',
#   'ACH-002522',
#   'ACH-002526',
#   'ACH-002531',
#   'ACH-002650',
#   'ACH-002996',
#   'ACH-003012',
#   'ACH-003071',
#   'ACH-003119',
#   'ACH-003120',
#   'ACH-003121',
#   'ACH-003152',
#   'ACH-003153',
#   'ACH-003154',
#   'ACH-003156',
#   'ACH-003157'],
#  'Lymphoid': ['ACH-000020',
#   'ACH-000024',
#   'ACH-000032',
#   'ACH-000038',
#   'ACH-000050',
#   'ACH-000053',
#   'ACH-000056',
#   'ACH-000057',
#   'ACH-000059',
#   'ACH-000061',
#   'ACH-000068',
#   'ACH-000069',
#   'ACH-000070',
#   'ACH-000073',
#   'ACH-000077',
#   'ACH-000101',
#   'ACH-000104',
#   'ACH-000105',
#   'ACH-000106',
#   'ACH-000122',
#   'ACH-000124',
#   'ACH-000130',
#   'ACH-000140',
#   'ACH-000151',
#   'ACH-000156',
#   'ACH-000157',
#   'ACH-000158',
#   'ACH-000162',
#   'ACH-000167',
#   'ACH-000183',
#   'ACH-000193',
#   'ACH-000197',
#   'ACH-000204',
#   'ACH-000206',
#   'ACH-000220',
#   'ACH-000226',
#   'ACH-000233',
#   'ACH-000245',
#   'ACH-000267',
#   'ACH-000271',
#   'ACH-000285',
#   'ACH-000287',
#   'ACH-000315',
#   'ACH-000334',
#   'ACH-000338',
#   'ACH-000346',
#   'ACH-000357',
#   'ACH-000363',
#   'ACH-000365',
#   'ACH-000371',
#   'ACH-000372',
#   'ACH-000380',
#   'ACH-000388',
#   'ACH-000398',
#   'ACH-000402',
#   'ACH-000405',
#   'ACH-000419',
#   'ACH-000426',
#   'ACH-000436',
#   'ACH-000440',
#   'ACH-000453',
#   'ACH-000492',
#   'ACH-000509',
#   'ACH-000512',
#   'ACH-000519',
#   'ACH-000534',
#   'ACH-000541',
#   'ACH-000564',
#   'ACH-000567',
#   'ACH-000576',
#   'ACH-000583',
#   'ACH-000588',
#   'ACH-000598',
#   'ACH-000611',
#   'ACH-000612',
#   'ACH-000626',
#   'ACH-000636',
#   'ACH-000653',
#   'ACH-000654',
#   'ACH-000656',
#   'ACH-000658',
#   'ACH-000660',
#   'ACH-000664',
#   'ACH-000687',
#   'ACH-000697',
#   'ACH-000702',
#   'ACH-000707',
#   'ACH-000714',
#   'ACH-000728',
#   'ACH-000745',
#   'ACH-000754',
#   'ACH-000763',
#   'ACH-000773',
#   'ACH-000782',
#   'ACH-000786',
#   'ACH-000795',
#   'ACH-000806',
#   'ACH-000815',
#   'ACH-000817',
#   'ACH-000821',
#   'ACH-000829',
#   'ACH-000838',
#   'ACH-000854',
#   'ACH-000874',
#   'ACH-000877',
#   'ACH-000889',
#   'ACH-000914',
#   'ACH-000918',
#   'ACH-000922',
#   'ACH-000923',
#   'ACH-000937',
#   'ACH-000938',
#   'ACH-000942',
#   'ACH-000944',
#   'ACH-000953',
#   'ACH-000960',
#   'ACH-000964',
#   'ACH-000981',
#   'ACH-000995',
#   'ACH-001043',
#   'ACH-001057',
#   'ACH-001060',
#   'ACH-001064',
#   'ACH-001068',
#   'ACH-001097',
#   'ACH-001100',
#   'ACH-001106',
#   'ACH-001111',
#   'ACH-001119',
#   'ACH-001121',
#   'ACH-001127',
#   'ACH-001130',
#   'ACH-001132',
#   'ACH-001134',
#   'ACH-001143',
#   'ACH-001146',
#   'ACH-001147',
#   'ACH-001148',
#   'ACH-001162',
#   'ACH-001182',
#   'ACH-001197',
#   'ACH-001203',
#   'ACH-001450',
#   'ACH-001452',
#   'ACH-001484',
#   'ACH-001485',
#   'ACH-001498',
#   'ACH-001520',
#   'ACH-001533',
#   'ACH-001539',
#   'ACH-001541',
#   'ACH-001616',
#   'ACH-001617',
#   'ACH-001634',
#   'ACH-001636',
#   'ACH-001638',
#   'ACH-001639',
#   'ACH-001642',
#   'ACH-001669',
#   'ACH-001677',
#   'ACH-001679',
#   'ACH-001680',
#   'ACH-001685',
#   'ACH-001703',
#   'ACH-001707',
#   'ACH-001708',
#   'ACH-001709',
#   'ACH-001735',
#   'ACH-001736',
#   'ACH-001737',
#   'ACH-001738',
#   'ACH-001993',
#   'ACH-002055',
#   'ACH-002058',
#   'ACH-002059',
#   'ACH-002062',
#   'ACH-002209',
#   'ACH-002211',
#   'ACH-002214',
#   'ACH-002215',
#   'ACH-002216',
#   'ACH-002220',
#   'ACH-002221',
#   'ACH-002222',
#   'ACH-002232',
#   'ACH-002236',
#   'ACH-002238',
#   'ACH-002240',
#   'ACH-002241',
#   'ACH-002242',
#   'ACH-002245',
#   'ACH-002252',
#   'ACH-002253',
#   'ACH-002254',
#   'ACH-002255',
#   'ACH-002256',
#   'ACH-002267',
#   'ACH-002272',
#   'ACH-002274',
#   'ACH-002275',
#   'ACH-002289',
#   'ACH-002293',
#   'ACH-002300',
#   'ACH-002301',
#   'ACH-002307',
#   'ACH-002308',
#   'ACH-002313',
#   'ACH-002317',
#   'ACH-002339',
#   'ACH-002392',
#   'ACH-002478',
#   'ACH-002485',
#   'ACH-002500',
#   'ACH-002677',
#   'ACH-002678',
#   'ACH-003100',
#   'ACH-003106',
#   'ACH-003107',
#   'ACH-003108'],
#  'Muscle': ['ACH-003139',
#   'ACH-003141',
#   'ACH-003142',
#   'ACH-003149',
#   'ACH-003158'],
#  'Myeloid': ['ACH-000002',
#   'ACH-000004',
#   'ACH-000005',
#   'ACH-000006',
#   'ACH-000034',
#   'ACH-000045',
#   'ACH-000065',
#   'ACH-000072',
#   'ACH-000074',
#   'ACH-000076',
#   'ACH-000080',
#   'ACH-000081',
#   'ACH-000084',
#   'ACH-000112',
#   'ACH-000113',
#   'ACH-000146',
#   'ACH-000166',
#   'ACH-000168',
#   'ACH-000190',
#   'ACH-000195',
#   'ACH-000198',
#   'ACH-000218',
#   'ACH-000241',
#   'ACH-000263',
#   'ACH-000294',
#   'ACH-000295',
#   'ACH-000299',
#   'ACH-000301',
#   'ACH-000321',
#   'ACH-000326',
#   'ACH-000336',
#   'ACH-000362',
#   'ACH-000369',
#   'ACH-000373',
#   'ACH-000386',
#   'ACH-000387',
#   'ACH-000406',
#   'ACH-000432',
#   'ACH-000439',
#   'ACH-000462',
#   'ACH-000487',
#   'ACH-000498',
#   'ACH-000551',
#   'ACH-000557',
#   'ACH-000602',
#   'ACH-000604',
#   'ACH-000641',
#   'ACH-000751',
#   'ACH-000770',
#   'ACH-000920',
#   'ACH-000983',
#   'ACH-001036',
#   'ACH-001037',
#   'ACH-001129',
#   'ACH-001230',
#   'ACH-001573',
#   'ACH-001574',
#   'ACH-001577',
#   'ACH-001613',
#   'ACH-001618',
#   'ACH-001647',
#   'ACH-001656',
#   'ACH-002061',
#   'ACH-002210',
#   'ACH-002218',
#   'ACH-002247',
#   'ACH-002258',
#   'ACH-002262',
#   'ACH-002270',
#   'ACH-002273',
#   'ACH-002276',
#   'ACH-002290',
#   'ACH-002299',
#   'ACH-002302',
#   'ACH-002314',
#   'ACH-002316',
#   'ACH-002475'],
#  'Normal': ['ACH-002342',
#   'ACH-002343',
#   'ACH-002344',
#   'ACH-002346',
#   'ACH-002347',
#   'ACH-002350',
#   'ACH-002351',
#   'ACH-002352',
#   'ACH-002353',
#   'ACH-002354',
#   'ACH-002355',
#   'ACH-002356',
#   'ACH-002357',
#   'ACH-002358',
#   'ACH-002360',
#   'ACH-002361',
#   'ACH-002362',
#   'ACH-002363',
#   'ACH-002364',
#   'ACH-002365',
#   'ACH-002366',
#   'ACH-002367',
#   'ACH-002368',
#   'ACH-002369',
#   'ACH-002370',
#   'ACH-002371',
#   'ACH-002372',
#   'ACH-002373',
#   'ACH-002374',
#   'ACH-002375',
#   'ACH-002376',
#   'ACH-002377',
#   'ACH-002378',
#   'ACH-002379',
#   'ACH-002380',
#   'ACH-002381',
#   'ACH-002382',
#   'ACH-002383',
#   'ACH-002384'],
#  'Other': ['ACH-002050', 'ACH-002198'],
#  'Ovary/Fallopian Tube': ['ACH-000001',
#   'ACH-000013',
#   'ACH-000048',
#   'ACH-000091',
#   'ACH-000103',
#   'ACH-000116',
#   'ACH-000123',
#   'ACH-000132',
#   'ACH-000237',
#   'ACH-000256',
#   'ACH-000278',
#   'ACH-000280',
#   'ACH-000291',
#   'ACH-000308',
#   'ACH-000324',
#   'ACH-000333',
#   'ACH-000409',
#   'ACH-000430',
#   'ACH-000443',
#   'ACH-000460',
#   'ACH-000494',
#   'ACH-000520',
#   'ACH-000524',
#   'ACH-000527',
#   'ACH-000542',
#   'ACH-000574',
#   'ACH-000584',
#   'ACH-000608',
#   'ACH-000617',
#   'ACH-000635',
#   'ACH-000646',
#   'ACH-000657',
#   'ACH-000663',
#   'ACH-000688',
#   'ACH-000696',
#   'ACH-000701',
#   'ACH-000704',
#   'ACH-000713',
#   'ACH-000719',
#   'ACH-000796',
#   'ACH-000811',
#   'ACH-000885',
#   'ACH-000906',
#   'ACH-000936',
#   'ACH-000947',
#   'ACH-000962',
#   'ACH-000966',
#   'ACH-001048',
#   'ACH-001063',
#   'ACH-001144',
#   'ACH-001145',
#   'ACH-001151',
#   'ACH-001278',
#   'ACH-001279',
#   'ACH-001340',
#   'ACH-001369',
#   'ACH-001370',
#   'ACH-001373',
#   'ACH-001374',
#   'ACH-001403',
#   'ACH-001418',
#   'ACH-001628',
#   'ACH-001630',
#   'ACH-001632',
#   'ACH-001719',
#   'ACH-001991',
#   'ACH-002038',
#   'ACH-002140',
#   'ACH-002146',
#   'ACH-002149',
#   'ACH-002181',
#   'ACH-002182',
#   'ACH-002183',
#   'ACH-002486',
#   'ACH-002524'],
#  'Pancreas': ['ACH-000022',
#   'ACH-000023',
#   'ACH-000031',
#   'ACH-000042',
#   'ACH-000060',
#   'ACH-000085',
#   'ACH-000093',
#   'ACH-000094',
#   'ACH-000107',
#   'ACH-000108',
#   'ACH-000114',
#   'ACH-000118',
#   'ACH-000138',
#   'ACH-000139',
#   'ACH-000155',
#   'ACH-000164',
#   'ACH-000178',
#   'ACH-000205',
#   'ACH-000213',
#   'ACH-000222',
#   'ACH-000235',
#   'ACH-000243',
#   'ACH-000265',
#   'ACH-000266',
#   'ACH-000270',
#   'ACH-000281',
#   'ACH-000307',
#   'ACH-000320',
#   'ACH-000332',
#   'ACH-000347',
#   'ACH-000354',
#   'ACH-000417',
#   'ACH-000468',
#   'ACH-000502',
#   'ACH-000517',
#   'ACH-000535',
#   'ACH-000599',
#   'ACH-000601',
#   'ACH-000652',
#   'ACH-000685',
#   'ACH-000933',
#   'ACH-001072',
#   'ACH-001098',
#   'ACH-001101',
#   'ACH-001107',
#   'ACH-001171',
#   'ACH-001353',
#   'ACH-001375',
#   'ACH-001376',
#   'ACH-001377',
#   'ACH-001378',
#   'ACH-001379',
#   'ACH-001380',
#   'ACH-001382',
#   'ACH-001999',
#   'ACH-002039',
#   'ACH-002164',
#   'ACH-002186',
#   'ACH-002672',
#   'ACH-002738',
#   'ACH-002742',
#   'ACH-002743',
#   'ACH-002744',
#   'ACH-002745',
#   'ACH-003161'],
#  'Peripheral Nervous System': ['ACH-000078',
#   'ACH-000099',
#   'ACH-000120',
#   'ACH-000136',
#   'ACH-000149',
#   'ACH-000203',
#   'ACH-000227',
#   'ACH-000259',
#   'ACH-000260',
#   'ACH-000310',
#   'ACH-000312',
#   'ACH-000341',
#   'ACH-000345',
#   'ACH-000366',
#   'ACH-000446',
#   'ACH-000804',
#   'ACH-001188',
#   'ACH-001300',
#   'ACH-001301',
#   'ACH-001302',
#   'ACH-001303',
#   'ACH-001338',
#   'ACH-001344',
#   'ACH-001354',
#   'ACH-001355',
#   'ACH-001366',
#   'ACH-001367',
#   'ACH-001481',
#   'ACH-001548',
#   'ACH-001603',
#   'ACH-001674',
#   'ACH-001716',
#   'ACH-002065',
#   'ACH-002066',
#   'ACH-002080',
#   'ACH-002083',
#   'ACH-002217',
#   'ACH-002248',
#   'ACH-002261',
#   'ACH-002277',
#   'ACH-002278',
#   'ACH-002279',
#   'ACH-002280',
#   'ACH-002281',
#   'ACH-002282',
#   'ACH-002283',
#   'ACH-002284',
#   'ACH-002285',
#   'ACH-002340',
#   'ACH-002389',
#   'ACH-002693',
#   'ACH-002710',
#   'ACH-002799',
#   'ACH-002800',
#   'ACH-002801',
#   'ACH-002922'],
#  'Pleura': ['ACH-000086',
#   'ACH-000092',
#   'ACH-000153',
#   'ACH-000319',
#   'ACH-000331',
#   'ACH-000335',
#   'ACH-000367',
#   'ACH-000569',
#   'ACH-000645',
#   'ACH-000648',
#   'ACH-001547',
#   'ACH-001555',
#   'ACH-001556',
#   'ACH-001557',
#   'ACH-001558',
#   'ACH-001559',
#   'ACH-001560',
#   'ACH-001561',
#   'ACH-001562',
#   'ACH-001977',
#   'ACH-001992',
#   'ACH-002033',
#   'ACH-002123',
#   'ACH-002124',
#   'ACH-002125',
#   'ACH-002126',
#   'ACH-002127',
#   'ACH-002128',
#   'ACH-002129',
#   'ACH-002130',
#   'ACH-002131',
#   'ACH-002132',
#   'ACH-002133',
#   'ACH-002134',
#   'ACH-002135',
#   'ACH-002136'],
#  'Prostate': ['ACH-000090',
#   'ACH-000115',
#   'ACH-000170',
#   'ACH-000177',
#   'ACH-000952',
#   'ACH-000956',
#   'ACH-000977',
#   'ACH-000979',
#   'ACH-001383',
#   'ACH-001422',
#   'ACH-001453',
#   'ACH-001627',
#   'ACH-001648',
#   'ACH-001649',
#   'ACH-003019'],
#  'Skin': ['ACH-000008',
#   'ACH-000014',
#   'ACH-000219',
#   'ACH-000274',
#   'ACH-000304',
#   'ACH-000322',
#   'ACH-000348',
#   'ACH-000401',
#   'ACH-000404',
#   'ACH-000423',
#   'ACH-000425',
#   'ACH-000441',
#   'ACH-000450',
#   'ACH-000458',
#   'ACH-000465',
#   'ACH-000477',
#   'ACH-000550',
#   'ACH-000572',
#   'ACH-000579',
#   'ACH-000580',
#   'ACH-000582',
#   'ACH-000614',
#   'ACH-000615',
#   'ACH-000632',
#   'ACH-000640',
#   'ACH-000644',
#   'ACH-000650',
#   'ACH-000661',
#   'ACH-000730',
#   'ACH-000750',
#   'ACH-000765',
#   'ACH-000788',
#   'ACH-000799',
#   'ACH-000801',
#   'ACH-000805',
#   'ACH-000810',
#   'ACH-000812',
#   'ACH-000814',
#   'ACH-000822',
#   'ACH-000827',
#   'ACH-000881',
#   'ACH-000882',
#   'ACH-000884',
#   'ACH-000899',
#   'ACH-000915',
#   'ACH-000931',
#   'ACH-000968',
#   'ACH-000987',
#   'ACH-001002',
#   'ACH-001024',
#   'ACH-001041',
#   'ACH-001044',
#   'ACH-001045',
#   'ACH-001122',
#   'ACH-001123',
#   'ACH-001131',
#   'ACH-001170',
#   'ACH-001190',
#   'ACH-001239',
#   'ACH-001328',
#   'ACH-001339',
#   'ACH-001442',
#   'ACH-001521',
#   'ACH-001522',
#   'ACH-001523',
#   'ACH-001524',
#   'ACH-001550',
#   'ACH-001551',
#   'ACH-001552',
#   'ACH-001563',
#   'ACH-001566',
#   'ACH-001567',
#   'ACH-001568',
#   'ACH-001569',
#   'ACH-001570',
#   'ACH-001645',
#   'ACH-001704',
#   'ACH-001970',
#   'ACH-001971',
#   'ACH-001972',
#   'ACH-001973',
#   'ACH-001975',
#   'ACH-001982',
#   'ACH-001986',
#   'ACH-001990',
#   'ACH-002001',
#   'ACH-002002',
#   'ACH-002003',
#   'ACH-002004',
#   'ACH-002005',
#   'ACH-002084',
#   'ACH-002096',
#   'ACH-002097',
#   'ACH-002098',
#   'ACH-002100',
#   'ACH-002121',
#   'ACH-002143',
#   'ACH-002147',
#   'ACH-002152',
#   'ACH-002153',
#   'ACH-002159',
#   'ACH-002162',
#   'ACH-002165',
#   'ACH-002166',
#   'ACH-002205',
#   'ACH-002206',
#   'ACH-002207',
#   'ACH-002338',
#   'ACH-002386',
#   'ACH-002387',
#   'ACH-002388',
#   'ACH-002458',
#   'ACH-002459',
#   'ACH-002460',
#   'ACH-002461',
#   'ACH-002508',
#   'ACH-002509',
#   'ACH-002510',
#   'ACH-002511',
#   'ACH-002512',
#   'ACH-002847',
#   'ACH-002928',
#   'ACH-003105'],
#  'Soft Tissue': ['ACH-000037',
#   'ACH-000051',
#   'ACH-000054',
#   'ACH-000100',
#   'ACH-000145',
#   'ACH-000169',
#   'ACH-000172',
#   'ACH-000505',
#   'ACH-000597',
#   'ACH-000607',
#   'ACH-000689',
#   'ACH-000772',
#   'ACH-000833',
#   'ACH-000835',
#   'ACH-001050',
#   'ACH-001059',
#   'ACH-001096',
#   'ACH-001099',
#   'ACH-001128',
#   'ACH-001164',
#   'ACH-001184',
#   'ACH-001189',
#   'ACH-001196',
#   'ACH-001211',
#   'ACH-001212',
#   'ACH-001270',
#   'ACH-001272',
#   'ACH-001274',
#   'ACH-001275',
#   'ACH-001277',
#   'ACH-001280',
#   'ACH-001322',
#   'ACH-001433',
#   'ACH-001540',
#   'ACH-001702',
#   'ACH-001740',
#   'ACH-001743',
#   'ACH-001745',
#   'ACH-001750',
#   'ACH-001751',
#   'ACH-001765',
#   'ACH-001791',
#   'ACH-001793',
#   'ACH-001794',
#   'ACH-001795',
#   'ACH-001796',
#   'ACH-001799',
#   'ACH-001802',
#   'ACH-001804',
#   'ACH-001807',
#   'ACH-002048',
#   'ACH-002085',
#   'ACH-002246',
#   'ACH-002271',
#   'ACH-002309',
#   'ACH-002310',
#   'ACH-002332',
#   'ACH-002334',
#   'ACH-002784',
#   'ACH-002785',
#   'ACH-002787',
#   'ACH-002794',
#   'ACH-003111',
#   'ACH-003125',
#   'ACH-003181',
#   'ACH-003183',
#   'ACH-003184'],
#  'Testis': ['ACH-001437',
#   'ACH-001438',
#   'ACH-001502',
#   'ACH-001578',
#   'ACH-001668',
#   'ACH-001672',
#   'ACH-002288',
#   'ACH-002291'],
#  'Thyroid': ['ACH-000058',
#   'ACH-000174',
#   'ACH-000191',
#   'ACH-000456',
#   'ACH-000716',
#   'ACH-000897',
#   'ACH-000903',
#   'ACH-001306',
#   'ACH-001307',
#   'ACH-001321',
#   'ACH-001350',
#   'ACH-001356',
#   'ACH-001384',
#   'ACH-001443',
#   'ACH-001528',
#   'ACH-002041',
#   'ACH-002148',
#   'ACH-002397'],
#  'Uterus': ['ACH-000173',
#   'ACH-000192',
#   'ACH-000293',
#   'ACH-000302',
#   'ACH-000397',
#   'ACH-000407',
#   'ACH-000435',
#   'ACH-000449',
#   'ACH-000831',
#   'ACH-000864',
#   'ACH-000879',
#   'ACH-000909',
#   'ACH-000913',
#   'ACH-000928',
#   'ACH-000939',
#   'ACH-000940',
#   'ACH-000941',
#   'ACH-000946',
#   'ACH-000954',
#   'ACH-000961',
#   'ACH-000965',
#   'ACH-000972',
#   'ACH-000974',
#   'ACH-000978',
#   'ACH-000984',
#   'ACH-000988',
#   'ACH-000990',
#   'ACH-000993',
#   'ACH-000994',
#   'ACH-000996',
#   'ACH-001042',
#   'ACH-001495',
#   'ACH-001517',
#   'ACH-001518',
#   'ACH-001529',
#   'ACH-001530',
#   'ACH-001655',
#   'ACH-002021',
#   'ACH-002026',
#   'ACH-002027',
#   'ACH-002046'],
#  'Vulva/Vagina': ['ACH-001400',
#   'ACH-002040',
#   'ACH-002091',
#   'ACH-002120',
#   'ACH-002200']}

# %%
categories = oncotree_lineage_dict.keys()
avg_trimmed_esen_df = pd.DataFrame(index=categories, columns=literature_gene_list)

# %%
# Calculate the average essentiality scores for each category
for category, cell_lines in oncotree_lineage_dict.items():
    # Filter out cell lines not present in trimmed_esen_df
    valid_cell_lines = [cell_line for cell_line in cell_lines if cell_line in trimmed_esen_df.index]
    if valid_cell_lines:  # Only calculate if there are valid cell lines
        avg_trimmed_esen_df.loc[category] = trimmed_esen_df.loc[valid_cell_lines].mean()

# %%
avg_trimmed_esen_df.dropna(how='all', inplace=True)

# %% [markdown]
# Renaming with "-" rather than "/" to avoid errors:

# %%
avg_trimmed_esen_df.index = avg_trimmed_esen_df.index.str.replace('/', '-')

# %%
avg_trimmed_esen_df
# Out:
#                                RAE1    FBXO17    YTHDF1     DDX27    SEC61G  \
# Bladder-Urinary Tract     -1.385351 -0.109342  0.237001 -1.080879 -1.190801
# Bone                      -1.557482  0.056929  0.004858 -0.996598 -1.022146
# Bowel                     -1.478825  0.026605  0.182104 -1.298502  -1.10381
# Breast                    -1.357247  0.008662  0.183749 -0.985533 -1.131014
# CNS-Brain                   -1.5105 -0.103304  0.122558 -1.130269 -1.169407
# Esophagus-Stomach         -1.461781 -0.051865  0.185681 -1.085251 -1.188414
# Head and Neck             -1.372551 -0.041591  0.164947 -1.035485 -1.274613
# Kidney                    -1.460705 -0.014413  0.191184 -1.160363  -1.17639
# Liver                     -1.346214 -0.088742  0.180911 -1.054046 -1.276581
# Lung                      -1.341175  -0.07513  0.183699  -1.06693 -1.203197
# Lymphoid                   -1.45625 -0.048884  0.180487 -0.943366 -1.246642
# Myeloid                   -1.327928  0.020522  0.129199 -1.131675 -1.116715
# Ovary-Fallopian Tube      -1.497763 -0.134232  0.176857 -1.161448 -1.154209
# Pancreas                   -1.51239  0.067253  0.118897 -1.003325 -1.288117
# Peripheral Nervous System -1.241757 -0.058014  0.057077 -1.320891  -1.16433
# Pleura                    -0.905166 -0.056478  0.242869 -1.051854 -1.255536
# Prostate                  -1.226452 -0.068053  0.118026 -0.990615 -0.988596
# Skin                      -1.594875 -0.116061  0.158764 -1.066958 -1.180189
# Soft Tissue               -1.205785  -0.03448  0.173199 -1.023235 -1.164713
# Thyroid                   -1.557082 -0.125668  0.028375 -0.854145 -1.344569
# Uterus                    -1.373142 -0.080502  0.227813 -1.044213 -1.300976
#
#                               CHMP7      XPO7     INTS9      GJC1    METTL1  \
# Bladder-Urinary Tract     -0.634477 -0.123798 -1.592092 -0.067727 -0.618874
# Bone                      -0.724917  -0.30894 -1.985228 -0.102306 -0.931291
# Bowel                     -0.454969 -0.088147 -1.615264 -0.092421 -0.476383
# Breast                    -0.695307 -0.059311 -1.739938 -0.109713 -0.279289
# CNS-Brain                 -0.734394 -0.061533 -1.736273  -0.17996 -0.381729
# Esophagus-Stomach          -0.53965 -0.051487  -1.67677 -0.132192 -0.516337
# Head and Neck             -0.788483 -0.098242 -1.852179 -0.187559 -0.486829
# Kidney                    -0.648485  0.095923 -1.724723 -0.087908 -0.519891
# Liver                     -0.580684  -0.02627 -1.905448 -0.118465   -0.3902
# Lung                      -0.666819 -0.056639 -1.722237 -0.166471 -0.392899
# Lymphoid                  -0.466297 -0.053338 -1.740988 -0.103028 -0.342625
# Myeloid                   -0.588024 -0.024913 -1.639308 -0.183939 -0.544223
# Ovary-Fallopian Tube       -0.65204  -0.01721 -1.776862   -0.1545 -0.393032
# Pancreas                  -0.919803 -0.074724 -1.945907 -0.112453 -0.412491
# Peripheral Nervous System  -0.65225 -0.125248 -1.641061 -0.176901 -0.621985
# Pleura                    -0.473875 -0.060434 -1.435837   0.02252 -0.421949
# Prostate                  -0.902136 -0.006682 -1.712531 -0.069759 -0.284655
# Skin                      -0.682726 -0.106183 -1.917683 -0.229371 -0.348722
# Soft Tissue               -0.572542  -0.00328  -1.76954 -0.131674 -0.251504
# Thyroid                   -0.778143 -0.231947 -1.979821 -0.005181 -0.911418
# Uterus                    -0.445897 -0.066026 -1.562068  -0.18306 -0.552147
#
#                            ...      CD48    RBMXL1     SNRPG      GMIP  \
# Bladder-Urinary Tract      ...  -0.07569 -0.704007  -2.17096   0.06253
# Bone                       ... -0.149628 -0.664241 -2.041113  0.239531
# Bowel                      ... -0.106845 -0.635035  -2.14239  0.006667
# Breast                     ... -0.064765 -0.868978 -2.174167  0.025725
# CNS-Brain                  ... -0.065231 -0.643529 -2.076679  0.028034
# Esophagus-Stomach          ...  -0.08242 -0.737726 -2.345009   0.03179
# Head and Neck              ... -0.134098 -0.793694 -2.008479  0.048077
# Kidney                     ... -0.085785 -0.809827 -2.224849  0.035601
# Liver                      ...  -0.05274 -0.824127 -2.088846  0.029885
# Lung                       ... -0.095072 -0.792325 -2.045227  0.010372
# Lymphoid                   ... -0.118738 -0.685722 -2.070086 -0.018286
# Myeloid                    ... -0.068222 -0.812347  -2.33794  0.033413
# Ovary-Fallopian Tube       ... -0.036689 -0.935244 -2.103983  0.059796
# Pancreas                   ...  0.041555 -0.558262 -1.974638 -0.053081
# Peripheral Nervous System  ... -0.054225 -0.613677 -1.772381  0.018057
# Pleura                     ... -0.071373 -0.817034 -2.237654  0.058687
# Prostate                   ...  0.072454 -0.617564 -2.544482  0.061616
# Skin                       ... -0.057317 -0.739517 -1.848525   0.02817
# Soft Tissue                ... -0.052742 -0.933991 -1.983235 -0.067068
# Thyroid                    ... -0.027996 -0.686951 -1.277119  0.032485
# Uterus                     ... -0.075962 -0.873745 -2.127179  0.016358
#
#                                 DEK     MITD1    SLAMF7       LY9 C10orf125  \
# Bladder-Urinary Tract      0.112852  -0.11852   0.06375 -0.056838       NaN
# Bone                       0.121346 -0.243796 -0.012276 -0.098541       NaN
# Bowel                      0.121557 -0.051641 -0.043331 -0.111743       NaN
# Breast                     0.124396 -0.097753 -0.060342 -0.138997       NaN
# CNS-Brain                  0.123782  -0.10399   0.02236 -0.128562       NaN
# Esophagus-Stomach          0.064371  -0.09314 -0.007267 -0.157906       NaN
# Head and Neck              0.072998 -0.099401 -0.039333 -0.063858       NaN
# Kidney                      0.02152 -0.077623 -0.031579 -0.160188       NaN
# Liver                      0.116234 -0.072034 -0.046456 -0.188249       NaN
# Lung                       0.114477 -0.094676 -0.051848 -0.123242       NaN
# Lymphoid                   0.061904 -0.045474 -0.072233 -0.232111       NaN
# Myeloid                     0.07832 -0.004363  0.022456 -0.324409       NaN
# Ovary-Fallopian Tube       0.114333 -0.026364  0.003868 -0.091699       NaN
# Pancreas                   0.102026 -0.109342 -0.004105 -0.145899       NaN
# Peripheral Nervous System  0.157234 -0.079815  0.003369 -0.146578       NaN
# Pleura                     0.165322  -0.21735 -0.012105  0.003074       NaN
# Prostate                   0.094675 -0.112405  0.064404  0.005372       NaN
# Skin                       0.049005 -0.098389 -0.015932 -0.080332       NaN
# Soft Tissue                0.200296 -0.117328 -0.007811 -0.202657       NaN
# Thyroid                    0.065291   0.04811 -0.097901 -0.280644       NaN
# Uterus                     0.090607 -0.236866 -0.010182 -0.008164       NaN
#
#                              SNRPA1
# Bladder-Urinary Tract     -2.551288
# Bone                      -2.448317
# Bowel                     -2.891235
# Breast                     -3.00402
# CNS-Brain                 -2.938365
# Esophagus-Stomach         -2.942543
# Head and Neck             -3.014571
# Kidney                    -2.911835
# Liver                      -2.99713
# Lung                      -2.833861
# Lymphoid                  -2.896036
# Myeloid                   -2.893755
# Ovary-Fallopian Tube      -2.994715
# Pancreas                  -2.993231
# Peripheral Nervous System -2.507592
# Pleura                    -3.049665
# Prostate                  -2.423069
# Skin                      -2.646231
# Soft Tissue               -3.426401
# Thyroid                    -2.82966
# Uterus                    -3.257553
#
# [21 rows x 643 columns]

# %% [markdown]
# ### Calculating mean essentiality values across <b>ecDNA-present</b> cell-lines for each category:

# %%
ecdna_present_lineage_dict = {}

for key,list in oncotree_lineage_dict.items():
    ecdna_present_lineage_dict[key] = [id for id in list if id in ec_aa_plus_ids]

# %%
ecdna_present_lineage_dict
# Out:
# {'Adrenal Gland': [],
#  'Ampulla of Vater': [],
#  'Biliary Tract': [],
#  'Bladder/Urinary Tract': ['ACH-000473',
#   'ACH-000724',
#   'ACH-000839',
#   'ACH-000905'],
#  'Bone': [],
#  'Bowel': ['ACH-000253', 'ACH-000360', 'ACH-000842', 'ACH-000986'],
#  'Breast': ['ACH-000019',
#   'ACH-000044',
#   'ACH-000097',
#   'ACH-000111',
#   'ACH-000117',
#   'ACH-000147',
#   'ACH-000196',
#   'ACH-000212',
#   'ACH-000223',
#   'ACH-000248',
#   'ACH-000276',
#   'ACH-000277',
#   'ACH-000330',
#   'ACH-000349',
#   'ACH-000536',
#   'ACH-000554',
#   'ACH-000568',
#   'ACH-000621',
#   'ACH-000643',
#   'ACH-000691',
#   'ACH-000725',
#   'ACH-000759',
#   'ACH-000783',
#   'ACH-000818',
#   'ACH-000857',
#   'ACH-000859',
#   'ACH-000910',
#   'ACH-000927',
#   'ACH-000930',
#   'ACH-000934'],
#  'CNS/Brain': ['ACH-000232',
#   'ACH-000376',
#   'ACH-000738',
#   'ACH-000756',
#   'ACH-000883'],
#  'Cervix': [],
#  'Embryonal': [],
#  'Esophagus/Stomach': ['ACH-000047',
#   'ACH-000144',
#   'ACH-000351',
#   'ACH-000356',
#   'ACH-000408',
#   'ACH-000488',
#   'ACH-000507',
#   'ACH-000581',
#   'ACH-000616',
#   'ACH-000633',
#   'ACH-000637',
#   'ACH-000647',
#   'ACH-000678',
#   'ACH-000679',
#   'ACH-000693',
#   'ACH-000758',
#   'ACH-000777',
#   'ACH-000784',
#   'ACH-000793',
#   'ACH-000809',
#   'ACH-000847',
#   'ACH-000865'],
#  'Eye': [],
#  'Fibroblast': [],
#  'Hair': [],
#  'Head and Neck': ['ACH-000163'],
#  'Kidney': ['ACH-000159', 'ACH-000433'],
#  'Liver': ['ACH-000422', 'ACH-000483', 'ACH-000620', 'ACH-000848'],
#  'Lung': ['ACH-000012',
#   'ACH-000021',
#   'ACH-000109',
#   'ACH-000187',
#   'ACH-000257',
#   'ACH-000264',
#   'ACH-000297',
#   'ACH-000298',
#   'ACH-000311',
#   'ACH-000355',
#   'ACH-000395',
#   'ACH-000431',
#   'ACH-000444',
#   'ACH-000447',
#   'ACH-000454',
#   'ACH-000463',
#   'ACH-000481',
#   'ACH-000496',
#   'ACH-000506',
#   'ACH-000508',
#   'ACH-000514',
#   'ACH-000515',
#   'ACH-000521',
#   'ACH-000523',
#   'ACH-000525',
#   'ACH-000528',
#   'ACH-000530',
#   'ACH-000559',
#   'ACH-000563',
#   'ACH-000586',
#   'ACH-000589',
#   'ACH-000628',
#   'ACH-000659',
#   'ACH-000662',
#   'ACH-000665',
#   'ACH-000666',
#   'ACH-000667',
#   'ACH-000669',
#   'ACH-000670',
#   'ACH-000698',
#   'ACH-000727',
#   'ACH-000729',
#   'ACH-000747',
#   'ACH-000749',
#   'ACH-000767',
#   'ACH-000800',
#   'ACH-000803',
#   'ACH-000816',
#   'ACH-000830',
#   'ACH-000843',
#   'ACH-000852',
#   'ACH-000853',
#   'ACH-000858',
#   'ACH-000860',
#   'ACH-000867',
#   'ACH-000871',
#   'ACH-000888',
#   'ACH-000893',
#   'ACH-000894',
#   'ACH-000900',
#   'ACH-000921',
#   'ACH-000945'],
#  'Lymphoid': ['ACH-000053', 'ACH-000068', 'ACH-000697'],
#  'Muscle': [],
#  'Myeloid': ['ACH-000146'],
#  'Normal': [],
#  'Other': [],
#  'Ovary/Fallopian Tube': ['ACH-000001',
#   'ACH-000132',
#   'ACH-000291',
#   'ACH-000409',
#   'ACH-000520',
#   'ACH-000574',
#   'ACH-000608',
#   'ACH-000617',
#   'ACH-000635',
#   'ACH-000696',
#   'ACH-000704',
#   'ACH-000713',
#   'ACH-000719',
#   'ACH-000811',
#   'ACH-000906'],
#  'Pancreas': ['ACH-000243', 'ACH-000347', 'ACH-000652'],
#  'Peripheral Nervous System': ['ACH-000120'],
#  'Pleura': ['ACH-000335'],
#  'Prostate': ['ACH-000090'],
#  'Skin': ['ACH-000614', 'ACH-001190'],
#  'Soft Tissue': [],
#  'Testis': [],
#  'Thyroid': ['ACH-001306'],
#  'Uterus': ['ACH-000192', 'ACH-000293', 'ACH-000965', 'ACH-000988'],
#  'Vulva/Vagina': []}

# %%
ec_dna_present_categories = ecdna_present_lineage_dict.keys()
avg_ecdna_present_trimmed_esen_df = pd.DataFrame(index=ec_dna_present_categories, columns=literature_gene_list)

# %%
# Calculate the average essentiality scores for each category
for category, cell_lines in ecdna_present_lineage_dict.items():
    # Filter out cell lines not present in trimmed_esen_df
    valid_ecdna_present_cell_lines = [cell_line for cell_line in cell_lines if cell_line in trimmed_esen_df.index]
    if valid_ecdna_present_cell_lines:  # Only calculate if there are valid cell lines
        avg_ecdna_present_trimmed_esen_df.loc[category] = trimmed_esen_df.loc[valid_ecdna_present_cell_lines].mean()

# %%
avg_ecdna_present_trimmed_esen_df.dropna(how='all', inplace=True)

# %% [markdown]
# Renaming with "-" rather than "/" to avoid errors:

# %%
avg_ecdna_present_trimmed_esen_df.index = avg_ecdna_present_trimmed_esen_df.index.str.replace('/', '-')

# %% [markdown]
# Adding an "ecDNA-present" tag to each category:

# %%
avg_ecdna_present_trimmed_esen_df.index = [str(index) + " (ecDNA-present)" for index in avg_ecdna_present_trimmed_esen_df.index]

# %%
avg_ecdna_present_trimmed_esen_df
# Out:
#                                                RAE1    FBXO17    YTHDF1  \
# Bladder-Urinary Tract (ecDNA-present)     -1.435676 -0.122214  0.291812
# Bowel (ecDNA-present)                     -1.594722 -0.037046  0.192765
# Breast (ecDNA-present)                    -1.342546  0.013041   0.19115
# CNS-Brain (ecDNA-present)                 -1.340171 -0.090806   0.10218
# Esophagus-Stomach (ecDNA-present)          -1.50832 -0.040027  0.188233
# Head and Neck (ecDNA-present)             -1.231776  0.018166  0.170376
# Kidney (ecDNA-present)                    -1.488507 -0.056142  0.194117
# Liver (ecDNA-present)                     -1.311143 -0.153977  0.233477
# Lung (ecDNA-present)                      -1.334061 -0.085929  0.187267
# Lymphoid (ecDNA-present)                  -1.346705 -0.121636  0.249524
# Myeloid (ecDNA-present)                   -1.232596 -0.127809  0.280508
# Ovary-Fallopian Tube (ecDNA-present)      -1.472449 -0.142691  0.156728
# Pancreas (ecDNA-present)                  -1.566133  -0.00115  0.130261
# Peripheral Nervous System (ecDNA-present)  -1.42088 -0.055773   0.03138
# Pleura (ecDNA-present)                    -0.666458  0.178286  0.193453
# Prostate (ecDNA-present)                  -1.587881 -0.019847  0.100584
# Skin (ecDNA-present)                      -1.549717 -0.153858  0.123454
# Thyroid (ecDNA-present)                   -1.557082 -0.125668  0.028375
# Uterus (ecDNA-present)                    -1.124114 -0.175674   0.21818
#
#                                               DDX27    SEC61G     CHMP7  \
# Bladder-Urinary Tract (ecDNA-present)     -0.943421  -1.26507 -0.552624
# Bowel (ecDNA-present)                     -1.114558 -1.218088 -0.491755
# Breast (ecDNA-present)                     -0.98242  -1.14297 -0.747882
# CNS-Brain (ecDNA-present)                 -1.150205 -1.086505 -0.803394
# Esophagus-Stomach (ecDNA-present)         -1.044836 -1.163893 -0.543904
# Head and Neck (ecDNA-present)             -0.675031 -1.295484 -0.758057
# Kidney (ecDNA-present)                    -1.092193 -1.296737 -0.582387
# Liver (ecDNA-present)                     -1.073833 -1.347051 -0.552038
# Lung (ecDNA-present)                      -1.044751 -1.187783 -0.644205
# Lymphoid (ecDNA-present)                  -0.898885 -1.193571 -0.310961
# Myeloid (ecDNA-present)                   -1.094053 -1.198877  -0.89819
# Ovary-Fallopian Tube (ecDNA-present)      -1.166877 -1.135464 -0.654659
# Pancreas (ecDNA-present)                  -0.923344 -1.209361 -1.225936
# Peripheral Nervous System (ecDNA-present) -1.231676  -1.16675 -0.614457
# Pleura (ecDNA-present)                    -1.440641 -1.006584 -0.418877
# Prostate (ecDNA-present)                  -0.597277 -1.029518 -1.070584
# Skin (ecDNA-present)                      -1.142468 -0.997296 -0.560868
# Thyroid (ecDNA-present)                   -0.854145 -1.344569 -0.778143
# Uterus (ecDNA-present)                     -0.93984 -1.642427 -0.433154
#
#                                                XPO7     INTS9      GJC1  \
# Bladder-Urinary Tract (ecDNA-present)     -0.110608 -1.590697   0.00665
# Bowel (ecDNA-present)                     -0.120123 -1.682627 -0.142233
# Breast (ecDNA-present)                    -0.099879 -1.759594 -0.083409
# CNS-Brain (ecDNA-present)                  0.016277 -1.503501 -0.156247
# Esophagus-Stomach (ecDNA-present)         -0.072742 -1.733175 -0.129732
# Head and Neck (ecDNA-present)             -0.243278 -2.022795  -0.42261
# Kidney (ecDNA-present)                    -0.037756 -2.064431 -0.042499
# Liver (ecDNA-present)                     -0.093409 -2.078646 -0.189642
# Lung (ecDNA-present)                      -0.067149 -1.732749 -0.162725
# Lymphoid (ecDNA-present)                   0.016591 -1.982902 -0.070356
# Myeloid (ecDNA-present)                   -0.103916 -1.877313 -0.182954
# Ovary-Fallopian Tube (ecDNA-present)      -0.018322  -1.71674 -0.194865
# Pancreas (ecDNA-present)                    -0.0979 -2.245008 -0.083928
# Peripheral Nervous System (ecDNA-present) -0.034203 -1.801553 -0.070267
# Pleura (ecDNA-present)                    -0.266636 -1.653405   0.09612
# Prostate (ecDNA-present)                  -0.093153 -1.808331 -0.057278
# Skin (ecDNA-present)                      -0.083112 -2.245634 -0.196275
# Thyroid (ecDNA-present)                   -0.231947 -1.979821 -0.005181
# Uterus (ecDNA-present)                    -0.163443  -1.55439 -0.201922
#
#                                              METTL1  ...      CD48    RBMXL1  \
# Bladder-Urinary Tract (ecDNA-present)     -0.532538  ... -0.072827 -0.753185
# Bowel (ecDNA-present)                     -0.361603  ...  -0.10836 -0.520982
# Breast (ecDNA-present)                    -0.234939  ... -0.023669 -0.855086
# CNS-Brain (ecDNA-present)                  -0.47458  ... -0.035369 -0.617705
# Esophagus-Stomach (ecDNA-present)         -0.510876  ... -0.066614 -0.731809
# Head and Neck (ecDNA-present)             -0.702315  ...  0.032978 -0.452239
# Kidney (ecDNA-present)                    -0.496695  ... -0.169142 -0.821899
# Liver (ecDNA-present)                     -0.376786  ...  -0.06265 -0.783201
# Lung (ecDNA-present)                      -0.340142  ... -0.101798 -0.774632
# Lymphoid (ecDNA-present)                  -0.284596  ... -0.071388 -0.713319
# Myeloid (ecDNA-present)                   -0.355125  ... -0.078396   -1.1778
# Ovary-Fallopian Tube (ecDNA-present)      -0.410673  ... -0.018497 -0.911928
# Pancreas (ecDNA-present)                  -0.328688  ... -0.017816  -0.57398
# Peripheral Nervous System (ecDNA-present) -0.641462  ... -0.067402 -0.497217
# Pleura (ecDNA-present)                    -0.600966  ... -0.250686 -0.772128
# Prostate (ecDNA-present)                  -0.127389  ... -0.040631 -0.201145
# Skin (ecDNA-present)                      -0.366399  ... -0.076658 -0.645749
# Thyroid (ecDNA-present)                   -0.911418  ... -0.027996 -0.686951
# Uterus (ecDNA-present)                    -0.346951  ... -0.077983  -0.87838
#
#                                               SNRPG      GMIP       DEK  \
# Bladder-Urinary Tract (ecDNA-present)     -2.251058  0.079474  0.069233
# Bowel (ecDNA-present)                     -2.299181 -0.095669  0.045609
# Breast (ecDNA-present)                    -2.233241  0.015364  0.103057
# CNS-Brain (ecDNA-present)                 -2.206709 -0.001816  0.120474
# Esophagus-Stomach (ecDNA-present)         -2.230609  0.041506  0.064018
# Head and Neck (ecDNA-present)             -1.553252  0.043443 -0.129803
# Kidney (ecDNA-present)                    -2.174614  -0.06455  0.086211
# Liver (ecDNA-present)                     -1.963516  0.000161  0.108069
# Lung (ecDNA-present)                       -2.07825  0.010642  0.125405
# Lymphoid (ecDNA-present)                  -2.120497  0.014497  0.173001
# Myeloid (ecDNA-present)                   -2.017412  0.022856  0.080084
# Ovary-Fallopian Tube (ecDNA-present)      -2.066659  0.034911  0.097533
# Pancreas (ecDNA-present)                  -1.810856 -0.084029  0.211236
# Peripheral Nervous System (ecDNA-present) -2.123741  0.039148  0.326765
# Pleura (ecDNA-present)                    -2.319161  0.032291   0.13101
# Prostate (ecDNA-present)                  -2.544482  0.127416  0.073887
# Skin (ecDNA-present)                      -2.012558 -0.000301  0.175393
# Thyroid (ecDNA-present)                   -1.277119  0.032485  0.065291
# Uterus (ecDNA-present)                    -1.745176  0.045158  0.079581
#
#                                               MITD1    SLAMF7       LY9  \
# Bladder-Urinary Tract (ecDNA-present)      -0.12556   0.10197 -0.018174
# Bowel (ecDNA-present)                     -0.039505 -0.016605 -0.057773
# Breast (ecDNA-present)                    -0.120455 -0.056963  -0.15912
# CNS-Brain (ecDNA-present)                  -0.07546  0.009886 -0.146377
# Esophagus-Stomach (ecDNA-present)         -0.066949 -0.020541 -0.142646
# Head and Neck (ecDNA-present)              0.030778  0.111898 -0.074504
# Kidney (ecDNA-present)                    -0.149975 -0.073592 -0.170988
# Liver (ecDNA-present)                      -0.12229 -0.030042 -0.179248
# Lung (ecDNA-present)                      -0.082617 -0.054034 -0.110666
# Lymphoid (ecDNA-present)                  -0.138473  0.022989  -0.21606
# Myeloid (ecDNA-present)                   -0.006952 -0.040538 -0.308595
# Ovary-Fallopian Tube (ecDNA-present)        -0.0573  0.026574 -0.066499
# Pancreas (ecDNA-present)                  -0.066726 -0.013125 -0.146213
# Peripheral Nervous System (ecDNA-present) -0.122145   0.00406  -0.10857
# Pleura (ecDNA-present)                    -0.153028 -0.219338 -0.008246
# Prostate (ecDNA-present)                  -0.129652  0.158229  0.130488
# Skin (ecDNA-present)                        -0.2001  0.037334 -0.012482
# Thyroid (ecDNA-present)                     0.04811 -0.097901 -0.280644
# Uterus (ecDNA-present)                    -0.293788 -0.026507 -0.058366
#
#                                           C10orf125    SNRPA1
# Bladder-Urinary Tract (ecDNA-present)           NaN -2.442733
# Bowel (ecDNA-present)                           NaN -2.495908
# Breast (ecDNA-present)                          NaN -3.039817
# CNS-Brain (ecDNA-present)                       NaN -2.653801
# Esophagus-Stomach (ecDNA-present)               NaN  -2.96949
# Head and Neck (ecDNA-present)                   NaN -3.149165
# Kidney (ecDNA-present)                          NaN -3.061135
# Liver (ecDNA-present)                           NaN -2.954553
# Lung (ecDNA-present)                            NaN -2.883159
# Lymphoid (ecDNA-present)                        NaN -2.618652
# Myeloid (ecDNA-present)                         NaN -3.063353
# Ovary-Fallopian Tube (ecDNA-present)            NaN -3.030175
# Pancreas (ecDNA-present)                        NaN -2.843176
# Peripheral Nervous System (ecDNA-present)       NaN -2.319106
# Pleura (ecDNA-present)                          NaN -2.785486
# Prostate (ecDNA-present)                        NaN -2.430357
# Skin (ecDNA-present)                            NaN -2.730323
# Thyroid (ecDNA-present)                         NaN  -2.82966
# Uterus (ecDNA-present)                          NaN -3.510405
#
# [19 rows x 643 columns]

# %% [markdown]
# ### Calculating mean essentiality values across <b>ecDNA-absent</b> cell-lines for each category:

# %%
ecdna_absent_lineage_dict = {}

for key,lst in oncotree_lineage_dict.items():
    ecdna_absent_lineage_dict[key] = [id for id in lst if id not in ec_aa_plus_ids]

# %%
ecdna_absent_lineage_dict
# Out:
# {'Adrenal Gland': ['ACH-001401', 'ACH-001598'],
#  'Ampulla of Vater': ['ACH-000182', 'ACH-000377', 'ACH-001862', 'ACH-002023'],
#  'Biliary Tract': ['ACH-000141',
#   'ACH-000209',
#   'ACH-000268',
#   'ACH-000461',
#   'ACH-000808',
#   'ACH-000976',
#   'ACH-001494',
#   'ACH-001536',
#   'ACH-001537',
#   'ACH-001538',
#   'ACH-001607',
#   'ACH-001619',
#   'ACH-001673',
#   'ACH-001834',
#   'ACH-001835',
#   'ACH-001836',
#   'ACH-001838',
#   'ACH-001839',
#   'ACH-001841',
#   'ACH-001842',
#   'ACH-001843',
#   'ACH-001844',
#   'ACH-001845',
#   'ACH-001846',
#   'ACH-001847',
#   'ACH-001848',
#   'ACH-001849',
#   'ACH-001850',
#   'ACH-001852',
#   'ACH-001854',
#   'ACH-001855',
#   'ACH-001856',
#   'ACH-001857',
#   'ACH-001858',
#   'ACH-001861',
#   'ACH-001863',
#   'ACH-001864',
#   'ACH-001959',
#   'ACH-001960',
#   'ACH-001961',
#   'ACH-001997',
#   'ACH-002237',
#   'ACH-002312',
#   'ACH-002647'],
#  'Bladder/Urinary Tract': ['ACH-000011',
#   'ACH-000018',
#   'ACH-000026',
#   'ACH-000127',
#   'ACH-000142',
#   'ACH-000242',
#   'ACH-000384',
#   'ACH-000396',
#   'ACH-000486',
#   'ACH-000522',
#   'ACH-000545',
#   'ACH-000547',
#   'ACH-000566',
#   'ACH-000593',
#   'ACH-000720',
#   'ACH-000741',
#   'ACH-000753',
#   'ACH-000802',
#   'ACH-000834',
#   'ACH-000862',
#   'ACH-000896',
#   'ACH-000973',
#   'ACH-001183',
#   'ACH-001407',
#   'ACH-001408',
#   'ACH-001409',
#   'ACH-001410',
#   'ACH-001411',
#   'ACH-001412',
#   'ACH-001413',
#   'ACH-001414',
#   'ACH-001415',
#   'ACH-001416',
#   'ACH-002235',
#   'ACH-002266'],
#  'Bone': ['ACH-000039',
#   'ACH-000041',
#   'ACH-000052',
#   'ACH-000082',
#   'ACH-000087',
#   'ACH-000210',
#   'ACH-000279',
#   'ACH-000359',
#   'ACH-000364',
#   'ACH-000391',
#   'ACH-000410',
#   'ACH-000418',
#   'ACH-000424',
#   'ACH-000499',
#   'ACH-000516',
#   'ACH-000613',
#   'ACH-000748',
#   'ACH-001001',
#   'ACH-001007',
#   'ACH-001008',
#   'ACH-001009',
#   'ACH-001010',
#   'ACH-001022',
#   'ACH-001029',
#   'ACH-001030',
#   'ACH-001032',
#   'ACH-001034',
#   'ACH-001035',
#   'ACH-001038',
#   'ACH-001066',
#   'ACH-001094',
#   'ACH-001150',
#   'ACH-001192',
#   'ACH-001193',
#   'ACH-001205',
#   'ACH-001206',
#   'ACH-001282',
#   'ACH-001283',
#   'ACH-001430',
#   'ACH-001431',
#   'ACH-001519',
#   'ACH-001526',
#   'ACH-001712',
#   'ACH-001715',
#   'ACH-001814',
#   'ACH-001818',
#   'ACH-002067',
#   'ACH-002069',
#   'ACH-002092',
#   'ACH-002093',
#   'ACH-002094',
#   'ACH-002099',
#   'ACH-002103',
#   'ACH-002104',
#   'ACH-002105',
#   'ACH-002106',
#   'ACH-002107',
#   'ACH-002108',
#   'ACH-002109',
#   'ACH-002110',
#   'ACH-002111',
#   'ACH-002112',
#   'ACH-002113',
#   'ACH-002114',
#   'ACH-002115',
#   'ACH-002116',
#   'ACH-002117',
#   'ACH-002118',
#   'ACH-002119',
#   'ACH-002142',
#   'ACH-002160',
#   'ACH-002178',
#   'ACH-002204',
#   'ACH-002471',
#   'ACH-002780',
#   'ACH-002781',
#   'ACH-002834',
#   'ACH-003191'],
#  'Bowel': ['ACH-000003',
#   'ACH-000007',
#   'ACH-000009',
#   'ACH-000089',
#   'ACH-000202',
#   'ACH-000236',
#   'ACH-000249',
#   'ACH-000252',
#   'ACH-000286',
#   'ACH-000296',
#   'ACH-000342',
#   'ACH-000350',
#   'ACH-000381',
#   'ACH-000400',
#   'ACH-000403',
#   'ACH-000412',
#   'ACH-000421',
#   'ACH-000467',
#   'ACH-000470',
#   'ACH-000489',
#   'ACH-000491',
#   'ACH-000501',
#   'ACH-000532',
#   'ACH-000538',
#   'ACH-000552',
#   'ACH-000565',
#   'ACH-000651',
#   'ACH-000680',
#   'ACH-000683',
#   'ACH-000708',
#   'ACH-000710',
#   'ACH-000722',
#   'ACH-000798',
#   'ACH-000820',
#   'ACH-000895',
#   'ACH-000926',
#   'ACH-000935',
#   'ACH-000943',
#   'ACH-000950',
#   'ACH-000955',
#   'ACH-000957',
#   'ACH-000958',
#   'ACH-000959',
#   'ACH-000963',
#   'ACH-000967',
#   'ACH-000969',
#   'ACH-000970',
#   'ACH-000971',
#   'ACH-000982',
#   'ACH-000985',
#   'ACH-000989',
#   'ACH-000991',
#   'ACH-000997',
#   'ACH-000998',
#   'ACH-000999',
#   'ACH-001015',
#   'ACH-001039',
#   'ACH-001061',
#   'ACH-001081',
#   'ACH-001084',
#   'ACH-001091',
#   'ACH-001199',
#   'ACH-001345',
#   'ACH-001399',
#   'ACH-001454',
#   'ACH-001456',
#   'ACH-001458',
#   'ACH-001459',
#   'ACH-001460',
#   'ACH-001461',
#   'ACH-001786',
#   'ACH-001825',
#   'ACH-002024',
#   'ACH-002025',
#   'ACH-002219',
#   'ACH-002233',
#   'ACH-002287',
#   'ACH-002345',
#   'ACH-002535',
#   'ACH-002539',
#   'ACH-002543',
#   'ACH-002654',
#   'ACH-002659',
#   'ACH-002660',
#   'ACH-002662',
#   'ACH-002664',
#   'ACH-002669',
#   'ACH-002839'],
#  'Breast': ['ACH-000017',
#   'ACH-000028',
#   'ACH-000148',
#   'ACH-000258',
#   'ACH-000288',
#   'ACH-000352',
#   'ACH-000374',
#   'ACH-000573',
#   'ACH-000624',
#   'ACH-000642',
#   'ACH-000668',
#   'ACH-000699',
#   'ACH-000711',
#   'ACH-000721',
#   'ACH-000755',
#   'ACH-000768',
#   'ACH-000828',
#   'ACH-000849',
#   'ACH-000856',
#   'ACH-000876',
#   'ACH-000902',
#   'ACH-001065',
#   'ACH-001249',
#   'ACH-001357',
#   'ACH-001358',
#   'ACH-001388',
#   'ACH-001389',
#   'ACH-001390',
#   'ACH-001391',
#   'ACH-001392',
#   'ACH-001393',
#   'ACH-001394',
#   'ACH-001395',
#   'ACH-001396',
#   'ACH-001397',
#   'ACH-001419',
#   'ACH-001514',
#   'ACH-001662',
#   'ACH-001683',
#   'ACH-001705',
#   'ACH-001819',
#   'ACH-001820',
#   'ACH-001827',
#   'ACH-002163',
#   'ACH-002179',
#   'ACH-002208',
#   'ACH-002319',
#   'ACH-002320',
#   'ACH-002321',
#   'ACH-002322',
#   'ACH-002323',
#   'ACH-002324',
#   'ACH-002325',
#   'ACH-002326',
#   'ACH-002327',
#   'ACH-002328',
#   'ACH-002329',
#   'ACH-002330',
#   'ACH-002331',
#   'ACH-002399',
#   'ACH-002401',
#   'ACH-002883',
#   'ACH-002884',
#   'ACH-002885',
#   'ACH-002921',
#   'ACH-002950',
#   'ACH-002951'],
#  'CNS/Brain': ['ACH-000025',
#   'ACH-000027',
#   'ACH-000036',
#   'ACH-000040',
#   'ACH-000055',
#   'ACH-000067',
#   'ACH-000075',
#   'ACH-000095',
#   'ACH-000098',
#   'ACH-000102',
#   'ACH-000126',
#   'ACH-000128',
#   'ACH-000137',
#   'ACH-000152',
#   'ACH-000160',
#   'ACH-000200',
#   'ACH-000208',
#   'ACH-000211',
#   'ACH-000215',
#   'ACH-000231',
#   'ACH-000244',
#   'ACH-000269',
#   'ACH-000273',
#   'ACH-000283',
#   'ACH-000289',
#   'ACH-000323',
#   'ACH-000328',
#   'ACH-000329',
#   'ACH-000368',
#   'ACH-000370',
#   'ACH-000389',
#   'ACH-000437',
#   'ACH-000445',
#   'ACH-000455',
#   'ACH-000464',
#   'ACH-000469',
#   'ACH-000479',
#   'ACH-000504',
#   'ACH-000543',
#   'ACH-000558',
#   'ACH-000570',
#   'ACH-000571',
#   'ACH-000591',
#   'ACH-000592',
#   'ACH-000595',
#   'ACH-000609',
#   'ACH-000622',
#   'ACH-000623',
#   'ACH-000629',
#   'ACH-000631',
#   'ACH-000634',
#   'ACH-000655',
#   'ACH-000673',
#   'ACH-000676',
#   'ACH-000760',
#   'ACH-000776',
#   'ACH-000807',
#   'ACH-000819',
#   'ACH-000863',
#   'ACH-000887',
#   'ACH-001000',
#   'ACH-001016',
#   'ACH-001020',
#   'ACH-001028',
#   'ACH-001031',
#   'ACH-001033',
#   'ACH-001052',
#   'ACH-001053',
#   'ACH-001054',
#   'ACH-001055',
#   'ACH-001067',
#   'ACH-001118',
#   'ACH-001125',
#   'ACH-001126',
#   'ACH-001142',
#   'ACH-001172',
#   'ACH-001198',
#   'ACH-001201',
#   'ACH-001214',
#   'ACH-001232',
#   'ACH-001289',
#   'ACH-001329',
#   'ACH-001605',
#   'ACH-001606',
#   'ACH-001608',
#   'ACH-001609',
#   'ACH-001610',
#   'ACH-001611',
#   'ACH-001622',
#   'ACH-001623',
#   'ACH-001624',
#   'ACH-001670',
#   'ACH-001711',
#   'ACH-002070',
#   'ACH-002223',
#   'ACH-002224',
#   'ACH-002225',
#   'ACH-002226',
#   'ACH-002227',
#   'ACH-002228',
#   'ACH-002229',
#   'ACH-002230',
#   'ACH-002231',
#   'ACH-002257',
#   'ACH-002259',
#   'ACH-002268',
#   'ACH-002269',
#   'ACH-002304',
#   'ACH-002348',
#   'ACH-002349',
#   'ACH-002680',
#   'ACH-002806',
#   'ACH-003135',
#   'ACH-003137',
#   'ACH-003138',
#   'ACH-003148',
#   'ACH-003150'],
#  'Cervix': ['ACH-000490',
#   'ACH-000556',
#   'ACH-001017',
#   'ACH-001071',
#   'ACH-001086',
#   'ACH-001333',
#   'ACH-001334',
#   'ACH-001335',
#   'ACH-001336',
#   'ACH-001341',
#   'ACH-001359',
#   'ACH-001360',
#   'ACH-001402',
#   'ACH-001451',
#   'ACH-001513',
#   'ACH-001515',
#   'ACH-001516',
#   'ACH-001525',
#   'ACH-001650',
#   'ACH-001651',
#   'ACH-001652',
#   'ACH-002019',
#   'ACH-002020',
#   'ACH-002180',
#   'ACH-002201'],
#  'Embryonal': ['ACH-003145'],
#  'Esophagus/Stomach': ['ACH-000110',
#   'ACH-000216',
#   'ACH-000225',
#   'ACH-000239',
#   'ACH-000247',
#   'ACH-000255',
#   'ACH-000303',
#   'ACH-000305',
#   'ACH-000318',
#   'ACH-000325',
#   'ACH-000344',
#   'ACH-000353',
#   'ACH-000383',
#   'ACH-000427',
#   'ACH-000452',
#   'ACH-000466',
#   'ACH-000485',
#   'ACH-000544',
#   'ACH-000560',
#   'ACH-000561',
#   'ACH-000605',
#   'ACH-000674',
#   'ACH-000694',
#   'ACH-000717',
#   'ACH-000726',
#   'ACH-000736',
#   'ACH-000746',
#   'ACH-000761',
#   'ACH-000764',
#   'ACH-000823',
#   'ACH-000824',
#   'ACH-000855',
#   'ACH-000873',
#   'ACH-000880',
#   'ACH-000898',
#   'ACH-000908',
#   'ACH-000911',
#   'ACH-000917',
#   'ACH-000919',
#   'ACH-000932',
#   'ACH-000948',
#   'ACH-000949',
#   'ACH-001368',
#   'ACH-001496',
#   'ACH-001497',
#   'ACH-001500',
#   'ACH-001544',
#   'ACH-001653',
#   'ACH-001654',
#   'ACH-001664',
#   'ACH-002141',
#   'ACH-002161',
#   'ACH-002202',
#   'ACH-002243',
#   'ACH-002263',
#   'ACH-002264',
#   'ACH-002292',
#   'ACH-002306',
#   'ACH-002311',
#   'ACH-002446',
#   'ACH-002705',
#   'ACH-002706',
#   'ACH-002730',
#   'ACH-002733',
#   'ACH-002736',
#   'ACH-002757',
#   'ACH-002835',
#   'ACH-002837',
#   'ACH-002871',
#   'ACH-002954',
#   'ACH-002967',
#   'ACH-002968',
#   'ACH-002972',
#   'ACH-002979',
#   'ACH-002981'],
#  'Eye': ['ACH-001295',
#   'ACH-001421',
#   'ACH-001441',
#   'ACH-001554',
#   'ACH-002010',
#   'ACH-002011',
#   'ACH-002014',
#   'ACH-002015',
#   'ACH-002016',
#   'ACH-002017',
#   'ACH-002018',
#   'ACH-002336',
#   'ACH-002462',
#   'ACH-002463',
#   'ACH-002464',
#   'ACH-002465',
#   'ACH-002466',
#   'ACH-002467',
#   'ACH-002687',
#   'ACH-002925',
#   'ACH-002926'],
#  'Fibroblast': ['ACH-000043',
#   'ACH-000063',
#   'ACH-000071',
#   'ACH-000079',
#   'ACH-000083',
#   'ACH-000088',
#   'ACH-000119',
#   'ACH-000125',
#   'ACH-000131',
#   'ACH-000133',
#   'ACH-000134',
#   'ACH-000135',
#   'ACH-000154',
#   'ACH-000165',
#   'ACH-000175',
#   'ACH-000180',
#   'ACH-000184',
#   'ACH-000185',
#   'ACH-000194',
#   'ACH-000199',
#   'ACH-000214',
#   'ACH-000224',
#   'ACH-000229',
#   'ACH-000230',
#   'ACH-000240',
#   'ACH-000275',
#   'ACH-000284',
#   'ACH-000306',
#   'ACH-000340',
#   'ACH-000413',
#   'ACH-000526',
#   'ACH-000529',
#   'ACH-000531',
#   'ACH-000539',
#   'ACH-000540',
#   'ACH-000742',
#   'ACH-000797',
#   'ACH-000850',
#   'ACH-001018',
#   'ACH-001093',
#   'ACH-001207',
#   'ACH-001767'],
#  'Hair': ['ACH-003159', 'ACH-003160'],
#  'Head and Neck': ['ACH-000181',
#   'ACH-000188',
#   'ACH-000207',
#   'ACH-000228',
#   'ACH-000238',
#   'ACH-000254',
#   'ACH-000415',
#   'ACH-000472',
#   'ACH-000500',
#   'ACH-000503',
#   'ACH-000518',
#   'ACH-000546',
#   'ACH-000548',
#   'ACH-000549',
#   'ACH-000606',
#   'ACH-000618',
#   'ACH-000619',
#   'ACH-000630',
#   'ACH-000682',
#   'ACH-000692',
#   'ACH-000715',
#   'ACH-000723',
#   'ACH-000732',
#   'ACH-000735',
#   'ACH-000740',
#   'ACH-000762',
#   'ACH-000771',
#   'ACH-000778',
#   'ACH-000794',
#   'ACH-000832',
#   'ACH-000836',
#   'ACH-000846',
#   'ACH-000992',
#   'ACH-001023',
#   'ACH-001090',
#   'ACH-001227',
#   'ACH-001228',
#   'ACH-001229',
#   'ACH-001331',
#   'ACH-001332',
#   'ACH-001346',
#   'ACH-001347',
#   'ACH-001385',
#   'ACH-001508',
#   'ACH-001509',
#   'ACH-001510',
#   'ACH-001511',
#   'ACH-001542',
#   'ACH-001543',
#   'ACH-001625',
#   'ACH-001626',
#   'ACH-001641',
#   'ACH-001675',
#   'ACH-001690',
#   'ACH-001691',
#   'ACH-001692',
#   'ACH-001693',
#   'ACH-001694',
#   'ACH-001695',
#   'ACH-001696',
#   'ACH-001698',
#   'ACH-001699',
#   'ACH-001701',
#   'ACH-002029',
#   'ACH-002030',
#   'ACH-002042',
#   'ACH-002043',
#   'ACH-002044',
#   'ACH-002045',
#   'ACH-002212',
#   'ACH-002213',
#   'ACH-002234',
#   'ACH-002239',
#   'ACH-002244',
#   'ACH-002249',
#   'ACH-002250',
#   'ACH-002251',
#   'ACH-002265',
#   'ACH-002294',
#   'ACH-002295',
#   'ACH-002296',
#   'ACH-002297',
#   'ACH-002298',
#   'ACH-002305',
#   'ACH-002711',
#   'ACH-003099'],
#  'Kidney': ['ACH-000016',
#   'ACH-000046',
#   'ACH-000049',
#   'ACH-000096',
#   'ACH-000171',
#   'ACH-000189',
#   'ACH-000201',
#   'ACH-000234',
#   'ACH-000246',
#   'ACH-000250',
#   'ACH-000262',
#   'ACH-000272',
#   'ACH-000300',
#   'ACH-000313',
#   'ACH-000317',
#   'ACH-000375',
#   'ACH-000385',
#   'ACH-000411',
#   'ACH-000428',
#   'ACH-000429',
#   'ACH-000457',
#   'ACH-000459',
#   'ACH-000484',
#   'ACH-000495',
#   'ACH-000513',
#   'ACH-000533',
#   'ACH-000555',
#   'ACH-000600',
#   'ACH-000649',
#   'ACH-000684',
#   'ACH-000709',
#   'ACH-000792',
#   'ACH-000907',
#   'ACH-001087',
#   'ACH-001109',
#   'ACH-001163',
#   'ACH-001175',
#   'ACH-001194',
#   'ACH-001200',
#   'ACH-001208',
#   'ACH-001210',
#   'ACH-001224',
#   'ACH-001225',
#   'ACH-001310',
#   'ACH-001398',
#   'ACH-001532',
#   'ACH-001687',
#   'ACH-001688',
#   'ACH-002090',
#   'ACH-002139',
#   'ACH-002150',
#   'ACH-002151',
#   'ACH-002155',
#   'ACH-002167',
#   'ACH-002168',
#   'ACH-002187',
#   'ACH-002188',
#   'ACH-002189',
#   'ACH-002190',
#   'ACH-002191',
#   'ACH-002192',
#   'ACH-002195',
#   'ACH-002199',
#   'ACH-002533',
#   'ACH-003143'],
#  'Liver': ['ACH-000217',
#   'ACH-000221',
#   'ACH-000316',
#   'ACH-000361',
#   'ACH-000393',
#   'ACH-000420',
#   'ACH-000471',
#   'ACH-000475',
#   'ACH-000476',
#   'ACH-000478',
#   'ACH-000480',
#   'ACH-000493',
#   'ACH-000537',
#   'ACH-000577',
#   'ACH-000625',
#   'ACH-000671',
#   'ACH-000686',
#   'ACH-000734',
#   'ACH-000739',
#   'ACH-001021',
#   'ACH-001089',
#   'ACH-001318',
#   'ACH-001853',
#   'ACH-002523',
#   'ACH-003155'],
#  'Lung': ['ACH-000015',
#   'ACH-000029',
#   'ACH-000030',
#   'ACH-000033',
#   'ACH-000035',
#   'ACH-000062',
#   'ACH-000064',
#   'ACH-000066',
#   'ACH-000121',
#   'ACH-000129',
#   'ACH-000143',
#   'ACH-000150',
#   'ACH-000161',
#   'ACH-000176',
#   'ACH-000179',
#   'ACH-000186',
#   'ACH-000251',
#   'ACH-000261',
#   'ACH-000282',
#   'ACH-000290',
#   'ACH-000292',
#   'ACH-000309',
#   'ACH-000314',
#   'ACH-000327',
#   'ACH-000337',
#   'ACH-000339',
#   'ACH-000343',
#   'ACH-000358',
#   'ACH-000378',
#   'ACH-000379',
#   'ACH-000382',
#   'ACH-000390',
#   'ACH-000392',
#   'ACH-000394',
#   'ACH-000399',
#   'ACH-000414',
#   'ACH-000416',
#   'ACH-000434',
#   'ACH-000438',
#   'ACH-000442',
#   'ACH-000448',
#   'ACH-000451',
#   'ACH-000482',
#   'ACH-000510',
#   'ACH-000511',
#   'ACH-000553',
#   'ACH-000562',
#   'ACH-000575',
#   'ACH-000578',
#   'ACH-000585',
#   'ACH-000587',
#   'ACH-000590',
#   'ACH-000594',
#   'ACH-000596',
#   'ACH-000603',
#   'ACH-000610',
#   'ACH-000627',
#   'ACH-000638',
#   'ACH-000639',
#   'ACH-000672',
#   'ACH-000675',
#   'ACH-000677',
#   'ACH-000681',
#   'ACH-000690',
#   'ACH-000695',
#   'ACH-000700',
#   'ACH-000703',
#   'ACH-000705',
#   'ACH-000706',
#   'ACH-000712',
#   'ACH-000718',
#   'ACH-000731',
#   'ACH-000733',
#   'ACH-000737',
#   'ACH-000743',
#   'ACH-000744',
#   'ACH-000752',
#   'ACH-000757',
#   'ACH-000766',
#   'ACH-000769',
#   'ACH-000774',
#   'ACH-000775',
#   'ACH-000779',
#   'ACH-000780',
#   'ACH-000781',
#   'ACH-000785',
#   'ACH-000787',
#   'ACH-000789',
#   'ACH-000790',
#   'ACH-000791',
#   'ACH-000813',
#   'ACH-000825',
#   'ACH-000826',
#   'ACH-000837',
#   'ACH-000840',
#   'ACH-000841',
#   'ACH-000844',
#   'ACH-000845',
#   'ACH-000851',
#   'ACH-000861',
#   'ACH-000866',
#   'ACH-000868',
#   'ACH-000869',
#   'ACH-000870',
#   'ACH-000872',
#   'ACH-000875',
#   'ACH-000878',
#   'ACH-000886',
#   'ACH-000890',
#   'ACH-000891',
#   'ACH-000892',
#   'ACH-000901',
#   'ACH-000904',
#   'ACH-000912',
#   'ACH-000916',
#   'ACH-000924',
#   'ACH-000925',
#   'ACH-000929',
#   'ACH-000951',
#   'ACH-000975',
#   'ACH-000980',
#   'ACH-001047',
#   'ACH-001049',
#   'ACH-001075',
#   'ACH-001079',
#   'ACH-001088',
#   'ACH-001113',
#   'ACH-001136',
#   'ACH-001137',
#   'ACH-001138',
#   'ACH-001233',
#   'ACH-001234',
#   'ACH-001362',
#   'ACH-001363',
#   'ACH-001364',
#   'ACH-001365',
#   'ACH-001386',
#   'ACH-001417',
#   'ACH-001489',
#   'ACH-001490',
#   'ACH-001549',
#   'ACH-001591',
#   'ACH-001599',
#   'ACH-001958',
#   'ACH-002035',
#   'ACH-002051',
#   'ACH-002052',
#   'ACH-002077',
#   'ACH-002089',
#   'ACH-002095',
#   'ACH-002101',
#   'ACH-002102',
#   'ACH-002122',
#   'ACH-002138',
#   'ACH-002144',
#   'ACH-002145',
#   'ACH-002154',
#   'ACH-002156',
#   'ACH-002157',
#   'ACH-002158',
#   'ACH-002169',
#   'ACH-002170',
#   'ACH-002171',
#   'ACH-002172',
#   'ACH-002173',
#   'ACH-002174',
#   'ACH-002175',
#   'ACH-002177',
#   'ACH-002184',
#   'ACH-002193',
#   'ACH-002196',
#   'ACH-002197',
#   'ACH-002286',
#   'ACH-002333',
#   'ACH-002337',
#   'ACH-002490',
#   'ACH-002497',
#   'ACH-002522',
#   'ACH-002526',
#   'ACH-002531',
#   'ACH-002650',
#   'ACH-002996',
#   'ACH-003012',
#   'ACH-003071',
#   'ACH-003119',
#   'ACH-003120',
#   'ACH-003121',
#   'ACH-003152',
#   'ACH-003153',
#   'ACH-003154',
#   'ACH-003156',
#   'ACH-003157'],
#  'Lymphoid': ['ACH-000020',
#   'ACH-000024',
#   'ACH-000032',
#   'ACH-000038',
#   'ACH-000050',
#   'ACH-000056',
#   'ACH-000057',
#   'ACH-000059',
#   'ACH-000061',
#   'ACH-000069',
#   'ACH-000070',
#   'ACH-000073',
#   'ACH-000077',
#   'ACH-000101',
#   'ACH-000104',
#   'ACH-000105',
#   'ACH-000106',
#   'ACH-000122',
#   'ACH-000124',
#   'ACH-000130',
#   'ACH-000140',
#   'ACH-000151',
#   'ACH-000156',
#   'ACH-000157',
#   'ACH-000158',
#   'ACH-000162',
#   'ACH-000167',
#   'ACH-000183',
#   'ACH-000193',
#   'ACH-000197',
#   'ACH-000204',
#   'ACH-000206',
#   'ACH-000220',
#   'ACH-000226',
#   'ACH-000233',
#   'ACH-000245',
#   'ACH-000267',
#   'ACH-000271',
#   'ACH-000285',
#   'ACH-000287',
#   'ACH-000315',
#   'ACH-000334',
#   'ACH-000338',
#   'ACH-000346',
#   'ACH-000357',
#   'ACH-000363',
#   'ACH-000365',
#   'ACH-000371',
#   'ACH-000372',
#   'ACH-000380',
#   'ACH-000388',
#   'ACH-000398',
#   'ACH-000402',
#   'ACH-000405',
#   'ACH-000419',
#   'ACH-000426',
#   'ACH-000436',
#   'ACH-000440',
#   'ACH-000453',
#   'ACH-000492',
#   'ACH-000509',
#   'ACH-000512',
#   'ACH-000519',
#   'ACH-000534',
#   'ACH-000541',
#   'ACH-000564',
#   'ACH-000567',
#   'ACH-000576',
#   'ACH-000583',
#   'ACH-000588',
#   'ACH-000598',
#   'ACH-000611',
#   'ACH-000612',
#   'ACH-000626',
#   'ACH-000636',
#   'ACH-000653',
#   'ACH-000654',
#   'ACH-000656',
#   'ACH-000658',
#   'ACH-000660',
#   'ACH-000664',
#   'ACH-000687',
#   'ACH-000702',
#   'ACH-000707',
#   'ACH-000714',
#   'ACH-000728',
#   'ACH-000745',
#   'ACH-000754',
#   'ACH-000763',
#   'ACH-000773',
#   'ACH-000782',
#   'ACH-000786',
#   'ACH-000795',
#   'ACH-000806',
#   'ACH-000815',
#   'ACH-000817',
#   'ACH-000821',
#   'ACH-000829',
#   'ACH-000838',
#   'ACH-000854',
#   'ACH-000874',
#   'ACH-000877',
#   'ACH-000889',
#   'ACH-000914',
#   'ACH-000918',
#   'ACH-000922',
#   'ACH-000923',
#   'ACH-000937',
#   'ACH-000938',
#   'ACH-000942',
#   'ACH-000944',
#   'ACH-000953',
#   'ACH-000960',
#   'ACH-000964',
#   'ACH-000981',
#   'ACH-000995',
#   'ACH-001043',
#   'ACH-001057',
#   'ACH-001060',
#   'ACH-001064',
#   'ACH-001068',
#   'ACH-001097',
#   'ACH-001100',
#   'ACH-001106',
#   'ACH-001111',
#   'ACH-001119',
#   'ACH-001121',
#   'ACH-001127',
#   'ACH-001130',
#   'ACH-001132',
#   'ACH-001134',
#   'ACH-001143',
#   'ACH-001146',
#   'ACH-001147',
#   'ACH-001148',
#   'ACH-001162',
#   'ACH-001182',
#   'ACH-001197',
#   'ACH-001203',
#   'ACH-001450',
#   'ACH-001452',
#   'ACH-001484',
#   'ACH-001485',
#   'ACH-001498',
#   'ACH-001520',
#   'ACH-001533',
#   'ACH-001539',
#   'ACH-001541',
#   'ACH-001616',
#   'ACH-001617',
#   'ACH-001634',
#   'ACH-001636',
#   'ACH-001638',
#   'ACH-001639',
#   'ACH-001642',
#   'ACH-001669',
#   'ACH-001677',
#   'ACH-001679',
#   'ACH-001680',
#   'ACH-001685',
#   'ACH-001703',
#   'ACH-001707',
#   'ACH-001708',
#   'ACH-001709',
#   'ACH-001735',
#   'ACH-001736',
#   'ACH-001737',
#   'ACH-001738',
#   'ACH-001993',
#   'ACH-002055',
#   'ACH-002058',
#   'ACH-002059',
#   'ACH-002062',
#   'ACH-002209',
#   'ACH-002211',
#   'ACH-002214',
#   'ACH-002215',
#   'ACH-002216',
#   'ACH-002220',
#   'ACH-002221',
#   'ACH-002222',
#   'ACH-002232',
#   'ACH-002236',
#   'ACH-002238',
#   'ACH-002240',
#   'ACH-002241',
#   'ACH-002242',
#   'ACH-002245',
#   'ACH-002252',
#   'ACH-002253',
#   'ACH-002254',
#   'ACH-002255',
#   'ACH-002256',
#   'ACH-002267',
#   'ACH-002272',
#   'ACH-002274',
#   'ACH-002275',
#   'ACH-002289',
#   'ACH-002293',
#   'ACH-002300',
#   'ACH-002301',
#   'ACH-002307',
#   'ACH-002308',
#   'ACH-002313',
#   'ACH-002317',
#   'ACH-002339',
#   'ACH-002392',
#   'ACH-002478',
#   'ACH-002485',
#   'ACH-002500',
#   'ACH-002677',
#   'ACH-002678',
#   'ACH-003100',
#   'ACH-003106',
#   'ACH-003107',
#   'ACH-003108'],
#  'Muscle': ['ACH-003139',
#   'ACH-003141',
#   'ACH-003142',
#   'ACH-003149',
#   'ACH-003158'],
#  'Myeloid': ['ACH-000002',
#   'ACH-000004',
#   'ACH-000005',
#   'ACH-000006',
#   'ACH-000034',
#   'ACH-000045',
#   'ACH-000065',
#   'ACH-000072',
#   'ACH-000074',
#   'ACH-000076',
#   'ACH-000080',
#   'ACH-000081',
#   'ACH-000084',
#   'ACH-000112',
#   'ACH-000113',
#   'ACH-000166',
#   'ACH-000168',
#   'ACH-000190',
#   'ACH-000195',
#   'ACH-000198',
#   'ACH-000218',
#   'ACH-000241',
#   'ACH-000263',
#   'ACH-000294',
#   'ACH-000295',
#   'ACH-000299',
#   'ACH-000301',
#   'ACH-000321',
#   'ACH-000326',
#   'ACH-000336',
#   'ACH-000362',
#   'ACH-000369',
#   'ACH-000373',
#   'ACH-000386',
#   'ACH-000387',
#   'ACH-000406',
#   'ACH-000432',
#   'ACH-000439',
#   'ACH-000462',
#   'ACH-000487',
#   'ACH-000498',
#   'ACH-000551',
#   'ACH-000557',
#   'ACH-000602',
#   'ACH-000604',
#   'ACH-000641',
#   'ACH-000751',
#   'ACH-000770',
#   'ACH-000920',
#   'ACH-000983',
#   'ACH-001036',
#   'ACH-001037',
#   'ACH-001129',
#   'ACH-001230',
#   'ACH-001573',
#   'ACH-001574',
#   'ACH-001577',
#   'ACH-001613',
#   'ACH-001618',
#   'ACH-001647',
#   'ACH-001656',
#   'ACH-002061',
#   'ACH-002210',
#   'ACH-002218',
#   'ACH-002247',
#   'ACH-002258',
#   'ACH-002262',
#   'ACH-002270',
#   'ACH-002273',
#   'ACH-002276',
#   'ACH-002290',
#   'ACH-002299',
#   'ACH-002302',
#   'ACH-002314',
#   'ACH-002316',
#   'ACH-002475'],
#  'Normal': ['ACH-002342',
#   'ACH-002343',
#   'ACH-002344',
#   'ACH-002346',
#   'ACH-002347',
#   'ACH-002350',
#   'ACH-002351',
#   'ACH-002352',
#   'ACH-002353',
#   'ACH-002354',
#   'ACH-002355',
#   'ACH-002356',
#   'ACH-002357',
#   'ACH-002358',
#   'ACH-002360',
#   'ACH-002361',
#   'ACH-002362',
#   'ACH-002363',
#   'ACH-002364',
#   'ACH-002365',
#   'ACH-002366',
#   'ACH-002367',
#   'ACH-002368',
#   'ACH-002369',
#   'ACH-002370',
#   'ACH-002371',
#   'ACH-002372',
#   'ACH-002373',
#   'ACH-002374',
#   'ACH-002375',
#   'ACH-002376',
#   'ACH-002377',
#   'ACH-002378',
#   'ACH-002379',
#   'ACH-002380',
#   'ACH-002381',
#   'ACH-002382',
#   'ACH-002383',
#   'ACH-002384'],
#  'Other': ['ACH-002050', 'ACH-002198'],
#  'Ovary/Fallopian Tube': ['ACH-000013',
#   'ACH-000048',
#   'ACH-000091',
#   'ACH-000103',
#   'ACH-000116',
#   'ACH-000123',
#   'ACH-000237',
#   'ACH-000256',
#   'ACH-000278',
#   'ACH-000280',
#   'ACH-000308',
#   'ACH-000324',
#   'ACH-000333',
#   'ACH-000430',
#   'ACH-000443',
#   'ACH-000460',
#   'ACH-000494',
#   'ACH-000524',
#   'ACH-000527',
#   'ACH-000542',
#   'ACH-000584',
#   'ACH-000646',
#   'ACH-000657',
#   'ACH-000663',
#   'ACH-000688',
#   'ACH-000701',
#   'ACH-000796',
#   'ACH-000885',
#   'ACH-000936',
#   'ACH-000947',
#   'ACH-000962',
#   'ACH-000966',
#   'ACH-001048',
#   'ACH-001063',
#   'ACH-001144',
#   'ACH-001145',
#   'ACH-001151',
#   'ACH-001278',
#   'ACH-001279',
#   'ACH-001340',
#   'ACH-001369',
#   'ACH-001370',
#   'ACH-001373',
#   'ACH-001374',
#   'ACH-001403',
#   'ACH-001418',
#   'ACH-001628',
#   'ACH-001630',
#   'ACH-001632',
#   'ACH-001719',
#   'ACH-001991',
#   'ACH-002038',
#   'ACH-002140',
#   'ACH-002146',
#   'ACH-002149',
#   'ACH-002181',
#   'ACH-002182',
#   'ACH-002183',
#   'ACH-002486',
#   'ACH-002524'],
#  'Pancreas': ['ACH-000022',
#   'ACH-000023',
#   'ACH-000031',
#   'ACH-000042',
#   'ACH-000060',
#   'ACH-000085',
#   'ACH-000093',
#   'ACH-000094',
#   'ACH-000107',
#   'ACH-000108',
#   'ACH-000114',
#   'ACH-000118',
#   'ACH-000138',
#   'ACH-000139',
#   'ACH-000155',
#   'ACH-000164',
#   'ACH-000178',
#   'ACH-000205',
#   'ACH-000213',
#   'ACH-000222',
#   'ACH-000235',
#   'ACH-000265',
#   'ACH-000266',
#   'ACH-000270',
#   'ACH-000281',
#   'ACH-000307',
#   'ACH-000320',
#   'ACH-000332',
#   'ACH-000354',
#   'ACH-000417',
#   'ACH-000468',
#   'ACH-000502',
#   'ACH-000517',
#   'ACH-000535',
#   'ACH-000599',
#   'ACH-000601',
#   'ACH-000685',
#   'ACH-000933',
#   'ACH-001072',
#   'ACH-001098',
#   'ACH-001101',
#   'ACH-001107',
#   'ACH-001171',
#   'ACH-001353',
#   'ACH-001375',
#   'ACH-001376',
#   'ACH-001377',
#   'ACH-001378',
#   'ACH-001379',
#   'ACH-001380',
#   'ACH-001382',
#   'ACH-001999',
#   'ACH-002039',
#   'ACH-002164',
#   'ACH-002186',
#   'ACH-002672',
#   'ACH-002738',
#   'ACH-002742',
#   'ACH-002743',
#   'ACH-002744',
#   'ACH-002745',
#   'ACH-003161'],
#  'Peripheral Nervous System': ['ACH-000078',
#   'ACH-000099',
#   'ACH-000136',
#   'ACH-000149',
#   'ACH-000203',
#   'ACH-000227',
#   'ACH-000259',
#   'ACH-000260',
#   'ACH-000310',
#   'ACH-000312',
#   'ACH-000341',
#   'ACH-000345',
#   'ACH-000366',
#   'ACH-000446',
#   'ACH-000804',
#   'ACH-001188',
#   'ACH-001300',
#   'ACH-001301',
#   'ACH-001302',
#   'ACH-001303',
#   'ACH-001338',
#   'ACH-001344',
#   'ACH-001354',
#   'ACH-001355',
#   'ACH-001366',
#   'ACH-001367',
#   'ACH-001481',
#   'ACH-001548',
#   'ACH-001603',
#   'ACH-001674',
#   'ACH-001716',
#   'ACH-002065',
#   'ACH-002066',
#   'ACH-002080',
#   'ACH-002083',
#   'ACH-002217',
#   'ACH-002248',
#   'ACH-002261',
#   'ACH-002277',
#   'ACH-002278',
#   'ACH-002279',
#   'ACH-002280',
#   'ACH-002281',
#   'ACH-002282',
#   'ACH-002283',
#   'ACH-002284',
#   'ACH-002285',
#   'ACH-002340',
#   'ACH-002389',
#   'ACH-002693',
#   'ACH-002710',
#   'ACH-002799',
#   'ACH-002800',
#   'ACH-002801',
#   'ACH-002922'],
#  'Pleura': ['ACH-000086',
#   'ACH-000092',
#   'ACH-000153',
#   'ACH-000319',
#   'ACH-000331',
#   'ACH-000367',
#   'ACH-000569',
#   'ACH-000645',
#   'ACH-000648',
#   'ACH-001547',
#   'ACH-001555',
#   'ACH-001556',
#   'ACH-001557',
#   'ACH-001558',
#   'ACH-001559',
#   'ACH-001560',
#   'ACH-001561',
#   'ACH-001562',
#   'ACH-001977',
#   'ACH-001992',
#   'ACH-002033',
#   'ACH-002123',
#   'ACH-002124',
#   'ACH-002125',
#   'ACH-002126',
#   'ACH-002127',
#   'ACH-002128',
#   'ACH-002129',
#   'ACH-002130',
#   'ACH-002131',
#   'ACH-002132',
#   'ACH-002133',
#   'ACH-002134',
#   'ACH-002135',
#   'ACH-002136'],
#  'Prostate': ['ACH-000115',
#   'ACH-000170',
#   'ACH-000177',
#   'ACH-000952',
#   'ACH-000956',
#   'ACH-000977',
#   'ACH-000979',
#   'ACH-001383',
#   'ACH-001422',
#   'ACH-001453',
#   'ACH-001627',
#   'ACH-001648',
#   'ACH-001649',
#   'ACH-003019'],
#  'Skin': ['ACH-000008',
#   'ACH-000014',
#   'ACH-000219',
#   'ACH-000274',
#   'ACH-000304',
#   'ACH-000322',
#   'ACH-000348',
#   'ACH-000401',
#   'ACH-000404',
#   'ACH-000423',
#   'ACH-000425',
#   'ACH-000441',
#   'ACH-000450',
#   'ACH-000458',
#   'ACH-000465',
#   'ACH-000477',
#   'ACH-000550',
#   'ACH-000572',
#   'ACH-000579',
#   'ACH-000580',
#   'ACH-000582',
#   'ACH-000615',
#   'ACH-000632',
#   'ACH-000640',
#   'ACH-000644',
#   'ACH-000650',
#   'ACH-000661',
#   'ACH-000730',
#   'ACH-000750',
#   'ACH-000765',
#   'ACH-000788',
#   'ACH-000799',
#   'ACH-000801',
#   'ACH-000805',
#   'ACH-000810',
#   'ACH-000812',
#   'ACH-000814',
#   'ACH-000822',
#   'ACH-000827',
#   'ACH-000881',
#   'ACH-000882',
#   'ACH-000884',
#   'ACH-000899',
#   'ACH-000915',
#   'ACH-000931',
#   'ACH-000968',
#   'ACH-000987',
#   'ACH-001002',
#   'ACH-001024',
#   'ACH-001041',
#   'ACH-001044',
#   'ACH-001045',
#   'ACH-001122',
#   'ACH-001123',
#   'ACH-001131',
#   'ACH-001170',
#   'ACH-001239',
#   'ACH-001328',
#   'ACH-001339',
#   'ACH-001442',
#   'ACH-001521',
#   'ACH-001522',
#   'ACH-001523',
#   'ACH-001524',
#   'ACH-001550',
#   'ACH-001551',
#   'ACH-001552',
#   'ACH-001563',
#   'ACH-001566',
#   'ACH-001567',
#   'ACH-001568',
#   'ACH-001569',
#   'ACH-001570',
#   'ACH-001645',
#   'ACH-001704',
#   'ACH-001970',
#   'ACH-001971',
#   'ACH-001972',
#   'ACH-001973',
#   'ACH-001975',
#   'ACH-001982',
#   'ACH-001986',
#   'ACH-001990',
#   'ACH-002001',
#   'ACH-002002',
#   'ACH-002003',
#   'ACH-002004',
#   'ACH-002005',
#   'ACH-002084',
#   'ACH-002096',
#   'ACH-002097',
#   'ACH-002098',
#   'ACH-002100',
#   'ACH-002121',
#   'ACH-002143',
#   'ACH-002147',
#   'ACH-002152',
#   'ACH-002153',
#   'ACH-002159',
#   'ACH-002162',
#   'ACH-002165',
#   'ACH-002166',
#   'ACH-002205',
#   'ACH-002206',
#   'ACH-002207',
#   'ACH-002338',
#   'ACH-002386',
#   'ACH-002387',
#   'ACH-002388',
#   'ACH-002458',
#   'ACH-002459',
#   'ACH-002460',
#   'ACH-002461',
#   'ACH-002508',
#   'ACH-002509',
#   'ACH-002510',
#   'ACH-002511',
#   'ACH-002512',
#   'ACH-002847',
#   'ACH-002928',
#   'ACH-003105'],
#  'Soft Tissue': ['ACH-000037',
#   'ACH-000051',
#   'ACH-000054',
#   'ACH-000100',
#   'ACH-000145',
#   'ACH-000169',
#   'ACH-000172',
#   'ACH-000505',
#   'ACH-000597',
#   'ACH-000607',
#   'ACH-000689',
#   'ACH-000772',
#   'ACH-000833',
#   'ACH-000835',
#   'ACH-001050',
#   'ACH-001059',
#   'ACH-001096',
#   'ACH-001099',
#   'ACH-001128',
#   'ACH-001164',
#   'ACH-001184',
#   'ACH-001189',
#   'ACH-001196',
#   'ACH-001211',
#   'ACH-001212',
#   'ACH-001270',
#   'ACH-001272',
#   'ACH-001274',
#   'ACH-001275',
#   'ACH-001277',
#   'ACH-001280',
#   'ACH-001322',
#   'ACH-001433',
#   'ACH-001540',
#   'ACH-001702',
#   'ACH-001740',
#   'ACH-001743',
#   'ACH-001745',
#   'ACH-001750',
#   'ACH-001751',
#   'ACH-001765',
#   'ACH-001791',
#   'ACH-001793',
#   'ACH-001794',
#   'ACH-001795',
#   'ACH-001796',
#   'ACH-001799',
#   'ACH-001802',
#   'ACH-001804',
#   'ACH-001807',
#   'ACH-002048',
#   'ACH-002085',
#   'ACH-002246',
#   'ACH-002271',
#   'ACH-002309',
#   'ACH-002310',
#   'ACH-002332',
#   'ACH-002334',
#   'ACH-002784',
#   'ACH-002785',
#   'ACH-002787',
#   'ACH-002794',
#   'ACH-003111',
#   'ACH-003125',
#   'ACH-003181',
#   'ACH-003183',
#   'ACH-003184'],
#  'Testis': ['ACH-001437',
#   'ACH-001438',
#   'ACH-001502',
#   'ACH-001578',
#   'ACH-001668',
#   'ACH-001672',
#   'ACH-002288',
#   'ACH-002291'],
#  'Thyroid': ['ACH-000058',
#   'ACH-000174',
#   'ACH-000191',
#   'ACH-000456',
#   'ACH-000716',
#   'ACH-000897',
#   'ACH-000903',
#   'ACH-001307',
#   'ACH-001321',
#   'ACH-001350',
#   'ACH-001356',
#   'ACH-001384',
#   'ACH-001443',
#   'ACH-001528',
#   'ACH-002041',
#   'ACH-002148',
#   'ACH-002397'],
#  'Uterus': ['ACH-000173',
#   'ACH-000302',
#   'ACH-000397',
#   'ACH-000407',
#   'ACH-000435',
#   'ACH-000449',
#   'ACH-000831',
#   'ACH-000864',
#   'ACH-000879',
#   'ACH-000909',
#   'ACH-000913',
#   'ACH-000928',
#   'ACH-000939',
#   'ACH-000940',
#   'ACH-000941',
#   'ACH-000946',
#   'ACH-000954',
#   'ACH-000961',
#   'ACH-000972',
#   'ACH-000974',
#   'ACH-000978',
#   'ACH-000984',
#   'ACH-000990',
#   'ACH-000993',
#   'ACH-000994',
#   'ACH-000996',
#   'ACH-001042',
#   'ACH-001495',
#   'ACH-001517',
#   'ACH-001518',
#   'ACH-001529',
#   'ACH-001530',
#   'ACH-001655',
#   'ACH-002021',
#   'ACH-002026',
#   'ACH-002027',
#   'ACH-002046'],
#  'Vulva/Vagina': ['ACH-001400',
#   'ACH-002040',
#   'ACH-002091',
#   'ACH-002120',
#   'ACH-002200']}

# %%
ec_dna_absent_categories = ecdna_absent_lineage_dict.keys()
avg_ecdna_absent_trimmed_esen_df = pd.DataFrame(index=ec_dna_absent_categories, columns=literature_gene_list)

# %%
# Calculate the average essentiality scores for each category
for category, cell_lines in ecdna_absent_lineage_dict.items():
    # Filter out cell lines not present in trimmed_esen_df
    valid_ecdna_absent_cell_lines = [cell_line for cell_line in cell_lines if cell_line in trimmed_esen_df.index]
    if valid_ecdna_absent_cell_lines:  # Only calculate if there are valid cell lines
        avg_ecdna_absent_trimmed_esen_df.loc[category] = trimmed_esen_df.loc[valid_ecdna_absent_cell_lines].mean()

# %%
avg_ecdna_absent_trimmed_esen_df.dropna(how='all', inplace=True)

# %% [markdown]
# Renaming with "-" rather than "/" to avoid errors:

# %%
avg_ecdna_absent_trimmed_esen_df.index = avg_ecdna_absent_trimmed_esen_df.index.str.replace('/', '-')

# %% [markdown]
# Adding an "ecDNA-absent" tag to each category:

# %%
avg_ecdna_absent_trimmed_esen_df.index = [str(index) + " (ecDNA-absent)" for index in avg_ecdna_absent_trimmed_esen_df.index]

# %%
avg_ecdna_absent_trimmed_esen_df
# Out:
#                                               RAE1    FBXO17    YTHDF1  \
# Bladder-Urinary Tract (ecDNA-absent)     -1.318251 -0.092179  0.163919
# Bone (ecDNA-absent)                      -1.557482  0.056929  0.004858
# Bowel (ecDNA-absent)                     -1.462269  0.035698  0.180581
# Breast (ecDNA-absent)                    -1.407231 -0.006225  0.158584
# CNS-Brain (ecDNA-absent)                 -1.578632 -0.108303  0.130709
# Esophagus-Stomach (ecDNA-absent)         -1.351251  -0.07998   0.17962
# Head and Neck (ecDNA-absent)             -1.396014  -0.05155  0.164043
# Kidney (ecDNA-absent)                    -1.449584  0.002279  0.190011
# Liver (ecDNA-absent)                     -1.369595 -0.045252  0.145867
# Lung (ecDNA-absent)                      -1.357774 -0.049934  0.175372
# Lymphoid (ecDNA-absent)                  -1.500068 -0.019783  0.152872
# Myeloid (ecDNA-absent)                   -1.351761  0.057605  0.091372
# Ovary-Fallopian Tube (ecDNA-absent)      -1.537543 -0.120938  0.208488
# Pancreas (ecDNA-absent)                  -1.497035  0.086797   0.11565
# Peripheral Nervous System (ecDNA-absent) -1.062633 -0.060256  0.082774
# Pleura (ecDNA-absent)                     -1.02452  -0.17386  0.267577
# Prostate (ecDNA-absent)                  -1.045738 -0.092156  0.126747
# Skin (ecDNA-absent)                      -1.603085 -0.109189  0.165184
# Soft Tissue (ecDNA-absent)               -1.205785  -0.03448  0.173199
# Uterus (ecDNA-absent)                     -1.53916 -0.017053  0.234235
#
#                                              DDX27    SEC61G     CHMP7  \
# Bladder-Urinary Tract (ecDNA-absent)     -1.264157 -1.091776 -0.743615
# Bone (ecDNA-absent)                      -0.996598 -1.022146 -0.724917
# Bowel (ecDNA-absent)                     -1.324779 -1.087485 -0.449714
# Breast (ecDNA-absent)                    -0.996117 -1.090367 -0.516553
# CNS-Brain (ecDNA-absent)                 -1.122295 -1.202568 -0.706795
# Esophagus-Stomach (ecDNA-absent)         -1.181236 -1.246651 -0.529545
# Head and Neck (ecDNA-absent)             -1.095561 -1.271134 -0.793555
# Kidney (ecDNA-absent)                    -1.187631 -1.128251 -0.674924
# Liver (ecDNA-absent)                     -1.040854 -1.229601 -0.599781
# Lung (ecDNA-absent)                       -1.11868 -1.239163 -0.719583
# Lymphoid (ecDNA-absent)                  -0.961159 -1.267871 -0.528432
# Myeloid (ecDNA-absent)                    -1.14108 -1.096174 -0.510482
# Ovary-Fallopian Tube (ecDNA-absent)      -1.152916 -1.183666 -0.647926
# Pancreas (ecDNA-absent)                  -1.026177 -1.310619 -0.832336
# Peripheral Nervous System (ecDNA-absent) -1.410107  -1.16191 -0.690042
# Pleura (ecDNA-absent)                     -0.85746 -1.380012 -0.501374
# Prostate (ecDNA-absent)                  -1.187285 -0.968135 -0.817912
# Skin (ecDNA-absent)                      -1.053229 -1.213442 -0.704882
# Soft Tissue (ecDNA-absent)               -1.023235 -1.164713 -0.572542
# Uterus (ecDNA-absent)                    -1.113795 -1.073342 -0.454392
#
#                                               XPO7     INTS9      GJC1  \
# Bladder-Urinary Tract (ecDNA-absent)     -0.141383 -1.593953 -0.166896
# Bone (ecDNA-absent)                       -0.30894 -1.985228 -0.102306
# Bowel (ecDNA-absent)                     -0.083579 -1.605641 -0.085305
# Breast (ecDNA-absent)                     0.078618  -1.67311 -0.199145
# CNS-Brain (ecDNA-absent)                 -0.092658 -1.829382 -0.189446
# Esophagus-Stomach (ecDNA-absent)         -0.001007 -1.542806 -0.138035
# Head and Neck (ecDNA-absent)             -0.074069 -1.823743 -0.148384
# Kidney (ecDNA-absent)                     0.149395  -1.58884 -0.106072
# Liver (ecDNA-absent)                       0.01849 -1.789982 -0.071014
# Lung (ecDNA-absent)                      -0.032114 -1.697709  -0.17521
# Lymphoid (ecDNA-absent)                  -0.081309 -1.644222 -0.116097
# Myeloid (ecDNA-absent)                   -0.005162 -1.579807 -0.184185
# Ovary-Fallopian Tube (ecDNA-absent)      -0.015464 -1.871338 -0.091069
# Pancreas (ecDNA-absent)                  -0.068103 -1.860449 -0.120603
# Peripheral Nervous System (ecDNA-absent) -0.216292 -1.480569 -0.283534
# Pleura (ecDNA-absent)                     0.042666 -1.327053 -0.014279
# Prostate (ecDNA-absent)                   0.036553 -1.664631 -0.075999
# Skin (ecDNA-absent)                      -0.110378 -1.858056 -0.235388
# Soft Tissue (ecDNA-absent)                -0.00328  -1.76954 -0.131674
# Uterus (ecDNA-absent)                    -0.001081 -1.567186 -0.170485
#
#                                             METTL1  ...      CD48    RBMXL1  \
# Bladder-Urinary Tract (ecDNA-absent)     -0.733989  ... -0.079506 -0.638436
# Bone (ecDNA-absent)                      -0.931291  ... -0.149628 -0.664241
# Bowel (ecDNA-absent)                      -0.49278  ... -0.106628 -0.651329
# Breast (ecDNA-absent)                     -0.43008  ... -0.204493 -0.916208
# CNS-Brain (ecDNA-absent)                 -0.344589  ... -0.077176 -0.653858
# Esophagus-Stomach (ecDNA-absent)         -0.529308  ...  -0.11996 -0.751778
# Head and Neck (ecDNA-absent)             -0.450915  ... -0.161944 -0.850603
# Kidney (ecDNA-absent)                     -0.52917  ... -0.052442 -0.804998
# Liver (ecDNA-absent)                     -0.399142  ... -0.046134  -0.85141
# Lung (ecDNA-absent)                      -0.516001  ... -0.079378 -0.833608
# Lymphoid (ecDNA-absent)                  -0.365837  ... -0.137679 -0.674684
# Myeloid (ecDNA-absent)                   -0.591497  ... -0.065679 -0.720983
# Ovary-Fallopian Tube (ecDNA-absent)      -0.365312  ... -0.065276 -0.971882
# Pancreas (ecDNA-absent)                  -0.436435  ...  0.058519 -0.553771
# Peripheral Nervous System (ecDNA-absent) -0.602507  ... -0.041048 -0.730136
# Pleura (ecDNA-absent)                    -0.332441  ...  0.018283 -0.839487
# Prostate (ecDNA-absent)                  -0.363289  ...  0.128996 -0.825773
# Skin (ecDNA-absent)                      -0.345508  ...   -0.0538 -0.756565
# Soft Tissue (ecDNA-absent)               -0.251504  ... -0.052742 -0.933991
# Uterus (ecDNA-absent)                    -0.688944  ... -0.074614 -0.870654
#
#                                              SNRPG      GMIP       DEK  \
# Bladder-Urinary Tract (ecDNA-absent)     -2.064163  0.039938  0.171011
# Bone (ecDNA-absent)                      -2.041113  0.239531  0.121346
# Bowel (ecDNA-absent)                     -2.113883  0.021286  0.132406
# Breast (ecDNA-absent)                    -1.952636  0.060952  0.196948
# CNS-Brain (ecDNA-absent)                 -2.024668  0.039974  0.125105
# Esophagus-Stomach (ecDNA-absent)         -2.602409  0.008714  0.065212
# Head and Neck (ecDNA-absent)              -2.08435  0.048849  0.106799
# Kidney (ecDNA-absent)                    -2.244943  0.075661 -0.004356
# Liver (ecDNA-absent)                       -2.1724  0.049701  0.121678
# Lung (ecDNA-absent)                      -1.973679  0.009743  0.088979
# Lymphoid (ecDNA-absent)                  -2.049922   -0.0314  0.017466
# Myeloid (ecDNA-absent)                   -2.418073  0.036052  0.077879
# Ovary-Fallopian Tube (ecDNA-absent)      -2.159969  0.098901  0.140732
# Pancreas (ecDNA-absent)                  -2.083826 -0.044239  0.070823
# Peripheral Nervous System (ecDNA-absent)  -1.42102 -0.003035 -0.012298
# Pleura (ecDNA-absent)                    -2.156147  0.071886  0.182479
# Prostate (ecDNA-absent)                        NaN  0.028716  0.105069
# Skin (ecDNA-absent)                      -1.818701  0.033346  0.026026
# Soft Tissue (ecDNA-absent)               -1.983235 -0.067068  0.200296
# Uterus (ecDNA-absent)                    -2.356381 -0.002842  0.097958
#
#                                              MITD1    SLAMF7       LY9  \
# Bladder-Urinary Tract (ecDNA-absent)     -0.109133   0.01279 -0.108389
# Bone (ecDNA-absent)                      -0.243796 -0.012276 -0.098541
# Bowel (ecDNA-absent)                     -0.053375 -0.047149 -0.119453
# Breast (ecDNA-absent)                    -0.020565 -0.071833 -0.070579
# CNS-Brain (ecDNA-absent)                 -0.115402   0.02735 -0.121437
# Esophagus-Stomach (ecDNA-absent)         -0.155344  0.024259  -0.19415
# Head and Neck (ecDNA-absent)             -0.121098 -0.064538 -0.062084
# Kidney (ecDNA-absent)                    -0.048682 -0.014774 -0.155868
# Liver (ecDNA-absent)                     -0.038531 -0.057398  -0.19425
# Lung (ecDNA-absent)                      -0.122815 -0.046748 -0.152588
# Lymphoid (ecDNA-absent)                  -0.008275 -0.110322 -0.238531
# Myeloid (ecDNA-absent)                   -0.003716  0.038204 -0.328363
# Ovary-Fallopian Tube (ecDNA-absent)       0.022249 -0.031813 -0.131299
# Pancreas (ecDNA-absent)                  -0.121518 -0.001528 -0.145809
# Peripheral Nervous System (ecDNA-absent) -0.037486  0.002679 -0.184585
# Pleura (ecDNA-absent)                    -0.249511  0.091512  0.008733
# Prostate (ecDNA-absent)                  -0.103782  0.017492 -0.057187
# Skin (ecDNA-absent)                      -0.079897 -0.025617 -0.092669
# Soft Tissue (ecDNA-absent)               -0.117328 -0.007811 -0.202657
# Uterus (ecDNA-absent)                    -0.198918    0.0007  0.025305
#
#                                          C10orf125    SNRPA1
# Bladder-Urinary Tract (ecDNA-absent)           NaN -2.696028
# Bone (ecDNA-absent)                            NaN -2.448317
# Bowel (ecDNA-absent)                           NaN  -2.94771
# Breast (ecDNA-absent)                          NaN -2.882308
# CNS-Brain (ecDNA-absent)                       NaN  -3.05219
# Esophagus-Stomach (ecDNA-absent)               NaN -2.878544
# Head and Neck (ecDNA-absent)                   NaN -2.992139
# Kidney (ecDNA-absent)                          NaN -2.852115
# Liver (ecDNA-absent)                           NaN -3.025515
# Lung (ecDNA-absent)                            NaN -2.718834
# Lymphoid (ecDNA-absent)                        NaN  -3.00699
# Myeloid (ecDNA-absent)                         NaN -2.851356
# Ovary-Fallopian Tube (ecDNA-absent)            NaN -2.938991
# Pancreas (ecDNA-absent)                        NaN -3.036104
# Peripheral Nervous System (ecDNA-absent)       NaN -2.696078
# Pleura (ecDNA-absent)                          NaN -3.181754
# Prostate (ecDNA-absent)                        NaN -2.419425
# Skin (ecDNA-absent)                            NaN -2.630941
# Soft Tissue (ecDNA-absent)                     NaN -3.426401
# Uterus (ecDNA-absent)                          NaN -3.088985
#
# [20 rows x 643 columns]

# %% [markdown]
# ### Literature Gene List (All Cell-Lines):

# %% [markdown]
# #### Common-Essential Genes Plot:

# %%
CE_grouped_df = grouped_cell_line_plot(common_esen_genes_dict, avg_trimmed_esen_df, avg_trimmed_esen_df.index, "CE_grouped_all_cell_lines")
# Out:
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:453: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:453: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:453: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:453: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:453: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:453: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:453: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:453: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:453: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:453: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:453: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:453: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:453: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:453: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:453: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:453: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:453: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:453: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:453: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:453: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:453: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)

# %%
CE_grouped_df[CE_grouped_df['p-value'] < 0.05]
# Out:
# Empty DataFrame
# Columns: [Cell-Line, H-stat, p-value]
# Index: []

# %% [markdown]
# #### Selectively-Essential Genes Plot:

# %%
SE_grouped_df = grouped_cell_line_plot(selec_esen_genes_dict, avg_trimmed_esen_df, avg_trimmed_esen_df.index, "SE_grouped_all_cell_lines")
# Out:
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:453: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:453: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:453: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:453: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:453: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:453: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:453: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:453: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:453: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:453: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:453: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:453: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:453: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:453: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:453: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:453: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:453: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:453: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:453: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:453: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:453: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)

# %%
SE_grouped_df[SE_grouped_df['p-value'] < 0.05]
# Out:
#                     Cell-Line     H-stat       p-value
# 20                     Uterus  52.762279  3.489929e-12
# 4                   CNS-Brain  50.691666  9.827535e-12
# 6               Head and Neck  48.247153  3.336290e-11
# 5           Esophagus-Stomach  46.392351  8.433909e-11
# 7                      Kidney  43.819938  3.052259e-10
# 17                       Skin  41.086800  1.197057e-09
# 0       Bladder-Urinary Tract  41.008740  1.244702e-09
# 8                       Liver  40.804011  1.378864e-09
# 9                        Lung  38.946509  3.490382e-09
# 12       Ovary-Fallopian Tube  38.857785  3.648708e-09
# 3                      Breast  38.147035  5.205671e-09
# 1                        Bone  37.863845  5.997502e-09
# 18                Soft Tissue  34.025712  4.087055e-08
# 15                     Pleura  32.208529  1.013927e-07
# 13                   Pancreas  30.889551  1.960737e-07
# 10                   Lymphoid  30.242711  2.709434e-07
# 16                   Prostate  29.369963  4.191733e-07
# 11                    Myeloid  29.178723  4.612335e-07
# 2                       Bowel  29.094494  4.810730e-07
# 19                    Thyroid  27.980061  8.398603e-07
# 14  Peripheral Nervous System  26.930092  1.419727e-06

# %% [markdown]
# #### Non-Essential Genes Plot:

# %%
NE_grouped_df = grouped_cell_line_plot(non_esen_genes_dict, avg_trimmed_esen_df, avg_trimmed_esen_df.index, "NE_grouped_all_cell_lines")
# Out:
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:453: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:453: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:453: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:453: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:453: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:453: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:453: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:453: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:453: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:453: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:453: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:453: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:453: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:453: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:453: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:453: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:453: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:453: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:453: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:453: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:453: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)

# %%
NE_grouped_df[NE_grouped_df['p-value'] < 0.05]
# Out:
# Empty DataFrame
# Columns: [Cell-Line, H-stat, p-value]
# Index: []

# %% [markdown]
# ### Literature Gene List (ecDNA-present Cell Lines):

# %% [markdown]
# #### Common-Essential Genes Plot:

# %%
CE_ecdna_present_grouped_df = grouped_cell_line_plot(common_esen_genes_dict, avg_ecdna_present_trimmed_esen_df, avg_ecdna_present_trimmed_esen_df.index, "CE_grouped_ecDNA_present_cell_lines")
# Out:
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:453: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:453: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:453: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:453: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:453: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:453: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:453: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:453: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:453: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:453: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:453: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:453: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:453: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:453: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:453: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:453: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:453: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:453: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:453: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)

# %%
CE_ecdna_present_grouped_df[CE_ecdna_present_grouped_df['p-value'] < 0.05]
# Out:
# Empty DataFrame
# Columns: [Cell-Line, H-stat, p-value]
# Index: []

# %%
CE_ecdna_present_grouped_df
# Out:
#                                     Cell-Line    H-stat   p-value
# 1                       Bowel (ecDNA-present)  2.320034  0.313481
# 2                      Breast (ecDNA-present)  2.067996  0.355582
# 9                    Lymphoid (ecDNA-present)  1.618546  0.445182
# 14                     Pleura (ecDNA-present)  1.473485  0.478671
# 15                   Prostate (ecDNA-present)  1.415146  0.492839
# 10                    Myeloid (ecDNA-present)  1.337048  0.512465
# 17                    Thyroid (ecDNA-present)  1.097882  0.577561
# 0       Bladder-Urinary Tract (ecDNA-present)  1.092568  0.579098
# 13  Peripheral Nervous System (ecDNA-present)  0.949907  0.621914
# 18                     Uterus (ecDNA-present)  0.843043  0.656048
# 8                        Lung (ecDNA-present)  0.781818  0.676442
# 12                   Pancreas (ecDNA-present)  0.735436  0.692312
# 3                   CNS-Brain (ecDNA-present)  0.504638  0.776997
# 16                       Skin (ecDNA-present)  0.394063  0.821165
# 5               Head and Neck (ecDNA-present)  0.367006  0.832349
# 6                      Kidney (ecDNA-present)  0.253368  0.881012
# 4           Esophagus-Stomach (ecDNA-present)  0.145455  0.929854
# 7                       Liver (ecDNA-present)  0.118404  0.942517
# 11       Ovary-Fallopian Tube (ecDNA-present)  0.086456  0.957693

# %% [markdown]
# #### Selectively-Essential Genes Plot:

# %%
SE_ecdna_present_grouped_df = grouped_cell_line_plot(selec_esen_genes_dict, avg_ecdna_present_trimmed_esen_df, avg_ecdna_present_trimmed_esen_df.index, "SE_grouped_ecDNA_present_cell_lines")
# Out:
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:453: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:453: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:453: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:453: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:453: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:453: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:453: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:453: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:453: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:453: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:453: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:453: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:453: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:453: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:453: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:453: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:453: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:453: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:453: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)

# %%
SE_ecdna_present_grouped_df[SE_ecdna_present_grouped_df['p-value'] < 0.05]
# Out:
#                                     Cell-Line     H-stat       p-value
# 16                       Skin (ecDNA-present)  53.385127  2.556036e-12
# 3                   CNS-Brain (ecDNA-present)  51.376667  6.977480e-12
# 6                      Kidney (ecDNA-present)  44.875300  1.800746e-10
# 4           Esophagus-Stomach (ecDNA-present)  44.009680  2.775999e-10
# 7                       Liver (ecDNA-present)  40.876941  1.329490e-09
# 11       Ovary-Fallopian Tube (ecDNA-present)  39.776378  2.304991e-09
# 2                      Breast (ecDNA-present)  38.991091  3.413439e-09
# 18                     Uterus (ecDNA-present)  38.761213  3.829213e-09
# 8                        Lung (ecDNA-present)  37.836541  6.079944e-09
# 5               Head and Neck (ecDNA-present)  32.711469  7.884875e-08
# 0       Bladder-Urinary Tract (ecDNA-present)  31.938968  1.160223e-07
# 10                    Myeloid (ecDNA-present)  30.778383  2.072808e-07
# 17                    Thyroid (ecDNA-present)  27.980061  8.398603e-07
# 1                       Bowel (ecDNA-present)  27.886451  8.801043e-07
# 12                   Pancreas (ecDNA-present)  25.352022  3.125204e-06
# 14                     Pleura (ecDNA-present)  23.454591  8.070496e-06
# 9                    Lymphoid (ecDNA-present)  23.391808  8.327860e-06
# 15                   Prostate (ecDNA-present)  21.889912  1.764680e-05
# 13  Peripheral Nervous System (ecDNA-present)  19.507575  5.807429e-05

# %%
SE_ecdna_present_grouped_df
# Out:
#                                     Cell-Line     H-stat       p-value
# 16                       Skin (ecDNA-present)  53.385127  2.556036e-12
# 3                   CNS-Brain (ecDNA-present)  51.376667  6.977480e-12
# 6                      Kidney (ecDNA-present)  44.875300  1.800746e-10
# 4           Esophagus-Stomach (ecDNA-present)  44.009680  2.775999e-10
# 7                       Liver (ecDNA-present)  40.876941  1.329490e-09
# 11       Ovary-Fallopian Tube (ecDNA-present)  39.776378  2.304991e-09
# 2                      Breast (ecDNA-present)  38.991091  3.413439e-09
# 18                     Uterus (ecDNA-present)  38.761213  3.829213e-09
# 8                        Lung (ecDNA-present)  37.836541  6.079944e-09
# 5               Head and Neck (ecDNA-present)  32.711469  7.884875e-08
# 0       Bladder-Urinary Tract (ecDNA-present)  31.938968  1.160223e-07
# 10                    Myeloid (ecDNA-present)  30.778383  2.072808e-07
# 17                    Thyroid (ecDNA-present)  27.980061  8.398603e-07
# 1                       Bowel (ecDNA-present)  27.886451  8.801043e-07
# 12                   Pancreas (ecDNA-present)  25.352022  3.125204e-06
# 14                     Pleura (ecDNA-present)  23.454591  8.070496e-06
# 9                    Lymphoid (ecDNA-present)  23.391808  8.327860e-06
# 15                   Prostate (ecDNA-present)  21.889912  1.764680e-05
# 13  Peripheral Nervous System (ecDNA-present)  19.507575  5.807429e-05

# %% [markdown]
# #### Non-Essential Genes Plot:

# %%
NE_ecdna_present_grouped_df = grouped_cell_line_plot(non_esen_genes_dict, avg_ecdna_present_trimmed_esen_df, avg_ecdna_present_trimmed_esen_df.index, "NE_grouped_ecDNA_present_cell_lines")
# Out:
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:453: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:453: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:453: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:453: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:453: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:453: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:453: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:453: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:453: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:453: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:453: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:453: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:453: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:453: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:453: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:453: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:453: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:453: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:453: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)

# %%
NE_grouped_df[NE_grouped_df['p-value'] < 0.05]
# Out:
# Empty DataFrame
# Columns: [Cell-Line, H-stat, p-value]
# Index: []

# %%
NE_grouped_df
# Out:
#                     Cell-Line    H-stat   p-value
# 13                   Pancreas  5.738033  0.056755
# 18                Soft Tissue  4.939584  0.084602
# 2                       Bowel  4.017731  0.134141
# 3                      Breast  3.118024  0.210344
# 9                        Lung  2.013987  0.365316
# 16                   Prostate  1.832198  0.400077
# 17                       Skin  1.800219  0.406525
# 6               Head and Neck  1.095159  0.578348
# 12       Ovary-Fallopian Tube  1.062437  0.587888
# 11                    Myeloid  0.904818  0.636094
# 19                    Thyroid  0.786040  0.675015
# 4                   CNS-Brain  0.753348  0.686140
# 20                     Uterus  0.695844  0.706154
# 10                   Lymphoid  0.651828  0.721867
# 7                      Kidney  0.590020  0.744524
# 15                     Pleura  0.374280  0.829328
# 14  Peripheral Nervous System  0.310186  0.856335
# 5           Esophagus-Stomach  0.108480  0.947205
# 8                       Liver  0.091553  0.955256
# 0       Bladder-Urinary Tract  0.082949  0.959374
# 1                        Bone  0.061535  0.969701

# %% [markdown]
# #### Common-Essential Genes Plot:

# %%
CE_ecdna_absent_grouped_df = grouped_cell_line_plot(common_esen_genes_dict, avg_ecdna_absent_trimmed_esen_df, avg_ecdna_absent_trimmed_esen_df.index, "CE_grouped_ecDNA_absent_cell_lines")
# Out:
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:453: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:453: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:453: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:453: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:453: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:453: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:453: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:453: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:453: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:453: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:453: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:453: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:453: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:453: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:453: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:453: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:453: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:453: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:453: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:453: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)

# %%
CE_ecdna_absent_grouped_df[CE_ecdna_absent_grouped_df['p-value'] < 0.05]
# Out:
# Empty DataFrame
# Columns: [Cell-Line, H-stat, p-value]
# Index: []

# %%
CE_ecdna_absent_grouped_df
# Out:
#                                    Cell-Line    H-stat   p-value
# 1                        Bone (ecDNA-absent)  2.373073  0.305277
# 15                     Pleura (ecDNA-absent)  1.621985  0.444417
# 4                   CNS-Brain (ecDNA-absent)  1.357328  0.507294
# 14  Peripheral Nervous System (ecDNA-absent)  1.266048  0.530984
# 10                   Lymphoid (ecDNA-absent)  1.236364  0.538923
# 18                Soft Tissue (ecDNA-absent)  1.053803  0.590431
# 16                   Prostate (ecDNA-absent)  0.947705  0.622599
# 11                    Myeloid (ecDNA-absent)  0.917305  0.632135
# 12       Ovary-Fallopian Tube (ecDNA-absent)  0.664193  0.717418
# 0       Bladder-Urinary Tract (ecDNA-absent)  0.588407  0.745125
# 2                       Bowel (ecDNA-absent)  0.433395  0.805173
# 7                      Kidney (ecDNA-absent)  0.310111  0.856368
# 3                      Breast (ecDNA-absent)  0.230798  0.891011
# 8                       Liver (ecDNA-absent)  0.208937  0.900803
# 17                       Skin (ecDNA-absent)  0.187662  0.910436
# 5           Esophagus-Stomach (ecDNA-absent)  0.148701  0.928346
# 19                     Uterus (ecDNA-absent)  0.129592  0.937259
# 6               Head and Neck (ecDNA-absent)  0.100649  0.950921
# 9                        Lung (ecDNA-absent)  0.092022  0.955031
# 13                   Pancreas (ecDNA-absent)  0.014193  0.992929

# %% [markdown]
# #### Selectively-Essential Genes Plot:

# %%
SE_ecdna_absent_grouped_df = grouped_cell_line_plot(selec_esen_genes_dict, avg_ecdna_absent_trimmed_esen_df, avg_ecdna_absent_trimmed_esen_df.index, "SE_grouped_ecDNA_absent_cell_lines")
# Out:
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:453: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:453: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:453: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:453: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:453: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:453: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:453: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:453: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:453: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:453: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:453: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:453: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:453: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:453: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:453: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:453: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:453: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:453: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:453: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:453: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)

# %%
SE_ecdna_absent_grouped_df[SE_ecdna_absent_grouped_df['p-value'] < 0.05]
# Out:
#                                    Cell-Line     H-stat       p-value
# 19                     Uterus (ecDNA-absent)  50.827219  9.183530e-12
# 4                   CNS-Brain (ecDNA-absent)  47.686684  4.415381e-11
# 6               Head and Neck (ecDNA-absent)  45.474787  1.334368e-10
# 0       Bladder-Urinary Tract (ecDNA-absent)  44.917568  1.763088e-10
# 5           Esophagus-Stomach (ecDNA-absent)  43.862295  2.988297e-10
# 9                        Lung (ecDNA-absent)  39.869477  2.200154e-09
# 1                        Bone (ecDNA-absent)  37.863845  5.997502e-09
# 7                      Kidney (ecDNA-absent)  37.536917  7.062556e-09
# 8                       Liver (ecDNA-absent)  36.290846  1.316870e-08
# 17                       Skin (ecDNA-absent)  35.897974  1.602707e-08
# 12       Ovary-Fallopian Tube (ecDNA-absent)  35.722256  1.749890e-08
# 18                Soft Tissue (ecDNA-absent)  34.025712  4.087055e-08
# 13                   Pancreas (ecDNA-absent)  30.172735  2.805911e-07
# 10                   Lymphoid (ecDNA-absent)  29.913055  3.194940e-07
# 3                      Breast (ecDNA-absent)  28.965316  5.131702e-07
# 2                       Bowel (ecDNA-absent)  28.052163  8.101217e-07
# 11                    Myeloid (ecDNA-absent)  27.066962  1.325818e-06
# 15                     Pleura (ecDNA-absent)  24.939873  3.840390e-06
# 14  Peripheral Nervous System (ecDNA-absent)  23.856841  6.600135e-06
# 16                   Prostate (ecDNA-absent)  23.432289  8.160997e-06

# %%
SE_ecdna_absent_grouped_df
# Out:
#                                    Cell-Line     H-stat       p-value
# 19                     Uterus (ecDNA-absent)  50.827219  9.183530e-12
# 4                   CNS-Brain (ecDNA-absent)  47.686684  4.415381e-11
# 6               Head and Neck (ecDNA-absent)  45.474787  1.334368e-10
# 0       Bladder-Urinary Tract (ecDNA-absent)  44.917568  1.763088e-10
# 5           Esophagus-Stomach (ecDNA-absent)  43.862295  2.988297e-10
# 9                        Lung (ecDNA-absent)  39.869477  2.200154e-09
# 1                        Bone (ecDNA-absent)  37.863845  5.997502e-09
# 7                      Kidney (ecDNA-absent)  37.536917  7.062556e-09
# 8                       Liver (ecDNA-absent)  36.290846  1.316870e-08
# 17                       Skin (ecDNA-absent)  35.897974  1.602707e-08
# 12       Ovary-Fallopian Tube (ecDNA-absent)  35.722256  1.749890e-08
# 18                Soft Tissue (ecDNA-absent)  34.025712  4.087055e-08
# 13                   Pancreas (ecDNA-absent)  30.172735  2.805911e-07
# 10                   Lymphoid (ecDNA-absent)  29.913055  3.194940e-07
# 3                      Breast (ecDNA-absent)  28.965316  5.131702e-07
# 2                       Bowel (ecDNA-absent)  28.052163  8.101217e-07
# 11                    Myeloid (ecDNA-absent)  27.066962  1.325818e-06
# 15                     Pleura (ecDNA-absent)  24.939873  3.840390e-06
# 14  Peripheral Nervous System (ecDNA-absent)  23.856841  6.600135e-06
# 16                   Prostate (ecDNA-absent)  23.432289  8.160997e-06

# %% [markdown]
# #### Non-Essential Genes Plot:

# %%
NE_ecdna_absent_grouped_df = grouped_cell_line_plot(non_esen_genes_dict, avg_ecdna_absent_trimmed_esen_df, avg_ecdna_absent_trimmed_esen_df.index, "NE_grouped_ecDNA_absent_cell_lines")
# Out:
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:453: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:453: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:453: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:453: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:453: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:453: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:453: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:453: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:453: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:453: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:453: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:453: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:453: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:453: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:453: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:453: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:453: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:453: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:453: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)
# c:\Users\OMARH\Desktop\EssenCDNA\src\utils.py:453: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Cell_Type', y='ecDNA_Score', data=df, jitter=True, color='black', edgecolor='gray', alpha=0.1)

# %%
NE_ecdna_absent_grouped_df[NE_ecdna_absent_grouped_df['p-value'] < 0.05]
# Out:
# Empty DataFrame
# Columns: [Cell-Line, H-stat, p-value]
# Index: []

# %%
NE_ecdna_absent_grouped_df
# Out:
#                                    Cell-Line    H-stat   p-value
# 13                   Pancreas (ecDNA-absent)  5.657954  0.059073
# 18                Soft Tissue (ecDNA-absent)  4.939584  0.084602
# 2                       Bowel (ecDNA-absent)  4.205037  0.122148
# 3                      Breast (ecDNA-absent)  3.083176  0.214041
# 9                        Lung (ecDNA-absent)  2.995492  0.223634
# 16                   Prostate (ecDNA-absent)  2.929517  0.231134
# 17                       Skin (ecDNA-absent)  2.640736  0.267037
# 19                     Uterus (ecDNA-absent)  2.337979  0.310681
# 12       Ovary-Fallopian Tube (ecDNA-absent)  1.928190  0.381328
# 0       Bladder-Urinary Tract (ecDNA-absent)  1.458729  0.482215
# 6               Head and Neck (ecDNA-absent)  1.238032  0.538474
# 4                   CNS-Brain (ecDNA-absent)  1.122450  0.570510
# 7                      Kidney (ecDNA-absent)  0.711545  0.700632
# 14  Peripheral Nervous System (ecDNA-absent)  0.457764  0.795422
# 10                   Lymphoid (ecDNA-absent)  0.432342  0.805597
# 11                    Myeloid (ecDNA-absent)  0.386665  0.824208
# 15                     Pleura (ecDNA-absent)  0.170179  0.918430
# 8                       Liver (ecDNA-absent)  0.142839  0.931071
# 5           Esophagus-Stomach (ecDNA-absent)  0.142567  0.931198
# 1                        Bone (ecDNA-absent)  0.061535  0.969701

# %% [markdown]
# # Further Oncogroup Analysis:

# %%
CE_ecdna_present_grouped_names = CE_ecdna_present_grouped_df["Cell-Line"].tolist()
CE_ecdna_present_grouped_names = [name.split("(")[0][:-1] for name in CE_ecdna_present_grouped_names]
CE_ecdna_absent_grouped_names = CE_ecdna_absent_grouped_df["Cell-Line"].tolist()
CE_ecdna_absent_grouped_names = [name.split("(")[0][:-1] for name in CE_ecdna_absent_grouped_names]

SE_ecdna_present_grouped_names = SE_ecdna_present_grouped_df["Cell-Line"].tolist()
SE_ecdna_present_grouped_names = [name.split("(")[0][:-1] for name in SE_ecdna_present_grouped_names]
SE_ecdna_absent_grouped_names = SE_ecdna_absent_grouped_df["Cell-Line"].tolist()
SE_ecdna_absent_grouped_names = [name.split("(")[0][:-1] for name in SE_ecdna_absent_grouped_names]

NE_ecdna_present_grouped_names = NE_ecdna_present_grouped_df["Cell-Line"].tolist()
NE_ecdna_present_grouped_names = [name.split("(")[0][:-1] for name in SE_ecdna_present_grouped_names]
NE_ecdna_absent_grouped_names = NE_ecdna_absent_grouped_df["Cell-Line"].tolist()
NE_ecdna_absent_grouped_names = [name.split("(")[0][:-1] for name in SE_ecdna_absent_grouped_names]

# %% [markdown]
# ## CE genes:

# %%
for group in oncotree_lineage_dict:
    if (group in CE_ecdna_present_grouped_names) and (group in CE_ecdna_absent_grouped_names):
        print(group + ":")
        print(CE_ecdna_present_grouped_df[CE_ecdna_present_grouped_df['Cell-Line'] == (group + " (ecDNA-present)")])
        print(CE_ecdna_absent_grouped_df[CE_ecdna_absent_grouped_df['Cell-Line'] == (group + " (ecDNA-absent)")])
        print("---------------------------------------------------")
# Out:
# Bowel:
#                Cell-Line    H-stat   p-value
# 1  Bowel (ecDNA-present)  2.320034  0.313481
#               Cell-Line    H-stat   p-value
# 2  Bowel (ecDNA-absent)  0.433395  0.805173
# ---------------------------------------------------
# Breast:
#                 Cell-Line    H-stat   p-value
# 2  Breast (ecDNA-present)  2.067996  0.355582
#                Cell-Line    H-stat   p-value
# 3  Breast (ecDNA-absent)  0.230798  0.891011
# ---------------------------------------------------
# Head and Neck:
#                        Cell-Line    H-stat   p-value
# 5  Head and Neck (ecDNA-present)  0.367006  0.832349
#                       Cell-Line    H-stat   p-value
# 6  Head and Neck (ecDNA-absent)  0.100649  0.950921
# ---------------------------------------------------
# Kidney:
#                 Cell-Line    H-stat   p-value
# 6  Kidney (ecDNA-present)  0.253368  0.881012
#                Cell-Line    H-stat   p-value
# 7  Kidney (ecDNA-absent)  0.310111  0.856368
# ---------------------------------------------------
# Liver:
#                Cell-Line    H-stat   p-value
# 7  Liver (ecDNA-present)  0.118404  0.942517
#               Cell-Line    H-stat   p-value
# 8  Liver (ecDNA-absent)  0.208937  0.900803
# ---------------------------------------------------
# Lung:
#               Cell-Line    H-stat   p-value
# 8  Lung (ecDNA-present)  0.781818  0.676442
#              Cell-Line    H-stat   p-value
# 9  Lung (ecDNA-absent)  0.092022  0.955031
# ---------------------------------------------------
# Lymphoid:
#                   Cell-Line    H-stat   p-value
# 9  Lymphoid (ecDNA-present)  1.618546  0.445182
#                   Cell-Line    H-stat   p-value
# 10  Lymphoid (ecDNA-absent)  1.236364  0.538923
# ---------------------------------------------------
# Myeloid:
#                   Cell-Line    H-stat   p-value
# 10  Myeloid (ecDNA-present)  1.337048  0.512465
#                  Cell-Line    H-stat   p-value
# 11  Myeloid (ecDNA-absent)  0.917305  0.632135
# ---------------------------------------------------
# Pancreas:
#                    Cell-Line    H-stat   p-value
# 12  Pancreas (ecDNA-present)  0.735436  0.692312
#                   Cell-Line    H-stat   p-value
# 13  Pancreas (ecDNA-absent)  0.014193  0.992929
# ---------------------------------------------------
# Peripheral Nervous System:
#                                     Cell-Line    H-stat   p-value
# 13  Peripheral Nervous System (ecDNA-present)  0.949907  0.621914
#                                    Cell-Line    H-stat   p-value
# 14  Peripheral Nervous System (ecDNA-absent)  1.266048  0.530984
# ---------------------------------------------------
# Pleura:
#                  Cell-Line    H-stat   p-value
# 14  Pleura (ecDNA-present)  1.473485  0.478671
#                 Cell-Line    H-stat   p-value
# 15  Pleura (ecDNA-absent)  1.621985  0.444417
# ---------------------------------------------------
# Prostate:
#                    Cell-Line    H-stat   p-value
# 15  Prostate (ecDNA-present)  1.415146  0.492839
#                   Cell-Line    H-stat   p-value
# 16  Prostate (ecDNA-absent)  0.947705  0.622599
# ---------------------------------------------------
# Skin:
#                Cell-Line    H-stat   p-value
# 16  Skin (ecDNA-present)  0.394063  0.821165
#               Cell-Line    H-stat   p-value
# 17  Skin (ecDNA-absent)  0.187662  0.910436
# ---------------------------------------------------
# Uterus:
#                  Cell-Line    H-stat   p-value
# 18  Uterus (ecDNA-present)  0.843043  0.656048
#                 Cell-Line    H-stat   p-value
# 19  Uterus (ecDNA-absent)  0.129592  0.937259
# ---------------------------------------------------

# %% [markdown]
# ## SE genes:

# %%
for group in oncotree_lineage_dict:
    if (group in SE_ecdna_present_grouped_names) and (group in SE_ecdna_absent_grouped_names):
        print(group + ":")
        print(SE_ecdna_present_grouped_df[SE_ecdna_present_grouped_df['Cell-Line'] == (group + " (ecDNA-present)")])
        print(SE_ecdna_absent_grouped_df[SE_ecdna_absent_grouped_df['Cell-Line'] == (group + " (ecDNA-absent)")])
        print("---------------------------------------------------")
# Out:
# Bowel:
#                Cell-Line     H-stat       p-value
# 1  Bowel (ecDNA-present)  27.886451  8.801043e-07
#               Cell-Line     H-stat       p-value
# 2  Bowel (ecDNA-absent)  28.052163  8.101217e-07
# ---------------------------------------------------
# Breast:
#                 Cell-Line     H-stat       p-value
# 2  Breast (ecDNA-present)  38.991091  3.413439e-09
#                Cell-Line     H-stat       p-value
# 3  Breast (ecDNA-absent)  28.965316  5.131702e-07
# ---------------------------------------------------
# Head and Neck:
#                        Cell-Line     H-stat       p-value
# 5  Head and Neck (ecDNA-present)  32.711469  7.884875e-08
#                       Cell-Line     H-stat       p-value
# 6  Head and Neck (ecDNA-absent)  45.474787  1.334368e-10
# ---------------------------------------------------
# Kidney:
#                 Cell-Line   H-stat       p-value
# 6  Kidney (ecDNA-present)  44.8753  1.800746e-10
#                Cell-Line     H-stat       p-value
# 7  Kidney (ecDNA-absent)  37.536917  7.062556e-09
# ---------------------------------------------------
# Liver:
#                Cell-Line     H-stat       p-value
# 7  Liver (ecDNA-present)  40.876941  1.329490e-09
#               Cell-Line     H-stat       p-value
# 8  Liver (ecDNA-absent)  36.290846  1.316870e-08
# ---------------------------------------------------
# Lung:
#               Cell-Line     H-stat       p-value
# 8  Lung (ecDNA-present)  37.836541  6.079944e-09
#              Cell-Line     H-stat       p-value
# 9  Lung (ecDNA-absent)  39.869477  2.200154e-09
# ---------------------------------------------------
# Lymphoid:
#                   Cell-Line     H-stat   p-value
# 9  Lymphoid (ecDNA-present)  23.391808  0.000008
#                   Cell-Line     H-stat       p-value
# 10  Lymphoid (ecDNA-absent)  29.913055  3.194940e-07
# ---------------------------------------------------
# Myeloid:
#                   Cell-Line     H-stat       p-value
# 10  Myeloid (ecDNA-present)  30.778383  2.072808e-07
#                  Cell-Line     H-stat   p-value
# 11  Myeloid (ecDNA-absent)  27.066962  0.000001
# ---------------------------------------------------
# Pancreas:
#                    Cell-Line     H-stat   p-value
# 12  Pancreas (ecDNA-present)  25.352022  0.000003
#                   Cell-Line     H-stat       p-value
# 13  Pancreas (ecDNA-absent)  30.172735  2.805911e-07
# ---------------------------------------------------
# Peripheral Nervous System:
#                                     Cell-Line     H-stat   p-value
# 13  Peripheral Nervous System (ecDNA-present)  19.507575  0.000058
#                                    Cell-Line     H-stat   p-value
# 14  Peripheral Nervous System (ecDNA-absent)  23.856841  0.000007
# ---------------------------------------------------
# Pleura:
#                  Cell-Line     H-stat   p-value
# 14  Pleura (ecDNA-present)  23.454591  0.000008
#                 Cell-Line     H-stat   p-value
# 15  Pleura (ecDNA-absent)  24.939873  0.000004
# ---------------------------------------------------
# Prostate:
#                    Cell-Line     H-stat   p-value
# 15  Prostate (ecDNA-present)  21.889912  0.000018
#                   Cell-Line     H-stat   p-value
# 16  Prostate (ecDNA-absent)  23.432289  0.000008
# ---------------------------------------------------
# Skin:
#                Cell-Line     H-stat       p-value
# 16  Skin (ecDNA-present)  53.385127  2.556036e-12
#               Cell-Line     H-stat       p-value
# 17  Skin (ecDNA-absent)  35.897974  1.602707e-08
# ---------------------------------------------------
# Uterus:
#                  Cell-Line     H-stat       p-value
# 18  Uterus (ecDNA-present)  38.761213  3.829213e-09
#                 Cell-Line     H-stat       p-value
# 19  Uterus (ecDNA-absent)  50.827219  9.183530e-12
# ---------------------------------------------------

# %% [markdown]
# ## NE genes:

# %%
for group in oncotree_lineage_dict:
    if (group in NE_ecdna_present_grouped_names) and (group in NE_ecdna_absent_grouped_names):
        print(group + ":")
        print(NE_ecdna_present_grouped_df[NE_ecdna_present_grouped_df['Cell-Line'] == (group + " (ecDNA-present)")])
        print(NE_ecdna_absent_grouped_df[NE_ecdna_absent_grouped_df['Cell-Line'] == (group + " (ecDNA-absent)")])
        print("---------------------------------------------------")
