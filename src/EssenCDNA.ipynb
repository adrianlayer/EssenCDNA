# %% [markdown]
# # EssenCDNA Analysis Notebook (DepMap 24Q2)

# %% [markdown]
# Adrian Layer (alayer@ucsd.edu); Anthony Vasquez (pavasquez@ucsd.edu); Yasmin A. Jaber (yjaber@ucsd.edu); Omar Halawa (ohalawa@ucsd.edu)

# %% [markdown]
# ##### The following is an analysis notebook that utilizes the repository code to <u>analyze the correlation between CRISPR gene essentiality (dependency) and the presence (or absence) of ecDNA</u> for DepMap 24Q2.

# %% [markdown]
# ##### By changing "Input Data" filepaths below, you may carry out the same analysis on your data of interest.

# %% [markdown]
# # Imports:

# %%
# Importing functions from utils.py supporting file
from utils import *

import matplotlib
import matplotlib.pyplot as plt
print(f"matplotlib: {matplotlib.__version__}")

import pandas as pd
print(f"pandas: {pd.__version__}")

import seaborn as sns
print(f"seaborn: {sns.__version__}")

import scipy
from scipy import stats
print(f"scipy: {scipy.__version__}")
# Out:
# matplotlib: 3.8.4
# pandas: 2.2.2
# seaborn: 0.13.2
# scipy: 1.13.1

# %% [markdown]
# # Input Data:

# %% [markdown]
# ### Change the following to match your respective data inputs:

# %%
# DepMap standard-format CRISPR essentiality data file
DEPMAP_CRISPR_ESEN = "../data/DepMap 24Q2/CRISPRGeneEffect.csv"

# DepMap metadata file
DEPMAP_METDATA = "../data/DepMap 24Q2/Model.csv"

# Amplicon Architect standard-format aggregated results file
AA_RESULTS = "../data/aggregated_results.csv"

# Dataset obtained from literature corresponding to most differentially-expressed genes for ecDNA up/downregulation
# See cell below for source
LITERATURE_ECDNA_TARGET_GENES = "../data/ecDNA Target genes.csv"

# %% [markdown]
# Lin Miin S., Jo Se-Young, Luebeck Jens, Chang Howard Y., Wu Sihan, Mischel Paul S., Bafna Vineet (2023) <b>Transcriptional immune suppression and upregulation of double stranded DNA damage and repair repertoires in ecDNA-containing tumors</b> <i>eLife</i> 12:RP88895
#
# https://doi.org/10.7554/eLife.88895.2

# %% [markdown]
# # Processing Data:

# %% [markdown]
# ### DepMap CRISPR essentiality data (cell-lines along rows, genes along columns):

# %% [markdown]
# ##### For the reason behind using the CRISPRGeneEffect.csv file as opposed to CRISPRGeneDependency, see [here.](https://forum.depmap.org/t/crisprgeneeffect-vs-crisprgenedependency/2333)

# %%
esen_df = read_esen(DEPMAP_CRISPR_ESEN)
esen_df
# Out:
#                 A1BG      A1CF       A2M     A2ML1   A3GALT2    A4GALT  \
# ACH-000001 -0.134132  0.029103  0.016454 -0.137540 -0.047273  0.181367
# ACH-000004 -0.001436 -0.080068 -0.125263 -0.027607 -0.053838 -0.151272
# ACH-000005 -0.144940  0.026541  0.160605  0.088015 -0.202605 -0.243420
# ACH-000007 -0.053334 -0.120420  0.047978  0.086984 -0.018987 -0.017309
# ACH-000009 -0.027684 -0.144202  0.052846  0.073833  0.038823 -0.108149
# ...              ...       ...       ...       ...       ...       ...
# ACH-002922 -0.057426  0.002047 -0.040007  0.231209 -0.222651 -0.071413
# ACH-002925 -0.158397 -0.036294  0.094842 -0.043724 -0.111456  0.083429
# ACH-002926 -0.104912 -0.098047  0.037632  0.093602 -0.154288 -0.081111
# ACH-002928 -0.210751 -0.083444 -0.135336 -0.056582 -0.237325  0.000792
# ACH-003012 -0.135195 -0.015838  0.108527  0.193879 -0.118829 -0.166840
#
#                A4GNT      AAAS      AACS     AADAC  ...    ZWILCH     ZWINT  \
# ACH-000001 -0.082437 -0.059023  0.194592  0.035473  ... -0.123528  0.085140
# ACH-000004  0.240094 -0.038922  0.186438  0.160221  ... -0.186899 -0.359257
# ACH-000005  0.133726 -0.034895 -0.126105  0.036030  ... -0.309668 -0.344502
# ACH-000007 -0.000041 -0.158419 -0.169559  0.201305  ... -0.323038 -0.387265
# ACH-000009  0.010811 -0.088600  0.032194  0.114270  ... -0.253057 -0.159965
# ...              ...       ...       ...       ...  ...       ...       ...
# ACH-002922  0.047366 -0.466785  0.004091  0.162563  ... -0.181586 -0.647909
# ACH-002925  0.116124 -0.140481 -0.027413  0.092128  ... -0.272191 -0.776332
# ACH-002926 -0.071124 -0.186031 -0.046870  0.147896  ... -0.428666 -0.621266
# ACH-002928  0.096235  0.061767 -0.212580  0.120619  ... -0.147648 -0.349586
# ACH-003012  0.005295 -0.263367 -0.004287  0.170630  ... -0.242553 -0.630630
#
#                 ZXDA      ZXDB      ZXDC    ZYG11A    ZYG11B       ZYX  \
# ACH-000001  0.181954  0.239474  0.172965 -0.230327  0.055657  0.044296
# ACH-000004  0.202271  0.057740  0.089295  0.086703 -0.304930  0.086858
# ACH-000005 -0.056160 -0.092447 -0.015550 -0.170380 -0.080934 -0.059685
# ACH-000007 -0.013816  0.183228  0.038424 -0.051728 -0.383499 -0.012801
# ACH-000009 -0.025342  0.191500 -0.071632 -0.077843 -0.525599  0.093219
# ...              ...       ...       ...       ...       ...       ...
# ACH-002922 -0.016507  0.127280 -0.224160 -0.070399 -0.264229 -0.083760
# ACH-002925 -0.036467  0.109655 -0.215080 -0.004304 -0.247449 -0.222342
# ACH-002926  0.014040  0.300715 -0.149142 -0.020698 -0.245670  0.065053
# ACH-002928  0.203556  0.038069  0.181405  0.048288  0.165457 -0.227231
# ACH-003012 -0.217218  0.142038 -0.027658  0.178237 -0.208381 -0.037664
#
#                ZZEF1      ZZZ3
# ACH-000001  0.107361 -0.410449
# ACH-000004  0.254538 -0.087671
# ACH-000005  0.030254 -0.145055
# ACH-000007 -0.294771 -0.431575
# ACH-000009 -0.029515 -0.255204
# ...              ...       ...
# ACH-002922 -0.071101 -0.310070
# ACH-002925 -0.079772 -0.196377
# ACH-002926 -0.159881 -0.388352
# ACH-002928 -0.139241 -0.205339
# ACH-003012 -0.209711 -0.335483
#
# [1150 rows x 18443 columns]

# %% [markdown]
# ### DepMap Metadata:

# %%
meta_df = read_metadata(DEPMAP_METDATA)
meta_df
# Out:
#             PatientID CellLineName StrippedCellLineName DepmapModelType  \
# ModelID
# ACH-000001  PT-gj46wT  NIH:OVCAR-3            NIHOVCAR3           HGSOC
# ACH-000002  PT-5qa3uk        HL-60                 HL60             AML
# ACH-000003  PT-puKIyc        CACO2                CACO2            COAD
# ACH-000004  PT-q4K2cp          HEL                  HEL             AML
# ACH-000005  PT-q4K2cp   HEL 92.1.7              HEL9217             AML
# ...               ...          ...                  ...             ...
# ACH-003161  PT-or1hkT    ABM-T9430             ABMT9430         ZIMMPSC
# ACH-003181  PT-W75e4m     NRH-LMS1              NRHLMS1             LMS
# ACH-003183  PT-BqidXH     NRH-MFS3              NRHMFS3             MFS
# ACH-003184  PT-21NMVa     NRH-LMS2              NRHLMS2             LMS
# ACH-003191  PT-B8KJKw     NRH-GCT2              NRHGCT2            GCTB
#
#                  OncotreeLineage     OncotreePrimaryDisease  \
# ModelID
# ACH-000001  Ovary/Fallopian Tube   Ovarian Epithelial Tumor
# ACH-000002               Myeloid     Acute Myeloid Leukemia
# ACH-000003                 Bowel  Colorectal Adenocarcinoma
# ACH-000004               Myeloid     Acute Myeloid Leukemia
# ACH-000005               Myeloid     Acute Myeloid Leukemia
# ...                          ...                        ...
# ACH-003161              Pancreas              Non-Cancerous
# ACH-003181           Soft Tissue             Leiomyosarcoma
# ACH-003183           Soft Tissue           Myxofibrosarcoma
# ACH-003184           Soft Tissue             Leiomyosarcoma
# ACH-003191                  Bone   Giant Cell Tumor of Bone
#
#                                   OncotreeSubtype OncotreeCode  \
# ModelID
# ACH-000001       High-Grade Serous Ovarian Cancer        HGSOC
# ACH-000002                 Acute Myeloid Leukemia          AML
# ACH-000003                   Colon Adenocarcinoma         COAD
# ACH-000004                 Acute Myeloid Leukemia          AML
# ACH-000005                 Acute Myeloid Leukemia          AML
# ...                                           ...          ...
# ACH-003161  Immortalized Pancreatic Stromal Cells          NaN
# ACH-003181                         Leiomyosarcoma          LMS
# ACH-003183                       Myxofibrosarcoma          MFS
# ACH-003184                         Leiomyosarcoma          LMS
# ACH-003191               Giant Cell Tumor of Bone         GCTB
#
#            LegacyMolecularSubtype   LegacySubSubtype  ... EngineeredModel  \
# ModelID                                               ...
# ACH-000001                    NaN  high_grade_serous  ...             NaN
# ACH-000002                    NaN                 M3  ...             NaN
# ACH-000003                    NaN                NaN  ...             NaN
# ACH-000004                    NaN                 M6  ...             NaN
# ACH-000005                    NaN                 M6  ...             NaN
# ...                           ...                ...  ...             ...
# ACH-003161                    NaN                NaN  ...             NaN
# ACH-003181                    NaN                NaN  ...             NaN
# ACH-003183                    NaN                NaN  ...             NaN
# ACH-003184                    NaN                NaN  ...             NaN
# ACH-003191                    NaN                NaN  ...             NaN
#
#            TissueOrigin  ModelDerivationMaterial PublicComments  \
# ModelID
# ACH-000001          NaN                      NaN            NaN
# ACH-000002          NaN                      NaN            NaN
# ACH-000003          NaN                      NaN            NaN
# ACH-000004          NaN                      NaN            NaN
# ACH-000005          NaN                      NaN            NaN
# ...                 ...                      ...            ...
# ACH-003161          NaN                      NaN            NaN
# ACH-003181          NaN                      NaN            NaN
# ACH-003183          NaN                      NaN            NaN
# ACH-003184          NaN                      NaN            NaN
# ACH-003191          NaN                      NaN            NaN
#
#                                               CCLEName HCMIID  \
# ModelID
# ACH-000001                             NIHOVCAR3_OVARY    NaN
# ACH-000002     HL60_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE    NaN
# ACH-000003                       CACO2_LARGE_INTESTINE    NaN
# ACH-000004      HEL_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE    NaN
# ACH-000005  HEL9217_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE    NaN
# ...                                                ...    ...
# ACH-003161                                         NaN    NaN
# ACH-003181                                    NRH-LMS1    NaN
# ACH-003183                                    NRH-MFS3    NaN
# ACH-003184                                    NRH-LMS2    NaN
# ACH-003191                                    NRH-GCT2    NaN
#
#            WTSIMasterCellID SangerModelID  COSMICID DateSharedIndbGaP
# ModelID
# ACH-000001           2201.0     SIDM00105  905933.0               NaN
# ACH-000002             55.0     SIDM00829  905938.0               NaN
# ACH-000003              NaN     SIDM00891       NaN               NaN
# ACH-000004            783.0     SIDM00594  907053.0               NaN
# ACH-000005              NaN     SIDM00593       NaN               NaN
# ...                     ...           ...       ...               ...
# ACH-003161              NaN           NaN       NaN               NaN
# ACH-003181              NaN           NaN       NaN               NaN
# ACH-003183              NaN           NaN       NaN               NaN
# ACH-003184              NaN           NaN       NaN               NaN
# ACH-003191              NaN           NaN       NaN               NaN
#
# [1959 rows x 42 columns]

# %% [markdown]
# ### Amplicon Architect Results:

# %%
aa_df = read_aa(AA_RESULTS, "Classification")
aa_df
# Out:
#                     Unnamed: 0                       Sample name  \
# Classification
# ecDNA                        0                5637_URINARY_TRACT
# ecDNA                        1                5637_URINARY_TRACT
# Complex non-cyclic           2                         59M_OVARY
# ecDNA                        3                         59M_OVARY
# ecDNA                        4                         59M_OVARY
# ...                        ...                               ...
# NaN                       1235                       A2780_OVARY
# NaN                       1236  ISHIKAWAHERAKLIO02ER_ENDOMETRIUM
# NaN                       1237                     HPAC_PANCREAS
# NaN                       1238             SW948_LARGE_INTESTINE
# NaN                       1239                 PANC1005_PANCREAS
#
#                     AA amplicon number  \
# Classification
# ecDNA                              1.0
# ecDNA                              1.0
# Complex non-cyclic                 1.0
# ecDNA                              2.0
# ecDNA                              2.0
# ...                                ...
# NaN                                NaN
# NaN                                NaN
# NaN                                NaN
# NaN                                NaN
# NaN                                NaN
#
#                                                   Feature ID  \
# Classification
# ecDNA                   5637_URINARY_TRACT_amplicon1_ecDNA_1
# ecDNA                   5637_URINARY_TRACT_amplicon1_ecDNA_2
# Complex non-cyclic  59M_OVARY_amplicon1_Complex non-cyclic_1
# ecDNA                            59M_OVARY_amplicon2_ecDNA_2
# ecDNA                            59M_OVARY_amplicon2_ecDNA_1
# ...                                                      ...
# NaN                                           A2780_OVARY_NA
# NaN                      ISHIKAWAHERAKLIO02ER_ENDOMETRIUM_NA
# NaN                                         HPAC_PANCREAS_NA
# NaN                                 SW948_LARGE_INTESTINE_NA
# NaN                                     PANC1005_PANCREAS_NA
#
#                                                              Location  \
# Classification
# ecDNA                                      ['chr6:20350615-22839372']
# ecDNA               ['chr3:9099507-9519221', 'chr3:9521655-1018449...
# Complex non-cyclic  ['chr5:51400000-52863895', 'chr9:104220123-104...
# ecDNA               ['chr8:124484622-125582885', 'chr8:125588889-1...
# ecDNA               ['chr8:52712046-56014576', 'chr8:65533018-6557...
# ...                                                               ...
# NaN                                                                []
# NaN                                                                []
# NaN                                                                []
# NaN                                                                []
# NaN                                                                []
#
#                                                        Oncogenes  \
# Classification
# ecDNA                                           ['E2F3', 'SOX4']
# ecDNA               ['FANCD2', 'PPARG', 'RAF1', 'SRGAP3', 'VHL']
# Complex non-cyclic                                            []
# ecDNA                                                  ['TRIB1']
# ecDNA                                                  ['TCEA1']
# ...                                                          ...
# NaN                                                           []
# NaN                                                           []
# NaN                                                           []
# NaN                                                           []
# NaN                                                           []
#
#                     Complexity score  Captured interval length  \
# Classification
# ecDNA                       1.223167                 2488757.0
# ecDNA                       0.709581                 4901014.0
# Complex non-cyclic          0.935892                 3998398.0
# ecDNA                       0.366705                 1463324.0
# ecDNA                       1.074874                 3343884.0
# ...                              ...                       ...
# NaN                              NaN                       NaN
# NaN                              NaN                       NaN
# NaN                              NaN                       NaN
# NaN                              NaN                       NaN
# NaN                              NaN                       NaN
#
#                     Feature median copy number  Feature maximum copy number  \
# Classification
# ecDNA                                29.757287                    67.419329
# ecDNA                                13.175019                    17.283490
# Complex non-cyclic                    5.026093                     5.787943
# ecDNA                                10.047201                    10.047201
# ecDNA                                15.129375                    24.854069
# ...                                        ...                          ...
# NaN                                        NaN                          NaN
# NaN                                        NaN                          NaN
# NaN                                        NaN                          NaN
# NaN                                        NaN                          NaN
# NaN                                        NaN                          NaN
#
#                     ... Tissue of origin Sample type  \
# Classification      ...
# ecDNA               ...    urinary tract   cell line
# ecDNA               ...    urinary tract   cell line
# Complex non-cyclic  ...            ovary   cell line
# ecDNA               ...            ovary   cell line
# ecDNA               ...            ovary   cell line
# ...                 ...              ...         ...
# NaN                 ...            ovary   cell line
# NaN                 ...      endometrium   cell line
# NaN                 ...         pancreas   cell line
# NaN                 ...  large intestine   cell line
# NaN                 ...         pancreas   cell line
#
#                                                      Feature BED file  \
# Classification
# ecDNA               /Users/jluebeck/Desktop/research/CCLE/hg38/ccl...
# ecDNA               /Users/jluebeck/Desktop/research/CCLE/hg38/ccl...
# Complex non-cyclic  /Users/jluebeck/Desktop/research/CCLE/hg38/ccl...
# ecDNA               /Users/jluebeck/Desktop/research/CCLE/hg38/ccl...
# ecDNA               /Users/jluebeck/Desktop/research/CCLE/hg38/ccl...
# ...                                                               ...
# NaN                 /Users/jluebeck/Desktop/research/CCLE/hg38/ccl...
# NaN                 /Users/jluebeck/Desktop/research/CCLE/hg38/ccl...
# NaN                 /Users/jluebeck/Desktop/research/CCLE/hg38/ccl...
# NaN                 /Users/jluebeck/Desktop/research/CCLE/hg38/ccl...
# NaN                 /Users/jluebeck/Desktop/research/CCLE/hg38/ccl...
#
#                                                          CNV BED file  \
# Classification
# ecDNA               /Users/jluebeck/Desktop/research/CCLE/hg38/ccl...
# ecDNA               /Users/jluebeck/Desktop/research/CCLE/hg38/ccl...
# Complex non-cyclic  /Users/jluebeck/Desktop/research/CCLE/hg38/ccl...
# ecDNA               /Users/jluebeck/Desktop/research/CCLE/hg38/ccl...
# ecDNA               /Users/jluebeck/Desktop/research/CCLE/hg38/ccl...
# ...                                                               ...
# NaN                 /Users/jluebeck/Desktop/research/CCLE/hg38/ccl...
# NaN                 /Users/jluebeck/Desktop/research/CCLE/hg38/ccl...
# NaN                 /Users/jluebeck/Desktop/research/CCLE/hg38/ccl...
# NaN                 /Users/jluebeck/Desktop/research/CCLE/hg38/ccl...
# NaN                 /Users/jluebeck/Desktop/research/CCLE/hg38/ccl...
#
#                                                           AA PNG file  \
# Classification
# ecDNA               /Users/jluebeck/Desktop/research/CCLE/hg38/CCL...
# ecDNA               /Users/jluebeck/Desktop/research/CCLE/hg38/CCL...
# Complex non-cyclic  /Users/jluebeck/Desktop/research/CCLE/hg38/CCL...
# ecDNA               /Users/jluebeck/Desktop/research/CCLE/hg38/CCL...
# ecDNA               /Users/jluebeck/Desktop/research/CCLE/hg38/CCL...
# ...                                                               ...
# NaN                                                               NaN
# NaN                                                               NaN
# NaN                                                               NaN
# NaN                                                               NaN
# NaN                                                               NaN
#
#                                                           AA PDF file  \
# Classification
# ecDNA               /Users/jluebeck/Desktop/research/CCLE/hg38/CCL...
# ecDNA               /Users/jluebeck/Desktop/research/CCLE/hg38/CCL...
# Complex non-cyclic  /Users/jluebeck/Desktop/research/CCLE/hg38/CCL...
# ecDNA               /Users/jluebeck/Desktop/research/CCLE/hg38/CCL...
# ecDNA               /Users/jluebeck/Desktop/research/CCLE/hg38/CCL...
# ...                                                               ...
# NaN                                                               NaN
# NaN                                                               NaN
# NaN                                                               NaN
# NaN                                                               NaN
# NaN                                                               NaN
#
#                                                       AA summary file  \
# Classification
# ecDNA               /Users/jluebeck/Desktop/research/CCLE/hg38/CCL...
# ecDNA               /Users/jluebeck/Desktop/research/CCLE/hg38/CCL...
# Complex non-cyclic  /Users/jluebeck/Desktop/research/CCLE/hg38/CCL...
# ecDNA               /Users/jluebeck/Desktop/research/CCLE/hg38/CCL...
# ecDNA               /Users/jluebeck/Desktop/research/CCLE/hg38/CCL...
# ...                                                               ...
# NaN                 /Users/jluebeck/Desktop/research/CCLE/hg38/CCL...
# NaN                 /Users/jluebeck/Desktop/research/CCLE/hg38/CCL...
# NaN                 /Users/jluebeck/Desktop/research/CCLE/hg38/CCL...
# NaN                 /Users/jluebeck/Desktop/research/CCLE/hg38/CCL...
# NaN                 /Users/jluebeck/Desktop/research/CCLE/hg38/CCL...
#
#                                                     Run metadata JSON  \
# Classification
# ecDNA               /Users/jluebeck/Desktop/research/CCLE/hg38/ccl...
# ecDNA               /Users/jluebeck/Desktop/research/CCLE/hg38/ccl...
# Complex non-cyclic  /Users/jluebeck/Desktop/research/CCLE/hg38/ccl...
# ecDNA               /Users/jluebeck/Desktop/research/CCLE/hg38/ccl...
# ecDNA               /Users/jluebeck/Desktop/research/CCLE/hg38/ccl...
# ...                                                               ...
# NaN                 /Users/jluebeck/Desktop/research/CCLE/hg38/ccl...
# NaN                 /Users/jluebeck/Desktop/research/CCLE/hg38/ccl...
# NaN                 /Users/jluebeck/Desktop/research/CCLE/hg38/ccl...
# NaN                 /Users/jluebeck/Desktop/research/CCLE/hg38/ccl...
# NaN                 /Users/jluebeck/Desktop/research/CCLE/hg38/ccl...
#
#                                                  Sample metadata JSON  \
# Classification
# ecDNA               /Users/jluebeck/Desktop/research/CCLE/hg38/ccl...
# ecDNA               /Users/jluebeck/Desktop/research/CCLE/hg38/ccl...
# Complex non-cyclic  /Users/jluebeck/Desktop/research/CCLE/hg38/ccl...
# ecDNA               /Users/jluebeck/Desktop/research/CCLE/hg38/ccl...
# ecDNA               /Users/jluebeck/Desktop/research/CCLE/hg38/ccl...
# ...                                                               ...
# NaN                 /Users/jluebeck/Desktop/research/CCLE/hg38/ccl...
# NaN                 /Users/jluebeck/Desktop/research/CCLE/hg38/ccl...
# NaN                 /Users/jluebeck/Desktop/research/CCLE/hg38/ccl...
# NaN                 /Users/jluebeck/Desktop/research/CCLE/hg38/ccl...
# NaN                 /Users/jluebeck/Desktop/research/CCLE/hg38/ccl...
#
#                                                             All genes
# Classification
# ecDNA               ['CASC15', 'CDKAL1', 'E2F3', 'HDGFL1', 'NBAT1'...
# ecDNA               ['ARPC4', 'ARPC4-TTLL3', 'ATG7', 'ATP2B2', 'AT...
# Complex non-cyclic  ['ABCA1', 'DNAJC25', 'DNAJC25-GNG10', 'ECPAS',...
# ecDNA               ['MTSS1', 'NDUFB9', 'NSMCE2', 'SQLE', 'TATDN1'...
# ecDNA               ['ATP6V1H', 'LYN', 'LYPLA1', 'MRPL15', 'NPBWR1...
# ...                                                               ...
# NaN                                                                []
# NaN                                                                []
# NaN                                                                []
# NaN                                                                []
# NaN                                                                []
#
# [1240 rows x 22 columns]

# %% [markdown]
# # Generating Gene Lists:

# %% [markdown]
# ##### Using our two datasets (<u>one from literature</u>, and the other being <u>from Amplicon Architect data</u>), we can generate two independent gene lists to utilize for our analyses.

# %% [markdown]
# ### Literature Gene List:

# %%
# The following function is niche and intended specifically for just this particular dataset, and as such, might not be very useful.
# Passing in the filename, column of gene names, and column of ecDNA regulation direction:
literature_gene_dict = read_literature_gene_list(LITERATURE_ECDNA_TARGET_GENES, "#Gene|GeneId", "direction(for_geneset_enrichment)")
literature_gene_list = list(literature_gene_dict.keys())
literature_gene_dict
# Out:
# {'RAE1': 'UP',
#  'FBXO17': 'UP',
#  'YTHDF1': 'UP',
#  'DDX27': 'UP',
#  'SEC61G': 'UP',
#  'CHMP7': 'DOWN',
#  'XPO7': 'DOWN',
#  'INTS9': 'DOWN',
#  'GJC1': 'UP',
#  'METTL1': 'UP',
#  'TACR1': 'DOWN',
#  'FAM72B': 'UP',
#  'NUP107': 'UP',
#  'KIAA1967': 'DOWN',
#  'C6orf145': 'UP',
#  'EGFR': 'UP',
#  'C20orf20': 'UP',
#  'TPX2': 'UP',
#  'KIF2C': 'UP',
#  'HOXA4': 'UP',
#  'CDK4': 'UP',
#  'PCM1': 'DOWN',
#  'AURKA': 'UP',
#  'HOXA2': 'UP',
#  'C8orf41': 'DOWN',
#  'TSFM': 'UP',
#  'FAM72D': 'UP',
#  'HOXA5': 'UP',
#  'PSMA7': 'UP',
#  'MCPH1': 'DOWN',
#  'CCDC25': 'DOWN',
#  'INTS10': 'DOWN',
#  'HOXA7': 'UP',
#  'SPAG5': 'UP',
#  'CNOT7': 'DOWN',
#  'BUB1': 'UP',
#  'HOXA3': 'UP',
#  'TRIM35': 'DOWN',
#  'PPP2R2A': 'DOWN',
#  'WRN': nan,
#  'HOXA6': 'UP',
#  'VPS37A': 'DOWN',
#  'TRIP13': 'UP',
#  'ZNF395': 'DOWN',
#  'FUT10': 'DOWN',
#  'KIF4A': 'UP',
#  'FDFT1': 'DOWN',
#  'NCAPH': 'UP',
#  'GSG2': 'UP',
#  'CDCA5': 'UP',
#  'MAK16': nan,
#  'ERI1': nan,
#  'RAD54L': 'UP',
#  'FBXO25': 'DOWN',
#  'PINX1': nan,
#  'RAD51': 'UP',
#  'MCM10': 'UP',
#  'PLK1': 'UP',
#  'CDCA8': 'UP',
#  'ORC1L': 'UP',
#  'CSTF1': 'UP',
#  'CDC20': 'UP',
#  'POLR3D': nan,
#  'FOXM1': 'UP',
#  'MRPS17': 'UP',
#  'UBXN8': nan,
#  'ERICH1': nan,
#  'KPNA2': 'UP',
#  'CHCHD2': 'UP',
#  'CDC6': 'UP',
#  'CCT6A': 'UP',
#  'CDC45': 'UP',
#  'PARP8': 'DOWN',
#  'FAM64A': 'UP',
#  'DOCK5': 'DOWN',
#  'ADAM28': 'DOWN',
#  'DTHD1': 'DOWN',
#  'NCAPG': 'UP',
#  'GPR18': 'DOWN',
#  'TTC9': 'DOWN',
#  'MDM2': 'UP',
#  'KCNRG': 'DOWN',
#  'TSPAN31': 'UP',
#  'KIF15': 'UP',
#  'HOXA11': 'UP',
#  'KIF13B': 'DOWN',
#  'UCKL1': 'UP',
#  'SYK': 'DOWN',
#  'CCT2': 'UP',
#  'CDC42SE2': 'DOWN',
#  'PFDN4': 'UP',
#  'HOXA1': 'UP',
#  'PCDH7': 'DOWN',
#  'ITGB7': 'DOWN',
#  'PSTPIP1': 'DOWN',
#  'AKNA': 'DOWN',
#  'OS9': 'UP',
#  'CYP27B1': 'UP',
#  'MLLT3': 'DOWN',
#  'ORAOV1': 'UP',
#  'TCF19': 'UP',
#  'STX19': 'DOWN',
#  'C10orf95': 'DOWN',
#  'CDCA2': nan,
#  'AVIL': 'UP',
#  'PDRG1': 'UP',
#  'TMEM194A': 'UP',
#  'PRC1': 'UP',
#  'SGOL2': 'UP',
#  'PPFIA1': 'UP',
#  'CCDC108': 'DOWN',
#  'ELP3': 'DOWN',
#  'NLRC3': 'DOWN',
#  'HOXC9': 'UP',
#  'TOP2A': 'UP',
#  'ESR1': 'DOWN',
#  'CXCR6': 'DOWN',
#  'GZMK': 'DOWN',
#  'CXCR3': 'DOWN',
#  'NUF2': 'UP',
#  'CENPL': 'UP',
#  'MARCH9': 'UP',
#  'SHOX2': 'UP',
#  'FAM179A': 'DOWN',
#  'RSPO1': 'DOWN',
#  'MAP6D1': 'UP',
#  'TAF4': 'UP',
#  'KCTD9': 'DOWN',
#  'CD5': 'DOWN',
#  'FASLG': 'DOWN',
#  'TBC1D10C': 'DOWN',
#  'CENPN': 'UP',
#  'IFT52': 'UP',
#  'GTF2E2': 'DOWN',
#  'TNIP1': 'DOWN',
#  'CCR4': 'DOWN',
#  'NUDT18': 'DOWN',
#  'YEATS4': 'UP',
#  'TTC7B': 'UP',
#  'C10orf26': 'DOWN',
#  'C9orf25': 'UP',
#  'ENTPD4': 'DOWN',
#  'GSR': 'DOWN',
#  'USP54': 'DOWN',
#  'C5orf34': 'UP',
#  'FAM160B2': 'DOWN',
#  'NLRX1': 'DOWN',
#  'CBX7': 'DOWN',
#  'MAD2L1': 'UP',
#  'MRPL36': 'UP',
#  'ZNF385B': 'DOWN',
#  'CD3E': 'DOWN',
#  'FAF1': 'UP',
#  'TRIM8': 'DOWN',
#  'DDIT3': 'UP',
#  'UBE2C': 'UP',
#  'HOXC8': 'UP',
#  'CLIC5': 'DOWN',
#  'MLH1': nan,
#  'EEF1B2': 'DOWN',
#  'CKAP2L': 'UP',
#  'C5orf33': 'UP',
#  'C20orf111': 'UP',
#  'FAM119B': 'UP',
#  'KDELR2': 'UP',
#  'ERAL1': 'UP',
#  'CTNNBL1': 'UP',
#  'C6orf97': 'DOWN',
#  'LTB': 'DOWN',
#  'NAT1': 'UP',
#  'SLC35E3': 'UP',
#  'MUC16': 'DOWN',
#  'MAD2L2': 'UP',
#  'IPCEF1': 'DOWN',
#  'SHCBP1': 'UP',
#  'PRKCQ': 'DOWN',
#  'MIPOL1': nan,
#  'C17orf37': 'UP',
#  'HOXA10': 'UP',
#  'MPV17L': 'UP',
#  'CYP4X1': 'DOWN',
#  'HOXC5': 'UP',
#  'RPL3': 'DOWN',
#  'SNTN': 'DOWN',
#  'ACAP1': 'DOWN',
#  'MED10': 'UP',
#  'ZNF883': 'UP',
#  'FTSJ2': 'UP',
#  'CKS1B': 'UP',
#  'PNPT1': 'UP',
#  'EPB49': 'DOWN',
#  'HOXC4': 'UP',
#  'MBD2': nan,
#  'CASP1': 'DOWN',
#  'AGPAT3': 'DOWN',
#  'HOXA9': nan,
#  'NDC80': 'UP',
#  'UBASH3A': 'DOWN',
#  'DEPDC1': 'UP',
#  'CD2': 'DOWN',
#  'CD3G': 'DOWN',
#  'DPM1': 'UP',
#  'BIN3': 'DOWN',
#  'RNF114': 'UP',
#  'SKA3': 'UP',
#  'IGDCC4': 'UP',
#  'MRPS27': 'DOWN',
#  'ANKLE1': 'UP',
#  'ST6GALNAC1': 'DOWN',
#  'PCMT1': 'UP',
#  'INTS5': 'DOWN',
#  'CTDSP2': 'UP',
#  'FADD': 'UP',
#  'GPR174': 'DOWN',
#  'CCNB2': 'UP',
#  'RTEL1': 'UP',
#  'CTTN': 'UP',
#  'KIF23': 'UP',
#  'JHDM1D': 'DOWN',
#  'NOP56': 'UP',
#  'NPEPL1': 'UP',
#  'TMED6': 'DOWN',
#  'WDR67': 'UP',
#  'PER2': 'DOWN',
#  'HOXC6': 'UP',
#  'BLM': 'UP',
#  'PLEKHG7': 'DOWN',
#  'ERLIN1': 'DOWN',
#  'CDC25A': 'UP',
#  'LDLRAD1': 'DOWN',
#  'YWHAB': 'UP',
#  'MCM6': nan,
#  'TMEM203': 'UP',
#  'WDHD1': 'UP',
#  'PIGR': 'DOWN',
#  'C11orf16': 'DOWN',
#  'STARD3': 'UP',
#  'EIF3L': 'DOWN',
#  'RAI2': 'DOWN',
#  'UQCC': 'UP',
#  'CCDC150': 'UP',
#  'MUC5B': 'DOWN',
#  'TRIB3': 'UP',
#  'KRT10': nan,
#  'PTK2B': 'DOWN',
#  'SAE1': 'UP',
#  'SPRED2': 'UP',
#  'MKNK2': 'DOWN',
#  'ATP9B': 'DOWN',
#  'RILPL1': 'UP',
#  'PLEKHA2': nan,
#  'ATP6V1B2': 'DOWN',
#  'KIAA1797': 'DOWN',
#  'FAM46C': 'DOWN',
#  'C10orf114': 'UP',
#  'MURC': nan,
#  'PTN': 'UP',
#  'FCRL6': 'DOWN',
#  'WDR76': nan,
#  'BSPRY': 'DOWN',
#  'ISPD': 'UP',
#  'GPR171': 'DOWN',
#  'C20orf85': 'DOWN',
#  'KIAA0415': 'UP',
#  'HOXC10': 'UP',
#  'WDR63': 'DOWN',
#  'KLHL9': nan,
#  'CHEK1': nan,
#  'C16orf54': 'DOWN',
#  'EME1': 'UP',
#  'TOM1': 'DOWN',
#  'CNDP2': 'DOWN',
#  'AMPD3': 'DOWN',
#  'MYBL2': 'UP',
#  'TIFAB': 'DOWN',
#  'INPP4A': nan,
#  'CPVL': nan,
#  'HOXC11': 'UP',
#  'TNFAIP6': 'UP',
#  'ORMDL3': 'UP',
#  'C20orf107': 'UP',
#  'CCDC6': nan,
#  'SCEL': 'DOWN',
#  'DUSP12': 'UP',
#  'SCUBE1': 'DOWN',
#  'ABCF1': 'UP',
#  'POLL': 'DOWN',
#  'CDHR4': 'DOWN',
#  'C8orf79': 'DOWN',
#  'CSE1L': 'UP',
#  'TMEM66': 'DOWN',
#  'TAGAP': 'DOWN',
#  'CALU': 'UP',
#  'DAPL1': 'DOWN',
#  'RASGEF1B': 'DOWN',
#  'ZNF516': 'DOWN',
#  'IL5RA': 'DOWN',
#  'TTK': 'UP',
#  'WDR70': 'UP',
#  'ARMC3': 'DOWN',
#  'IK': nan,
#  'SLC40A1': 'DOWN',
#  'CDK1': 'UP',
#  'DACH1': 'DOWN',
#  'BHLHA15': 'DOWN',
#  'BRD9': nan,
#  'SIT1': 'DOWN',
#  'NEK2': 'UP',
#  'MAP7D3': 'UP',
#  'IL2RB': 'DOWN',
#  'CCDC127': nan,
#  'C1orf112': 'UP',
#  'EYA2': nan,
#  'CD3D': 'DOWN',
#  'RAB36': nan,
#  'STAC': 'UP',
#  'DIDO1': nan,
#  'FAHD2B': 'UP',
#  'MON1B': 'DOWN',
#  'ZNF622': nan,
#  'PDCD6': 'UP',
#  'NDUFS6': 'UP',
#  'SPC25': 'UP',
#  'SDHA': nan,
#  'CNTFR': 'UP',
#  'THEMIS': 'DOWN',
#  'SLPI': 'DOWN',
#  'CLNK': 'DOWN',
#  'NUDT1': 'UP',
#  'RPAP3': 'UP',
#  'CCR8': 'DOWN',
#  'EXOC3': nan,
#  'CTBP2': 'DOWN',
#  'FRS2': 'UP',
#  'ASPM': 'UP',
#  'ZNF772': 'UP',
#  'PGR': 'DOWN',
#  'SEPT1': 'DOWN',
#  'GAL': 'UP',
#  'REEP4': nan,
#  'KLRK1': 'DOWN',
#  'CDC25B': 'UP',
#  'PRSS27': 'DOWN',
#  'BCR': 'DOWN',
#  'PTX3': 'UP',
#  'NOXO1': 'DOWN',
#  'S1PR4': 'DOWN',
#  'SORBS2': 'DOWN',
#  'RPS6KA1': 'DOWN',
#  'EYA4': 'UP',
#  'ENPP3': 'DOWN',
#  'ANKRD44': 'DOWN',
#  'STAU1': 'UP',
#  'HEXIM2': nan,
#  'SLC25A21': 'DOWN',
#  'LEPROTL1': 'DOWN',
#  'ARHGAP11A': 'UP',
#  'C2orf54': 'DOWN',
#  'BCL2L15': 'DOWN',
#  'IGF1': 'DOWN',
#  'GNB3': 'UP',
#  'TUBA4B': 'DOWN',
#  'CCDC17': 'DOWN',
#  'TIRAP': 'DOWN',
#  'SRPR': nan,
#  'CXCR5': 'DOWN',
#  'DCDC2B': 'DOWN',
#  'ARSD': 'DOWN',
#  'P2RY10': 'DOWN',
#  'C20orf4': 'UP',
#  'TMEM190': 'DOWN',
#  'C1orf186': 'DOWN',
#  'XPO5': 'UP',
#  'DAK': 'DOWN',
#  'FUT6': 'DOWN',
#  'CXCL17': 'DOWN',
#  'CCDC152': 'UP',
#  'GZMH': 'DOWN',
#  'TTLL10': 'DOWN',
#  'TCTEX1D4': 'DOWN',
#  'BET1': nan,
#  'PAM': 'DOWN',
#  'MYBPC2': 'DOWN',
#  'LPXN': 'DOWN',
#  'APOBEC4': 'DOWN',
#  'LYN': 'DOWN',
#  'EEF2': 'DOWN',
#  'LRFN1': 'UP',
#  'XKRX': 'DOWN',
#  'C1orf52': 'UP',
#  'EPM2AIP1': nan,
#  'SLC6A20': 'DOWN',
#  'IGF2BP3': 'UP',
#  'PTPRCAP': 'DOWN',
#  'TMEM199': 'UP',
#  'MARCKS': 'UP',
#  'KCNMA1': 'DOWN',
#  'SLC18A2': 'DOWN',
#  'EZH1': 'DOWN',
#  'C19orf44': 'UP',
#  'ALDH2': 'DOWN',
#  'PSRC1': 'UP',
#  'GCHFR': 'DOWN',
#  'MFHAS1': 'DOWN',
#  'C7orf42': nan,
#  'SNX20': 'DOWN',
#  'TCF25': 'DOWN',
#  'TMEFF1': 'UP',
#  'GZMM': 'DOWN',
#  'HMGB2': 'UP',
#  'C17orf96': 'UP',
#  'CFTR': 'DOWN',
#  'SYTL3': 'DOWN',
#  'COL4A3BP': 'DOWN',
#  'CHAF1A': 'UP',
#  'SLMO2': 'UP',
#  'C12orf74': 'DOWN',
#  'KDELR3': nan,
#  'TLR3': 'DOWN',
#  'DMBT1': 'DOWN',
#  'DHX35': 'UP',
#  'GRB7': 'UP',
#  'POLDIP2': 'UP',
#  'NKAIN1': 'UP',
#  'ZFP64': 'UP',
#  'SPN': 'DOWN',
#  'CTSB': 'DOWN',
#  'RNF144B': 'DOWN',
#  'C5orf20': 'DOWN',
#  'PSMD3': 'UP',
#  'MS4A8B': 'DOWN',
#  'LARP4B': nan,
#  'CFLAR': 'DOWN',
#  'C8orf58': nan,
#  'SERPINB1': 'DOWN',
#  'SPC24': 'UP',
#  'FAM81B': 'DOWN',
#  'ERBB2': 'UP',
#  'HKDC1': 'DOWN',
#  'C20orf27': 'UP',
#  'IDH3B': 'UP',
#  'CENPO': 'UP',
#  'ZNF311': 'UP',
#  'C2orf74': nan,
#  'ATAD2': 'UP',
#  'NPM2': 'DOWN',
#  'GTPBP4': 'UP',
#  'USP1': 'UP',
#  'C10orf140': 'UP',
#  'MTBP': 'UP',
#  'CNOT2': 'UP',
#  'SUN1': 'UP',
#  'CARD16': 'DOWN',
#  'DHX16': 'UP',
#  'DSCC1': 'UP',
#  'PTCD2': nan,
#  'FLT3': 'DOWN',
#  'C4orf21': 'UP',
#  'FUT3': 'DOWN',
#  'MORN5': 'DOWN',
#  'RACGAP1': 'UP',
#  'PDCD1': 'DOWN',
#  'FKBP9': 'UP',
#  'ZNF831': 'DOWN',
#  'SPRY4': nan,
#  'R3HCC1': 'DOWN',
#  'DUSP6': nan,
#  'EPHB2': 'UP',
#  'ARFGAP1': 'UP',
#  'KIAA0748': 'DOWN',
#  'STX18': 'DOWN',
#  'CYP7B1': 'DOWN',
#  'STAT4': 'DOWN',
#  'SDF2': 'UP',
#  'ETV4': nan,
#  'PPP5C': 'UP',
#  'ZBBX': 'DOWN',
#  'GARS': 'UP',
#  'SYTL1': 'DOWN',
#  'MUC20': nan,
#  'MAP4K1': 'DOWN',
#  'ARMC4': 'DOWN',
#  'MUC4': 'DOWN',
#  'GPR110': nan,
#  'CCR5': 'DOWN',
#  'CD6': 'DOWN',
#  'TUBB': 'UP',
#  'TXNDC3': 'DOWN',
#  'IL12B': 'DOWN',
#  'WDR62': 'UP',
#  'ALCAM': 'DOWN',
#  'FUT2': 'DOWN',
#  'PDZK1IP1': 'DOWN',
#  'FZD7': 'UP',
#  'FANCD2': 'UP',
#  'IGF2BP2': 'UP',
#  'SIKE1': 'UP',
#  'LCN2': 'DOWN',
#  'ADRA2B': 'UP',
#  'TNFRSF10A': 'DOWN',
#  'HPS6': 'DOWN',
#  'SEPP1': 'UP',
#  'FBXO18': nan,
#  'SLFN12L': 'DOWN',
#  'WWP2': 'DOWN',
#  'NUSAP1': 'UP',
#  'HOXD13': 'UP',
#  'ITGAL': 'DOWN',
#  'DLL3': 'UP',
#  'CNR2': 'DOWN',
#  'STMN1': 'UP',
#  'PSMB10': 'DOWN',
#  'FAM32A': 'UP',
#  'STT3A': nan,
#  'FAM24B': 'UP',
#  'PNPLA1': 'UP',
#  'TNFRSF10B': 'DOWN',
#  'ALOXE3': nan,
#  'FRMPD2': 'DOWN',
#  'THEM5': nan,
#  'MSL1': 'UP',
#  'CUZD1': nan,
#  'CD27': 'DOWN',
#  'IKZF2': 'DOWN',
#  'CENPF': 'UP',
#  'DGCR2': nan,
#  'SNRPD1': 'UP',
#  'E2F1': 'UP',
#  'ASMT': nan,
#  'RASAL3': 'DOWN',
#  'PRRG2': nan,
#  'IGF2BP1': nan,
#  'ST14': nan,
#  'HMGA2': 'UP',
#  'KIF14': 'UP',
#  'CD52': 'DOWN',
#  'RP9': 'UP',
#  'AKR1A1': nan,
#  'C9orf169': 'DOWN',
#  'ALOX12B': nan,
#  'SQRDL': 'DOWN',
#  'SLC4A5': nan,
#  'KRT1': nan,
#  'SBSN': 'DOWN',
#  'PLA2G4D': 'DOWN',
#  'C20orf106': 'UP',
#  'DSG1': 'DOWN',
#  'RSPH4A': 'DOWN',
#  'C1orf192': 'DOWN',
#  'C17orf72': 'DOWN',
#  'KCTD11': nan,
#  'LSR': nan,
#  'C2orf39': 'DOWN',
#  'GATAD1': nan,
#  'VWA3A': 'DOWN',
#  'GLTP': 'DOWN',
#  'DPAGT1': nan,
#  'C1orf230': 'DOWN',
#  'SLC39A2': nan,
#  'CRB3': 'DOWN',
#  'CCDC135': 'DOWN',
#  'TMEM106A': 'DOWN',
#  'C1orf210': nan,
#  'C1orf172': nan,
#  'SCNN1A': 'DOWN',
#  'NCCRP1': nan,
#  'CNKSR1': nan,
#  'KIAA1751': 'DOWN',
#  'PRSS22': nan,
#  'RTDR1': nan,
#  'CD163': nan,
#  'MSR1': 'DOWN',
#  'OLAH': nan,
#  'ACTL8': nan,
#  'CNFN': 'DOWN',
#  'MTHFD2': nan,
#  'CHMP4C': nan,
#  'RNF222': 'DOWN',
#  'CIB1': nan,
#  'ESRP2': nan,
#  'TMEM79': nan,
#  'YSK4': 'DOWN',
#  'SPINT2': 'UP',
#  'ELMO3': nan,
#  'RAB25': nan,
#  'TEX19': 'DOWN',
#  'SIGLEC1': nan,
#  'FCGR2A': 'DOWN',
#  'IFT20': 'UP',
#  'AP1M2': nan,
#  'MS4A6A': nan,
#  'FCGR3A': 'DOWN',
#  'TMEM184A': nan,
#  'ELF3': nan,
#  'PRSS8': nan,
#  'FOLR2': 'UP',
#  'CBLC': 'UP',
#  'MS4A7': nan,
#  'C20orf151': 'UP',
#  'OVOL2': nan,
#  'C7orf23': nan,
#  'CCDC64B': nan,
#  'MPP1': nan,
#  'CLDN4': nan,
#  'GRHL2': nan,
#  'CYBA': 'DOWN',
#  'MS4A4A': nan,
#  'CLDN7': nan,
#  'CSDE1': nan,
#  'C1orf194': 'DOWN',
#  'HORMAD1': 'UP',
#  'C10orf99': nan,
#  'C9orf171': 'DOWN',
#  'C6orf118': 'DOWN',
#  'TYW1': 'UP',
#  'VKORC1L1': nan,
#  'KLRB1': 'DOWN',
#  'LIPG': 'UP',
#  'CRCP': nan,
#  'CD40LG': 'DOWN',
#  'NRAS': 'UP',
#  'DR1': nan,
#  'LIME1': 'UP',
#  'HIAT1': nan,
#  'PBX4': 'UP',
#  'CCR2': 'DOWN',
#  'NRM': 'UP',
#  'TPRKB': 'UP',
#  'ZNHIT6': nan,
#  'GNAI3': 'UP',
#  'INSL3': nan,
#  'CTTNBP2NL': nan,
#  'METTL5': nan,
#  'CD48': 'DOWN',
#  'RBMXL1': nan,
#  'SNRPG': 'UP',
#  'GMIP': nan,
#  'DEK': 'UP',
#  'MITD1': nan,
#  'SLAMF7': 'DOWN',
#  'LY9': 'DOWN',
#  'C10orf125': 'UP',
#  'SNRPA1': 'UP'}

# %% [markdown]
# ### Amplicon Architect Gene List:

# %%
aa_gene_dict = ecdna_freq_genes(aa_df, "Sample name", "All genes", "Oncogenes")
aa_oncogene_dict = ecdna_freq_genes(aa_df, "Sample name", "All genes", "Oncogenes", True)
aa_gene_dict
# Out:
# {'CASC11': [26,
#   {'AU565_BREAST',
#    'CORL23_LUNG',
#    'CORL279_LUNG',
#    'CORL311_LUNG',
#    'DMS273_LUNG',
#    'EFM192A_BREAST',
#    'FUOV1_OVARY',
#    'GCIY_STOMACH',
#    'HCC1419_BREAST',
#    'HCC44_LUNG',
#    'HGC27_STOMACH',
#    'KYSE450_OESOPHAGUS',
#    'MSTO211H_PLEURA',
#    'NCIH1792_LUNG',
#    'NCIH2122_LUNG',
#    'NCIH2170_LUNG',
#    'NCIH2171_LUNG',
#    'NCIH23_LUNG',
#    'NCIH446_LUNG',
#    'NCIH460_LUNG',
#    'NCIH510_LUNG',
#    'NCIH524_LUNG',
#    'NCIH82_LUNG',
#    'SCLC21H_LUNG',
#    'SNU16_STOMACH',
#    'SW480_LARGE_INTESTINE'}],
#  'MYC': [26,
#   {'AU565_BREAST',
#    'CORL23_LUNG',
#    'CORL279_LUNG',
#    'CORL311_LUNG',
#    'DMS273_LUNG',
#    'EFM192A_BREAST',
#    'FUOV1_OVARY',
#    'GCIY_STOMACH',
#    'HCC1419_BREAST',
#    'HCC44_LUNG',
#    'HGC27_STOMACH',
#    'KYSE450_OESOPHAGUS',
#    'MSTO211H_PLEURA',
#    'NCIH1792_LUNG',
#    'NCIH2122_LUNG',
#    'NCIH2170_LUNG',
#    'NCIH2171_LUNG',
#    'NCIH23_LUNG',
#    'NCIH446_LUNG',
#    'NCIH460_LUNG',
#    'NCIH510_LUNG',
#    'NCIH524_LUNG',
#    'NCIH82_LUNG',
#    'SCLC21H_LUNG',
#    'SNU16_STOMACH',
#    'SW480_LARGE_INTESTINE'}],
#  'PVT1': [20,
#   {'CORL23_LUNG',
#    'CORL311_LUNG',
#    'EFM192A_BREAST',
#    'FUOV1_OVARY',
#    'HCC1419_BREAST',
#    'HCC44_LUNG',
#    'HGC27_STOMACH',
#    'KYSE450_OESOPHAGUS',
#    'MSTO211H_PLEURA',
#    'NCIH1792_LUNG',
#    'NCIH2170_LUNG',
#    'NCIH2171_LUNG',
#    'NCIH23_LUNG',
#    'NCIH446_LUNG',
#    'NCIH460_LUNG',
#    'NCIH510_LUNG',
#    'NCIH524_LUNG',
#    'NCIH82_LUNG',
#    'SNU16_STOMACH',
#    'SW480_LARGE_INTESTINE'}],
#  'TMEM75': [18,
#   {'AU565_BREAST',
#    'CORL23_LUNG',
#    'CORL311_LUNG',
#    'EFM192A_BREAST',
#    'FUOV1_OVARY',
#    'HCC1419_BREAST',
#    'HCC1954_BREAST',
#    'HCC44_LUNG',
#    'HGC27_STOMACH',
#    'KYSE450_OESOPHAGUS',
#    'MSTO211H_PLEURA',
#    'NCIH1792_LUNG',
#    'NCIH2170_LUNG',
#    'NCIH23_LUNG',
#    'NCIH460_LUNG',
#    'NCIH510_LUNG',
#    'SNU16_STOMACH',
#    'SW480_LARGE_INTESTINE'}],
#  'CASC21': [17,
#   {'AU565_BREAST',
#    'CORL23_LUNG',
#    'EFM192A_BREAST',
#    'GCIY_STOMACH',
#    'HCC1419_BREAST',
#    'HCC44_LUNG',
#    'HCC827_LUNG',
#    'HGC27_STOMACH',
#    'KYSE450_OESOPHAGUS',
#    'NCIH2171_LUNG',
#    'NCIH23_LUNG',
#    'NCIH446_LUNG',
#    'NCIH524_LUNG',
#    'NCIH82_LUNG',
#    'SKOV3_OVARY',
#    'SNU16_STOMACH',
#    'SW480_LARGE_INTESTINE'}],
#  'CASC8': [17,
#   {'AU565_BREAST',
#    'CORL23_LUNG',
#    'EFM192A_BREAST',
#    'GCIY_STOMACH',
#    'HCC1419_BREAST',
#    'HCC44_LUNG',
#    'HCC827_LUNG',
#    'HGC27_STOMACH',
#    'KYSE450_OESOPHAGUS',
#    'NCIH2170_LUNG',
#    'NCIH2171_LUNG',
#    'NCIH23_LUNG',
#    'NCIH446_LUNG',
#    'NCIH510_LUNG',
#    'NCIH524_LUNG',
#    'NCIH82_LUNG',
#    'SNU16_STOMACH'}],
#  'CCAT2': [17,
#   {'AU565_BREAST',
#    'CORL23_LUNG',
#    'EFM192A_BREAST',
#    'HCC1419_BREAST',
#    'HCC44_LUNG',
#    'HCC827_LUNG',
#    'HGC27_STOMACH',
#    'KYSE450_OESOPHAGUS',
#    'NCIH2170_LUNG',
#    'NCIH2171_LUNG',
#    'NCIH23_LUNG',
#    'NCIH446_LUNG',
#    'NCIH510_LUNG',
#    'NCIH524_LUNG',
#    'NCIH82_LUNG',
#    'SNU16_STOMACH',
#    'SW480_LARGE_INTESTINE'}],
#  'POU5F1B': [17,
#   {'AU565_BREAST',
#    'CORL23_LUNG',
#    'EFM192A_BREAST',
#    'GCIY_STOMACH',
#    'HCC1419_BREAST',
#    'HCC44_LUNG',
#    'HCC827_LUNG',
#    'HGC27_STOMACH',
#    'KYSE450_OESOPHAGUS',
#    'NCIH2170_LUNG',
#    'NCIH2171_LUNG',
#    'NCIH23_LUNG',
#    'NCIH446_LUNG',
#    'NCIH510_LUNG',
#    'NCIH524_LUNG',
#    'NCIH82_LUNG',
#    'SNU16_STOMACH'}],
#  'CASC19': [15,
#   {'AU565_BREAST',
#    'CORL23_LUNG',
#    'EFM192A_BREAST',
#    'GCIY_STOMACH',
#    'HCC1419_BREAST',
#    'HCC44_LUNG',
#    'HCC827_LUNG',
#    'HGC27_STOMACH',
#    'KYSE450_OESOPHAGUS',
#    'NCIH2171_LUNG',
#    'NCIH23_LUNG',
#    'NCIH446_LUNG',
#    'NCIH82_LUNG',
#    'SKOV3_OVARY',
#    'SW480_LARGE_INTESTINE'}],
#  'CCAT1': [15,
#   {'AU565_BREAST',
#    'CORL23_LUNG',
#    'EFM192A_BREAST',
#    'GCIY_STOMACH',
#    'HCC1419_BREAST',
#    'HCC44_LUNG',
#    'HCC827_LUNG',
#    'HGC27_STOMACH',
#    'KYSE450_OESOPHAGUS',
#    'NCIH2171_LUNG',
#    'NCIH23_LUNG',
#    'NCIH446_LUNG',
#    'NCIH82_LUNG',
#    'SKOV3_OVARY',
#    'SW480_LARGE_INTESTINE'}],
#  'PCAT2': [14,
#   {'AU565_BREAST',
#    'CORL23_LUNG',
#    'EFM192A_BREAST',
#    'GCIY_STOMACH',
#    'HCC1419_BREAST',
#    'HCC1954_BREAST',
#    'HCC44_LUNG',
#    'HCC827_LUNG',
#    'HGC27_STOMACH',
#    'NCIH2171_LUNG',
#    'NCIH23_LUNG',
#    'NCIH446_LUNG',
#    'NCIH82_LUNG',
#    'SW480_LARGE_INTESTINE'}],
#  'PRNCR1': [14,
#   {'AU565_BREAST',
#    'CORL23_LUNG',
#    'EFM192A_BREAST',
#    'GCIY_STOMACH',
#    'HCC1419_BREAST',
#    'HCC1954_BREAST',
#    'HCC44_LUNG',
#    'HCC827_LUNG',
#    'HGC27_STOMACH',
#    'NCIH2171_LUNG',
#    'NCIH23_LUNG',
#    'NCIH446_LUNG',
#    'NCIH82_LUNG',
#    'SW480_LARGE_INTESTINE'}],
#  'ERBB2': [13,
#   {'BT474_BREAST',
#    'EFM192A_BREAST',
#    'HCC1419_BREAST',
#    'HCC1569_BREAST',
#    'HCC202_BREAST',
#    'KYSE410_OESOPHAGUS',
#    'MFE280_ENDOMETRIUM',
#    'MKN7_STOMACH',
#    'NCIH2170_LUNG',
#    'OE19_OESOPHAGUS',
#    'SKOV3_OVARY',
#    'UACC812_BREAST',
#    'UACC893_BREAST'}],
#  'PGAP3': [13,
#   {'BT474_BREAST',
#    'EFM192A_BREAST',
#    'HCC1419_BREAST',
#    'HCC1569_BREAST',
#    'HCC202_BREAST',
#    'KYSE410_OESOPHAGUS',
#    'MFE280_ENDOMETRIUM',
#    'MKN7_STOMACH',
#    'NCIH2170_LUNG',
#    'OE19_OESOPHAGUS',
#    'SKOV3_OVARY',
#    'UACC812_BREAST',
#    'UACC893_BREAST'}],
#  'GRB7': [12,
#   {'BT474_BREAST',
#    'EFM192A_BREAST',
#    'HCC1419_BREAST',
#    'HCC1569_BREAST',
#    'HCC202_BREAST',
#    'KYSE410_OESOPHAGUS',
#    'MFE280_ENDOMETRIUM',
#    'MKN7_STOMACH',
#    'NCIH2170_LUNG',
#    'OE19_OESOPHAGUS',
#    'UACC812_BREAST',
#    'UACC893_BREAST'}],
#  'IKZF3': [12,
#   {'BT474_BREAST',
#    'EFM192A_BREAST',
#    'HCC1419_BREAST',
#    'HCC1569_BREAST',
#    'HCC202_BREAST',
#    'KYSE410_OESOPHAGUS',
#    'MFE280_ENDOMETRIUM',
#    'MKN7_STOMACH',
#    'NCIH2170_LUNG',
#    'OE19_OESOPHAGUS',
#    'UACC812_BREAST',
#    'UACC893_BREAST'}],
#  'MIEN1': [12,
#   {'BT474_BREAST',
#    'EFM192A_BREAST',
#    'HCC1419_BREAST',
#    'HCC1569_BREAST',
#    'HCC202_BREAST',
#    'KYSE410_OESOPHAGUS',
#    'MFE280_ENDOMETRIUM',
#    'MKN7_STOMACH',
#    'NCIH2170_LUNG',
#    'OE19_OESOPHAGUS',
#    'UACC812_BREAST',
#    'UACC893_BREAST'}],
#  'MYCL': [12,
#   {'COLO668_LUNG',
#    'CORL88_LUNG',
#    'HCC33_LUNG',
#    'NCIH1092_LUNG',
#    'NCIH1184_LUNG',
#    'NCIH1694_LUNG',
#    'NCIH1836_LUNG',
#    'NCIH1963_LUNG',
#    'NCIH510_LUNG',
#    'NCIH520_LUNG',
#    'NCIH889_LUNG',
#    'THP1_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE'}],
#  'TRIT1': [12,
#   {'COLO668_LUNG',
#    'CORL88_LUNG',
#    'HCC33_LUNG',
#    'NCIH1092_LUNG',
#    'NCIH1184_LUNG',
#    'NCIH1694_LUNG',
#    'NCIH1836_LUNG',
#    'NCIH1963_LUNG',
#    'NCIH510_LUNG',
#    'NCIH520_LUNG',
#    'NCIH889_LUNG',
#    'THP1_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE'}],
#  'PCAT1': [11,
#   {'AU565_BREAST',
#    'EFM192A_BREAST',
#    'HCC1419_BREAST',
#    'HCC1954_BREAST',
#    'HCC827_LUNG',
#    'HGC27_STOMACH',
#    'NCIH2170_LUNG',
#    'NCIH2171_LUNG',
#    'NCIH23_LUNG',
#    'NCIH446_LUNG',
#    'SW480_LARGE_INTESTINE'}],
#  'PNMT': [11,
#   {'BT474_BREAST',
#    'EFM192A_BREAST',
#    'HCC1419_BREAST',
#    'HCC202_BREAST',
#    'KYSE410_OESOPHAGUS',
#    'MFE280_ENDOMETRIUM',
#    'MKN7_STOMACH',
#    'NCIH2170_LUNG',
#    'SKOV3_OVARY',
#    'UACC812_BREAST',
#    'UACC893_BREAST'}],
#  'TCAP': [11,
#   {'BT474_BREAST',
#    'EFM192A_BREAST',
#    'HCC1419_BREAST',
#    'HCC202_BREAST',
#    'KYSE410_OESOPHAGUS',
#    'MFE280_ENDOMETRIUM',
#    'MKN7_STOMACH',
#    'NCIH2170_LUNG',
#    'SKOV3_OVARY',
#    'UACC812_BREAST',
#    'UACC893_BREAST'}],
#  'BMP8B': [11,
#   {'COLO668_LUNG',
#    'CORL88_LUNG',
#    'NCIH1092_LUNG',
#    'NCIH1184_LUNG',
#    'NCIH1694_LUNG',
#    'NCIH1836_LUNG',
#    'NCIH1963_LUNG',
#    'NCIH510_LUNG',
#    'NCIH520_LUNG',
#    'NCIH889_LUNG',
#    'THP1_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE'}],
#  'HPCAL4': [11,
#   {'COLO668_LUNG',
#    'CORL88_LUNG',
#    'NCIH1092_LUNG',
#    'NCIH1184_LUNG',
#    'NCIH1694_LUNG',
#    'NCIH1836_LUNG',
#    'NCIH1963_LUNG',
#    'NCIH510_LUNG',
#    'NCIH520_LUNG',
#    'NCIH889_LUNG',
#    'THP1_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE'}],
#  'NT5C1A': [11,
#   {'COLO668_LUNG',
#    'CORL88_LUNG',
#    'NCIH1092_LUNG',
#    'NCIH1184_LUNG',
#    'NCIH1694_LUNG',
#    'NCIH1836_LUNG',
#    'NCIH1963_LUNG',
#    'NCIH510_LUNG',
#    'NCIH520_LUNG',
#    'NCIH889_LUNG',
#    'THP1_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE'}],
#  'OXCT2': [11,
#   {'COLO668_LUNG',
#    'CORL88_LUNG',
#    'NCIH1092_LUNG',
#    'NCIH1184_LUNG',
#    'NCIH1694_LUNG',
#    'NCIH1836_LUNG',
#    'NCIH1963_LUNG',
#    'NCIH510_LUNG',
#    'NCIH520_LUNG',
#    'NCIH889_LUNG',
#    'THP1_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE'}],
#  'PPIE': [11,
#   {'COLO668_LUNG',
#    'CORL88_LUNG',
#    'NCIH1092_LUNG',
#    'NCIH1184_LUNG',
#    'NCIH1694_LUNG',
#    'NCIH1836_LUNG',
#    'NCIH1963_LUNG',
#    'NCIH510_LUNG',
#    'NCIH520_LUNG',
#    'NCIH889_LUNG',
#    'THP1_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE'}],
#  'NEUROD2': [10,
#   {'BT474_BREAST',
#    'EFM192A_BREAST',
#    'HCC1419_BREAST',
#    'HCC202_BREAST',
#    'KYSE410_OESOPHAGUS',
#    'MFE280_ENDOMETRIUM',
#    'MKN7_STOMACH',
#    'SKOV3_OVARY',
#    'UACC812_BREAST',
#    'UACC893_BREAST'}],
#  'PPP1R1B': [10,
#   {'BT474_BREAST',
#    'EFM192A_BREAST',
#    'HCC1419_BREAST',
#    'HCC202_BREAST',
#    'KYSE410_OESOPHAGUS',
#    'MFE280_ENDOMETRIUM',
#    'MKN7_STOMACH',
#    'SKOV3_OVARY',
#    'UACC812_BREAST',
#    'UACC893_BREAST'}],
#  'STARD3': [10,
#   {'BT474_BREAST',
#    'EFM192A_BREAST',
#    'HCC1419_BREAST',
#    'HCC202_BREAST',
#    'KYSE410_OESOPHAGUS',
#    'MFE280_ENDOMETRIUM',
#    'MKN7_STOMACH',
#    'SKOV3_OVARY',
#    'UACC812_BREAST',
#    'UACC893_BREAST'}],
#  'MYEOV': [10,
#   {'CAMA1_BREAST',
#    'DMS114_LUNG',
#    'ES2_OVARY',
#    'HCC1954_BREAST',
#    'JHH7_LIVER',
#    'KYSE410_OESOPHAGUS',
#    'MDAMB175VII_BREAST',
#    'MDAMB361_BREAST',
#    'SF295_CENTRAL_NERVOUS_SYSTEM',
#    'SNU475_LIVER'}],
#  'SMIM38': [10,
#   {'CAMA1_BREAST',
#    'DMS114_LUNG',
#    'ES2_OVARY',
#    'HCC1954_BREAST',
#    'JHH7_LIVER',
#    'KYSE410_OESOPHAGUS',
#    'MDAMB175VII_BREAST',
#    'MDAMB361_BREAST',
#    'SF295_CENTRAL_NERVOUS_SYSTEM',
#    'SNU475_LIVER'}],
#  'HEYL': [10,
#   {'COLO668_LUNG',
#    'CORL88_LUNG',
#    'NCIH1092_LUNG',
#    'NCIH1184_LUNG',
#    'NCIH1694_LUNG',
#    'NCIH1836_LUNG',
#    'NCIH510_LUNG',
#    'NCIH520_LUNG',
#    'NCIH889_LUNG',
#    'THP1_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE'}],
#  'MFSD2A': [10,
#   {'COLO668_LUNG',
#    'CORL88_LUNG',
#    'HCC33_LUNG',
#    'NCIH1092_LUNG',
#    'NCIH1184_LUNG',
#    'NCIH1694_LUNG',
#    'NCIH1836_LUNG',
#    'NCIH1963_LUNG',
#    'NCIH520_LUNG',
#    'THP1_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE'}],
#  'ANO1': [9,
#   {'CAMA1_BREAST',
#    'DMS114_LUNG',
#    'ES2_OVARY',
#    'JHH7_LIVER',
#    'KYSE410_OESOPHAGUS',
#    'MDAMB134VI_BREAST',
#    'MDAMB175VII_BREAST',
#    'MDAMB361_BREAST',
#    'SNU475_LIVER'}],
#  'CCND1': [9,
#   {'CAMA1_BREAST',
#    'DMS114_LUNG',
#    'ES2_OVARY',
#    'JHH7_LIVER',
#    'KYSE410_OESOPHAGUS',
#    'MDAMB175VII_BREAST',
#    'MDAMB361_BREAST',
#    'SF295_CENTRAL_NERVOUS_SYSTEM',
#    'SNU475_LIVER'}],
#  'FGF19': [9,
#   {'CAMA1_BREAST',
#    'DMS114_LUNG',
#    'ES2_OVARY',
#    'JHH7_LIVER',
#    'KYSE410_OESOPHAGUS',
#    'MDAMB175VII_BREAST',
#    'MDAMB361_BREAST',
#    'SF295_CENTRAL_NERVOUS_SYSTEM',
#    'SNU475_LIVER'}],
#  'FGF3': [9,
#   {'CAMA1_BREAST',
#    'DMS114_LUNG',
#    'ES2_OVARY',
#    'JHH7_LIVER',
#    'KYSE410_OESOPHAGUS',
#    'MDAMB175VII_BREAST',
#    'MDAMB361_BREAST',
#    'SF295_CENTRAL_NERVOUS_SYSTEM',
#    'SNU475_LIVER'}],
#  'FGF4': [9,
#   {'CAMA1_BREAST',
#    'DMS114_LUNG',
#    'ES2_OVARY',
#    'JHH7_LIVER',
#    'KYSE410_OESOPHAGUS',
#    'MDAMB175VII_BREAST',
#    'MDAMB361_BREAST',
#    'SF295_CENTRAL_NERVOUS_SYSTEM',
#    'SNU475_LIVER'}],
#  'LTO1': [9,
#   {'CAMA1_BREAST',
#    'DMS114_LUNG',
#    'ES2_OVARY',
#    'JHH7_LIVER',
#    'KYSE410_OESOPHAGUS',
#    'MDAMB175VII_BREAST',
#    'MDAMB361_BREAST',
#    'SF295_CENTRAL_NERVOUS_SYSTEM',
#    'SNU475_LIVER'}],
#  'TPCN2': [9,
#   {'CAMA1_BREAST',
#    'DMS114_LUNG',
#    'ES2_OVARY',
#    'JHH7_LIVER',
#    'KYSE410_OESOPHAGUS',
#    'MDAMB175VII_BREAST',
#    'MDAMB361_BREAST',
#    'SF295_CENTRAL_NERVOUS_SYSTEM',
#    'SNU475_LIVER'}],
#  'CAP1': [9,
#   {'COLO668_LUNG',
#    'CORL88_LUNG',
#    'HCC33_LUNG',
#    'NCIH1092_LUNG',
#    'NCIH1184_LUNG',
#    'NCIH1836_LUNG',
#    'NCIH1963_LUNG',
#    'NCIH520_LUNG',
#    'THP1_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE'}],
#  'PABPC4': [9,
#   {'COLO668_LUNG',
#    'CORL88_LUNG',
#    'NCIH1092_LUNG',
#    'NCIH1184_LUNG',
#    'NCIH1694_LUNG',
#    'NCIH1836_LUNG',
#    'NCIH510_LUNG',
#    'NCIH520_LUNG',
#    'THP1_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE'}],
#  'PABPC4-AS1': [9,
#   {'COLO668_LUNG',
#    'CORL88_LUNG',
#    'NCIH1092_LUNG',
#    'NCIH1184_LUNG',
#    'NCIH1694_LUNG',
#    'NCIH1836_LUNG',
#    'NCIH510_LUNG',
#    'NCIH520_LUNG',
#    'THP1_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE'}],
#  'PPIEL': [9,
#   {'COLO668_LUNG',
#    'CORL88_LUNG',
#    'NCIH1092_LUNG',
#    'NCIH1184_LUNG',
#    'NCIH1694_LUNG',
#    'NCIH1836_LUNG',
#    'NCIH510_LUNG',
#    'NCIH520_LUNG',
#    'THP1_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE'}],
#  'RLF': [9,
#   {'COLO668_LUNG',
#    'CORL88_LUNG',
#    'HCC33_LUNG',
#    'NCIH1092_LUNG',
#    'NCIH1184_LUNG',
#    'NCIH1963_LUNG',
#    'NCIH520_LUNG',
#    'NCIH889_LUNG',
#    'THP1_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE'}],
#  'SNORA55': [9,
#   {'COLO668_LUNG',
#    'CORL88_LUNG',
#    'NCIH1092_LUNG',
#    'NCIH1184_LUNG',
#    'NCIH1694_LUNG',
#    'NCIH1836_LUNG',
#    'NCIH510_LUNG',
#    'NCIH520_LUNG',
#    'THP1_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE'}],
#  'ZPBP2': [8,
#   {'BT474_BREAST',
#    'EFM192A_BREAST',
#    'HCC202_BREAST',
#    'MFE280_ENDOMETRIUM',
#    'MKN7_STOMACH',
#    'NCIH2170_LUNG',
#    'UACC812_BREAST',
#    'UACC893_BREAST'}],
#  'CTTN': [8,
#   {'CAMA1_BREAST',
#    'DMS114_LUNG',
#    'ES2_OVARY',
#    'JHH7_LIVER',
#    'KYSE410_OESOPHAGUS',
#    'MDAMB175VII_BREAST',
#    'MDAMB361_BREAST',
#    'SNU475_LIVER'}],
#  'FADD': [8,
#   {'CAMA1_BREAST',
#    'DMS114_LUNG',
#    'ES2_OVARY',
#    'JHH7_LIVER',
#    'KYSE410_OESOPHAGUS',
#    'MDAMB175VII_BREAST',
#    'MDAMB361_BREAST',
#    'SNU475_LIVER'}],
#  'MRGPRD': [8,
#   {'CAMA1_BREAST',
#    'DMS114_LUNG',
#    'JHH7_LIVER',
#    'KYSE410_OESOPHAGUS',
#    'MDAMB175VII_BREAST',
#    'MDAMB361_BREAST',
#    'SF295_CENTRAL_NERVOUS_SYSTEM',
#    'SNU475_LIVER'}],
#  'MRGPRF': [8,
#   {'CAMA1_BREAST',
#    'DMS114_LUNG',
#    'JHH7_LIVER',
#    'KYSE410_OESOPHAGUS',
#    'MDAMB175VII_BREAST',
#    'MDAMB361_BREAST',
#    'SF295_CENTRAL_NERVOUS_SYSTEM',
#    'SNU475_LIVER'}],
#  'MRGPRF-AS1': [8,
#   {'CAMA1_BREAST',
#    'DMS114_LUNG',
#    'JHH7_LIVER',
#    'KYSE410_OESOPHAGUS',
#    'MDAMB175VII_BREAST',
#    'MDAMB361_BREAST',
#    'SF295_CENTRAL_NERVOUS_SYSTEM',
#    'SNU475_LIVER'}],
#  'PPFIA1': [8,
#   {'CAMA1_BREAST',
#    'DMS114_LUNG',
#    'ES2_OVARY',
#    'JHH7_LIVER',
#    'KYSE410_OESOPHAGUS',
#    'MDAMB175VII_BREAST',
#    'MDAMB361_BREAST',
#    'SNU475_LIVER'}],
#  'COL9A2': [8,
#   {'COLO668_LUNG',
#    'CORL88_LUNG',
#    'HCC33_LUNG',
#    'NCIH1092_LUNG',
#    'NCIH1184_LUNG',
#    'NCIH1963_LUNG',
#    'NCIH520_LUNG',
#    'THP1_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE'}],
#  'OXCT2P1': [8,
#   {'COLO668_LUNG',
#    'CORL88_LUNG',
#    'NCIH1184_LUNG',
#    'NCIH1694_LUNG',
#    'NCIH1836_LUNG',
#    'NCIH510_LUNG',
#    'NCIH520_LUNG',
#    'THP1_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE'}],
#  'PPT1': [8,
#   {'CORL88_LUNG',
#    'HCC33_LUNG',
#    'NCIH1092_LUNG',
#    'NCIH1184_LUNG',
#    'NCIH1836_LUNG',
#    'NCIH1963_LUNG',
#    'NCIH520_LUNG',
#    'THP1_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE'}],
#  'CDK12': [7,
#   {'BT474_BREAST',
#    'EFM192A_BREAST',
#    'HCC202_BREAST',
#    'MFE280_ENDOMETRIUM',
#    'MKN7_STOMACH',
#    'UACC812_BREAST',
#    'UACC893_BREAST'}],
#  'FBXL20': [7,
#   {'BT474_BREAST',
#    'EFM192A_BREAST',
#    'HCC202_BREAST',
#    'MFE280_ENDOMETRIUM',
#    'MKN7_STOMACH',
#    'UACC812_BREAST',
#    'UACC893_BREAST'}],
#  'MED1': [7,
#   {'BT474_BREAST',
#    'EFM192A_BREAST',
#    'HCC202_BREAST',
#    'MFE280_ENDOMETRIUM',
#    'MKN7_STOMACH',
#    'UACC812_BREAST',
#    'UACC893_BREAST'}],
#  'ADGRA2': [7,
#   {'BT483_BREAST',
#    'CAL120_BREAST',
#    'CAMA1_BREAST',
#    'DANG_PANCREAS',
#    'DMS114_LUNG',
#    'MDAMB134VI_BREAST',
#    'ZR751_BREAST'}],
#  'ADRB3': [7,
#   {'BT483_BREAST',
#    'CAL120_BREAST',
#    'CAMA1_BREAST',
#    'DANG_PANCREAS',
#    'DMS114_LUNG',
#    'MDAMB134VI_BREAST',
#    'ZR751_BREAST'}],
#  'ASH2L': [7,
#   {'BT483_BREAST',
#    'CAL120_BREAST',
#    'CAMA1_BREAST',
#    'DANG_PANCREAS',
#    'DMS114_LUNG',
#    'MDAMB134VI_BREAST',
#    'ZR751_BREAST'}],
#  'BRF2': [7,
#   {'BT483_BREAST',
#    'CAL120_BREAST',
#    'CAMA1_BREAST',
#    'DANG_PANCREAS',
#    'DMS114_LUNG',
#    'MDAMB134VI_BREAST',
#    'ZR751_BREAST'}],
#  'EIF4EBP1': [7,
#   {'BT483_BREAST',
#    'CAL120_BREAST',
#    'CAMA1_BREAST',
#    'DANG_PANCREAS',
#    'DMS114_LUNG',
#    'MDAMB134VI_BREAST',
#    'ZR751_BREAST'}],
#  'GOT1L1': [7,
#   {'BT483_BREAST',
#    'CAL120_BREAST',
#    'CAMA1_BREAST',
#    'DANG_PANCREAS',
#    'DMS114_LUNG',
#    'MDAMB134VI_BREAST',
#    'ZR751_BREAST'}],
#  'PLPBP': [7,
#   {'BT483_BREAST',
#    'CAL120_BREAST',
#    'CAMA1_BREAST',
#    'DANG_PANCREAS',
#    'DMS114_LUNG',
#    'MDAMB134VI_BREAST',
#    'ZR751_BREAST'}],
#  'RAB11FIP1': [7,
#   {'BT483_BREAST',
#    'CAL120_BREAST',
#    'CAMA1_BREAST',
#    'DANG_PANCREAS',
#    'DMS114_LUNG',
#    'MDAMB134VI_BREAST',
#    'ZR751_BREAST'}],
#  'STAR': [7,
#   {'BT483_BREAST',
#    'CAL120_BREAST',
#    'CAMA1_BREAST',
#    'DANG_PANCREAS',
#    'DMS114_LUNG',
#    'MDAMB134VI_BREAST',
#    'ZR751_BREAST'}],
#  'LRATD2': [7,
#   {'CORL23_LUNG',
#    'EFM192A_BREAST',
#    'HCC1419_BREAST',
#    'HGC27_STOMACH',
#    'NCIH446_LUNG',
#    'SNU16_STOMACH',
#    'SW480_LARGE_INTESTINE'}],
#  'ZDHHC11B': [7,
#   {'CORL279_LUNG',
#    'FU97_STOMACH',
#    'GI1_CENTRAL_NERVOUS_SYSTEM',
#    'HCC1954_BREAST',
#    'NCIH1437_LUNG',
#    'NCIH2066_LUNG',
#    'OSRC2_KIDNEY'}],
#  'TMCO2': [7,
#   {'CORL88_LUNG',
#    'HCC33_LUNG',
#    'NCIH1092_LUNG',
#    'NCIH1184_LUNG',
#    'NCIH1963_LUNG',
#    'NCIH520_LUNG',
#    'THP1_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE'}],
#  'ZMPSTE24': [7,
#   {'CORL88_LUNG',
#    'HCC33_LUNG',
#    'NCIH1092_LUNG',
#    'NCIH1184_LUNG',
#    'NCIH1963_LUNG',
#    'NCIH520_LUNG',
#    'THP1_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE'}],
#  'ERLIN2': [6,
#   {'BT483_BREAST',
#    'CAL120_BREAST',
#    'CAMA1_BREAST',
#    'DANG_PANCREAS',
#    'MDAMB134VI_BREAST',
#    'ZR751_BREAST'}],
#  'ZNF703': [6,
#   {'BT483_BREAST',
#    'CAL120_BREAST',
#    'CAMA1_BREAST',
#    'DANG_PANCREAS',
#    'MDAMB134VI_BREAST',
#    'ZR751_BREAST'}],
#  'BAG4': [6,
#   {'CAL120_BREAST',
#    'CAMA1_BREAST',
#    'DANG_PANCREAS',
#    'DMS114_LUNG',
#    'MDAMB134VI_BREAST',
#    'ZR751_BREAST'}],
#  'C8orf86': [6,
#   {'CAL120_BREAST',
#    'CAMA1_BREAST',
#    'DANG_PANCREAS',
#    'DMS114_LUNG',
#    'MDAMB134VI_BREAST',
#    'ZR751_BREAST'}],
#  'DDHD2': [6,
#   {'CAL120_BREAST',
#    'CAMA1_BREAST',
#    'DANG_PANCREAS',
#    'DMS114_LUNG',
#    'MDAMB134VI_BREAST',
#    'ZR751_BREAST'}],
#  'FGFR1': [6,
#   {'CAL120_BREAST',
#    'CAMA1_BREAST',
#    'DANG_PANCREAS',
#    'DMS114_LUNG',
#    'MDAMB134VI_BREAST',
#    'ZR751_BREAST'}],
#  'LETM2': [6,
#   {'CAL120_BREAST',
#    'CAMA1_BREAST',
#    'DANG_PANCREAS',
#    'DMS114_LUNG',
#    'MDAMB134VI_BREAST',
#    'ZR751_BREAST'}],
#  'LSM1': [6,
#   {'CAL120_BREAST',
#    'CAMA1_BREAST',
#    'DANG_PANCREAS',
#    'DMS114_LUNG',
#    'MDAMB134VI_BREAST',
#    'ZR751_BREAST'}],
#  'NSD3': [6,
#   {'CAL120_BREAST',
#    'CAMA1_BREAST',
#    'DANG_PANCREAS',
#    'DMS114_LUNG',
#    'MDAMB134VI_BREAST',
#    'ZR751_BREAST'}],
#  'PLPP5': [6,
#   {'CAL120_BREAST',
#    'CAMA1_BREAST',
#    'DANG_PANCREAS',
#    'DMS114_LUNG',
#    'MDAMB134VI_BREAST',
#    'ZR751_BREAST'}],
#  'IGHMBP2': [6,
#   {'CAMA1_BREAST',
#    'DMS114_LUNG',
#    'JHH7_LIVER',
#    'MDAMB175VII_BREAST',
#    'SF295_CENTRAL_NERVOUS_SYSTEM',
#    'SNU475_LIVER'}],
#  'MRPL21': [6,
#   {'CAMA1_BREAST',
#    'DMS114_LUNG',
#    'JHH7_LIVER',
#    'MDAMB175VII_BREAST',
#    'SF295_CENTRAL_NERVOUS_SYSTEM',
#    'SNU475_LIVER'}],
#  'BMP8A': [6,
#   {'COLO668_LUNG',
#    'NCIH1184_LUNG',
#    'NCIH1694_LUNG',
#    'NCIH1836_LUNG',
#    'NCIH520_LUNG',
#    'THP1_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE'}],
#  'SMAP2': [6,
#   {'COLO668_LUNG',
#    'CORL88_LUNG',
#    'NCIH1184_LUNG',
#    'NCIH1963_LUNG',
#    'NCIH520_LUNG',
#    'THP1_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE'}],
#  'TPPP': [6,
#   {'FU97_STOMACH',
#    'GI1_CENTRAL_NERVOUS_SYSTEM',
#    'HCC1954_BREAST',
#    'NCIH1437_LUNG',
#    'NCIH2066_LUNG',
#    'OSRC2_KIDNEY'}],
#  'NDUFB9': [5,
#   {'59M_OVARY',
#    'AU565_BREAST',
#    'EFM192A_BREAST',
#    'HCC1419_BREAST',
#    'HGC27_STOMACH'}],
#  'TATDN1': [5,
#   {'59M_OVARY',
#    'AU565_BREAST',
#    'EFM192A_BREAST',
#    'HCC1419_BREAST',
#    'HGC27_STOMACH'}],
#  'FAM91A1': [5,
#   {'AU565_BREAST',
#    'CORL279_LUNG',
#    'EFM192A_BREAST',
#    'HCC1419_BREAST',
#    'HGC27_STOMACH'}],
#  'FER1L6': [5,
#   {'AU565_BREAST',
#    'CORL279_LUNG',
#    'EFM192A_BREAST',
#    'HCC1419_BREAST',
#    'HGC27_STOMACH'}],
#  'FER1L6-AS1': [5,
#   {'AU565_BREAST',
#    'CORL279_LUNG',
#    'EFM192A_BREAST',
#    'HCC1419_BREAST',
#    'HGC27_STOMACH'}],
#  'FER1L6-AS2': [5,
#   {'AU565_BREAST',
#    'CORL279_LUNG',
#    'EFM192A_BREAST',
#    'HCC1419_BREAST',
#    'HGC27_STOMACH'}],
#  'TBC1D31': [5,
#   {'AU565_BREAST',
#    'EFM192A_BREAST',
#    'HCC1419_BREAST',
#    'HGC27_STOMACH',
#    'MKN7_STOMACH'}],
#  'ZNF704': [5,
#   {'AU565_BREAST',
#    'EFM192A_BREAST',
#    'HCC1419_BREAST',
#    'HCC38_BREAST',
#    'HCC827_LUNG'}],
#  'CACNB1': [5,
#   {'BT474_BREAST',
#    'EFM192A_BREAST',
#    'MFE280_ENDOMETRIUM',
#    'MKN7_STOMACH',
#    'UACC812_BREAST'}],
#  'GSDMA': [5,
#   {'BT474_BREAST',
#    'EFM192A_BREAST',
#    'MFE280_ENDOMETRIUM',
#    'UACC812_BREAST',
#    'UACC893_BREAST'}],
#  'GSDMB': [5,
#   {'BT474_BREAST',
#    'EFM192A_BREAST',
#    'MFE280_ENDOMETRIUM',
#    'UACC812_BREAST',
#    'UACC893_BREAST'}],
#  'LRRC3C': [5,
#   {'BT474_BREAST',
#    'EFM192A_BREAST',
#    'MFE280_ENDOMETRIUM',
#    'UACC812_BREAST',
#    'UACC893_BREAST'}],
#  'ORMDL3': [5,
#   {'BT474_BREAST',
#    'EFM192A_BREAST',
#    'MFE280_ENDOMETRIUM',
#    'UACC812_BREAST',
#    'UACC893_BREAST'}],
#  'PSMD3': [5,
#   {'BT474_BREAST',
#    'EFM192A_BREAST',
#    'MFE280_ENDOMETRIUM',
#    'UACC812_BREAST',
#    'UACC893_BREAST'}],
#  'RPL19': [5,
#   {'BT474_BREAST',
#    'EFM192A_BREAST',
#    'MFE280_ENDOMETRIUM',
#    'MKN7_STOMACH',
#    'UACC812_BREAST'}],
#  'STAC2': [5,
#   {'BT474_BREAST',
#    'EFM192A_BREAST',
#    'MFE280_ENDOMETRIUM',
#    'MKN7_STOMACH',
#    'UACC812_BREAST'}],
#  'RNF5P1': [5,
#   {'CAL120_BREAST',
#    'CAMA1_BREAST',
#    'DANG_PANCREAS',
#    'DMS114_LUNG',
#    'MDAMB134VI_BREAST'}],
#  'CPT1A': [5,
#   {'CAMA1_BREAST',
#    'DMS114_LUNG',
#    'JHH7_LIVER',
#    'MDAMB175VII_BREAST',
#    'SNU475_LIVER'}],
#  'GAL': [5,
#   {'CAMA1_BREAST',
#    'DMS114_LUNG',
#    'JHH7_LIVER',
#    'MDAMB175VII_BREAST',
#    'SNU475_LIVER'}],
#  'TESMIN': [5,
#   {'CAMA1_BREAST',
#    'DMS114_LUNG',
#    'JHH7_LIVER',
#    'MDAMB175VII_BREAST',
#    'SNU475_LIVER'}],
#  'MUC20': [5,
#   {'COLO201_LARGE_INTESTINE',
#    'FUOV1_OVARY',
#    'KYSE30_OESOPHAGUS',
#    'MDAMB453_BREAST',
#    'NCIH2066_LUNG'}],
#  'ZFP69': [5,
#   {'COLO668_LUNG',
#    'CORL88_LUNG',
#    'NCIH1184_LUNG',
#    'NCIH1963_LUNG',
#    'THP1_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE'}],
#  'ZFP69B': [5,
#   {'COLO668_LUNG',
#    'CORL88_LUNG',
#    'NCIH1184_LUNG',
#    'NCIH1963_LUNG',
#    'THP1_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE'}],
#  'ZNF684': [5,
#   {'COLO668_LUNG',
#    'CORL88_LUNG',
#    'NCIH1184_LUNG',
#    'NCIH1963_LUNG',
#    'THP1_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE'}],
#  'CASC1': [5,
#   {'CORL23_LUNG',
#    'DMS53_LUNG',
#    'KE39_STOMACH',
#    'KLE_ENDOMETRIUM',
#    'MKN1_STOMACH'}],
#  'ETFRF1': [5,
#   {'CORL23_LUNG',
#    'DMS53_LUNG',
#    'KE39_STOMACH',
#    'KLE_ENDOMETRIUM',
#    'MKN1_STOMACH'}],
#  'KRAS': [5,
#   {'CORL23_LUNG',
#    'DMS53_LUNG',
#    'KE39_STOMACH',
#    'KLE_ENDOMETRIUM',
#    'MKN1_STOMACH'}],
#  'LMNTD1': [5,
#   {'CORL23_LUNG',
#    'DMS53_LUNG',
#    'KE39_STOMACH',
#    'KLE_ENDOMETRIUM',
#    'MKN1_STOMACH'}],
#  'KIAA0754': [5,
#   {'NCIH1184_LUNG',
#    'NCIH1694_LUNG',
#    'NCIH1836_LUNG',
#    'NCIH510_LUNG',
#    'NCIH520_LUNG'}],
#  'MTSS1': [4,
#   {'59M_OVARY', 'EFM192A_BREAST', 'HCC1419_BREAST', 'HGC27_STOMACH'}],
#  'NSMCE2': [4,
#   {'59M_OVARY', 'EFM192A_BREAST', 'HCC1419_BREAST', 'HGC27_STOMACH'}],
#  'SQLE': [4,
#   {'59M_OVARY', 'EFM192A_BREAST', 'HCC1419_BREAST', 'HGC27_STOMACH'}],
#  'TRIB1': [4,
#   {'59M_OVARY', 'EFM192A_BREAST', 'HCC1419_BREAST', 'HGC27_STOMACH'}],
#  'WASHC5': [4,
#   {'59M_OVARY', 'EFM192A_BREAST', 'HCC1419_BREAST', 'HGC27_STOMACH'}],
#  'ZNF572': [4,
#   {'59M_OVARY', 'EFM192A_BREAST', 'HCC1419_BREAST', 'HGC27_STOMACH'}],
#  'ANXA13': [4,
#   {'AU565_BREAST', 'EFM192A_BREAST', 'HCC1419_BREAST', 'HGC27_STOMACH'}],
#  'ATAD2': [4,
#   {'AU565_BREAST', 'EFM192A_BREAST', 'HCC1419_BREAST', 'HGC27_STOMACH'}],
#  'C8orf76': [4,
#   {'AU565_BREAST', 'EFM192A_BREAST', 'HCC1419_BREAST', 'HGC27_STOMACH'}],
#  'DERL1': [4,
#   {'AU565_BREAST', 'EFM192A_BREAST', 'HCC1419_BREAST', 'HGC27_STOMACH'}],
#  'FAM83A': [4,
#   {'AU565_BREAST', 'EFM192A_BREAST', 'HCC1419_BREAST', 'HGC27_STOMACH'}],
#  'FAM83A-AS1': [4,
#   {'AU565_BREAST', 'EFM192A_BREAST', 'HCC1419_BREAST', 'HGC27_STOMACH'}],
#  'FBXO32': [4,
#   {'AU565_BREAST', 'EFM192A_BREAST', 'HCC1419_BREAST', 'HGC27_STOMACH'}],
#  'KLHL38': [4,
#   {'AU565_BREAST', 'EFM192A_BREAST', 'HCC1419_BREAST', 'HGC27_STOMACH'}],
#  'RNF139': [4,
#   {'AU565_BREAST', 'EFM192A_BREAST', 'HCC1419_BREAST', 'HGC27_STOMACH'}],
#  'RNF139-AS1': [4,
#   {'AU565_BREAST', 'EFM192A_BREAST', 'HCC1419_BREAST', 'HGC27_STOMACH'}],
#  'SAMD12': [4,
#   {'AU565_BREAST', 'EFM192A_BREAST', 'HCC1419_BREAST', 'HCC1954_BREAST'}],
#  'SAMD12-AS1': [4,
#   {'AU565_BREAST', 'EFM192A_BREAST', 'HCC1419_BREAST', 'HCC1954_BREAST'}],
#  'SMILR': [4,
#   {'AU565_BREAST', 'EFM192A_BREAST', 'HCC1419_BREAST', 'HGC27_STOMACH'}],
#  'TMEM65': [4,
#   {'AU565_BREAST', 'EFM192A_BREAST', 'HCC1419_BREAST', 'HGC27_STOMACH'}],
#  'TRMT12': [4,
#   {'AU565_BREAST', 'EFM192A_BREAST', 'HCC1419_BREAST', 'HGC27_STOMACH'}],
#  'WDYHV1': [4,
#   {'AU565_BREAST', 'EFM192A_BREAST', 'HCC1419_BREAST', 'HGC27_STOMACH'}],
#  'ZBTB10': [4,
#   {'AU565_BREAST', 'EFM192A_BREAST', 'HCC38_BREAST', 'HCC827_LUNG'}],
#  'ZHX1': [4,
#   {'AU565_BREAST', 'EFM192A_BREAST', 'HCC1419_BREAST', 'HGC27_STOMACH'}],
#  'ZHX1-C8orf76': [4,
#   {'AU565_BREAST', 'EFM192A_BREAST', 'HCC1419_BREAST', 'HGC27_STOMACH'}],
#  'ZHX2': [4,
#   {'AU565_BREAST', 'EFM192A_BREAST', 'HCC1419_BREAST', 'HGC27_STOMACH'}],
#  'NPEPL1': [4,
#   {'BT474_BREAST', 'HCC1419_BREAST', 'HCC1954_BREAST', 'UACC893_BREAST'}],
#  'STX16': [4,
#   {'BT474_BREAST', 'HCC1419_BREAST', 'HCC1954_BREAST', 'UACC893_BREAST'}],
#  'STX16-NPEPL1': [4,
#   {'BT474_BREAST', 'HCC1419_BREAST', 'HCC1954_BREAST', 'UACC893_BREAST'}],
#  'ZNF217': [4,
#   {'BT474_BREAST', 'EFM192A_BREAST', 'HCC1419_BREAST', 'MCF7_BREAST'}],
#  'ARL5C': [4,
#   {'BT474_BREAST', 'EFM192A_BREAST', 'MFE280_ENDOMETRIUM', 'UACC812_BREAST'}],
#  'ATP5MC1': [4,
#   {'BT474_BREAST', 'EFM192A_BREAST', 'HCC1419_BREAST', 'HCC202_BREAST'}],
#  'CALCOCO2': [4,
#   {'BT474_BREAST', 'EFM192A_BREAST', 'HCC1419_BREAST', 'HCC202_BREAST'}],
#  'CSF3': [4,
#   {'BT474_BREAST', 'MFE280_ENDOMETRIUM', 'UACC812_BREAST', 'UACC893_BREAST'}],
#  'FBXO47': [4,
#   {'BT474_BREAST', 'EFM192A_BREAST', 'MFE280_ENDOMETRIUM', 'UACC812_BREAST'}],
#  'HOXB13': [4,
#   {'BT474_BREAST', 'EFM192A_BREAST', 'HCC1419_BREAST', 'HCC202_BREAST'}],
#  'LRRC37A11P': [4,
#   {'BT474_BREAST', 'EFM192A_BREAST', 'MFE280_ENDOMETRIUM', 'UACC812_BREAST'}],
#  'MED24': [4,
#   {'BT474_BREAST', 'MFE280_ENDOMETRIUM', 'UACC812_BREAST', 'UACC893_BREAST'}],
#  'PLXDC1': [4,
#   {'BT474_BREAST', 'EFM192A_BREAST', 'MFE280_ENDOMETRIUM', 'UACC812_BREAST'}],
#  'PRAC1': [4,
#   {'BT474_BREAST', 'EFM192A_BREAST', 'HCC1419_BREAST', 'HCC202_BREAST'}],
#  'PRAC2': [4,
#   {'BT474_BREAST', 'EFM192A_BREAST', 'HCC1419_BREAST', 'HCC202_BREAST'}],
#  'RDM1P5': [4,
#   {'BT474_BREAST', 'EFM192A_BREAST', 'MFE280_ENDOMETRIUM', 'UACC812_BREAST'}],
#  'SNORD124': [4,
#   {'BT474_BREAST', 'MFE280_ENDOMETRIUM', 'UACC812_BREAST', 'UACC893_BREAST'}],
#  'THRA': [4,
#   {'BT474_BREAST', 'MFE280_ENDOMETRIUM', 'UACC812_BREAST', 'UACC893_BREAST'}],
#  'TTLL6': [4,
#   {'BT474_BREAST', 'EFM192A_BREAST', 'HCC1419_BREAST', 'HCC202_BREAST'}],
#  'UBE2Z': [4,
#   {'BT474_BREAST', 'EFM192A_BREAST', 'HCC1419_BREAST', 'HCC202_BREAST'}],
#  'TACC1': [4,
#   {'CAL120_BREAST', 'CAMA1_BREAST', 'DANG_PANCREAS', 'DMS114_LUNG'}],
#  'SDHAP2': [4,
#   {'COLO201_LARGE_INTESTINE',
#    'FUOV1_OVARY',
#    'KYSE30_OESOPHAGUS',
#    'NCIH2066_LUNG'}],
#  'RASSF8': [4,
#   {'CORL23_LUNG', 'DMS53_LUNG', 'KLE_ENDOMETRIUM', 'MKN1_STOMACH'}],
#  'RASSF8-AS1': [4,
#   {'CORL23_LUNG', 'DMS53_LUNG', 'KLE_ENDOMETRIUM', 'MKN1_STOMACH'}],
#  'EXO5': [4,
#   {'CORL88_LUNG',
#    'NCIH1184_LUNG',
#    'NCIH1963_LUNG',
#    'THP1_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE'}],
#  'CLCF1': [4,
#   {'DMS114_LUNG', 'KYSE410_OESOPHAGUS', 'MKN7_STOMACH', 'SNU475_LIVER'}],
#  'POLD4': [4,
#   {'DMS114_LUNG', 'KYSE410_OESOPHAGUS', 'MKN7_STOMACH', 'SNU475_LIVER'}],
#  'PPP6R3': [4,
#   {'DMS114_LUNG', 'JHH7_LIVER', 'MDAMB175VII_BREAST', 'SNU475_LIVER'}],
#  'C12orf77': [4,
#   {'DMS53_LUNG', 'KE39_STOMACH', 'KLE_ENDOMETRIUM', 'MKN1_STOMACH'}],
#  'LRMP': [4,
#   {'DMS53_LUNG', 'KE39_STOMACH', 'KLE_ENDOMETRIUM', 'MKN1_STOMACH'}],
#  'CCDC26': [4,
#   {'EFM192A_BREAST', 'HCC1419_BREAST', 'NCIH23_LUNG', 'NCIH460_LUNG'}],
#  'LPCAT1': [4,
#   {'GI1_CENTRAL_NERVOUS_SYSTEM',
#    'HCC1954_BREAST',
#    'NCIH1437_LUNG',
#    'NCIH650_LUNG'}],
#  'SLC6A3': [4,
#   {'GI1_CENTRAL_NERVOUS_SYSTEM',
#    'HCC1954_BREAST',
#    'NCIH1437_LUNG',
#    'NCIH650_LUNG'}],
#  'CITED4': [4,
#   {'HCC2157_BREAST',
#    'NCIH1184_LUNG',
#    'NCIH1836_LUNG',
#    'THP1_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE'}],
#  'GJA9': [4,
#   {'NCIH1184_LUNG', 'NCIH2122_LUNG', 'NCIH520_LUNG', 'NCIH889_LUNG'}],
#  'GJA9-MYCBP': [4,
#   {'NCIH1184_LUNG', 'NCIH2122_LUNG', 'NCIH520_LUNG', 'NCIH889_LUNG'}],
#  'CALB1': [3, {'AU565_BREAST', 'EFM192A_BREAST', 'HCC1419_BREAST'}],
#  'CCN3': [3, {'AU565_BREAST', 'EFM192A_BREAST', 'HCC1419_BREAST'}],
#  'COL14A1': [3, {'AU565_BREAST', 'EFM192A_BREAST', 'HCC1419_BREAST'}],
#  'COLEC10': [3, {'AU565_BREAST', 'EFM192A_BREAST', 'HCC1419_BREAST'}],
#  'CSMD3': [3, {'AU565_BREAST', 'EFM192A_BREAST', 'HGC27_STOMACH'}],
#  'DECR1': [3, {'AU565_BREAST', 'EFM192A_BREAST', 'HCC1419_BREAST'}],
#  'DEPTOR': [3, {'AU565_BREAST', 'EFM192A_BREAST', 'HCC1419_BREAST'}],
#  'DSCC1': [3, {'AU565_BREAST', 'EFM192A_BREAST', 'HCC1419_BREAST'}],
#  'ENPP2': [3, {'AU565_BREAST', 'EFM192A_BREAST', 'HCC1419_BREAST'}],
#  'HAS2': [3, {'AU565_BREAST', 'EFM192A_BREAST', 'HCC1419_BREAST'}],
#  'HAS2-AS1': [3, {'AU565_BREAST', 'EFM192A_BREAST', 'HCC1419_BREAST'}],
#  'MAL2': [3, {'AU565_BREAST', 'EFM192A_BREAST', 'HCC1419_BREAST'}],
#  'MAL2-AS1': [3, {'AU565_BREAST', 'EFM192A_BREAST', 'HCC1419_BREAST'}],
#  'MRPL13': [3, {'AU565_BREAST', 'EFM192A_BREAST', 'HCC1419_BREAST'}],
#  'MTBP': [3, {'AU565_BREAST', 'EFM192A_BREAST', 'HCC1419_BREAST'}],
#  'NBN': [3, {'AU565_BREAST', 'EFM192A_BREAST', 'HCC1419_BREAST'}],
#  'SNTB1': [3, {'AU565_BREAST', 'EFM192A_BREAST', 'HCC1419_BREAST'}],
#  'TAF2': [3, {'AU565_BREAST', 'EFM192A_BREAST', 'HCC1419_BREAST'}],
#  'TNFRSF11B': [3, {'AU565_BREAST', 'EFM192A_BREAST', 'HCC1419_BREAST'}],
#  'TRPS1': [3, {'AU565_BREAST', 'EFM192A_BREAST', 'HGC27_STOMACH'}],
#  'ADNP-AS1': [3, {'BT474_BREAST', 'EFM192A_BREAST', 'HCC1419_BREAST'}],
#  'ANKRD60': [3, {'BT474_BREAST', 'HCC1954_BREAST', 'UACC893_BREAST'}],
#  'APCDD1L': [3, {'BT474_BREAST', 'HCC1954_BREAST', 'UACC893_BREAST'}],
#  'APCDD1L-DT': [3, {'BT474_BREAST', 'HCC1954_BREAST', 'UACC893_BREAST'}],
#  'BCAS1': [3, {'BT474_BREAST', 'EFM192A_BREAST', 'MCF7_BREAST'}],
#  'BCAS4': [3, {'BT474_BREAST', 'HCC1419_BREAST', 'MCF7_BREAST'}],
#  'BMP7': [3, {'BT474_BREAST', 'MCF7_BREAST', 'UACC893_BREAST'}],
#  'BMP7-AS1': [3, {'BT474_BREAST', 'MCF7_BREAST', 'UACC893_BREAST'}],
#  'CYP24A1': [3, {'BT474_BREAST', 'EFM192A_BREAST', 'MCF7_BREAST'}],
#  'DOK5': [3, {'BT474_BREAST', 'EFM192A_BREAST', 'MCF7_BREAST'}],
#  'DPM1': [3, {'BT474_BREAST', 'EFM192A_BREAST', 'HCC1419_BREAST'}],
#  'KCNG1': [3, {'BT474_BREAST', 'EFM192A_BREAST', 'HCC1419_BREAST'}],
#  'MOCS3': [3, {'BT474_BREAST', 'EFM192A_BREAST', 'HCC1419_BREAST'}],
#  'PARD6B': [3, {'BT474_BREAST', 'HCC1419_BREAST', 'MCF7_BREAST'}],
#  'PFDN4': [3, {'BT474_BREAST', 'EFM192A_BREAST', 'MCF7_BREAST'}],
#  'PPP4R1L': [3, {'BT474_BREAST', 'HCC1954_BREAST', 'UACC893_BREAST'}],
#  'RAB22A': [3, {'BT474_BREAST', 'HCC1954_BREAST', 'UACC893_BREAST'}],
#  'SUMO1P1': [3, {'BT474_BREAST', 'EFM192A_BREAST', 'MCF7_BREAST'}],
#  'VAPB': [3, {'BT474_BREAST', 'HCC1954_BREAST', 'UACC893_BREAST'}],
#  'B4GALNT2': [3, {'BT474_BREAST', 'EFM192A_BREAST', 'HCC1419_BREAST'}],
#  'C17orf98': [3, {'BT474_BREAST', 'EFM192A_BREAST', 'UACC812_BREAST'}],
#  'CISD3': [3, {'BT474_BREAST', 'EFM192A_BREAST', 'UACC812_BREAST'}],
#  'CWC25': [3, {'BT474_BREAST', 'EFM192A_BREAST', 'UACC812_BREAST'}],
#  'GIP': [3, {'BT474_BREAST', 'EFM192A_BREAST', 'HCC1419_BREAST'}],
#  'HOXB6': [3, {'BT474_BREAST', 'EFM192A_BREAST', 'HCC202_BREAST'}],
#  'HOXB7': [3, {'BT474_BREAST', 'EFM192A_BREAST', 'HCC202_BREAST'}],
#  'HOXB8': [3, {'BT474_BREAST', 'EFM192A_BREAST', 'HCC202_BREAST'}],
#  'HOXB9': [3, {'BT474_BREAST', 'EFM192A_BREAST', 'HCC202_BREAST'}],
#  'IGF2BP1': [3, {'BT474_BREAST', 'EFM192A_BREAST', 'HCC1419_BREAST'}],
#  'LASP1': [3, {'BT474_BREAST', 'EFM192A_BREAST', 'UACC812_BREAST'}],
#  'PCGF2': [3, {'BT474_BREAST', 'EFM192A_BREAST', 'UACC812_BREAST'}],
#  'PIP4K2B': [3, {'BT474_BREAST', 'EFM192A_BREAST', 'UACC812_BREAST'}],
#  'PSMB3': [3, {'BT474_BREAST', 'EFM192A_BREAST', 'UACC812_BREAST'}],
#  'RPL23': [3, {'BT474_BREAST', 'EFM192A_BREAST', 'UACC812_BREAST'}],
#  'SNF8': [3, {'BT474_BREAST', 'EFM192A_BREAST', 'HCC1419_BREAST'}],
#  'SNORA21': [3, {'BT474_BREAST', 'EFM192A_BREAST', 'UACC812_BREAST'}],
#  'SNORA21B': [3, {'BT474_BREAST', 'EFM192A_BREAST', 'UACC812_BREAST'}],
#  'ADAM18': [3, {'CAL120_BREAST', 'DANG_PANCREAS', 'DMS114_LUNG'}],
#  'ADAM32': [3, {'CAL120_BREAST', 'CAMA1_BREAST', 'DMS114_LUNG'}],
#  'ADAM9': [3, {'CAL120_BREAST', 'CAMA1_BREAST', 'DMS114_LUNG'}],
#  'HTRA4': [3, {'CAL120_BREAST', 'CAMA1_BREAST', 'DMS114_LUNG'}],
#  'PLEKHA2': [3, {'CAL120_BREAST', 'CAMA1_BREAST', 'DMS114_LUNG'}],
#  'SNORD38D': [3, {'CAL120_BREAST', 'CAMA1_BREAST', 'DMS114_LUNG'}],
#  'TM2D2': [3, {'CAL120_BREAST', 'CAMA1_BREAST', 'DMS114_LUNG'}],
#  'GDPD5': [3, {'CAMA1_BREAST', 'KYSE410_OESOPHAGUS', 'MDAMB175VII_BREAST'}],
#  'KLHL35': [3, {'CAMA1_BREAST', 'MDAMB134VI_BREAST', 'MDAMB175VII_BREAST'}],
#  'MAP6': [3, {'CAMA1_BREAST', 'KYSE410_OESOPHAGUS', 'MDAMB175VII_BREAST'}],
#  'MOGAT2': [3, {'CAMA1_BREAST', 'KYSE410_OESOPHAGUS', 'MDAMB175VII_BREAST'}],
#  'SERPINH1': [3, {'CAMA1_BREAST', 'KYSE410_OESOPHAGUS', 'MDAMB175VII_BREAST'}],
#  'NFYC': [3,
#   {'COLO668_LUNG',
#    'NCIH1184_LUNG',
#    'THP1_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE'}],
#  'NFYC-AS1': [3,
#   {'COLO668_LUNG',
#    'NCIH1184_LUNG',
#    'THP1_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE'}],
#  'RIMS3': [3,
#   {'COLO668_LUNG',
#    'NCIH1184_LUNG',
#    'THP1_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE'}],
#  'CRACR2A': [3, {'CORL23_LUNG', 'DMS53_LUNG', 'NCIH2171_LUNG'}],
#  'PARP11': [3, {'CORL23_LUNG', 'DMS53_LUNG', 'NCIH2171_LUNG'}],
#  'THCAT155': [3, {'CORL23_LUNG', 'DMS53_LUNG', 'NCIH2171_LUNG'}],
#  'TIGAR': [3, {'CORL23_LUNG', 'DMS53_LUNG', 'NCIH2171_LUNG'}],
#  'UNC5D': [3, {'DANG_PANCREAS', 'DMS114_LUNG', 'MDAMB134VI_BREAST'}],
#  'AIP': [3, {'DMS114_LUNG', 'MKN7_STOMACH', 'SNU475_LIVER'}],
#  'ANKRD13D': [3, {'DMS114_LUNG', 'KYSE410_OESOPHAGUS', 'SNU475_LIVER'}],
#  'C11orf72': [3, {'DMS114_LUNG', 'MKN7_STOMACH', 'SNU475_LIVER'}],
#  'CABP2': [3, {'DMS114_LUNG', 'MKN7_STOMACH', 'SNU475_LIVER'}],
#  'CABP4': [3, {'DMS114_LUNG', 'MKN7_STOMACH', 'SNU475_LIVER'}],
#  'CARNS1': [3, {'DMS114_LUNG', 'MKN7_STOMACH', 'SNU475_LIVER'}],
#  'CDK2AP2': [3, {'DMS114_LUNG', 'MKN7_STOMACH', 'SNU475_LIVER'}],
#  'CORO1B': [3, {'DMS114_LUNG', 'MKN7_STOMACH', 'SNU475_LIVER'}],
#  'DOC2GP': [3, {'DMS114_LUNG', 'MKN7_STOMACH', 'SNU475_LIVER'}],
#  'GPR152': [3, {'DMS114_LUNG', 'MKN7_STOMACH', 'SNU475_LIVER'}],
#  'GRK2': [3, {'DMS114_LUNG', 'KYSE410_OESOPHAGUS', 'SNU475_LIVER'}],
#  'GSTP1': [3, {'DMS114_LUNG', 'MKN7_STOMACH', 'SNU475_LIVER'}],
#  'KDM2A': [3, {'DMS114_LUNG', 'KYSE410_OESOPHAGUS', 'SNU475_LIVER'}],
#  'NDUFV1': [3, {'DMS114_LUNG', 'MKN7_STOMACH', 'SNU475_LIVER'}],
#  'NUDT8': [3, {'DMS114_LUNG', 'MKN7_STOMACH', 'SNU475_LIVER'}],
#  'PITPNM1': [3, {'DMS114_LUNG', 'MKN7_STOMACH', 'SNU475_LIVER'}],
#  'PPP1CA': [3, {'DMS114_LUNG', 'MKN7_STOMACH', 'SNU475_LIVER'}],
#  'PTPRCAP': [3, {'DMS114_LUNG', 'MKN7_STOMACH', 'SNU475_LIVER'}],
#  'RAD9A': [3, {'DMS114_LUNG', 'MKN7_STOMACH', 'SNU475_LIVER'}],
#  'RPS6KB2': [3, {'DMS114_LUNG', 'MKN7_STOMACH', 'SNU475_LIVER'}],
#  'SSH3': [3, {'DMS114_LUNG', 'KYSE410_OESOPHAGUS', 'SNU475_LIVER'}],
#  'TBC1D10C': [3, {'DMS114_LUNG', 'MKN7_STOMACH', 'SNU475_LIVER'}],
#  'TBX10': [3, {'DMS114_LUNG', 'MKN7_STOMACH', 'SNU475_LIVER'}],
#  'TMEM134': [3, {'DMS114_LUNG', 'MKN7_STOMACH', 'SNU475_LIVER'}],
#  'GBAT2': [3,
#   {'DMS273_LUNG',
#    'KARPAS299_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE',
#    'MFE280_ENDOMETRIUM'}],
#  'PI4KB': [3,
#   {'DMS273_LUNG',
#    'KARPAS299_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE',
#    'MFE280_ENDOMETRIUM'}],
#  'PSMB4': [3,
#   {'DMS273_LUNG',
#    'KARPAS299_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE',
#    'MFE280_ENDOMETRIUM'}],
#  'PSMD4': [3,
#   {'DMS273_LUNG',
#    'KARPAS299_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE',
#    'MFE280_ENDOMETRIUM'}],
#  'RFX5': [3,
#   {'DMS273_LUNG',
#    'KARPAS299_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE',
#    'MFE280_ENDOMETRIUM'}],
#  'SELENBP1': [3,
#   {'DMS273_LUNG',
#    'KARPAS299_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE',
#    'MFE280_ENDOMETRIUM'}],
#  'ZNF687': [3,
#   {'DMS273_LUNG',
#    'KARPAS299_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE',
#    'MFE280_ENDOMETRIUM'}],
#  'ZNF687-AS1': [3,
#   {'DMS273_LUNG',
#    'KARPAS299_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE',
#    'MFE280_ENDOMETRIUM'}],
#  'VIPR2': [3, {'DMS273_LUNG', 'HGC27_STOMACH', 'MKN7_STOMACH'}],
#  'BCAT1': [3, {'DMS53_LUNG', 'KLE_ENDOMETRIUM', 'MKN1_STOMACH'}],
#  'BAZ1A': [3, {'EBC1_LUNG', 'NCIH2029_LUNG', 'NCIH661_LUNG'}],
#  'BRMS1L': [3, {'EBC1_LUNG', 'NCIH2029_LUNG', 'NCIH661_LUNG'}],
#  'CFL2': [3, {'EBC1_LUNG', 'NCIH2029_LUNG', 'NCIH661_LUNG'}],
#  'EAPP': [3, {'EBC1_LUNG', 'NCIH2029_LUNG', 'NCIH661_LUNG'}],
#  'INSM2': [3, {'EBC1_LUNG', 'NCIH2029_LUNG', 'NCIH661_LUNG'}],
#  'MBIP': [3, {'EBC1_LUNG', 'NCIH2029_LUNG', 'NCIH661_LUNG'}],
#  'NFKBIA': [3, {'EBC1_LUNG', 'NCIH2029_LUNG', 'NCIH661_LUNG'}],
#  'NKX2-1': [3, {'EBC1_LUNG', 'NCIH2029_LUNG', 'NCIH661_LUNG'}],
#  'NKX2-1-AS1': [3, {'EBC1_LUNG', 'NCIH2029_LUNG', 'NCIH661_LUNG'}],
#  'PPP2R3C': [3, {'EBC1_LUNG', 'NCIH2029_LUNG', 'NCIH661_LUNG'}],
#  'PRORP': [3, {'EBC1_LUNG', 'NCIH2029_LUNG', 'NCIH661_LUNG'}],
#  'PSMA6': [3, {'EBC1_LUNG', 'NCIH2029_LUNG', 'NCIH661_LUNG'}],
#  'PTCSC3': [3, {'EBC1_LUNG', 'NCIH2029_LUNG', 'NCIH661_LUNG'}],
#  'RALGAPA1': [3, {'EBC1_LUNG', 'NCIH2029_LUNG', 'NCIH661_LUNG'}],
#  'SFTA3': [3, {'EBC1_LUNG', 'NCIH2029_LUNG', 'NCIH661_LUNG'}],
#  'SNORA101B': [3, {'EBC1_LUNG', 'NCIH2029_LUNG', 'NCIH661_LUNG'}],
#  'SNX6': [3, {'EBC1_LUNG', 'NCIH2029_LUNG', 'NCIH661_LUNG'}],
#  'SPTSSA': [3, {'EBC1_LUNG', 'NCIH2029_LUNG', 'NCIH661_LUNG'}],
#  'MTDH': [3, {'EFM192A_BREAST', 'HCC1419_BREAST', 'NCIH446_LUNG'}],
#  'EXT1': [3, {'EFM192A_BREAST', 'HCC1419_BREAST', 'HCC1954_BREAST'}],
#  'FABP5': [3, {'EFM192A_BREAST', 'HCC1419_BREAST', 'HCC827_LUNG'}],
#  'PAG1': [3, {'EFM192A_BREAST', 'HCC1419_BREAST', 'HCC827_LUNG'}],
#  'PMP2': [3, {'EFM192A_BREAST', 'HCC1419_BREAST', 'HCC827_LUNG'}],
#  'SNORD168': [3, {'EFM192A_BREAST', 'HCC1419_BREAST', 'HCC1954_BREAST'}],
#  'DUPD1': [3, {'EFM19_BREAST', 'MFE280_ENDOMETRIUM', 'PC3_PROSTATE'}],
#  'KAT6B': [3, {'EFM19_BREAST', 'MFE280_ENDOMETRIUM', 'PC3_PROSTATE'}],
#  'SNORD172': [3, {'EFM19_BREAST', 'MFE280_ENDOMETRIUM', 'PC3_PROSTATE'}],
#  'BIRC2': [3, {'ES2_OVARY', 'KYSE410_OESOPHAGUS', 'TE1_OESOPHAGUS'}],
#  'BIRC3': [3, {'ES2_OVARY', 'KYSE410_OESOPHAGUS', 'TE1_OESOPHAGUS'}],
#  'CFAP300': [3, {'ES2_OVARY', 'KYSE410_OESOPHAGUS', 'TE1_OESOPHAGUS'}],
#  'DCUN1D5': [3, {'ES2_OVARY', 'KYSE410_OESOPHAGUS', 'TE1_OESOPHAGUS'}],
#  'DYNC2H1': [3, {'ES2_OVARY', 'KYSE410_OESOPHAGUS', 'TE1_OESOPHAGUS'}],
#  'FGFR3': [3, {'ES2_OVARY', 'RMGI_OVARY', 'RT112_URINARY_TRACT'}],
#  'MMP7': [3, {'ES2_OVARY', 'KYSE410_OESOPHAGUS', 'TE1_OESOPHAGUS'}],
#  'TMEM123': [3, {'ES2_OVARY', 'KYSE410_OESOPHAGUS', 'TE1_OESOPHAGUS'}],
#  'YAP1': [3, {'ES2_OVARY', 'KYSE410_OESOPHAGUS', 'TE1_OESOPHAGUS'}],
#  'C19orf12': [3, {'FUOV1_OVARY', 'HCC1569_BREAST', 'MKN7_STOMACH'}],
#  'CCNE1': [3, {'FUOV1_OVARY', 'HCC1569_BREAST', 'MKN7_STOMACH'}],
#  'URI1': [3, {'FUOV1_OVARY', 'HCC1569_BREAST', 'MKN7_STOMACH'}],
#  'BRD9': [3,
#   {'GI1_CENTRAL_NERVOUS_SYSTEM', 'HCC1954_BREAST', 'NCIH1437_LUNG'}],
#  'CEP72': [3,
#   {'GI1_CENTRAL_NERVOUS_SYSTEM', 'HCC1954_BREAST', 'NCIH1437_LUNG'}],
#  'CLPTM1L': [3,
#   {'GI1_CENTRAL_NERVOUS_SYSTEM', 'HCC1954_BREAST', 'NCIH1437_LUNG'}],
#  'CTD-2194D22.4': [3,
#   {'GI1_CENTRAL_NERVOUS_SYSTEM', 'HCC1954_BREAST', 'NCIH1437_LUNG'}],
#  'CTD-3080P12.3': [3,
#   {'GI1_CENTRAL_NERVOUS_SYSTEM', 'HCC1954_BREAST', 'NCIH1437_LUNG'}],
#  'IRX4': [3,
#   {'GI1_CENTRAL_NERVOUS_SYSTEM', 'HCC1954_BREAST', 'NCIH1437_LUNG'}],
#  'MRPL36': [3,
#   {'GI1_CENTRAL_NERVOUS_SYSTEM', 'HCC1954_BREAST', 'NCIH1437_LUNG'}],
#  'NDUFS6': [3,
#   {'GI1_CENTRAL_NERVOUS_SYSTEM', 'HCC1954_BREAST', 'NCIH1437_LUNG'}],
#  'NKD2': [3,
#   {'GI1_CENTRAL_NERVOUS_SYSTEM', 'HCC1954_BREAST', 'NCIH1437_LUNG'}],
#  'SDHAP3': [3,
#   {'GI1_CENTRAL_NERVOUS_SYSTEM', 'HCC1954_BREAST', 'NCIH1437_LUNG'}],
#  'SLC12A7': [3,
#   {'GI1_CENTRAL_NERVOUS_SYSTEM', 'HCC1954_BREAST', 'NCIH1437_LUNG'}],
#  'SLC6A18': [3,
#   {'GI1_CENTRAL_NERVOUS_SYSTEM', 'HCC1954_BREAST', 'NCIH1437_LUNG'}],
#  'SLC6A19': [3,
#   {'GI1_CENTRAL_NERVOUS_SYSTEM', 'HCC1954_BREAST', 'NCIH1437_LUNG'}],
#  'TERT': [3,
#   {'GI1_CENTRAL_NERVOUS_SYSTEM', 'HCC1954_BREAST', 'NCIH1437_LUNG'}],
#  'TRIP13': [3,
#   {'GI1_CENTRAL_NERVOUS_SYSTEM', 'HCC1954_BREAST', 'NCIH1437_LUNG'}],
#  'ZDHHC11': [3,
#   {'GI1_CENTRAL_NERVOUS_SYSTEM', 'HCC1954_BREAST', 'NCIH1437_LUNG'}],
#  'OXR1': [3, {'HCC1419_BREAST', 'HCC1954_BREAST', 'NCIH510_LUNG'}],
#  'ATP5F1E': [3, {'HCC1419_BREAST', 'HCC1954_BREAST', 'UACC893_BREAST'}],
#  'CTSZ': [3, {'HCC1419_BREAST', 'HCC1954_BREAST', 'UACC893_BREAST'}],
#  'EDN3': [3, {'HCC1419_BREAST', 'HCC1954_BREAST', 'UACC893_BREAST'}],
#  'GNAS': [3, {'HCC1419_BREAST', 'HCC1954_BREAST', 'UACC893_BREAST'}],
#  'GNAS-AS1': [3, {'HCC1419_BREAST', 'HCC1954_BREAST', 'UACC893_BREAST'}],
#  'NELFCD': [3, {'HCC1419_BREAST', 'HCC1954_BREAST', 'UACC893_BREAST'}],
#  'PRELID3B': [3, {'HCC1419_BREAST', 'HCC1954_BREAST', 'UACC893_BREAST'}],
#  'SLMO2-ATP5E': [3, {'HCC1419_BREAST', 'HCC1954_BREAST', 'UACC893_BREAST'}],
#  'TUBB1': [3, {'HCC1419_BREAST', 'HCC1954_BREAST', 'UACC893_BREAST'}],
#  'ZNF831': [3, {'HCC1419_BREAST', 'HCC1954_BREAST', 'UACC893_BREAST'}],
#  'CTPS1': [3, {'HCC2157_BREAST', 'NCIH1184_LUNG', 'NCIH1836_LUNG'}],
#  'SLFNL1-AS1': [3, {'HCC2157_BREAST', 'NCIH1184_LUNG', 'NCIH1836_LUNG'}],
#  'EGFR': [3, {'HCC827_LUNG', 'KYSE520_OESOPHAGUS', 'NCIH3255_LUNG'}],
#  'EGFR-AS1': [3, {'HCC827_LUNG', 'KYSE520_OESOPHAGUS', 'NCIH3255_LUNG'}],
#  'SEC61G': [3, {'HCC827_LUNG', 'KYSE520_OESOPHAGUS', 'NCIH3255_LUNG'}],
#  'VSTM2A': [3, {'HCC827_LUNG', 'KYSE520_OESOPHAGUS', 'NCIH3255_LUNG'}],
#  'VSTM2A-OT1': [3, {'HCC827_LUNG', 'KYSE520_OESOPHAGUS', 'NCIH3255_LUNG'}],
#  'POM121L12': [3,
#   {'KYSE30_OESOPHAGUS', 'KYSE520_OESOPHAGUS', 'NCIH3255_LUNG'}],
#  'C11orf80': [3, {'KYSE410_OESOPHAGUS', 'SNU475_LIVER', 'TE11_OESOPHAGUS'}],
#  'SPTBN2': [3, {'KYSE410_OESOPHAGUS', 'SNU475_LIVER', 'TE11_OESOPHAGUS'}],
#  'AAMDC': [3, {'MDAMB134VI_BREAST', 'MDAMB175VII_BREAST', 'NCIH1435_LUNG'}],
#  'ACER3': [3, {'MDAMB134VI_BREAST', 'MDAMB175VII_BREAST', 'NCIH1435_LUNG'}],
#  'ALG8': [3, {'MDAMB134VI_BREAST', 'MDAMB175VII_BREAST', 'NCIH1435_LUNG'}],
#  'AQP11': [3, {'MDAMB134VI_BREAST', 'MDAMB175VII_BREAST', 'NCIH1435_LUNG'}],
#  'CLNS1A': [3, {'MDAMB134VI_BREAST', 'MDAMB175VII_BREAST', 'NCIH1435_LUNG'}],
#  'GUCY2EP': [3, {'MDAMB134VI_BREAST', 'MDAMB175VII_BREAST', 'NCIH1435_LUNG'}],
#  'INTS4': [3, {'MDAMB134VI_BREAST', 'MDAMB175VII_BREAST', 'NCIH1435_LUNG'}],
#  'KCTD14': [3, {'MDAMB134VI_BREAST', 'MDAMB175VII_BREAST', 'NCIH1435_LUNG'}],
#  'KCTD21-AS1': [3,
#   {'MDAMB134VI_BREAST', 'MDAMB175VII_BREAST', 'NCIH1435_LUNG'}],
#  'NDUFC2': [3, {'MDAMB134VI_BREAST', 'MDAMB175VII_BREAST', 'NCIH1435_LUNG'}],
#  'NDUFC2-KCTD14': [3,
#   {'MDAMB134VI_BREAST', 'MDAMB175VII_BREAST', 'NCIH1435_LUNG'}],
#  'PAK1': [3, {'MDAMB134VI_BREAST', 'MDAMB175VII_BREAST', 'NCIH1435_LUNG'}],
#  'RSF1': [3, {'MDAMB134VI_BREAST', 'MDAMB175VII_BREAST', 'NCIH1435_LUNG'}],
#  'THRSP': [3, {'MDAMB134VI_BREAST', 'MDAMB175VII_BREAST', 'NCIH1435_LUNG'}],
#  'TSKU': [3, {'MDAMB134VI_BREAST', 'MDAMB175VII_BREAST', 'NCIH1435_LUNG'}],
#  'CASC3': [3, {'MFE280_ENDOMETRIUM', 'UACC812_BREAST', 'UACC893_BREAST'}],
#  'MSL1': [3, {'MFE280_ENDOMETRIUM', 'UACC812_BREAST', 'UACC893_BREAST'}],
#  'NR1D1': [3, {'MFE280_ENDOMETRIUM', 'UACC812_BREAST', 'UACC893_BREAST'}],
#  'DDX11': [3, {'MKN1_STOMACH', 'SNU475_LIVER', 'SW900_LUNG'}],
#  'DDX11-AS1': [3, {'MKN1_STOMACH', 'SNU475_LIVER', 'SW900_LUNG'}],
#  'OVOS2': [3, {'MKN1_STOMACH', 'SNU475_LIVER', 'SW900_LUNG'}],
#  'AKIRIN1': [3, {'NCIH1184_LUNG', 'NCIH520_LUNG', 'NCIH889_LUNG'}],
#  'C1orf109': [3, {'NCIH1184_LUNG', 'NCIH1836_LUNG', 'NCIH2122_LUNG'}],
#  'CDCA8': [3, {'NCIH1184_LUNG', 'NCIH1836_LUNG', 'NCIH2122_LUNG'}],
#  'KCNQ4': [3,
#   {'NCIH1184_LUNG',
#    'NCIH1836_LUNG',
#    'THP1_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE'}],
#  'MYCBP': [3, {'NCIH1184_LUNG', 'NCIH520_LUNG', 'NCIH889_LUNG'}],
#  'NDUFS5': [3, {'NCIH1184_LUNG', 'NCIH520_LUNG', 'NCIH889_LUNG'}],
#  'RHBDL2': [3, {'NCIH1184_LUNG', 'NCIH520_LUNG', 'NCIH889_LUNG'}],
#  'RRAGC': [3, {'NCIH1184_LUNG', 'NCIH520_LUNG', 'NCIH889_LUNG'}],
#  'CHIC2': [3,
#   {'NCIH1703_LUNG',
#    'SW1783_CENTRAL_NERVOUS_SYSTEM',
#    'U251MG_CENTRAL_NERVOUS_SYSTEM'}],
#  'GSX2': [3,
#   {'NCIH1703_LUNG',
#    'SW1783_CENTRAL_NERVOUS_SYSTEM',
#    'U251MG_CENTRAL_NERVOUS_SYSTEM'}],
#  'PDGFRA': [3,
#   {'NCIH1703_LUNG',
#    'SW1783_CENTRAL_NERVOUS_SYSTEM',
#    'U251MG_CENTRAL_NERVOUS_SYSTEM'}],
#  'RPL21P44': [3,
#   {'NCIH1703_LUNG',
#    'SW1783_CENTRAL_NERVOUS_SYSTEM',
#    'U251MG_CENTRAL_NERVOUS_SYSTEM'}],
#  'CDC6': [3, {'NCIH2170_LUNG', 'UACC812_BREAST', 'UACC893_BREAST'}],
#  'RAPGEFL1': [3, {'NCIH2170_LUNG', 'UACC812_BREAST', 'UACC893_BREAST'}],
#  'RARA': [3, {'NCIH2170_LUNG', 'UACC812_BREAST', 'UACC893_BREAST'}],
#  'WIPF2': [3, {'NCIH2170_LUNG', 'UACC812_BREAST', 'UACC893_BREAST'}],
#  'CASC15': [2, {'5637_URINARY_TRACT', 'HT1376_URINARY_TRACT'}],
#  'CDKAL1': [2, {'5637_URINARY_TRACT', 'HT1376_URINARY_TRACT'}],
#  'E2F3': [2, {'5637_URINARY_TRACT', 'HT1376_URINARY_TRACT'}],
#  'HDGFL1': [2, {'5637_URINARY_TRACT', 'HT1376_URINARY_TRACT'}],
#  'NBAT1': [2, {'5637_URINARY_TRACT', 'HT1376_URINARY_TRACT'}],
#  'PRL': [2, {'5637_URINARY_TRACT', 'HT1376_URINARY_TRACT'}],
#  'SOX4': [2, {'5637_URINARY_TRACT', 'HT1376_URINARY_TRACT'}],
#  'SYN2': [2, {'5637_URINARY_TRACT', 'OAW42_OVARY'}],
#  'TIMP4': [2, {'5637_URINARY_TRACT', 'OAW42_OVARY'}],
#  'AHCY': [2, {'8305C_THYROID', 'FUOV1_OVARY'}],
#  'DUSP26': [2, {'8305C_THYROID', 'SUIT2_PANCREAS'}],
#  'DYNLRB1': [2, {'8305C_THYROID', 'FUOV1_OVARY'}],
#  'FUT10': [2, {'8305C_THYROID', 'SUIT2_PANCREAS'}],
#  'ITCH': [2, {'8305C_THYROID', 'FUOV1_OVARY'}],
#  'MAK16': [2, {'8305C_THYROID', 'SUIT2_PANCREAS'}],
#  'MAP1LC3A': [2, {'8305C_THYROID', 'FUOV1_OVARY'}],
#  'RNF122': [2, {'8305C_THYROID', 'SUIT2_PANCREAS'}],
#  'SNORD13': [2, {'8305C_THYROID', 'SUIT2_PANCREAS'}],
#  'TTI2': [2, {'8305C_THYROID', 'SUIT2_PANCREAS'}],
#  'TFRC': [2, {'A3KAW_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE', 'FUOV1_OVARY'}],
#  'ELOC': [2, {'AU565_BREAST', 'HCC827_LUNG'}],
#  'GDAP1': [2, {'AU565_BREAST', 'HCC827_LUNG'}],
#  'JPH1': [2, {'AU565_BREAST', 'HCC827_LUNG'}],
#  'LY96': [2, {'AU565_BREAST', 'HCC827_LUNG'}],
#  'MRPS28': [2, {'AU565_BREAST', 'HCC827_LUNG'}],
#  'OSGIN2': [2, {'AU565_BREAST', 'HCC1419_BREAST'}],
#  'RDH10': [2, {'AU565_BREAST', 'HCC827_LUNG'}],
#  'RDH10-AS1': [2, {'AU565_BREAST', 'HCC827_LUNG'}],
#  'RIPK2': [2, {'AU565_BREAST', 'HCC1419_BREAST'}],
#  'RPL7': [2, {'AU565_BREAST', 'HCC827_LUNG'}],
#  'STAU2': [2, {'AU565_BREAST', 'HCC827_LUNG'}],
#  'STAU2-AS1': [2, {'AU565_BREAST', 'HCC827_LUNG'}],
#  'TMEM70': [2, {'AU565_BREAST', 'HCC827_LUNG'}],
#  'TPD52': [2, {'AU565_BREAST', 'HCC827_LUNG'}],
#  'UBE2W': [2, {'AU565_BREAST', 'HCC827_LUNG'}],
#  'MDFIC': [2, {'AU565_BREAST', 'MKN45_STOMACH'}],
#  'FZD8': [2, {'BT20_BREAST', 'PC3_PROSTATE'}],
#  'GJD4': [2, {'BT20_BREAST', 'PC3_PROSTATE'}],
#  'PCAT5': [2, {'BT20_BREAST', 'PC3_PROSTATE'}],
#  'ADNP': [2, {'BT474_BREAST', 'HCC1419_BREAST'}],
#  'ATP9A': [2, {'BT474_BREAST', 'EFM192A_BREAST'}],
#  'AURKA': [2, {'BT474_BREAST', 'UACC893_BREAST'}],
#  'C20orf85': [2, {'BT474_BREAST', 'UACC893_BREAST'}],
#  'CASS4': [2, {'BT474_BREAST', 'UACC893_BREAST'}],
#  'CBLN4': [2, {'BT474_BREAST', 'UACC893_BREAST'}],
#  'CSTF1': [2, {'BT474_BREAST', 'UACC893_BREAST'}],
#  'CTCFL': [2, {'BT474_BREAST', 'UACC893_BREAST'}],
#  'FAM209A': [2, {'BT474_BREAST', 'UACC893_BREAST'}],
#  'FAM209B': [2, {'BT474_BREAST', 'UACC893_BREAST'}],
#  'FAM210B': [2, {'BT474_BREAST', 'UACC893_BREAST'}],
#  'GCNT7': [2, {'BT474_BREAST', 'UACC893_BREAST'}],
#  'KCNS1': [2, {'BT474_BREAST', 'HCC1569_BREAST'}],
#  'MC3R': [2, {'BT474_BREAST', 'UACC893_BREAST'}],
#  'MTRNR2L3': [2, {'BT474_BREAST', 'UACC893_BREAST'}],
#  'NFATC2': [2, {'BT474_BREAST', 'EFM192A_BREAST'}],
#  'NKILA': [2, {'BT474_BREAST', 'UACC893_BREAST'}],
# ...
#  'TMEM64': [2, {'EFM192A_BREAST', 'HCC1419_BREAST'}],
#  'UTP23': [2, {'EFM192A_BREAST', 'HCC1954_BREAST'}],
#  'KCNV1': [2, {'EFM192A_BREAST', 'HCC1954_BREAST'}],
#  'ADK': [2, {'EFM19_BREAST', 'PC3_PROSTATE'}],
#  'AGAP5': [2, {'EFM19_BREAST', 'PC3_PROSTATE'}],
#  'AP3M1': [2, {'EFM19_BREAST', 'PC3_PROSTATE'}],
#  'BMS1P4': [2, {'EFM19_BREAST', 'PC3_PROSTATE'}],
#  'BMS1P4-AGAP5': [2, {'EFM19_BREAST', 'PC3_PROSTATE'}],
#  'C10orf55': [2, {'EFM19_BREAST', 'PC3_PROSTATE'}],
#  'CAMK2G': [2, {'EFM19_BREAST', 'PC3_PROSTATE'}],
#  'CHCHD1': [2, {'EFM19_BREAST', 'PC3_PROSTATE'}],
#  'COMTD1': [2, {'EFM19_BREAST', 'PC3_PROSTATE'}],
#  'DUSP13': [2, {'EFM19_BREAST', 'PC3_PROSTATE'}],
#  'FUT11': [2, {'EFM19_BREAST', 'PC3_PROSTATE'}],
#  'GLUD1P3': [2, {'EFM19_BREAST', 'PC3_PROSTATE'}],
#  'LRMDA': [2, {'EFM19_BREAST', 'PC3_PROSTATE'}],
#  'MYOZ1': [2, {'EFM19_BREAST', 'PC3_PROSTATE'}],
#  'NDST2': [2, {'EFM19_BREAST', 'PC3_PROSTATE'}],
#  'PLAU': [2, {'EFM19_BREAST', 'PC3_PROSTATE'}],
#  'SAMD8': [2, {'EFM19_BREAST', 'PC3_PROSTATE'}],
#  'SEC24C': [2, {'EFM19_BREAST', 'PC3_PROSTATE'}],
#  'SYNPO2L': [2, {'EFM19_BREAST', 'PC3_PROSTATE'}],
#  'VCL': [2, {'EFM19_BREAST', 'PC3_PROSTATE'}],
#  'VDAC2': [2, {'EFM19_BREAST', 'PC3_PROSTATE'}],
#  'ZNF503': [2, {'EFM19_BREAST', 'PC3_PROSTATE'}],
#  'ZNF503-AS1': [2, {'EFM19_BREAST', 'PC3_PROSTATE'}],
#  'ZNF503-AS2': [2, {'EFM19_BREAST', 'PC3_PROSTATE'}],
#  'ZSWIM8': [2, {'EFM19_BREAST', 'PC3_PROSTATE'}],
#  'ZSWIM8-AS1': [2, {'EFM19_BREAST', 'PC3_PROSTATE'}],
#  'ANGPTL5': [2, {'ES2_OVARY', 'TE1_OESOPHAGUS'}],
#  'ARHGAP42': [2, {'ES2_OVARY', 'TE1_OESOPHAGUS'}],
#  'CEP126': [2, {'ES2_OVARY', 'TE1_OESOPHAGUS'}],
#  'MMP1': [2, {'ES2_OVARY', 'TE1_OESOPHAGUS'}],
#  'MMP10': [2, {'ES2_OVARY', 'TE1_OESOPHAGUS'}],
#  'MMP12': [2, {'ES2_OVARY', 'TE1_OESOPHAGUS'}],
#  'MMP13': [2, {'ES2_OVARY', 'TE1_OESOPHAGUS'}],
#  'MMP20': [2, {'ES2_OVARY', 'TE1_OESOPHAGUS'}],
#  'MMP27': [2, {'ES2_OVARY', 'TE1_OESOPHAGUS'}],
#  'MMP3': [2, {'ES2_OVARY', 'TE1_OESOPHAGUS'}],
#  'MMP8': [2, {'ES2_OVARY', 'TE1_OESOPHAGUS'}],
#  'PGR': [2, {'ES2_OVARY', 'TE1_OESOPHAGUS'}],
#  'PGR-AS1': [2, {'ES2_OVARY', 'TE1_OESOPHAGUS'}],
#  'SNORD13I': [2, {'ES2_OVARY', 'TE1_OESOPHAGUS'}],
#  'TRPC6': [2, {'ES2_OVARY', 'TE1_OESOPHAGUS'}],
#  'WTAPP1': [2, {'ES2_OVARY', 'TE1_OESOPHAGUS'}],
#  'PLEKHF1': [2, {'FUOV1_OVARY', 'HCC1569_BREAST'}],
#  'POP4': [2, {'FUOV1_OVARY', 'HCC1569_BREAST'}],
#  'VSTM2B': [2, {'FUOV1_OVARY', 'HCC1569_BREAST'}],
#  'CASKIN2': [2, {'FUOV1_OVARY', 'UACC893_BREAST'}],
#  'FGFR4': [2, {'FUOV1_OVARY', 'HCC1954_BREAST'}],
#  'HK3': [2, {'FUOV1_OVARY', 'HCC1954_BREAST'}],
#  'LLGL2': [2, {'FUOV1_OVARY', 'UACC893_BREAST'}],
#  'MUC4': [2, {'FUOV1_OVARY', 'MDAMB453_BREAST'}],
#  'MYO15B': [2, {'FUOV1_OVARY', 'UACC893_BREAST'}],
#  'NSD1': [2, {'FUOV1_OVARY', 'HCC1954_BREAST'}],
#  'RECQL5': [2, {'FUOV1_OVARY', 'UACC893_BREAST'}],
#  'SAP30BP': [2, {'FUOV1_OVARY', 'UACC893_BREAST'}],
#  'SDHAP1': [2, {'FUOV1_OVARY', 'MDAMB453_BREAST'}],
#  'SMIM5': [2, {'FUOV1_OVARY', 'UACC893_BREAST'}],
#  'SMIM6': [2, {'FUOV1_OVARY', 'UACC893_BREAST'}],
#  'TNK2': [2, {'FUOV1_OVARY', 'MDAMB453_BREAST'}],
#  'TNK2-AS1': [2, {'FUOV1_OVARY', 'MDAMB453_BREAST'}],
#  'TSEN54': [2, {'FUOV1_OVARY', 'UACC893_BREAST'}],
#  'UIMC1': [2, {'FUOV1_OVARY', 'HCC1954_BREAST'}],
#  'UNC5A': [2, {'FUOV1_OVARY', 'HCC1954_BREAST'}],
#  'ZNF346': [2, {'FUOV1_OVARY', 'HCC1954_BREAST'}],
#  'GRHL2': [2, {'GCIY_STOMACH', 'MCF7_BREAST'}],
#  'ODF1': [2, {'GCIY_STOMACH', 'TE5_OESOPHAGUS'}],
#  'SLC9A3': [2, {'GI1_CENTRAL_NERVOUS_SYSTEM', 'HCC1954_BREAST'}],
#  'ABRA': [2, {'HCC1419_BREAST', 'HCC1954_BREAST'}],
#  'DPYS': [2, {'HCC1419_BREAST', 'NCIH510_LUNG'}],
#  'LRP12': [2, {'HCC1419_BREAST', 'NCIH510_LUNG'}],
#  'OSR2': [2, {'HCC1419_BREAST', 'HCC1954_BREAST'}],
#  'VPS13B': [2, {'HCC1419_BREAST', 'HCC1954_BREAST'}],
#  'ZFPM2': [2, {'HCC1419_BREAST', 'NCIH510_LUNG'}],
#  'ABHD16B': [2, {'HCC1419_BREAST', 'JHOS2_OVARY'}],
#  'B4GALT5': [2, {'HCC1419_BREAST', 'MKN1_STOMACH'}],
#  'DNAJC5': [2, {'HCC1419_BREAST', 'JHOS2_OVARY'}],
#  'PTGIS': [2, {'HCC1419_BREAST', 'MKN1_STOMACH'}],
#  'RTEL1': [2, {'HCC1419_BREAST', 'MCF7_BREAST'}],
#  'RTEL1-TNFRSF6B': [2, {'HCC1419_BREAST', 'MCF7_BREAST'}],
#  'SLCO4A1-AS1': [2, {'HCC1419_BREAST', 'UACC893_BREAST'}],
#  'TPD52L2': [2, {'HCC1419_BREAST', 'JHOS2_OVARY'}],
#  'C20orf197': [2, {'HCC1954_BREAST', 'UACC893_BREAST'}],
#  'CDH26': [2, {'HCC1954_BREAST', 'UACC893_BREAST'}],
#  'CDH4': [2, {'HCC1954_BREAST', 'UACC893_BREAST'}],
#  'FAM217B': [2, {'HCC1954_BREAST', 'UACC893_BREAST'}],
#  'PHACTR3': [2, {'HCC1954_BREAST', 'UACC893_BREAST'}],
#  'PHACTR3-AS1': [2, {'HCC1954_BREAST', 'UACC893_BREAST'}],
#  'PPP1R3D': [2, {'HCC1954_BREAST', 'UACC893_BREAST'}],
#  'SYCP2': [2, {'HCC1954_BREAST', 'UACC893_BREAST'}],
#  'PPY2P': [2, {'HCC202_BREAST', 'KYSE410_OESOPHAGUS'}],
#  'PYY2': [2, {'HCC202_BREAST', 'KYSE410_OESOPHAGUS'}],
#  'SLFNL1': [2, {'HCC2157_BREAST', 'NCIH1836_LUNG'}],
#  'TTLL10': [2, {'HCC33_LUNG', 'SCLC21H_LUNG'}],
#  'APIP': [2, {'HCC95_LUNG', 'SNU16_STOMACH'}],
#  'CD44': [2, {'HCC95_LUNG', 'SNU16_STOMACH'}],
#  'FJX1': [2, {'HCC95_LUNG', 'SNU16_STOMACH'}],
#  'LDLRAD3': [2, {'HCC95_LUNG', 'SNU16_STOMACH'}],
#  'PAMR1': [2, {'HCC95_LUNG', 'SNU16_STOMACH'}],
#  'PDHX': [2, {'HCC95_LUNG', 'SNU16_STOMACH'}],
#  'SLC1A2': [2, {'HCC95_LUNG', 'SNU16_STOMACH'}],
#  'SNORD164': [2, {'HCC95_LUNG', 'SNU16_STOMACH'}],
#  'TRIM44': [2, {'HCC95_LUNG', 'SNU16_STOMACH'}],
#  'ASZ1': [2, {'HS746T_STOMACH', 'MKN45_STOMACH'}],
#  'CAPZA2': [2, {'HS746T_STOMACH', 'MKN45_STOMACH'}],
#  'CAV1': [2, {'HS746T_STOMACH', 'MKN45_STOMACH'}],
#  'CAV2': [2, {'HS746T_STOMACH', 'MKN45_STOMACH'}],
#  'CFTR': [2, {'HS746T_STOMACH', 'MKN45_STOMACH'}],
#  'CFTR-AS1': [2, {'HS746T_STOMACH', 'MKN45_STOMACH'}],
#  'MET': [2, {'HS746T_STOMACH', 'MKN45_STOMACH'}],
#  'ST7': [2, {'HS746T_STOMACH', 'MKN45_STOMACH'}],
#  'ST7-AS1': [2, {'HS746T_STOMACH', 'MKN45_STOMACH'}],
#  'ST7-AS2': [2, {'HS746T_STOMACH', 'MKN45_STOMACH'}],
#  'ST7-OT3': [2, {'HS746T_STOMACH', 'MKN45_STOMACH'}],
#  'ST7-OT4': [2, {'HS746T_STOMACH', 'MKN45_STOMACH'}],
#  'WNT2': [2, {'HS746T_STOMACH', 'MKN45_STOMACH'}],
#  'CGN': [2,
#   {'KARPAS299_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE', 'MFE280_ENDOMETRIUM'}],
#  'POGZ': [2,
#   {'KARPAS299_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE', 'MFE280_ENDOMETRIUM'}],
#  'TUFT1': [2,
#   {'KARPAS299_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE', 'MFE280_ENDOMETRIUM'}],
#  'FGFR2': [2, {'KATOIII_STOMACH', 'SNU16_STOMACH'}],
#  'PLPP4': [2, {'KATOIII_STOMACH', 'SNU16_STOMACH'}],
#  'RPL21': [2, {'KATOIII_STOMACH', 'SNU16_STOMACH'}],
#  'WDR11': [2, {'KATOIII_STOMACH', 'SNU16_STOMACH'}],
#  'WDR11-AS1': [2, {'KATOIII_STOMACH', 'SNU16_STOMACH'}],
#  'BHLHE41': [2, {'KLE_ENDOMETRIUM', 'MKN1_STOMACH'}],
#  'SSPN': [2, {'KLE_ENDOMETRIUM', 'MKN1_STOMACH'}],
#  'C11orf86': [2, {'KYSE410_OESOPHAGUS', 'SNU475_LIVER'}],
#  'LRFN4': [2, {'KYSE410_OESOPHAGUS', 'SNU475_LIVER'}],
#  'PC': [2, {'KYSE410_OESOPHAGUS', 'SNU475_LIVER'}],
#  'RCE1': [2, {'KYSE410_OESOPHAGUS', 'SNU475_LIVER'}],
#  'RHOD': [2, {'KYSE410_OESOPHAGUS', 'SNU475_LIVER'}],
#  'SYT12': [2, {'KYSE410_OESOPHAGUS', 'SNU475_LIVER'}],
#  'DGAT2': [2, {'KYSE410_OESOPHAGUS', 'MDAMB175VII_BREAST'}],
#  'SHANK2': [2, {'KYSE410_OESOPHAGUS', 'SNU475_LIVER'}],
#  'SHANK2-AS1': [2, {'KYSE410_OESOPHAGUS', 'SNU475_LIVER'}],
#  'UVRAG': [2, {'KYSE410_OESOPHAGUS', 'MDAMB175VII_BREAST'}],
#  'UVRAG-DT': [2, {'KYSE410_OESOPHAGUS', 'MDAMB175VII_BREAST'}],
#  'MYO18A': [2, {'KYSE410_OESOPHAGUS', 'OE19_OESOPHAGUS'}],
#  'PHF12': [2, {'KYSE410_OESOPHAGUS', 'OE19_OESOPHAGUS'}],
#  'PIPOX': [2, {'KYSE410_OESOPHAGUS', 'OE19_OESOPHAGUS'}],
#  'TIAF1': [2, {'KYSE410_OESOPHAGUS', 'OE19_OESOPHAGUS'}],
#  'COBL': [2, {'KYSE520_OESOPHAGUS', 'NCIH3255_LUNG'}],
#  'ELDR': [2, {'KYSE520_OESOPHAGUS', 'NCIH3255_LUNG'}],
#  'LANCL2': [2, {'KYSE520_OESOPHAGUS', 'NCIH3255_LUNG'}],
#  'TESC': [2, {'LU99_LUNG', 'NCIH1355_LUNG'}],
#  'TESC-AS1': [2, {'LU99_LUNG', 'NCIH1355_LUNG'}],
#  'B3GNT6': [2, {'MDAMB134VI_BREAST', 'MDAMB175VII_BREAST'}],
#  'CAPN5': [2, {'MDAMB134VI_BREAST', 'MDAMB175VII_BREAST'}],
#  'EMSY': [2, {'MDAMB134VI_BREAST', 'MDAMB175VII_BREAST'}],
#  'GDPD4': [2, {'MDAMB134VI_BREAST', 'MDAMB175VII_BREAST'}],
#  'GVQW3': [2, {'MDAMB134VI_BREAST', 'MDAMB175VII_BREAST'}],
#  'LRRC32': [2, {'MDAMB134VI_BREAST', 'MDAMB175VII_BREAST'}],
#  'MYO7A': [2, {'MDAMB134VI_BREAST', 'MDAMB175VII_BREAST'}],
#  'OMP': [2, {'MDAMB134VI_BREAST', 'MDAMB175VII_BREAST'}],
#  'THAP12': [2, {'MDAMB134VI_BREAST', 'MDAMB175VII_BREAST'}],
#  'WNT11': [2, {'MDAMB134VI_BREAST', 'MDAMB175VII_BREAST'}],
#  'GAB2': [2, {'MDAMB175VII_BREAST', 'NCIH1435_LUNG'}],
#  'KCTD21': [2, {'MDAMB175VII_BREAST', 'NCIH1435_LUNG'}],
#  'NARS2': [2, {'MDAMB175VII_BREAST', 'NCIH1435_LUNG'}],
#  'TENM4': [2, {'MDAMB175VII_BREAST', 'NCIH1435_LUNG'}],
#  'USP35': [2, {'MDAMB175VII_BREAST', 'NCIH1435_LUNG'}],
#  'CLRN1-AS1': [2, {'MFE280_ENDOMETRIUM', 'NCIH2066_LUNG'}],
#  'CCDC91': [2, {'MKN1_STOMACH', 'NCIH2171_LUNG'}],
#  'FAR2': [2, {'MKN1_STOMACH', 'NCIH2171_LUNG'}],
#  'TSPAN11': [2, {'MKN1_STOMACH', 'SW900_LUNG'}],
#  'DKK4': [2, {'MKN7_STOMACH', 'ZR751_BREAST'}],
#  'VDAC3': [2, {'MKN7_STOMACH', 'ZR751_BREAST'}],
#  'C1orf122': [2, {'NCIH1184_LUNG', 'NCIH2122_LUNG'}],
#  'MACF1': [2, {'NCIH1184_LUNG', 'NCIH520_LUNG'}],
#  'MANEAL': [2, {'NCIH1184_LUNG', 'NCIH2122_LUNG'}],
#  'YRDC': [2, {'NCIH1184_LUNG', 'NCIH2122_LUNG'}],
#  'LNX1': [2, {'NCIH1703_LUNG', 'U251MG_CENTRAL_NERVOUS_SYSTEM'}],
#  'LNX1-AS2': [2, {'NCIH1703_LUNG', 'U251MG_CENTRAL_NERVOUS_SYSTEM'}],
#  'MSRB3': [2, {'NCIH1792_LUNG', 'QGP1_PANCREAS'}],
#  'VAMP7': [2, {'NCIH1876_LUNG', 'OVCAR4_OVARY'}],
#  'AKAP6': [2, {'NCIH2029_LUNG', 'NCIH508_LARGE_INTESTINE'}],
#  'AP4S1': [2, {'NCIH2029_LUNG', 'NCIH508_LARGE_INTESTINE'}],
#  'ARHGAP5': [2, {'NCIH2029_LUNG', 'NCIH508_LARGE_INTESTINE'}],
#  'ARHGAP5-AS1': [2, {'NCIH2029_LUNG', 'NCIH508_LARGE_INTESTINE'}],
#  'BCL2L2': [2, {'NCIH2029_LUNG', 'NCIH82_LUNG'}],
#  'BCL2L2-PABPN1': [2, {'NCIH2029_LUNG', 'NCIH82_LUNG'}],
#  'CMTM5': [2, {'NCIH2029_LUNG', 'NCIH82_LUNG'}],
#  'DTD2': [2, {'NCIH2029_LUNG', 'NCIH508_LARGE_INTESTINE'}],
#  'EFS': [2, {'NCIH2029_LUNG', 'NCIH82_LUNG'}],
#  'GPR33': [2, {'NCIH2029_LUNG', 'NCIH508_LARGE_INTESTINE'}],
#  'HEATR5A': [2, {'NCIH2029_LUNG', 'NCIH508_LARGE_INTESTINE'}],
#  'HECTD1': [2, {'NCIH2029_LUNG', 'NCIH508_LARGE_INTESTINE'}],
#  'HOMEZ': [2, {'NCIH2029_LUNG', 'NCIH82_LUNG'}],
#  'IL25': [2, {'NCIH2029_LUNG', 'NCIH82_LUNG'}],
#  'MYH6': [2, {'NCIH2029_LUNG', 'NCIH82_LUNG'}],
#  'NUBPL': [2, {'NCIH2029_LUNG', 'NCIH508_LARGE_INTESTINE'}],
#  'PABPN1': [2, {'NCIH2029_LUNG', 'NCIH82_LUNG'}],
#  'PPP1R3E': [2, {'NCIH2029_LUNG', 'NCIH82_LUNG'}],
#  'RNF212B': [2, {'NCIH2029_LUNG', 'NCIH82_LUNG'}],
#  'SLC22A17': [2, {'NCIH2029_LUNG', 'NCIH82_LUNG'}],
#  'SLC7A7': [2, {'NCIH2029_LUNG', 'NCIH2171_LUNG'}],
#  'STRN3': [2, {'NCIH2029_LUNG', 'NCIH508_LARGE_INTESTINE'}],
#  'KDM4A': [2, {'NCIH510_LUNG', 'THP1_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE'}],
#  'KDM4A-AS1': [2, {'NCIH510_LUNG', 'THP1_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE'}],
#  'ST3GAL3': [2, {'NCIH510_LUNG', 'THP1_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE'}],
#  'ADSS2': [2, {'OVSAHO_OVARY', 'UACC812_BREAST'}],
#  'C1orf100': [2, {'OVSAHO_OVARY', 'UACC812_BREAST'}],
#  'CATSPERE': [2, {'OVSAHO_OVARY', 'UACC812_BREAST'}],
#  'ZBTB18': [2, {'OVSAHO_OVARY', 'UACC812_BREAST'}],
#  'ELAC2': [2, {'SNU182_LIVER', 'UACC812_BREAST'}],
#  'AMN1': [2, {'SNU475_LIVER', 'SW900_LUNG'}],
#  'DENND5B': [2, {'SNU475_LIVER', 'SW900_LUNG'}],
#  'DENND5B-AS1': [2, {'SNU475_LIVER', 'SW900_LUNG'}],
#  'ETFBKMT': [2, {'SNU475_LIVER', 'SW900_LUNG'}],
#  'FLJ13224': [2, {'SNU475_LIVER', 'SW900_LUNG'}],
#  'SINHCAF': [2, {'SNU475_LIVER', 'SW900_LUNG'}],
#  'ARPC4': [1, {'5637_URINARY_TRACT'}],
#  'ARPC4-TTLL3': [1, {'5637_URINARY_TRACT'}],
#  'ATG7': [1, {'5637_URINARY_TRACT'}],
#  'ATP2B2': [1, {'5637_URINARY_TRACT'}],
#  'ATP2B2-IT2': [1, {'5637_URINARY_TRACT'}],
#  'BRK1': [1, {'5637_URINARY_TRACT'}],
#  'BRPF1': [1, {'5637_URINARY_TRACT'}],
#  'CAMK1': [1, {'5637_URINARY_TRACT'}],
#  'CAND2': [1, {'5637_URINARY_TRACT'}],
#  'CIDEC': [1, {'5637_URINARY_TRACT'}],
#  'CIDECP1': [1, {'5637_URINARY_TRACT'}],
#  'CPNE9': [1, {'5637_URINARY_TRACT'}],
#  'CRELD1': [1, {'5637_URINARY_TRACT'}],
#  'EMC3': [1, {'5637_URINARY_TRACT'}],
#  'EMC3-AS1': [1, {'5637_URINARY_TRACT'}],
#  'FANCD2': [1, {'5637_URINARY_TRACT'}],
#  'FANCD2OS': [1, {'5637_URINARY_TRACT'}],
#  'FBLN2': [1, {'5637_URINARY_TRACT'}],
#  'FGD5P1': [1, {'5637_URINARY_TRACT'}],
#  'GHRL': [1, {'5637_URINARY_TRACT'}],
#  'GHRLOS': [1, {'5637_URINARY_TRACT'}],
#  'HDAC11': [1, {'5637_URINARY_TRACT'}],
#  'HDAC11-AS1': [1, {'5637_URINARY_TRACT'}],
#  'HRH1': [1, {'5637_URINARY_TRACT'}],
#  'IL17RC': [1, {'5637_URINARY_TRACT'}],
#  'IL17RE': [1, {'5637_URINARY_TRACT'}],
#  'IQSEC1': [1, {'5637_URINARY_TRACT'}],
#  'IRAK2': [1, {'5637_URINARY_TRACT'}],
#  'JAGN1': [1, {'5637_URINARY_TRACT'}],
#  'LHFPL4': [1, {'5637_URINARY_TRACT'}],
#  'MKRN2': [1, {'5637_URINARY_TRACT'}],
#  'MKRN2OS': [1, {'5637_URINARY_TRACT'}],
#  'MTMR14': [1, {'5637_URINARY_TRACT'}],
#  'NUP210': [1, {'5637_URINARY_TRACT'}],
#  'OGG1': [1, {'5637_URINARY_TRACT'}],
#  'PPARG': [1, {'5637_URINARY_TRACT'}],
#  'PRRT3': [1, {'5637_URINARY_TRACT'}],
#  'PRRT3-AS1': [1, {'5637_URINARY_TRACT'}],
#  'RAF1': [1, {'5637_URINARY_TRACT'}],
#  'RPL32': [1, {'5637_URINARY_TRACT'}],
#  'RPUSD3': [1, {'5637_URINARY_TRACT'}],
#  'SEC13': [1, {'5637_URINARY_TRACT'}],
#  'SETD5': [1, {'5637_URINARY_TRACT'}],
#  'SLC6A1': [1, {'5637_URINARY_TRACT'}],
#  'SLC6A1-AS1': [1, {'5637_URINARY_TRACT'}],
#  'SLC6A11': [1, {'5637_URINARY_TRACT'}],
#  'SNORA7A': [1, {'5637_URINARY_TRACT'}],
#  'SNORA93': [1, {'5637_URINARY_TRACT'}],
#  'SRGAP3': [1, {'5637_URINARY_TRACT'}],
#  'SRGAP3-AS2': [1, {'5637_URINARY_TRACT'}],
#  'SRGAP3-AS3': [1, {'5637_URINARY_TRACT'}],
#  'SRGAP3-AS4': [1, {'5637_URINARY_TRACT'}],
#  'TADA3': [1, {'5637_URINARY_TRACT'}],
#  'TAMM41': [1, {'5637_URINARY_TRACT'}],
#  'TATDN2': [1, {'5637_URINARY_TRACT'}],
#  'THUMPD3': [1, {'5637_URINARY_TRACT'}],
#  'THUMPD3-AS1': [1, {'5637_URINARY_TRACT'}],
#  'TMEM40': [1, {'5637_URINARY_TRACT'}],
#  'TPRXL': [1, {'5637_URINARY_TRACT'}],
#  'TSEN2': [1, {'5637_URINARY_TRACT'}],
#  'TTLL3': [1, {'5637_URINARY_TRACT'}],
#  'VGLL4': [1, {'5637_URINARY_TRACT'}],
#  'VHL': [1, {'5637_URINARY_TRACT'}],
#  'WNT7A': [1, {'5637_URINARY_TRACT'}],
#  'ATP6V1H': [1, {'59M_OVARY'}],
#  'LYN': [1, {'59M_OVARY'}],
#  'LYPLA1': [1, {'59M_OVARY'}],
#  'MRPL15': [1, {'59M_OVARY'}],
#  'NPBWR1': [1, {'59M_OVARY'}],
#  'OPRK1': [1, {'59M_OVARY'}],
#  'RB1CC1': [1, {'59M_OVARY'}],
#  'RGS20': [1, {'59M_OVARY'}],
#  'RNU105C': [1, {'59M_OVARY'}],
#  'RP1': [1, {'59M_OVARY'}],
#  'SBF1P1': [1, {'59M_OVARY'}],
#  'SNORA1B': [1, {'59M_OVARY'}],
#  'SOX17': [1, {'59M_OVARY'}],
#  'TCEA1': [1, {'59M_OVARY'}],
#  'TGS1': [1, {'59M_OVARY'}],
#  'TMEM68': [1, {'59M_OVARY'}],
#  'XKR4': [1, {'59M_OVARY'}],
#  'IGLL5': [1, {'A3KAW_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE'}],
#  'FSTL5': [1, {'ABC1_LUNG'}],
#  'ANGPT4': [1, {'ABC1_LUNG'}],
#  'C20orf202': [1, {'ABC1_LUNG'}],
#  'CSNK2A1': [1, {'ABC1_LUNG'}],
#  'FAM110A': [1, {'ABC1_LUNG'}],
#  'FKBP1A': [1, {'ABC1_LUNG'}],
#  'FKBP1A-SDCBP2': [1, {'ABC1_LUNG'}],
#  'NSFL1C': [1, {'ABC1_LUNG'}],
#  'PSMF1': [1, {'ABC1_LUNG'}],
#  'RAD21L1': [1, {'ABC1_LUNG'}],
#  'RSPO4': [1, {'ABC1_LUNG'}],
#  'SCRT2': [1, {'ABC1_LUNG'}],
#  'SDCBP2': [1, {'ABC1_LUNG'}],
#  'SDCBP2-AS1': [1, {'ABC1_LUNG'}],
#  'SIRPB2': [1, {'ABC1_LUNG'}],
#  'SIRPB3P': [1, {'ABC1_LUNG'}],
#  'SIRPD': [1, {'ABC1_LUNG'}],
#  'SIRPG': [1, {'ABC1_LUNG'}],
#  'SIRPG-AS1': [1, {'ABC1_LUNG'}],
#  'SLC52A3': [1, {'ABC1_LUNG'}],
#  'SNPH': [1, {'ABC1_LUNG'}],
#  'SRXN1': [1, {'ABC1_LUNG'}],
#  'TCF15': [1, {'ABC1_LUNG'}],
#  'TMEM74B': [1, {'ABC1_LUNG'}],
#  'ACAA1': [1, {'AU565_BREAST'}],
#  'DLEC1': [1, {'AU565_BREAST'}],
#  'MYD88': [1, {'AU565_BREAST'}],
#  'OXSR1': [1, {'AU565_BREAST'}],
#  'PLCD1': [1, {'AU565_BREAST'}],
#  'SLC22A13': [1, {'AU565_BREAST'}],
#  'SLC22A14': [1, {'AU565_BREAST'}],
#  'VILL': [1, {'AU565_BREAST'}],
#  'C8orf89': [1, {'AU565_BREAST'}],
#  'CASC9': [1, {'AU565_BREAST'}],
#  'CNBD1': [1, {'AU565_BREAST'}],
#  'DCAF4L2': [1, {'AU565_BREAST'}],
#  'HEY1': [1, {'AU565_BREAST'}],
#  'HNF4G': [1, {'AU565_BREAST'}],
#  'IL7': [1, {'AU565_BREAST'}],
#  'KCNB2': [1, {'AU565_BREAST'}],
#  'KRT33A': [1, {'AU565_BREAST'}],
#  'KRT33B': [1, {'AU565_BREAST'}],
#  'KRT34': [1, {'AU565_BREAST'}],
#  'KRTAP16-1': [1, {'AU565_BREAST'}],
#  ...}

# %% [markdown]
# ##### Top 400 Most Frequent Genes in ecDNA (genes with >= 3 ecDNA amplicons):

# %%
aa_gene_list = list(aa_gene_dict.keys())[0:400]
aa_gene_list
# Out:
# ['CASC11',
#  'MYC',
#  'PVT1',
#  'TMEM75',
#  'CASC21',
#  'CASC8',
#  'CCAT2',
#  'POU5F1B',
#  'CASC19',
#  'CCAT1',
#  'PCAT2',
#  'PRNCR1',
#  'ERBB2',
#  'PGAP3',
#  'GRB7',
#  'IKZF3',
#  'MIEN1',
#  'MYCL',
#  'TRIT1',
#  'PCAT1',
#  'PNMT',
#  'TCAP',
#  'BMP8B',
#  'HPCAL4',
#  'NT5C1A',
#  'OXCT2',
#  'PPIE',
#  'NEUROD2',
#  'PPP1R1B',
#  'STARD3',
#  'MYEOV',
#  'SMIM38',
#  'HEYL',
#  'MFSD2A',
#  'ANO1',
#  'CCND1',
#  'FGF19',
#  'FGF3',
#  'FGF4',
#  'LTO1',
#  'TPCN2',
#  'CAP1',
#  'PABPC4',
#  'PABPC4-AS1',
#  'PPIEL',
#  'RLF',
#  'SNORA55',
#  'ZPBP2',
#  'CTTN',
#  'FADD',
#  'MRGPRD',
#  'MRGPRF',
#  'MRGPRF-AS1',
#  'PPFIA1',
#  'COL9A2',
#  'OXCT2P1',
#  'PPT1',
#  'CDK12',
#  'FBXL20',
#  'MED1',
#  'ADGRA2',
#  'ADRB3',
#  'ASH2L',
#  'BRF2',
#  'EIF4EBP1',
#  'GOT1L1',
#  'PLPBP',
#  'RAB11FIP1',
#  'STAR',
#  'LRATD2',
#  'ZDHHC11B',
#  'TMCO2',
#  'ZMPSTE24',
#  'ERLIN2',
#  'ZNF703',
#  'BAG4',
#  'C8orf86',
#  'DDHD2',
#  'FGFR1',
#  'LETM2',
#  'LSM1',
#  'NSD3',
#  'PLPP5',
#  'IGHMBP2',
#  'MRPL21',
#  'BMP8A',
#  'SMAP2',
#  'TPPP',
#  'NDUFB9',
#  'TATDN1',
#  'FAM91A1',
#  'FER1L6',
#  'FER1L6-AS1',
#  'FER1L6-AS2',
#  'TBC1D31',
#  'ZNF704',
#  'CACNB1',
#  'GSDMA',
#  'GSDMB',
#  'LRRC3C',
#  'ORMDL3',
#  'PSMD3',
#  'RPL19',
#  'STAC2',
#  'RNF5P1',
#  'CPT1A',
#  'GAL',
#  'TESMIN',
#  'MUC20',
#  'ZFP69',
#  'ZFP69B',
#  'ZNF684',
#  'CASC1',
#  'ETFRF1',
#  'KRAS',
#  'LMNTD1',
#  'KIAA0754',
#  'MTSS1',
#  'NSMCE2',
#  'SQLE',
#  'TRIB1',
#  'WASHC5',
#  'ZNF572',
#  'ANXA13',
#  'ATAD2',
#  'C8orf76',
#  'DERL1',
#  'FAM83A',
#  'FAM83A-AS1',
#  'FBXO32',
#  'KLHL38',
#  'RNF139',
#  'RNF139-AS1',
#  'SAMD12',
#  'SAMD12-AS1',
#  'SMILR',
#  'TMEM65',
#  'TRMT12',
#  'WDYHV1',
#  'ZBTB10',
#  'ZHX1',
#  'ZHX1-C8orf76',
#  'ZHX2',
#  'NPEPL1',
#  'STX16',
#  'STX16-NPEPL1',
#  'ZNF217',
#  'ARL5C',
#  'ATP5MC1',
#  'CALCOCO2',
#  'CSF3',
#  'FBXO47',
#  'HOXB13',
#  'LRRC37A11P',
#  'MED24',
#  'PLXDC1',
#  'PRAC1',
#  'PRAC2',
#  'RDM1P5',
#  'SNORD124',
#  'THRA',
#  'TTLL6',
#  'UBE2Z',
#  'TACC1',
#  'SDHAP2',
#  'RASSF8',
#  'RASSF8-AS1',
#  'EXO5',
#  'CLCF1',
#  'POLD4',
#  'PPP6R3',
#  'C12orf77',
#  'LRMP',
#  'CCDC26',
#  'LPCAT1',
#  'SLC6A3',
#  'CITED4',
#  'GJA9',
#  'GJA9-MYCBP',
#  'CALB1',
#  'CCN3',
#  'COL14A1',
#  'COLEC10',
#  'CSMD3',
#  'DECR1',
#  'DEPTOR',
#  'DSCC1',
#  'ENPP2',
#  'HAS2',
#  'HAS2-AS1',
#  'MAL2',
#  'MAL2-AS1',
#  'MRPL13',
#  'MTBP',
#  'NBN',
#  'SNTB1',
#  'TAF2',
#  'TNFRSF11B',
#  'TRPS1',
#  'ADNP-AS1',
#  'ANKRD60',
#  'APCDD1L',
#  'APCDD1L-DT',
#  'BCAS1',
#  'BCAS4',
#  'BMP7',
#  'BMP7-AS1',
#  'CYP24A1',
#  'DOK5',
#  'DPM1',
#  'KCNG1',
#  'MOCS3',
#  'PARD6B',
#  'PFDN4',
#  'PPP4R1L',
#  'RAB22A',
#  'SUMO1P1',
#  'VAPB',
#  'B4GALNT2',
#  'C17orf98',
#  'CISD3',
#  'CWC25',
#  'GIP',
#  'HOXB6',
#  'HOXB7',
#  'HOXB8',
#  'HOXB9',
#  'IGF2BP1',
#  'LASP1',
#  'PCGF2',
#  'PIP4K2B',
#  'PSMB3',
#  'RPL23',
#  'SNF8',
#  'SNORA21',
#  'SNORA21B',
#  'ADAM18',
#  'ADAM32',
#  'ADAM9',
#  'HTRA4',
#  'PLEKHA2',
#  'SNORD38D',
#  'TM2D2',
#  'GDPD5',
#  'KLHL35',
#  'MAP6',
#  'MOGAT2',
#  'SERPINH1',
#  'NFYC',
#  'NFYC-AS1',
#  'RIMS3',
#  'CRACR2A',
#  'PARP11',
#  'THCAT155',
#  'TIGAR',
#  'UNC5D',
#  'AIP',
#  'ANKRD13D',
#  'C11orf72',
#  'CABP2',
#  'CABP4',
#  'CARNS1',
#  'CDK2AP2',
#  'CORO1B',
#  'DOC2GP',
#  'GPR152',
#  'GRK2',
#  'GSTP1',
#  'KDM2A',
#  'NDUFV1',
#  'NUDT8',
#  'PITPNM1',
#  'PPP1CA',
#  'PTPRCAP',
#  'RAD9A',
#  'RPS6KB2',
#  'SSH3',
#  'TBC1D10C',
#  'TBX10',
#  'TMEM134',
#  'GBAT2',
#  'PI4KB',
#  'PSMB4',
#  'PSMD4',
#  'RFX5',
#  'SELENBP1',
#  'ZNF687',
#  'ZNF687-AS1',
#  'VIPR2',
#  'BCAT1',
#  'BAZ1A',
#  'BRMS1L',
#  'CFL2',
#  'EAPP',
#  'INSM2',
#  'MBIP',
#  'NFKBIA',
#  'NKX2-1',
#  'NKX2-1-AS1',
#  'PPP2R3C',
#  'PRORP',
#  'PSMA6',
#  'PTCSC3',
#  'RALGAPA1',
#  'SFTA3',
#  'SNORA101B',
#  'SNX6',
#  'SPTSSA',
#  'MTDH',
#  'EXT1',
#  'FABP5',
#  'PAG1',
#  'PMP2',
#  'SNORD168',
#  'DUPD1',
#  'KAT6B',
#  'SNORD172',
#  'BIRC2',
#  'BIRC3',
#  'CFAP300',
#  'DCUN1D5',
#  'DYNC2H1',
#  'FGFR3',
#  'MMP7',
#  'TMEM123',
#  'YAP1',
#  'C19orf12',
#  'CCNE1',
#  'URI1',
#  'BRD9',
#  'CEP72',
#  'CLPTM1L',
#  'CTD-2194D22.4',
#  'CTD-3080P12.3',
#  'IRX4',
#  'MRPL36',
#  'NDUFS6',
#  'NKD2',
#  'SDHAP3',
#  'SLC12A7',
#  'SLC6A18',
#  'SLC6A19',
#  'TERT',
#  'TRIP13',
#  'ZDHHC11',
#  'OXR1',
#  'ATP5F1E',
#  'CTSZ',
#  'EDN3',
#  'GNAS',
#  'GNAS-AS1',
#  'NELFCD',
#  'PRELID3B',
#  'SLMO2-ATP5E',
#  'TUBB1',
#  'ZNF831',
#  'CTPS1',
#  'SLFNL1-AS1',
#  'EGFR',
#  'EGFR-AS1',
#  'SEC61G',
#  'VSTM2A',
#  'VSTM2A-OT1',
#  'POM121L12',
#  'C11orf80',
#  'SPTBN2',
#  'AAMDC',
#  'ACER3',
#  'ALG8',
#  'AQP11',
#  'CLNS1A',
#  'GUCY2EP',
#  'INTS4',
#  'KCTD14',
#  'KCTD21-AS1',
#  'NDUFC2',
#  'NDUFC2-KCTD14',
#  'PAK1',
#  'RSF1',
#  'THRSP',
#  'TSKU',
#  'CASC3',
#  'MSL1',
#  'NR1D1',
#  'DDX11',
#  'DDX11-AS1',
#  'OVOS2',
#  'AKIRIN1',
#  'C1orf109',
#  'CDCA8',
#  'KCNQ4',
#  'MYCBP',
#  'NDUFS5',
#  'RHBDL2',
#  'RRAGC',
#  'CHIC2',
#  'GSX2',
#  'PDGFRA',
#  'RPL21P44',
#  'CDC6']

# %%
aa_gene_dict["CASC11"]
# Out:
# [26,
#  {'AU565_BREAST',
#   'CORL23_LUNG',
#   'CORL279_LUNG',
#   'CORL311_LUNG',
#   'DMS273_LUNG',
#   'EFM192A_BREAST',
#   'FUOV1_OVARY',
#   'GCIY_STOMACH',
#   'HCC1419_BREAST',
#   'HCC44_LUNG',
#   'HGC27_STOMACH',
#   'KYSE450_OESOPHAGUS',
#   'MSTO211H_PLEURA',
#   'NCIH1792_LUNG',
#   'NCIH2122_LUNG',
#   'NCIH2170_LUNG',
#   'NCIH2171_LUNG',
#   'NCIH23_LUNG',
#   'NCIH446_LUNG',
#   'NCIH460_LUNG',
#   'NCIH510_LUNG',
#   'NCIH524_LUNG',
#   'NCIH82_LUNG',
#   'SCLC21H_LUNG',
#   'SNU16_STOMACH',
#   'SW480_LARGE_INTESTINE'}]

# %%
aa_gene_dict["CDC6"]
# Out:
# [3, {'NCIH2170_LUNG', 'UACC812_BREAST', 'UACC893_BREAST'}]

# %% [markdown]
# ### With Literature Gene List:

# %% [markdown]
# ##### Top 20 Most Frequent Oncogenes in ecDNA:

# %%
aa_oncogene_list = list(aa_oncogene_dict.keys())[0:20]
aa_oncogene_list
# Out:
# ['MYC',
#  'PVT1',
#  'ERBB2',
#  'CCND1',
#  'FGF3',
#  'FGF4',
#  'CTTN',
#  'CDK12',
#  'BRF2',
#  'ZNF703',
#  'DDHD2',
#  'FGFR1',
#  'LSM1',
#  'KRAS',
#  'TRIB1',
#  'ZNF217',
#  'CSF3',
#  'THRA',
#  'BMP7',
#  'CYP24A1']

# %%
aa_oncogene_dict["MYC"]
# Out:
# [26,
#  {'AU565_BREAST',
#   'CORL23_LUNG',
#   'CORL279_LUNG',
#   'CORL311_LUNG',
#   'DMS273_LUNG',
#   'EFM192A_BREAST',
#   'FUOV1_OVARY',
#   'GCIY_STOMACH',
#   'HCC1419_BREAST',
#   'HCC44_LUNG',
#   'HGC27_STOMACH',
#   'KYSE450_OESOPHAGUS',
#   'MSTO211H_PLEURA',
#   'NCIH1792_LUNG',
#   'NCIH2122_LUNG',
#   'NCIH2170_LUNG',
#   'NCIH2171_LUNG',
#   'NCIH23_LUNG',
#   'NCIH446_LUNG',
#   'NCIH460_LUNG',
#   'NCIH510_LUNG',
#   'NCIH524_LUNG',
#   'NCIH82_LUNG',
#   'SCLC21H_LUNG',
#   'SNU16_STOMACH',
#   'SW480_LARGE_INTESTINE'}]

# %%
aa_oncogene_dict["ERBB2"]
# Out:
# [13,
#  {'BT474_BREAST',
#   'EFM192A_BREAST',
#   'HCC1419_BREAST',
#   'HCC1569_BREAST',
#   'HCC202_BREAST',
#   'KYSE410_OESOPHAGUS',
#   'MFE280_ENDOMETRIUM',
#   'MKN7_STOMACH',
#   'NCIH2170_LUNG',
#   'OE19_OESOPHAGUS',
#   'SKOV3_OVARY',
#   'UACC812_BREAST',
#   'UACC893_BREAST'}]

# %%
aa_oncogene_dict["BMP7"]
# Out:
# [3, {'BT474_BREAST', 'MCF7_BREAST', 'UACC893_BREAST'}]

# %% [markdown]
# # Calculating Essentiality Across Cell-Lines:

# %% [markdown]
# ##### The following gene categories are based on the median values across cell-lines as follows:
# - <u>Non-essential</u> (greater than 0): genes where the knockout <b>does NOT affect</b> the cancer cell-line's <b>survival</b>
# - <u>Selectively-essential</u> (between -1 and 0): genes where the knockout <b>affects the survival of most</b> cancer cell-lines
# - <u>Common-essential</u> (less than -1): genes where the knockout <b>affects the survival of almost all</b> cancer cell-lines

# %% [markdown]
# ### With Literature Gene List:

# %% [markdown]
# ##### The following is sorted by median value (most essential):

# %%
literature_avg_esen = avg_esen(literature_gene_list, esen_df)
literature_avg_esen.sort_values(by="Median")
# Out:
#        Gene      Mean    Median  Standard Deviation          Category
# 559  SNRPA1 -2.848278 -2.863018            0.418750  Common-essential
# 50     PLK1 -2.656581 -2.672847            0.472205  Common-essential
# 463  SNRPD1 -2.591417 -2.626916            0.430849  Common-essential
# 159    RPL3 -2.520890 -2.513504            0.336514  Common-essential
# 339    EEF2 -2.326072 -2.424840            0.511596  Common-essential
# ..      ...       ...       ...                 ...               ...
# 58   ERICH1  0.210255  0.209041            0.103781     Non-essential
# 176    BIN3  0.219264  0.219210            0.111792     Non-essential
# 15    HOXA4  0.238866  0.246487            0.122658     Non-essential
# 366    TLR3  0.249413  0.248230            0.096221     Non-essential
# 319  TUBA4B  0.335575  0.339692            0.202309     Non-essential
#
# [560 rows x 5 columns]

# %% [markdown]
# ### With Amplicon Architect Most Frequent Genes List:

# %% [markdown]
# ##### The following is sorted by median value (most essential):

# %%
aa_avg_esen = avg_esen(aa_gene_list, esen_df)
aa_avg_esen.sort_values(by="Median")
# Out:
#           Gene      Mean    Median  Standard Deviation          Category
# 246      PSMA6 -2.799824 -2.822722            0.412962  Common-essential
# 186      PSMB3 -2.690280 -2.698995            0.391548  Common-essential
# 187      RPL23 -2.657507 -2.680870            0.401600  Common-essential
# 229      PSMB4 -2.249115 -2.241404            0.358707  Common-essential
# 83       RPL19 -2.261818 -2.238109            0.338898  Common-essential
# ..         ...       ...       ...                 ...               ...
# 283       EDN3  0.196774  0.195733            0.113218     Non-essential
# 199   SERPINH1  0.203149  0.196871            0.093530     Non-essential
# 189     ADAM18  0.210093  0.214992            0.136893     Non-essential
# 269    CLPTM1L  0.233281  0.232301            0.107643     Non-essential
# 51   RAB11FIP1  0.272094  0.273495            0.108012     Non-essential
#
# [324 rows x 5 columns]

# %% [markdown]
# # Splitting AA Cell-Lines (ecDNA +/-)

# %%
ec_aa_plus_genes = set()
all_aa_genes = set()

for index, row in aa_df.iterrows():
    achilles_id = ccle_to_achilles(meta_df, "CCLEName")[row["Sample name"]]
    all_aa_genes.add(achilles_id)
    if index == "ecDNA":
        ec_aa_plus_genes.add(achilles_id)

print("Number of ecDNA+ cell-lines in AA data:", len(ec_aa_plus_genes))
print("Total number of cell-lines in AA data:", len(all_aa_genes))
# Out:
# Number of ecDNA+ cell-lines in AA data: 166
# Total number of cell-lines in AA data: 329

# %% [markdown]
# # Generating Plots and Statistics:

# %% [markdown]
# ## Individual Gene Plots:

# %% [markdown]
# ### AA Gene List:

# %%
aa_genes_plot_df = plot_genes(aa_gene_list, esen_df, ec_aa_plus_genes, "aa")
# Out:
# Number of ecDNA+ cell lines: 121
# Number of ecDNA- cell lines: 1029

# %%
aa_genes_plot_df[aa_genes_plot_df['p-value'] < 0.05].sort_values(by="p-value")
# Out:
#           Gene   u-stat   p-value
# 246      PSMA6  47493.0  0.000019
# 309       MSL1  75337.0  0.000153
# 264   C19orf12  75066.0  0.000210
# 248       SNX6  73958.0  0.000708
# 37      MRGPRF  51623.0  0.002096
# 313   C1orf109  72806.0  0.002265
# 249     SPTSSA  72456.0  0.003159
# 17     PPP1R1B  52116.0  0.003350
# 231       RFX5  52167.0  0.003513
# 233     ZNF687  52504.0  0.004782
# 229      PSMB4  52691.0  0.005653
# 266       URI1  52733.0  0.005868
# 153       MTBP  52743.0  0.005920
# 138     SLC6A3  71549.0  0.007158
# 136     PPP6R3  53033.0  0.007624
# 181      HOXB9  53039.0  0.007664
# 184      PCGF2  71468.0  0.007677
# 76      ZNF704  53325.0  0.009772
# 323       CDC6  53345.0  0.009938
# 317     NDUFS5  53740.0  0.013751
# 71      NDUFB9  53776.0  0.014156
# 232   SELENBP1  53877.0  0.015349
# 45       ADRB3  53881.0  0.015398
# 303     NDUFC2  54137.0  0.018833
# 157  TNFRSF11B  70356.0  0.019069
# 283       EDN3  70301.0  0.019898
# 63        LSM1  54448.0  0.023895
# 314      CDCA8  54535.0  0.025507
# 286   PRELID3B  54577.0  0.026318
# 214       GRK2  54644.0  0.027658
# 22      MFSD2A  54674.0  0.028277
# 8        TRIT1  54779.0  0.030538
# 154        NBN  54817.0  0.031394
# 315      KCNQ4  54953.0  0.034628
# 168      MOCS3  69498.0  0.036091
# 36      MRGPRD  55096.0  0.038330
# 33       ZPBP2  55173.0  0.040460
# 119    ATP5MC1  69325.0  0.040772
# 6        MIEN1  55272.0  0.043344
# 57      ERLIN2  55323.0  0.044897
# 294   C11orf80  55423.0  0.048078
# 239       EAPP  69050.0  0.049268

# %% [markdown]
# ### Literature Gene List:

# %%
literature_genes_plot_df = plot_genes(literature_gene_list, esen_df, ec_aa_plus_genes, "literature")
# Out:
# Number of ecDNA+ cell lines: 121
# Number of ecDNA- cell lines: 1029

# %%
literature_genes_plot_df[literature_genes_plot_df['p-value'] < 0.05].sort_values(by="p-value")
# Out:
#           Gene   u-stat   p-value
# 504       CIB1  75578.0  0.000116
# 457       MSL1  75337.0  0.000153
# 6         XPO7  50476.0  0.000654
# 404    RACGAP1  50527.0  0.000690
# 71        MDM2  73595.0  0.001033
# ..         ...      ...       ...
# 400      PTCD2  55379.0  0.046655
# 277      DIDO1  55379.0  0.046655
# 492     SCNN1A  69108.0  0.047362
# 453  TNFRSF10B  55406.0  0.047524
# 550     METTL5  55460.0  0.049301
#
# [88 rows x 3 columns]

# %% [markdown]
# ## Individual Cell-Line Plots:

# %% [markdown]
# ### AA Gene List:

# %% [markdown]
# ### Literature Gene List:

# %% [markdown]
# ## Grouped Cell-Line Plots:

# %% [markdown]
# ### AA Gene List:

# %% [markdown]
# ### Literature Gene List:
